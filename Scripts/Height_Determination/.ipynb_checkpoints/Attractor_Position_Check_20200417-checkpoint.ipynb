# %%
# import stuff
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os

import cv2

import scipy
from scipy import signal
import h5py, time
from iminuit import Minuit, describe
from pprint import pprint # we use this to pretty print some stuff later
import glob
import pandas as pd
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile
from discharge_tools import *
from AnaUtil import *
from bisect import bisect_left
from tqdm import tqdm

from joblib import Parallel, delayed
import multiprocessing
import datetime as dt
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
def load_img_files(path):
    # read in the data 
    files = glob.glob(path)
    files.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))    
    img_files = []
    for i in range(0,len(files)):
        img_files.append(cv2.imread(files[i],0))
        print(files[i]) 
    return img_files

def laplacian(img):
    lap = np.sum(cv2.Laplacian(img,cv2.CV_64F)*cv2.Laplacian(img,cv2.CV_64F))
    return lap

def maxi(img):
    return np.argmax(np.mean(img,axis=1))

# %%
images =load_img_files('/data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/*')
images_after =load_img_files('/data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/*')
# Out:
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/1.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/2.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/3.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/4.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/5.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/6.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/7.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/8.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/9.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/10.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/11.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/12.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/13.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/14.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/15.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/16.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/17.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/18.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/19.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/20.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/21.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/22.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/23.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/24.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/25.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/26.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/27.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/28.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/29.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/30.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/31.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/32.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/33.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/34.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/35.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/36.bmp
# /data/new_trap/ImageAnalysis/20200225/Image_Campaign_Attr_20200225/37.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/1.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/2.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/3.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/4.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/5.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/6.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/7.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/8.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/9.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/10.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/11.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/12.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/13.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/14.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/15.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/16.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/17.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/18.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/19.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/20.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/21.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/22.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/23.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/24.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/25.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/26.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/27.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/28.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/29.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/30.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/31.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/32.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/33.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/34.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/35.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/36.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/37.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/38.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/39.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/40.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/41.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/42.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/43.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/44.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/45.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/46.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/47.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/48.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/49.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/50.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/51.bmp
# /data/new_trap/ImageAnalysis/20200302/Image_Attractor_Campagin_20200302/52.bmp

# %%
max_list = []
[max_list.append(maxi(img)) for img in images]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
plt.plot(max_list, marker = "*",linestyle="")
#plt.xlim(48.5,52)

# %%
def gaussian(x,params=list):
        norm = (1/((1/2*params[2])*np.sqrt(np.pi * 2)))
        return params[0] * norm * np.exp(-(np.subtract(x,params[1])**2/(2*params[2]**2)))+np.multiply(params[3],x)+params[4]

# %%
#np.piecewise(x,[x>np.argmax(data_y),x<=np.argmax(data_y)],[constant1,constant2])

# %%
def gaussian_attr_pos_fit(img,axis=0,low_x_lim=100,up_x_lim=1100,low_y_lim=400,up_y_lim=500,upper_area=300,up_lim_width=15):

    def chisquare_1d(function, functionparams, data_x, data_y,data_y_error):
        chisquarevalue=np.sum(np.power(np.divide(np.subtract(function(data_x,functionparams),data_y),data_y_error),2))
        ndf = len(data_y)-len(functionparams)
        #print(ndf)
        return (chisquarevalue, ndf)


    
    def chisquare_gaussian(area,mean,sigma,constant1,constant2):
        return chisquare_1d(function=gaussian,functionparams=[area,mean,sigma,constant1,constant2],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]
   

    area=0
    mean=0
    sigma=0
    constant1=0
    constant2=0
    low_fitrange=50
    up_fitrange=10

    if(axis==0):
        img2 = img.transpose()
        data_y_input = np.mean(img2[low_x_lim:up_x_lim],axis=0) # give y data 
        data_x = np.arange(np.argmax(data_y_input)-low_fitrange,np.argmax(data_y_input)+up_fitrange,1)#range(1024) # give x data
        data_y = np.mean(img2[low_x_lim:up_x_lim],axis=0)[np.argmax(data_y_input)-low_fitrange:np.argmax(data_y_input)+up_fitrange] # give y data 
        data_y_error = np.sqrt(data_y) # give y uncertainty
        low_lim_mean = low_y_lim
        up_lim_mean = up_y_lim
        
    if(axis==1):
        data_x = range(1280) # give x data
        data_y = np.mean(img[low_y_lim:up_y_lim],axis=0) # give y data 
        data_y_error = np.sqrt(data_y) # give y uncertainty
        low_lim_mean = low_x_lim
        up_lim_mean = up_x_lim
        
        
    m=Minuit(chisquare_gaussian, 
             area = 100, # set start parameter
             error_area = 1,
             limit_area= (0,upper_area), # if you want to limit things
             #fix_area = "True", # you can also fix it
             mean = np.argmax(np.mean(img2[low_x_lim:up_x_lim],axis=0)),
             error_mean = 1,
             #fix_mean = "False",
             #limit_mean = (450,490),
             sigma = 4.5,
             error_sigma = 1,
             limit_sigma=(0,up_lim_width),
             constant1 = 0,
             fix_constant1=True,
             error_constant1 = 1,
             constant2 = 55,
             error_constant2 = 1,
             fix_constant2=False,
             errordef = 1,
             print_level=0)
    #print('Now proceed with the fit.')
    m.migrad(ncall=500000)
    #m.minos(), if you need fancy mapping
    chisquare=m.fval
    return m.values['mean'],m

# %%
data_x = np.arange(430,495,1)#range(1024) # give x data
data_y = np.mean(images[0].transpose()[500:600],axis=0)[430:495] # give y data 
plt.plot(data_x,data_y)

# %%
np.argmax(np.mean(images[16].transpose()[100:1100],axis=0))
# Out:
# 488

# %%
mlist = []
for i in range(len(images)):
    m1 = gaussian_attr_pos_fit(img=images[i])
    mlist.append(m1[0])

# %%
index = 31
m1 = gaussian_attr_pos_fit(img=images[index])
print(m1[1].values["sigma"],2*np.sqrt(2*np.log(2))*m1[1].values["sigma"])
plt.plot(np.mean(images[index],axis=1))
plt.plot(gaussian(range(1024),params=[m1[1].values["area"],m1[1].values["mean"],m1[1].values["sigma"],m1[1].values["constant1"],m1[1].values["constant2"]]))
plt.xlabel("Pixel")
plt.ylabel("Intensity [a.u]")
plt.savefig("full_attractor_marginialization_y_20200226.png",dpi=300,bbox_inches="tight")
plt.show()
#plt.xlim(400,600)
#plt.ylim(0,150)
# Out:
# 3.724462716788253 8.770439462463406

# %%
plt.plot(np.mean(images[30],axis=1))
plt.plot(np.mean(images[20],axis=1))
plt.xlim(450,500)
# Out:
# (450, 500)

# %%
index = 11
m1 = gaussian_attr_pos_fit(img=images[index])
print(m1[1].values["sigma"],2*np.sqrt(2*np.log(2))*m1[1].values["sigma"])
plt.plot(np.mean(images[index],axis=1))
plt.plot(gaussian(range(1024),params=[m1[1].values["area"],m1[1].values["mean"],m1[1].values["sigma"],m1[1].values["constant1"],m1[1].values["constant2"]]))
plt.xlabel("Pixel")
plt.ylabel("Intensity [a.u]")
plt.xlim(450,550)
#plt.savefig("full_attractor_marginialization_y_zoomed_20200226.png",dpi=300,bbox_inches="tight")
plt.show()
#plt.xlim(400,600)
#plt.ylim(0,150)
# Out:
# 3.655334942064574 8.607655992875703

# %%
#z1 = [46]*20
z2= np.arange(43.0,45.5,0.5)
z3 = np.arange(45.2,46.2,0.2)
z4 = np.arange(46.5,51.5,0.5)
z5=np.arange(52,61,1)
z6 = [50]*3
z=list(z2)+list(z3)+list(z4)+list(z5)+list(z6)

# %%
plt.plot(z,1024*0.46-np.multiply(0.46,mlist[20:]), linestyle="",marker="$x$",markersize=15)
#plt.grid()
#for i in np.arange(474.85,492.85,1):
#    plt.axhline(i,color="red",alpha=0.5)
#plt.xlim(0,37)
#plt.axvline(50)
plt.xlabel("Z position as from attractor [um]")
plt.ylabel("Pixel height from fit")
#plt.savefig("Results/Height_Measurement_comparison_20200226.png",dpi=300,bbox_inches="tight")
plt.show()
#plt.xlim(0,19)
#plt.ylim(486,488)

# %%
z= np.arange(387,397,0.5)
plt.plot(z,mlist[0:20], linestyle="",marker="$x$",markersize=15)
#plt.grid()
#plt.xlim(19.5,37)
plt.xlabel("X position as from attractor [um]")
plt.ylabel("Pixel height from fit")
#plt.savefig("Results/Height_Measurement_as_function_of_distance_20200226.png",dpi=300,bbox_inches="tight")
plt.show()
#plt.xlim(0,19)
#plt.ylim(486,488)

# %%
# Out:
# array([43. , 43.5, 44. , 44.5, 45. , 45.5, 46. ])
