# %%
print("Nadav does not know anything about basketball")
# Out:
# Nadav does not know anything about basketball

# %%
print("blabla")
# Out:
# blabla

# %%
import numpy as np
import matplotlib
from matplotlib import mlab
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
A = 100.
f = 10
t = np.arange(0,1,1/10000.)
data = A*np.sin(2*np.pi*t*f)
data3 = np.zeros(len(t))+5
data0 = np.zeros(3000)-25
data2 = (data<0)*25

# %%
data2 = np.concatenate((data0,data2,data0))
data3 = np.concatenate((data0,data3,data0))

# %%
_,ax = plt.subplots()
ax.plot(range(len(data2)),data2)
ax.plot(range(len(data3)),data3)
t.shape
# Out:
# <img src="data:image/png;base64,..." width="640">
# (10000,)

# %%
res = len(t)
ypsd, freqs = mlab.psd(data, Fs = len(t), NFFT = res, window = matplotlib.mlab.window_none)

# %%
fft = np.abs(np.fft.rfft(data3))
fft2 = np.abs(np.fft.rfft(data2))
freq = np.fft.rfftfreq(len(data3), d=1)
freq2 = np.fft.rfftfreq(len(data), d=1)

# %%
freq[1:11]-freq[:10]
# Out:
# array([6.25e-05, 6.25e-05, 6.25e-05, 6.25e-05, 6.25e-05, 6.25e-05,
#        6.25e-05, 6.25e-05, 6.25e-05, 6.25e-05])

# %%
_,ax = plt.subplots()
# ax.semilogy(range(len(fft)),fft)
ax.semilogy(range(len(fft2)),fft2)
ax.set(xlim=(0,1000))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(0, 1000)]

# %%
G=6.67e-11 ## m3 kg-1 s-2
m=130e-15 ##130 pico gram in kg
r=1e-6 ## 10um
M=2.23e-3*1e-8 #1e-5
Force = G*M*m/r**2
print(Force)
# Out:
# 1.9336330000000003e-22

# %% [markdown]
# ### Ringdown

# %%
A = 100.
f = 100
f1 = 150
t = np.arange(0,10,0.0002)
samples = 10/0.0002
# ff = np.arange(f,f1,(f1-f)/samples)
ff = np.logspace(np.log(f),np.log(f1),num=50000, base=np.exp(1))
# ff = f1
data = A*np.sin(2*np.pi*t*ff)

# %%
ypsd, freqs = mlab.psd(data, Fs = 5000, NFFT=50000)
x = data
fft2 = np.abs(np.fft.rfft(x))**2
freq2 = np.fft.rfftfreq(len(x), d=1./5000)

# %%
_,ax = plt.subplots()
ax.semilogy(freqs, ypsd/ypsd[freqs==1000])
ax.semilogy(freq2, fft2/fft2[freq2==1000])
# ax.set(xlim=(f-10,f1+10),ylim=(1e-4,None))
# Out:
# <img src="data:image/png;base64,..." width="640">
