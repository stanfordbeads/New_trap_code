# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal

import h5py

# %%
# %matplotlib notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../nadavp/new_trap/PythonScripts/')
import BeadDataFile
from discharge_tools import *

# %% [markdown]
# ## Load data

# %%
fname = r'/data/new_trap/20190704/BeamProfile/test4_0.h5'
bd = BeadDataFile.BeadDataFile(fname)

# %%
bd.cant_pos[0]*500/9.9, bd.quad_sum.shape
# Out:
# (array([-53.95274511,   6.8855308 ,  57.3351745 , ...,   2.93502926,
#           3.18888206,   2.98868616]), (5000,))

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].plot(range(5000), bd.cant_pos[1]*500/9.9)
ax[0].plot(range(5000), bd.quad_sum/np.max(bd.quad_sum)*250+100)
ax[1].plot(bd.cant_pos[1]*500/9.9, bd.quad_sum/np.max(bd.quad_sum)*250+100)
# Out:
# <img src="data:image/png;base64,..." width="950">

# %% [markdown]
# ## Test after change to X scan

# %%
fname = r'/home/data_transfer/data_from_windows/Testdata/20190703/test10_0.h5'
fname1 = r'/home/data_transfer/data_from_windows/Testdata/20190703/test10_1.h5'
fname = r'/data/new_trap/20190704/BeamProfile/test3_0.h5'
fname1 = r'/data/new_trap/20190704/BeamProfile/test3_1.h5'
bd = BeadDataFile.BeadDataFile(fname)
bd1 = BeadDataFile.BeadDataFile(fname1)

# %%
_,ax = plt.subplots()
ax.plot(range(5000), bd.quad_sum)
ax.plot(range(5000), bd1.quad_sum)
# Out:
# <img src="data:image/png;base64,..." width="640">
