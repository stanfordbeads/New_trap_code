# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal

import h5py

# %%
# %matplotlib notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../../nadavp/new_trap/PythonScripts/')
import BeadDataFile
from discharge_tools import *

# %% [markdown]
# ## Test sychronization

# %%
fname = r'/home/data_transfer/data_from_windows/Testdata/syncQPD/Discharge_6.h5'
bdf = BeadDataFile.BeadDataFile(fname)

# %%
f = h5py.File(fname,'r')
spin_data = np.array(f['spin_data'])

# %%
bdf.x2.shape, spin_data
# Out:
# ((50000,), array([], dtype=float64))

# %%
xpos = bdf.cant_pos[0]
xpos -= np.min(xpos)
xpos /= np.max(xpos)

qpdsum = np.sum(bdf.amp[:4], axis=0)
qpdsum -= np.min(qpdsum)
qpdsum = qpdsum/np.max(qpdsum)

# %%
bdf.cant_pos.shape
# Out:
# (3, 10000)

# %%
_,ax = plt.subplots()
# ax.plot(np.arange(0,2,1/5000.), xpos)
# ax.plot(np.arange(0,2,1/5000.), qpdsum)
ax.plot(np.arange(0,2,1/5000.), spin_data.flatten())
# Out:
# <img src="data:image/png;base64,..." width="640">
