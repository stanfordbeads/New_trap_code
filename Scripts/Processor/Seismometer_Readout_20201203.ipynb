# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
a = BDF.BeadDataFile("/data/new_trap/20201203/Bead2/Discharge/Discharge_27.h5")
a2 = BDF.BeadDataFile("/data/new_trap/20201203/Bead2/Discharge/SeismometerTest/Discharge_4215.h5")

# %%
plt.plot(a.seismometer)
plt.plot(a2.seismometer)

# %%
plt.plot(np.abs(np.fft.fft(a2.seismometer[0:25000])))
plt.plot(np.abs(np.fft.fft(a2.seismometer[25000:-1])))
plt.yscale("log")
plt.xlim(0,10000)
# Out:
# (0.0, 10000.0)
