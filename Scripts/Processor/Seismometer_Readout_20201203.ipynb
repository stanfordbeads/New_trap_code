# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
a = BDF.BeadDataFile("/home/data_transfer/data_from_windows/20210304/Discharge_0.h5")
a = BDF.BeadDataFile("/home/data_transfer/data_from_windows/20210304/Discharge_5.h5")


fft1= np.fft.rfft(a.seismometer)
fft2 =np.fft.rfft(a2.seismometer)

# %%
x = np.arange(0,2500.1,0.1)

# %%
plt.plot(a.seismometer)
plt.plot(a2.seismometer)

# %%
plt.plot(x,np.abs(fft1))
plt.plot(x,np.abs(fft2))
plt.yscale("log")
plt.xlim(0,1500)
#plt.ylim(1e-1,1e2)
plt.show()

# %%
plt.plot(x,np.divide(np.abs(fft1),np.abs(fft2)))
plt.xlim(0,450)
# Out:
# (0.0, 450.0)
