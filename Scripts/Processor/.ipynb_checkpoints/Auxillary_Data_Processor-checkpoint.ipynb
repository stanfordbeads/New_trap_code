# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
pixel_size_cal = 0.503 # obtained from attractor calibration data February2020, but cross checked during Wilson itself

# %%
bead_date =20200614
bead_number = 1

# %%
# get the attractor 0 position
image_folder = "/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number + "HeightPictures/"
images = load_img_files(image_folder+"*")
# Out:
# /data/new_trap/20200614/Bead1/HeightPictures/shadow_when_approaching.bmp 0
# /data/new_trap/20200614/Bead1/HeightPictures/shield_bead.bmp 1
# /data/new_trap/20200614/Bead1/HeightPictures/bead_only_filter_and_handle_in.bmp 2
# /data/new_trap/20200614/Bead1/HeightPictures/image_during_long_z.bmp 3
# /data/new_trap/20200614/Bead1/HeightPictures/shield_bead_2.bmp 4
# /data/new_trap/20200614/Bead1/HeightPictures/4dB.bmp 5
# /data/new_trap/20200614/Bead1/HeightPictures/5dB.bmp 6
# /data/new_trap/20200614/Bead1/HeightPictures/6dB.bmp 7
# /data/new_trap/20200614/Bead1/HeightPictures/5.5dB.bmp 8
# /data/new_trap/20200614/Bead1/HeightPictures/shield_x_100mV.bmp 9
# /data/new_trap/20200614/Bead1/HeightPictures/shield_x_200mV.bmp 10
# /data/new_trap/20200614/Bead1/HeightPictures/shield_x_500mV.bmp 11
# /data/new_trap/20200614/Bead1/HeightPictures/shield_x_600mV.bmp 12
# /data/new_trap/20200614/Bead1/HeightPictures/6dB_500k.bmp 13
# /data/new_trap/20200614/Bead1/HeightPictures/shield_and_bead_next_to_each_other_150us_20db.bmp 14
# /data/new_trap/20200614/Bead1/HeightPictures/shield_next_to_sphere_right_before_reinsertion_154_20.bmp 15
# /data/new_trap/20200614/Bead1/HeightPictures/shield_and_bead_at_edge_20200618.bmp 16
# /data/new_trap/20200614/Bead1/HeightPictures/shield_and_bead_next_to_each_other_20200618.bmp 17
# /data/new_trap/20200614/Bead1/HeightPictures/attractor_390_500_39_filter_in_at_TF.bmp 18
# /data/new_trap/20200614/Bead1/HeightPictures/shield_in_600mV_x_3_2V_z_133_20.bmp 19
# /data/new_trap/20200614/Bead1/HeightPictures/attractor_390_500_39_shiny_bead_700k_at_tf.bmp 20
# /data/new_trap/20200614/Bead1/HeightPictures/height_check_20200614_2200.bmp 21
# /data/new_trap/20200614/Bead1/HeightPictures/height_check_20200615_0822.bmp 22
# /data/new_trap/20200614/Bead1/HeightPictures/height_check_20200615_1211.bmp 23
# /data/new_trap/20200614/Bead1/HeightPictures/height_check_202006151213.bmp 24
# /data/new_trap/20200614/Bead1/HeightPictures/height_check_20200615_1219.bmp 25
# /data/new_trap/20200614/Bead1/HeightPictures/height_check_20200615_1221.bmp 26
# /data/new_trap/20200614/Bead1/HeightPictures/height_check_20200615_1745.bmp 27
# /data/new_trap/20200614/Bead1/HeightPictures/390_484_42_44_20.bmp 28
# /data/new_trap/20200614/Bead1/HeightPictures/390_499_57_44_20.bmp 29
# /data/new_trap/20200614/Bead1/HeightPictures/385_484_42_154_20.bmp 30
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_71.npy 71
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_72.npy 72
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_73.npy 73
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_74.npy 74
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_75.npy 75
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_76.npy 76
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_77.npy 77
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_78.npy 78
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_79.npy 79
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_80.npy 80
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_81.npy 81
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_82.npy 82
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_83.npy 83
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_84.npy 84
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_85.npy 85
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_86.npy 86
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_87.npy 87
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_88.npy 88
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_89.npy 89
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_90.npy 90
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_91.npy 91
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_92.npy 92
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_93.npy 93
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_94.npy 94
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_95.npy 95
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_96.npy 96
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_97.npy 97
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_98.npy 98
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/ImageTest0_99.npy 99

# %%
ret, thresh = cv2.threshold(data[0],210,255,0)
plt.imshow(thresh)

# %%
for y in np.arange(150,250,5):
    height = [] # get the height using the shadow method
    width = []
    for i in tqdm(range(len(data))):
        mean, m = from_shadow_image_to_height(data[i],190,area_low_limits=[650,730],area_widths=[45,70],plot=False)
        #mean2,m2 = from_shadow_image_to_width(data[i],190,area_low_limits=[650,730],area_width=70,plot=False)
        height.append(pixel_to_height(mean,calibration=True,pix_size_from_calib=pixel_size_cal))
    #    width.append(mean2)
        print(np.mean(height),np.std(height))
        #plt.show()
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 46.56it/s]

# %%
np.std(height)
# Out:
# 0.18597583564805084

# %%
df = pd.DataFrame() # create the dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bff8125772a> in <module>
# ----> 1 df = pd.DataFrame() # create the dataframe
#
# NameError: name 'pd' is not defined

# %%
factor_std = 1.5 # pick the sigma away from the mean used for the correction of outlier
df["height_raw"] = height # just the fit result
df["y_pos_raw"] = width
df["mean_height"] = [x if np.abs(x-np.mean(height))<(factor_std*np.std(height)) else np.mean(height) for x in height] # bring outlier to the mean

# %%
plt.plot(np.arange(0,len(width)*10,10),width,linestyle="",marker="o")
plt.xlabel("Time [s]")
plt.ylabel("Y [a.u.]")
plt.ylim(np.mean(width)-1/10*np.mean(width),np.mean(width)+1/10*np.mean(width))
plt.show()
print(len([x for x in width if np.abs(x-np.mean(width))<(factor_std*np.std(width))]))
# Out:
# 855

# %%
plt.plot(np.arange(0,len(height)*10,10),height,linestyle="",marker="o")
plt.xlabel("Time [s]")
plt.ylabel("Height [um]")
plt.show()
print(np.mean(height),np.std(height))
print(np.mean([x for x in height if np.abs(x-np.mean(height))<(factor_std*np.std(height))]),np.std([x for x in height if np.abs(x-np.mean(height))<factor_std*np.std(height)]))
print(len([x for x in height if np.abs(x-np.mean(height))<(factor_std*np.std(height))]))
# Out:
# 279.30655930745786 0.29876713104188357
# 279.311320493452 0.2300870421732691
# 873

# %%
df['ewm_20'] = df.mean_height.ewm(span=20, adjust=True).mean() # do the exponential weighted mean over 20 files
df['ewm_100'] = df.mean_height.ewm(span=100, adjust=True).mean() # do the exponential weighted mean over 100 files
df['ewm_500'] = df.mean_height.ewm(span=500, adjust=True).mean() # do the exponential weighted mean over 500 files

# %%
df.mean_height.plot(marker="*",linestyle="")#), label = "height-filtered data")
df.ewm_20.plot()#, label = "20 datasets EWM")
df.ewm_100.plot()#, label = "100 datasets EWM")
plt.xlabel("Time [10s]")
plt.ylabel("Average Height [um]")
plt.legend()
plt.show()

# %%
# load the attractor mean position for the data file
data_filename = "/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
attr_pos = load_dir_reduced_to_attr_pos(dirname=data_filename,file_prefix=FOI,max_files=10000)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|          | 1/100 [00:06<10:37,  6.44s/it]
#   2%|▏         | 2/100 [00:12<10:32,  6.46s/it]
#   3%|▎         | 3/100 [00:19<10:27,  6.47s/it]
#   4%|▍         | 4/100 [00:27<10:57,  6.85s/it]
#   5%|▌         | 5/100 [00:34<11:16,  7.12s/it]
#   6%|▌         | 6/100 [00:42<11:19,  7.23s/it]
#   7%|▋         | 7/100 [00:48<10:50,  7.00s/it]
#   8%|▊         | 8/100 [00:55<10:33,  6.89s/it]
#   9%|▉         | 9/100 [01:02<10:18,  6.80s/it]
#  10%|█         | 10/100 [01:08<09:59,  6.66s/it]
# 100%|██████████| 100/100 [01:08<00:00,  1.46it/s]

# %%
# load the time frame from all the data sets in 100er chunks to not flood the memory (could be parallelized)
t = load_dir_reduced_to_time(dirname=data_filename,file_prefix=FOI,max_files=10000)
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 24.62it/s]

# %%
df["Time_Epoch"] = t # store the time
df["Attr_Pos_V"] = attr_pos # save raw position

del t # free some memory, otherwise bunnies die
del attr_pos # free more memory

# %%
# save three values
## height_cal is the position of the bead in Aerotech coordinates
## z_distance transforms the cant_pos[2] voltage directly into um (using the vanilla calibration)
## z_distance_emp uses Akio's empirical data
df["height_cal"] = df['ewm_100'].apply(lambda element: element-attractor_0)
df["z_distance"] = df['height_cal'] - voltage_to_z_position(df['Attr_Pos_V'])
df["z_distance_emp"] = df['height_cal'] - voltage_to_z_position(df['Attr_Pos_V'],redo=True)
# Out:
# ------------------------------------------------------------------
# | FCN = 2.381E-13               |      Ncalls=35 (35 total)      |
# | EDM = 2.38E-13 (Goal: 1E-05)  |            up = 1.0            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# 0.09904999993134567 -0.00499999621661118
# /home/analysis_user/New_trap_code/Tools/analysis_tools.py:97: InitialParamWarning: Parameter a is floating but does not have initial step size. Assume 1.
#   print_level=1)
# /home/analysis_user/New_trap_code/Tools/analysis_tools.py:97: InitialParamWarning: Parameter b is floating but does not have initial step size. Assume 1.
#   print_level=1)

# %%
df.z_distance.plot()
df.z_distance_emp.plot()
plt.legend()

# %%
# assume for same year and same month, it can have multiple days. get those
dt.datetime.fromtimestamp(df["Time_Epoch"][0])
year = dt.datetime.fromtimestamp(df["Time_Epoch"][0]).year
month = dt.datetime.fromtimestamp(df["Time_Epoch"][0]).month
#months = []
#months = set(months)
days = []
days = set(days)
for i in range(len(df)):
    days.add(dt.datetime.fromtimestamp(df["Time_Epoch"][i]).day)
    #months.add(dt.datetime.fromtimestamp(df["Time_Epoch"][i]).month)
print(days)
# Out:
# {22}

# %%
# prepare the files to match the time stamp to extract the environmental data
fn = []
for day in days:
    env_file = "/data/new_trap_processed/processed_files/{0}/Bead{1}/EnvData/{2}{3}{4}/environmental_data_{2}{3}{4}.pkl".format(bead_date,bead_number,year,str(month).zfill(2),str(day).zfill(2))
    fn.append(env_file)
print(fn)
# Out:
# ['/data/new_trap_processed/processed_files/20200518/Bead2/EnvData/20200522/environmental_data_20200522.pkl']

# %%
df_new = match_environmental_data(df,fn) # match the environmental data
# Out:
# 100%|██████████| 1000/1000 [00:04<00:00, 207.75it/s]

# %%
plt.plot(df_new.AirTemperature/df_new.AirTemperature.mean())
plt.plot(df_new.height_cal/df_new.height_cal.mean())
plt.plot(df_new.z_distance/df_new.z_distance.mean())
#plt.plot(df_new.z_distance_emp/df_new.z_distance_emp.mean())
#plt.xlim(0,1000)
plt.show()

# %%
df_new
# Out:
#      height_raw  y_pos_raw  mean_height      ewm_20     ewm_100     ewm_500  \
# 0    281.870631  33.535716   281.870631  281.870631  281.870631  281.870631
# 1    281.880750  32.907756   281.880750  281.875944  281.875741  281.875701
# 2    281.882115  33.048451   281.882115  281.878210  281.877908  281.877847
# 3    281.880790  33.129911   281.880790  281.878955  281.878651  281.878588
# 4    281.855391  33.462326   281.855391  281.873255  281.873811  281.873911
# ..          ...        ...          ...         ...         ...         ...
# 995  282.119467  32.925835   282.119467  281.951613  281.940130  281.955456
# 996  282.075738  33.628368   282.075738  281.963434  281.942815  281.955945
# 997  281.898266  33.068685   281.898266  281.957228  281.941933  281.955710
# 998  282.018636  33.293961   282.018636  281.963076  281.943452  281.955966
# 999  281.925808  32.925334   281.925808  281.959527  281.943102  281.955844
#
#        Time_Epoch  Attr_Pos_V  height_cal  z_distance  z_distance_emp  \
# 0    1.590193e+09    5.161603   41.322483  -10.293546      -10.839081
# 1    1.590193e+09    5.161622   41.327593  -10.288632      -10.834169
# 2    1.590193e+09    5.161615   41.329760  -10.286391      -10.831927
# 3    1.590193e+09    5.161614   41.330502  -10.285634      -10.831170
# 4    1.590193e+09    5.161601   41.325662  -10.290345      -10.835879
# ..            ...         ...         ...         ...             ...
# 995  1.590204e+09    5.161612   41.391981  -10.224136      -10.769672
# 996  1.590204e+09    5.161628   41.394666  -10.221611      -10.767148
# 997  1.590204e+09    5.161638   41.393784  -10.222600      -10.768138
# 998  1.590204e+09    5.161612   41.395303  -10.220819      -10.766355
# 999  1.590204e+09    5.161637   41.394954  -10.221419      -10.766957
#
#      AirTemperature  SurfaceTemperature     Pressure
# 0         23.230342           22.996509  1016.234653
# 1         23.212965           22.996415  1016.238376
# 2         23.197690           22.996409  1016.283125
# 3         23.185667           22.996262  1016.240443
# 4         23.172988           22.996168  1016.263179
# ..              ...                 ...          ...
# 995       23.341817           22.990232  1016.994668
# 996       23.335268           22.990284  1016.936073
# 997       23.327359           22.990426  1016.950141
# 998       23.319250           22.990589  1016.995524
# 999       23.317952           22.990248  1016.990501
#
# [1000 rows x 14 columns]

# %%
# save the file
base_proc = "/data/new_trap_processed/processed_files/" + str(bead_date) +  "/Bead%s/" %bead_number

try:
    os.makedirs(base_proc+dataset)
    print("Created subdirs %s" %dataset)
except:
    print("Folder exists or you do not have permissions")
    
outputname = base_proc + dataset+FOI+"_aux.pkl"
if(os.path.isfile(outputname)==False):
    df_new.to_pickle(outputname)
    print("Successfully saved auxiliary file")
else:print("No auxiliary file produced. %s exists already!" %outputname)
# Out:
# Folder exists or you do not have permissions
# Successfully saved auxiliary file

# %%
del data # free the data

# %%
del df

# %%
del df_new
