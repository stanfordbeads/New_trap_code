# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
dirname = "/data/new_trap/20201203/Bead2/Discharge/SeismometerTest/"
file_prefix="Discharge_"
max_files=10

# %%
a = BDF.BeadDataFile("/data/new_trap/20201203/Bead2/Discharge/SeismometerTest/Discharge_1.h5")
a2 = BDF.BeadDataFile("/data/new_trap/20201203/Bead2/Discharge/SeismometerTest/Discharge_2.h5")
# Out:
# Seismometer loaded
# Seismometer loaded

# %%
plt.plot(a.seismometer)
plt.plot(a2.seismometer)

# %%
plt.plot(np.abs(np.fft.rfft(a.seismometer)))
plt.plot(np.abs(np.fft.rfft(a2.seismometer)))
plt.yscale("log")
plt.xlim(0,5000)
# Out:
# (0.0, 5000.0)
