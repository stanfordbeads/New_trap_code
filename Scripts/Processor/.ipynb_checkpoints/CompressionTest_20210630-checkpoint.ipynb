# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# get a test file

fileIn = "Discharge_4.h5"

# %%
BDF= BeadDataFile.BeadDataFile(fileIn)

# %%
data=BDF.spin_data[0]
data_det = signal.detrend(data)
fsamp=len(data)/10
res = int(len(data)/100)
spinPSD, freqs = matplotlib.mlab.psd(data_det, Fs = fsamp, NFFT = res)

# %%
plt.loglog(freqs,spinPSD)

# %%
with h5py.File(fileIn, 'r') as f_in:
    spin_data_in = np.array(f_in['spin_data'])
    data_in = spin_data_in[0] 
    f_in.close()
#with h5py.File(fileIn, 'r+') as f_out:
#    del f_out['spin_data']
#    f_out.create_dataset("spin_data", data_in.shape,data=spinPSD)
#    f_out.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-7e7dbb70fdb0> in <module>
#       1 with h5py.File(fileIn, 'r') as f_in:
# ----> 2     spin_data_in = np.array(f_in['spin_data'])
#       3     data_in = spin_data_in[0]
#       4     f_in.close()
#       5 #with h5py.File(fileIn, 'r+') as f_out:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/.local/lib/python3.6/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     260                 raise ValueError("Invalid HDF5 object reference")
#     261         else:
# --> 262             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     263
#     264         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: "Unable to open object (object 'spin_data' doesn't exist)"
