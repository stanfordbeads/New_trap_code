# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24

plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
def wavemeter_processor(year,month,day,bead_date,bead_number):
    

    dirname="/data/SC_data/Wavemeter/Data/"
    df_wavemeter = pd.DataFrame()
    hour = 0
    minute = 0
    date = str(day).zfill(2)+"."+str(month).zfill(2)+"."+str(year)
    wavelength=[]
    time_stamp=[]
    
    basic_folder = "/data/new_trap_processed/processed_files/%s/Bead%s/EnvData/" %(bead_date,bead_number)
    output_folder =  basic_folder + "%s" %(str(year)+str(month)+str(day))
    try: os.makedirs(basic_folder)
    except: print("Did not create %s. It may exist or you do not have perimissions." %basic_folder)
    try: os.mkdir(output_folder)
    except: print("Did not create output folder:%s. It may exist or you do not have perimissions."% output_folder)
    
    for hour in tqdm(np.arange(0,24,1)):
        for minute in np.arange(0,60,1):
            try:
                file = "%s, %s.%s" %(date,str(hour).zfill(2),str(minute).zfill(2))
                filename= dirname + str([file_ for file_ in os.listdir(dirname) if file_.startswith(file) if file_.endswith('.lta')][0])
                with open(filename,"r") as fin:  
                        start_at = dropwhile(lambda L: 'Time' not in L.split(), fin)
                        for line in islice(start_at, 1, None): # ignore the line still with Abstract in
                            time_line = float(line.replace('\n',"").split("\t")[0])
                            #print(time_line)
                            seconds=(int(time_line/1000))
                            if(seconds<60):
                                #print(seconds)
                                microseconds=int(1000*time_line-seconds*1e6)
                                wavelength.append(float(line.replace('\n',"").split("\t")[1]))
                                time_stamp.append(dt.datetime(year,month,day,hour,minute,seconds,microseconds))
            except:print("%d%d does not exist or did not work"  %(hour,minute))               
    df_wavemeter["WAVE_LENGTH"] = wavelength
    df_wavemeter["LASER_FREQ"] = np.divide(np.divide(3e8,np.divide(wavelength,1e9)),1e12)

    df_wavemeter["TIMESTAMP_WM"] = time_stamp
    df_wavemeter["TIMESTAMP_WM_EPOCH"] = df_wavemeter["TIMESTAMP_WM"].apply(lambda element: dt.datetime.timestamp(element))
    
    processed_file_name = output_folder + "/wavemeter_data_%s%s%s.pkl" %(year,str(month).zfill(2),str(day).zfill(2)) # create the filename
    if(os.path.isfile(processed_file_name)==False):
    #df.to_csv(processed_file_name.replace(".pkl",".csv"),index=False) ## comment back in if you want a .csv for whatever reason
        df_wavemeter.to_pickle(processed_file_name) 
    else: print("Wave meter file %s exists already" %processed_file_name)  
    return df_wavemeter

# %%
year = 2020
month=10
day=1
bead_date=20200930
bead_number=1
df = wavemeter_processor(year,month,day,str(bead_date),bead_number)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# Did not create /data/new_trap_processed/processed_files/20200930/Bead1/EnvData/. It may exist or you do not have perimissions.
# Did not create output folder:/data/new_trap_processed/processed_files/20200930/Bead1/EnvData/01.10.2020. It may exist or you do not have perimissions.
# 011 does not exist or did not work
#  46%|████▌     | 11/24 [00:07<00:08,  1.52it/s]
# 1112 does not exist or did not work
# 1113 does not exist or did not work
# 1114 does not exist or did not work
# 1115 does not exist or did not work
# 1116 does not exist or did not work
# 1117 does not exist or did not work
# 1118 does not exist or did not work
# 1119 does not exist or did not work
# 1120 does not exist or did not work
# 1121 does not exist or did not work
# 1122 does not exist or did not work
# 1123 does not exist or did not work
# 1124 does not exist or did not work
# 1125 does not exist or did not work
# 1126 does not exist or did not work
# 1127 does not exist or did not work
# 1128 does not exist or did not work
# 1129 does not exist or did not work
# 1130 does not exist or did not work
# 1131 does not exist or did not work
# 1132 does not exist or did not work
# 1133 does not exist or did not work
# 1134 does not exist or did not work
# 1135 does not exist or did not work
# 1136 does not exist or did not work
# 1137 does not exist or did not work
# 1138 does not exist or did not work
# 1139 does not exist or did not work
# 1140 does not exist or did not work
# 1141 does not exist or did not work
# 1142 does not exist or did not work
# 1143 does not exist or did not work
# 1144 does not exist or did not work
# 1145 does not exist or did not work
# 1146 does not exist or did not work
# 1147 does not exist or did not work
# 1148 does not exist or did not work
# 1149 does not exist or did not work
# 1150 does not exist or did not work
# 1151 does not exist or did not work
# 1152 does not exist or did not work
#  50%|█████     | 12/24 [00:07<00:06,  1.75it/s]
# 1153 does not exist or did not work
# 1154 does not exist or did not work
# 1155 does not exist or did not work
# 1156 does not exist or did not work
# 1157 does not exist or did not work
# 1158 does not exist or did not work
# 1159 does not exist or did not work
# 120 does not exist or did not work
# 121 does not exist or did not work
# 122 does not exist or did not work
# 123 does not exist or did not work
# 124 does not exist or did not work
# 125 does not exist or did not work
# 126 does not exist or did not work
# 127 does not exist or did not work
# 128 does not exist or did not work
# 129 does not exist or did not work
# 1210 does not exist or did not work
# 1211 does not exist or did not work
# 1212 does not exist or did not work
# 1213 does not exist or did not work
# 1214 does not exist or did not work
# 1215 does not exist or did not work
# 1216 does not exist or did not work
# 1217 does not exist or did not work
# 1218 does not exist or did not work
# 1219 does not exist or did not work
# 1220 does not exist or did not work
# 1221 does not exist or did not work
# 1222 does not exist or did not work
# 1223 does not exist or did not work
# 1224 does not exist or did not work
# 1225 does not exist or did not work
# 1226 does not exist or did not work
# 1227 does not exist or did not work
# 1228 does not exist or did not work
# 1229 does not exist or did not work
# 1230 does not exist or did not work
# 1231 does not exist or did not work
# 1232 does not exist or did not work
# 1233 does not exist or did not work
#  54%|█████▍    | 13/24 [00:07<00:05,  2.04it/s]
# 1234 does not exist or did not work
# 1235 does not exist or did not work
# 1236 does not exist or did not work
# 1237 does not exist or did not work
# 1238 does not exist or did not work
# 1239 does not exist or did not work
# 1240 does not exist or did not work
# 1241 does not exist or did not work
# 1242 does not exist or did not work
# 1243 does not exist or did not work
# 1244 does not exist or did not work
# 1245 does not exist or did not work
# 1246 does not exist or did not work
# 1247 does not exist or did not work
# 1248 does not exist or did not work
# 1249 does not exist or did not work
# 1250 does not exist or did not work
# 1251 does not exist or did not work
# 1252 does not exist or did not work
# 1253 does not exist or did not work
# 1254 does not exist or did not work
# 1255 does not exist or did not work
# 1256 does not exist or did not work
# 1257 does not exist or did not work
# 1258 does not exist or did not work
# 1259 does not exist or did not work
# 130 does not exist or did not work
# 131 does not exist or did not work
# 132 does not exist or did not work
# 133 does not exist or did not work
# 134 does not exist or did not work
# 135 does not exist or did not work
# 136 does not exist or did not work
# 137 does not exist or did not work
# 138 does not exist or did not work
# 139 does not exist or did not work
# 1310 does not exist or did not work
# 1311 does not exist or did not work
# 1312 does not exist or did not work
# 1313 does not exist or did not work
# 1314 does not exist or did not work
# 1315 does not exist or did not work
# 1316 does not exist or did not work
# 1317 does not exist or did not work
# 1318 does not exist or did not work
# 1319 does not exist or did not work
# 1320 does not exist or did not work
# 1321 does not exist or did not work
# 1322 does not exist or did not work
# 1323 does not exist or did not work
# 1324 does not exist or did not work
# 1325 does not exist or did not work
# 1326 does not exist or did not work
# 1327 does not exist or did not work
# 1328 does not exist or did not work
# 1329 does not exist or did not work
# 1330 does not exist or did not work
# 1331 does not exist or did not work
# 1332 does not exist or did not work
# 1333 does not exist or did not work
# 1334 does not exist or did not work
# 1335 does not exist or did not work
# 1336 does not exist or did not work
# 1337 does not exist or did not work
# 1338 does not exist or did not work
# 1339 does not exist or did not work
# 1340 does not exist or did not work
# 1341 does not exist or did not work
# 1342 does not exist or did not work
# 1343 does not exist or did not work
# 1344 does not exist or did not work
# 1345 does not exist or did not work
# 1346 does not exist or did not work
# 1347 does not exist or did not work
# 1348 does not exist or did not work
# 1349 does not exist or did not work
# 1350 does not exist or did not work
# 1351 does not exist or did not work
# 1352 does not exist or did not work
# 1353 does not exist or did not work
# 1354 does not exist or did not work
#  58%|█████▊    | 14/24 [00:08<00:04,  2.31it/s]
# 1355 does not exist or did not work
# 1356 does not exist or did not work
# 1357 does not exist or did not work
# 1358 does not exist or did not work
# 1359 does not exist or did not work
# 140 does not exist or did not work
# 141 does not exist or did not work
# 142 does not exist or did not work
# 143 does not exist or did not work
# 144 does not exist or did not work
# 145 does not exist or did not work
# 146 does not exist or did not work
# 147 does not exist or did not work
# 148 does not exist or did not work
# 149 does not exist or did not work
# 1410 does not exist or did not work
# 1411 does not exist or did not work
# 1412 does not exist or did not work
# 1413 does not exist or did not work
# 1414 does not exist or did not work
# 1415 does not exist or did not work
# 1416 does not exist or did not work
# 1417 does not exist or did not work
# 1418 does not exist or did not work
# 1419 does not exist or did not work
# 1420 does not exist or did not work
# 1421 does not exist or did not work
# 1422 does not exist or did not work
# 1423 does not exist or did not work
# 1424 does not exist or did not work
# 1425 does not exist or did not work
# 1426 does not exist or did not work
# 1427 does not exist or did not work
# 1428 does not exist or did not work
# 1429 does not exist or did not work
# 1430 does not exist or did not work
# 1431 does not exist or did not work
# 1432 does not exist or did not work
# 1433 does not exist or did not work
# 1434 does not exist or did not work
# 1435 does not exist or did not work
#  62%|██████▎   | 15/24 [00:08<00:03,  2.55it/s]
# 1436 does not exist or did not work
# 1437 does not exist or did not work
# 1438 does not exist or did not work
# 1439 does not exist or did not work
# 1440 does not exist or did not work
# 1441 does not exist or did not work
# 1442 does not exist or did not work
# 1443 does not exist or did not work
# 1444 does not exist or did not work
# 1445 does not exist or did not work
# 1446 does not exist or did not work
# 1447 does not exist or did not work
# 1448 does not exist or did not work
# 1449 does not exist or did not work
# 1450 does not exist or did not work
# 1451 does not exist or did not work
# 1452 does not exist or did not work
# 1453 does not exist or did not work
# 1454 does not exist or did not work
# 1455 does not exist or did not work
# 1456 does not exist or did not work
# 1457 does not exist or did not work
# 1458 does not exist or did not work
# 1459 does not exist or did not work
# 150 does not exist or did not work
# 151 does not exist or did not work
# 152 does not exist or did not work
# 153 does not exist or did not work
# 154 does not exist or did not work
# 155 does not exist or did not work
# 156 does not exist or did not work
# 157 does not exist or did not work
# 158 does not exist or did not work
# 159 does not exist or did not work
# 1510 does not exist or did not work
# 1511 does not exist or did not work
# 1512 does not exist or did not work
# 1513 does not exist or did not work
# 1514 does not exist or did not work
# 1515 does not exist or did not work
# 1516 does not exist or did not work
# 1517 does not exist or did not work
# 1518 does not exist or did not work
# 1519 does not exist or did not work
# 1520 does not exist or did not work
# 1521 does not exist or did not work
# 1522 does not exist or did not work
# 1523 does not exist or did not work
# 1524 does not exist or did not work
# 1525 does not exist or did not work
# 1526 does not exist or did not work
# 1527 does not exist or did not work
# 1528 does not exist or did not work
# 1529 does not exist or did not work
# 1530 does not exist or did not work
# 1531 does not exist or did not work
# 1532 does not exist or did not work
# 1533 does not exist or did not work
# 1534 does not exist or did not work
# 1535 does not exist or did not work
# 1536 does not exist or did not work
# 1537 does not exist or did not work
# 1538 does not exist or did not work
# 1539 does not exist or did not work
# 1540 does not exist or did not work
# 1541 does not exist or did not work
# 1542 does not exist or did not work
# 1543 does not exist or did not work
# 1544 does not exist or did not work
# 1545 does not exist or did not work
# 1546 does not exist or did not work
# 1547 does not exist or did not work
# 1548 does not exist or did not work
# 1549 does not exist or did not work
# 1550 does not exist or did not work
# 1551 does not exist or did not work
# 1552 does not exist or did not work
# 1553 does not exist or did not work
# 1554 does not exist or did not work
# 1555 does not exist or did not work
# 1556 does not exist or did not work
#  67%|██████▋   | 16/24 [00:08<00:02,  2.73it/s]
# 1557 does not exist or did not work
# 1558 does not exist or did not work
# 1559 does not exist or did not work
# 160 does not exist or did not work
# 161 does not exist or did not work
# 162 does not exist or did not work
# 163 does not exist or did not work
# 164 does not exist or did not work
# 165 does not exist or did not work
# 166 does not exist or did not work
# 167 does not exist or did not work
# 168 does not exist or did not work
# 169 does not exist or did not work
# 1610 does not exist or did not work
# 1611 does not exist or did not work
# 1612 does not exist or did not work
# 1613 does not exist or did not work
# 1614 does not exist or did not work
# 1615 does not exist or did not work
# 1616 does not exist or did not work
# 1617 does not exist or did not work
# 1618 does not exist or did not work
# 1619 does not exist or did not work
# 1620 does not exist or did not work
# 1621 does not exist or did not work
# 1622 does not exist or did not work
# 1623 does not exist or did not work
# 1624 does not exist or did not work
# 1625 does not exist or did not work
# 1626 does not exist or did not work
# 1627 does not exist or did not work
# 1628 does not exist or did not work
# 1629 does not exist or did not work
# 1630 does not exist or did not work
# 1631 does not exist or did not work
# 1632 does not exist or did not work
# 1633 does not exist or did not work
# 1634 does not exist or did not work
# 1635 does not exist or did not work
# 1636 does not exist or did not work
# 1637 does not exist or did not work
#  71%|███████   | 17/24 [00:08<00:02,  2.89it/s]
# 1638 does not exist or did not work
# 1639 does not exist or did not work
# 1640 does not exist or did not work
# 1641 does not exist or did not work
# 1642 does not exist or did not work
# 1643 does not exist or did not work
# 1644 does not exist or did not work
# 1645 does not exist or did not work
# 1646 does not exist or did not work
# 1647 does not exist or did not work
# 1648 does not exist or did not work
# 1649 does not exist or did not work
# 1650 does not exist or did not work
# 1651 does not exist or did not work
# 1652 does not exist or did not work
# 1653 does not exist or did not work
# 1654 does not exist or did not work
# 1655 does not exist or did not work
# 1656 does not exist or did not work
# 1657 does not exist or did not work
# 1658 does not exist or did not work
# 1659 does not exist or did not work
# 170 does not exist or did not work
# 171 does not exist or did not work
# 172 does not exist or did not work
# 173 does not exist or did not work
# 174 does not exist or did not work
# 175 does not exist or did not work
# 176 does not exist or did not work
# 177 does not exist or did not work
# 178 does not exist or did not work
# 179 does not exist or did not work
# 1710 does not exist or did not work
# 1711 does not exist or did not work
# 1712 does not exist or did not work
# 1713 does not exist or did not work
# 1714 does not exist or did not work
# 1715 does not exist or did not work
# 1716 does not exist or did not work
# 1717 does not exist or did not work
# 1718 does not exist or did not work
#  75%|███████▌  | 18/24 [00:09<00:01,  3.01it/s]
# 1719 does not exist or did not work
# 1720 does not exist or did not work
# 1721 does not exist or did not work
# 1722 does not exist or did not work
# 1723 does not exist or did not work
# 1724 does not exist or did not work
# 1725 does not exist or did not work
# 1726 does not exist or did not work
# 1727 does not exist or did not work
# 1728 does not exist or did not work
# 1729 does not exist or did not work
# 1730 does not exist or did not work
# 1731 does not exist or did not work
# 1732 does not exist or did not work
# 1733 does not exist or did not work
# 1734 does not exist or did not work
# 1735 does not exist or did not work
# 1736 does not exist or did not work
# 1737 does not exist or did not work
# 1738 does not exist or did not work
# 1739 does not exist or did not work
# 1740 does not exist or did not work
# 1741 does not exist or did not work
# 1742 does not exist or did not work
# 1743 does not exist or did not work
# 1744 does not exist or did not work
# 1745 does not exist or did not work
# 1746 does not exist or did not work
# 1747 does not exist or did not work
# 1748 does not exist or did not work
# 1749 does not exist or did not work
# 1750 does not exist or did not work
# 1751 does not exist or did not work
# 1752 does not exist or did not work
# 1753 does not exist or did not work
# 1754 does not exist or did not work
# 1755 does not exist or did not work
# 1756 does not exist or did not work
# 1757 does not exist or did not work
# 1758 does not exist or did not work
# 1759 does not exist or did not work
# 180 does not exist or did not work
# 181 does not exist or did not work
# 182 does not exist or did not work
# 183 does not exist or did not work
# 184 does not exist or did not work
# 185 does not exist or did not work
# 186 does not exist or did not work
# 187 does not exist or did not work
# 188 does not exist or did not work
# 189 does not exist or did not work
# 1810 does not exist or did not work
# 1811 does not exist or did not work
# 1812 does not exist or did not work
# 1813 does not exist or did not work
# 1814 does not exist or did not work
# 1815 does not exist or did not work
# 1816 does not exist or did not work
# 1817 does not exist or did not work
# 1818 does not exist or did not work
# 1819 does not exist or did not work
# 1820 does not exist or did not work
# 1821 does not exist or did not work
# 1822 does not exist or did not work
# 1823 does not exist or did not work
# 1824 does not exist or did not work
# 1825 does not exist or did not work
# 1826 does not exist or did not work
# 1827 does not exist or did not work
# 1828 does not exist or did not work
# 1829 does not exist or did not work
# 1830 does not exist or did not work
# 1831 does not exist or did not work
# 1832 does not exist or did not work
# 1833 does not exist or did not work
# 1834 does not exist or did not work
# 1835 does not exist or did not work
# 1836 does not exist or did not work
# 1837 does not exist or did not work
# 1838 does not exist or did not work
# 1839 does not exist or did not work
# 1840 does not exist or did not work
#  79%|███████▉  | 19/24 [00:09<00:01,  3.11it/s]
# 1841 does not exist or did not work
# 1842 does not exist or did not work
# 1843 does not exist or did not work
# 1844 does not exist or did not work
# 1845 does not exist or did not work
# 1846 does not exist or did not work
# 1847 does not exist or did not work
# 1848 does not exist or did not work
# 1849 does not exist or did not work
# 1850 does not exist or did not work
# 1851 does not exist or did not work
# 1852 does not exist or did not work
# 1853 does not exist or did not work
# 1854 does not exist or did not work
# 1855 does not exist or did not work
# 1856 does not exist or did not work
# 1857 does not exist or did not work
# 1858 does not exist or did not work
# 1859 does not exist or did not work
# 190 does not exist or did not work
# 191 does not exist or did not work
# 192 does not exist or did not work
# 193 does not exist or did not work
# 194 does not exist or did not work
# 195 does not exist or did not work
# 196 does not exist or did not work
# 197 does not exist or did not work
# 198 does not exist or did not work
# 199 does not exist or did not work
# 1910 does not exist or did not work
# 1911 does not exist or did not work
# 1912 does not exist or did not work
# 1913 does not exist or did not work
# 1914 does not exist or did not work
# 1915 does not exist or did not work
# 1916 does not exist or did not work
# 1917 does not exist or did not work
# 1918 does not exist or did not work
# 1919 does not exist or did not work
# 1920 does not exist or did not work
# 1921 does not exist or did not work
# 1922 does not exist or did not work
#  83%|████████▎ | 20/24 [00:09<00:01,  3.18it/s]
# 1923 does not exist or did not work
# 1924 does not exist or did not work
# 1925 does not exist or did not work
# 1926 does not exist or did not work
# 1927 does not exist or did not work
# 1928 does not exist or did not work
# 1929 does not exist or did not work
# 1930 does not exist or did not work
# 1931 does not exist or did not work
# 1932 does not exist or did not work
# 1933 does not exist or did not work
# 1934 does not exist or did not work
# 1935 does not exist or did not work
# 1936 does not exist or did not work
# 1937 does not exist or did not work
# 1938 does not exist or did not work
# 1939 does not exist or did not work
# 1940 does not exist or did not work
# 1941 does not exist or did not work
# 1942 does not exist or did not work
# 1943 does not exist or did not work
# 1944 does not exist or did not work
# 1945 does not exist or did not work
# 1946 does not exist or did not work
# 1947 does not exist or did not work
# 1948 does not exist or did not work
# 1949 does not exist or did not work
# 1950 does not exist or did not work
# 1951 does not exist or did not work
# 1952 does not exist or did not work
# 1953 does not exist or did not work
# 1954 does not exist or did not work
# 1955 does not exist or did not work
# 1956 does not exist or did not work
# 1957 does not exist or did not work
# 1958 does not exist or did not work
# 1959 does not exist or did not work
# 200 does not exist or did not work
# 201 does not exist or did not work
# 202 does not exist or did not work
# 203 does not exist or did not work
# 204 does not exist or did not work
# 205 does not exist or did not work
# 206 does not exist or did not work
# 207 does not exist or did not work
# 208 does not exist or did not work
# 209 does not exist or did not work
# 2010 does not exist or did not work
# 2011 does not exist or did not work
# 2012 does not exist or did not work
# 2013 does not exist or did not work
# 2014 does not exist or did not work
# 2015 does not exist or did not work
# 2016 does not exist or did not work
# 2017 does not exist or did not work
# 2018 does not exist or did not work
# 2019 does not exist or did not work
# 2020 does not exist or did not work
# 2021 does not exist or did not work
# 2022 does not exist or did not work
# 2023 does not exist or did not work
# 2024 does not exist or did not work
# 2025 does not exist or did not work
# 2026 does not exist or did not work
# 2027 does not exist or did not work
# 2028 does not exist or did not work
# 2029 does not exist or did not work
# 2030 does not exist or did not work
# 2031 does not exist or did not work
# 2032 does not exist or did not work
# 2033 does not exist or did not work
# 2034 does not exist or did not work
# 2035 does not exist or did not work
# 2036 does not exist or did not work
# 2037 does not exist or did not work
# 2038 does not exist or did not work
# 2039 does not exist or did not work
# 2040 does not exist or did not work
# 2041 does not exist or did not work
# 2042 does not exist or did not work
# 2043 does not exist or did not work
# 2044 does not exist or did not work
#  88%|████████▊ | 21/24 [00:10<00:00,  3.23it/s]
# 2045 does not exist or did not work
# 2046 does not exist or did not work
# 2047 does not exist or did not work
# 2048 does not exist or did not work
# 2049 does not exist or did not work
# 2050 does not exist or did not work
# 2051 does not exist or did not work
# 2052 does not exist or did not work
# 2053 does not exist or did not work
# 2054 does not exist or did not work
# 2055 does not exist or did not work
# 2056 does not exist or did not work
# 2057 does not exist or did not work
# 2058 does not exist or did not work
# 2059 does not exist or did not work
# 210 does not exist or did not work
# 211 does not exist or did not work
# 212 does not exist or did not work
# 213 does not exist or did not work
# 214 does not exist or did not work
# 215 does not exist or did not work
# 216 does not exist or did not work
# 217 does not exist or did not work
# 218 does not exist or did not work
# 219 does not exist or did not work
# 2110 does not exist or did not work
# 2111 does not exist or did not work
# 2112 does not exist or did not work
# 2113 does not exist or did not work
# 2114 does not exist or did not work
# 2115 does not exist or did not work
# 2116 does not exist or did not work
# 2117 does not exist or did not work
# 2118 does not exist or did not work
# 2119 does not exist or did not work
# 2120 does not exist or did not work
# 2121 does not exist or did not work
# 2122 does not exist or did not work
# 2123 does not exist or did not work
# 2124 does not exist or did not work
# 2125 does not exist or did not work
#  92%|█████████▏| 22/24 [00:10<00:00,  3.26it/s]
# 2126 does not exist or did not work
# 2127 does not exist or did not work
# 2128 does not exist or did not work
# 2129 does not exist or did not work
# 2130 does not exist or did not work
# 2131 does not exist or did not work
# 2132 does not exist or did not work
# 2133 does not exist or did not work
# 2134 does not exist or did not work
# 2135 does not exist or did not work
# 2136 does not exist or did not work
# 2137 does not exist or did not work
# 2138 does not exist or did not work
# 2139 does not exist or did not work
# 2140 does not exist or did not work
# 2141 does not exist or did not work
# 2142 does not exist or did not work
# 2143 does not exist or did not work
# 2144 does not exist or did not work
# 2145 does not exist or did not work
# 2146 does not exist or did not work
# 2147 does not exist or did not work
# 2148 does not exist or did not work
# 2149 does not exist or did not work
# 2150 does not exist or did not work
# 2151 does not exist or did not work
# 2152 does not exist or did not work
# 2153 does not exist or did not work
# 2154 does not exist or did not work
# 2155 does not exist or did not work
# 2156 does not exist or did not work
# 2157 does not exist or did not work
# 2158 does not exist or did not work
# 2159 does not exist or did not work
# 220 does not exist or did not work
# 221 does not exist or did not work
# 222 does not exist or did not work
# 223 does not exist or did not work
# 224 does not exist or did not work
# 225 does not exist or did not work
# 226 does not exist or did not work
# 227 does not exist or did not work
# 228 does not exist or did not work
# 229 does not exist or did not work
# 2210 does not exist or did not work
# 2211 does not exist or did not work
# 2212 does not exist or did not work
# 2213 does not exist or did not work
# 2214 does not exist or did not work
# 2215 does not exist or did not work
# 2216 does not exist or did not work
# 2217 does not exist or did not work
# 2218 does not exist or did not work
# 2219 does not exist or did not work
# 2220 does not exist or did not work
# 2221 does not exist or did not work
# 2222 does not exist or did not work
# 2223 does not exist or did not work
# 2224 does not exist or did not work
# 2225 does not exist or did not work
# 2226 does not exist or did not work
# 2227 does not exist or did not work
# 2228 does not exist or did not work
# 2229 does not exist or did not work
# 2230 does not exist or did not work
# 2231 does not exist or did not work
# 2232 does not exist or did not work
# 2233 does not exist or did not work
# 2234 does not exist or did not work
# 2235 does not exist or did not work
# 2236 does not exist or did not work
# 2237 does not exist or did not work
# 2238 does not exist or did not work
# 2239 does not exist or did not work
# 2240 does not exist or did not work
# 2241 does not exist or did not work
# 2242 does not exist or did not work
# 2243 does not exist or did not work
# 2244 does not exist or did not work
# 2245 does not exist or did not work
# 2246 does not exist or did not work
# 2247 does not exist or did not work
#  96%|█████████▌| 23/24 [00:10<00:00,  3.28it/s]
# 2248 does not exist or did not work
# 2249 does not exist or did not work
# 2250 does not exist or did not work
# 2251 does not exist or did not work
# 2252 does not exist or did not work
# 2253 does not exist or did not work
# 2254 does not exist or did not work
# 2255 does not exist or did not work
# 2256 does not exist or did not work
# 2257 does not exist or did not work
# 2258 does not exist or did not work
# 2259 does not exist or did not work
# 230 does not exist or did not work
# 231 does not exist or did not work
# 232 does not exist or did not work
# 233 does not exist or did not work
# 234 does not exist or did not work
# 235 does not exist or did not work
# 236 does not exist or did not work
# 237 does not exist or did not work
# 238 does not exist or did not work
# 239 does not exist or did not work
# 2310 does not exist or did not work
# 2311 does not exist or did not work
# 2312 does not exist or did not work
# 2313 does not exist or did not work
# 2314 does not exist or did not work
# 2315 does not exist or did not work
# 2316 does not exist or did not work
# 2317 does not exist or did not work
# 2318 does not exist or did not work
# 2319 does not exist or did not work
# 2320 does not exist or did not work
# 2321 does not exist or did not work
# 2322 does not exist or did not work
# 2323 does not exist or did not work
# 2324 does not exist or did not work
# 2325 does not exist or did not work
# 2326 does not exist or did not work
# 2327 does not exist or did not work
# 100%|██████████| 24/24 [00:11<00:00,  3.29it/s]
# 2328 does not exist or did not work
# 2329 does not exist or did not work
# 2330 does not exist or did not work
# 2331 does not exist or did not work
# 2332 does not exist or did not work
# 2333 does not exist or did not work
# 2334 does not exist or did not work
# 2335 does not exist or did not work
# 2336 does not exist or did not work
# 2337 does not exist or did not work
# 2338 does not exist or did not work
# 2339 does not exist or did not work
# 2340 does not exist or did not work
# 2341 does not exist or did not work
# 2342 does not exist or did not work
# 2343 does not exist or did not work
# 2344 does not exist or did not work
# 2345 does not exist or did not work
# 2346 does not exist or did not work
# 2347 does not exist or did not work
# 2348 does not exist or did not work
# 2349 does not exist or did not work
# 2350 does not exist or did not work
# 2351 does not exist or did not work
# 2352 does not exist or did not work
# 2353 does not exist or did not work
# 2354 does not exist or did not work
# 2355 does not exist or did not work
# 2356 does not exist or did not work
# 2357 does not exist or did not work
# 2358 does not exist or did not work
# 2359 does not exist or did not work
# Wave meter file /data/new_trap_processed/processed_files/20200930/Bead1/EnvData/01.10.2020/wavemeter_data_20201001.pkl exists already

# %%
def run_environment_processor_batch(year,month,day_start,day_end,bead_date,bead_number=1):
    """
    Wrapper to run the environmental processor in a practical way. This way it works for an entire month if necessary. We had no bead living longer than a month. So further scripting will not be done until they start to behave as annual events!
    Inputs are: 
    year = year of interest as int, i.e. where the measurement was performed 
    month = same as above
    start_day = the day to start with
    end_day = the day to end with
    bead_date = day the bead was trapped (YYYYMMDD)
    bead_number= number of the bead that date
    """
    day = range(day_start,day_end+1,1)
    year = [year]*len(day)
    month = [month]*len(day)
    dataset_list=(year,month,day)
    dataset_list_T=np.transpose(dataset_list)
    for year,month,day in tqdm(dataset_list_T):
        environment_processor(year,month,day,str(bead_date),bead_number)
    return print("Done")
# Out:
# 0
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.00,  281.62023 THz, OnReset.lta
# 1
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.01,  281.62019 THz, OnReset.lta
# 2
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.02,  281.62019 THz, OnReset.lta
# 3
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.03,  281.62018 THz, OnReset.lta
# 4
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.04,  281.62018 THz, OnReset.lta
# 5
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.05,  281.62014 THz, OnReset.lta
# 6
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.06,  281.62015 THz, OnReset.lta
# 7
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.07,  281.62015 THz, OnReset.lta
# 8
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.08,  281.62016 THz, OnReset.lta
# 9
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.09,  281.62015 THz, OnReset.lta
# 10
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.10,  281.62016 THz, OnReset.lta
# 11
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.11,  281.62014 THz, OnReset.lta
# 12
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.12,  281.62015 THz, OnReset.lta
# 13
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.13,  281.62015 THz, OnReset.lta
# 14
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.14,  281.62018 THz, OnReset.lta
# 15
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.15,  281.62018 THz, OnReset.lta
# 16
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.16,  281.62017 THz, OnReset.lta
# 17
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.17,  281.62017 THz, OnReset.lta
# 18
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.18,  281.62017 THz, OnReset.lta
# 19
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.19,  281.62017 THz, OnReset.lta
# 20
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.20,  281.62020 THz, OnReset.lta
# 21
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.21,  281.62019 THz, OnReset.lta
# 22
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.22,  281.62018 THz, OnReset.lta
# 23
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.23,  281.62019 THz, OnReset.lta
# 24
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.24,  281.62018 THz, OnReset.lta
# 25
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.25,  281.62019 THz, OnReset.lta
# 26
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.26,  281.62019 THz, OnReset.lta
# 27
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.27,  281.62020 THz, OnReset.lta
# 28
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.28,  281.62018 THz, OnReset.lta
# 29
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.29,  281.62018 THz, OnReset.lta
# 30
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.30,  281.62016 THz, OnReset.lta
# 31
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.31,  281.62016 THz, OnReset.lta
# 32
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.32,  281.62016 THz, OnReset.lta
# 33
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.33,  281.62017 THz, OnReset.lta
# 34
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.34,  281.62015 THz, OnReset.lta
# 35
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.35,  281.62015 THz, OnReset.lta
# 36
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.36,  281.62015 THz, OnReset.lta
# 37
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.37,  281.62015 THz, OnReset.lta
# 38
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.38,  281.62015 THz, OnReset.lta
# 39
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.39,  281.62016 THz, OnReset.lta
# 40
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.40,  281.62015 THz, OnReset.lta
# 41
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.41,  281.62015 THz, OnReset.lta
# 42
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.42,  281.62014 THz, OnReset.lta
# 43
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.43,  281.62016 THz, OnReset.lta
# 44
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.44,  281.62015 THz, OnReset.lta
# 45
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.45,  281.62016 THz, OnReset.lta
# 46
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.46,  281.62015 THz, OnReset.lta
# 47
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.47,  281.62017 THz, OnReset.lta
# 48
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.48,  281.62017 THz, OnReset.lta
# 49
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.49,  281.62015 THz, OnReset.lta
# 50
# /data/SC_data/Wavemeter/20200923/29.09.2020, 22.50,  281.62018 THz, OnReset.lta
# 51
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-95962d28e630> in <module>
#       4         #try:
#       5         file = "%s, %s.%s" %(date,str(hour).zfill(2),str(minute).zfill(2))
# ----> 6         filename= dirname + str([file_ for file_ in os.listdir(dirname) if file_.startswith(file) if file_.endswith('.lta')][0])
#       7         print(filename)
#
# IndexError: list index out of range

# %%
plt.plot(df_wavemeter["TIMESTAMP_WM_EPOCH"],df_wavemeter["LASER_FREQ"])

# %%
test ="%d-%d-%d-%d:%d:%0.3f" %(year,month,day,hour,minute,time_stamp[0]/1000)

# %%
i=166
print(time_stamp[i])
seconds=(int(time_stamp[i]/1000))
microseconds=int(1000*time_stamp[i]-seconds*1e6)
dt(year,month,day,hour,minute,seconds,microseconds)
# Out:
# 4683.6979
# datetime.datetime(2020, 10, 1, 0, 0, 4, 683697)

# %%
df["Time_Human"]= df["Time"].apply(lambda element: "-".join([str(year),str(month).zfill(2),str(day).zfill(2),element])) # Get a date format readable
df["Time_Epoch"]= df["Time_Human"].apply(lambda element: dt.datetime.timestamp(dt.datetime.strptime(element,"%Y-%m-%d-%H:%M:%S"))) # in epoch

# %%
plt.plot(time_stamp,wavelength)
plt.xlabel("time")
plt.ylabel("wavelength")
# Out:
# Text(0, 0.5, 'wavelength')
