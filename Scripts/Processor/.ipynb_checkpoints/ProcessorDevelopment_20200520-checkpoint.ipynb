# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# load the files
bead_date =20200320
bead_number = 1
dataset = "Shaking/Shaking2_20200403/"
FOI = "NoShaking_1"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
filename = "/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset + FOI

# %%
df_tot = pd.DataFrame()
start_file = 0
run = FOI
end_file = 600
step_size= 200
for i in np.arange(start_file,end_file,step_size):
    df_temp = pd.DataFrame()
    df_temp = harmonics_processor_input(bead_date,bead_number,dataset,run,i,step_size,no_harmonics=15,res=5000,save_file=False)
    df_tot.append(df_temp)
# Out:
#   2%|▏         | 3/200 [00:00<00:09, 21.55it/s]
# 6905  files in folder
# 200  files loaded
# 3
# 100%|██████████| 200/200 [00:04<00:00, 46.06it/s]
#             start_time    stroke    x_mean    y_mean        z_mean  \
# 0  1586398032997822136  0.170500 -0.226400 -0.142406 -3.200002e+06
# 1  1586398043393209606  0.170288 -0.226336 -0.142229 -3.200291e+06
# 2  1586398053744193712  0.170296 -0.226583 -0.142115 -3.201443e+06
# 3  1586398064105778621  0.170345 -0.226530 -0.142138 -3.202594e+06
# 4  1586398074403958727  0.170616 -0.226862 -0.142125 -3.202842e+06
#
#    attractor_position_x  attractor_position_y  attractor_position_z  \
# 0              7.379445              3.863097              5.755284
# 1              7.379470              3.863079              5.755296
# 2              7.379465              3.863087              5.755302
# 3              7.379461              3.863093              5.755306
# 4              7.379453              3.863096              5.755322
#
# ...

# %%
df_tot
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
s = time.time()
df5x00 = loop_run_harmonics_processor(bead_date,bead_number,dataset,FOI,start_file=0,no_harmonics=15,max_file=500,save_file=True)
e = time.time()
print(e-s)
# Out:
#   2%|▏         | 2/100 [00:00<00:05, 19.43it/s]
# 6905  files in folder
# 100  files loaded
# 3
# ...
#   6%|▌         | 6/100 [00:00<00:01, 57.95it/s]
# 6905  files in folder
# 100  files loaded
# 3
# ...
#   6%|▌         | 6/100 [00:00<00:01, 58.95it/s]
# 6905  files in folder
# 100  files loaded
# 3
# ...
#   9%|▉         | 9/100 [00:00<00:01, 88.05it/s]
# 6905  files in folder
# 100  files loaded
# 3
# ...
#   8%|▊         | 8/100 [00:00<00:01, 75.25it/s]
# 6905  files in folder
# 100  files loaded
# 3
# 100%|██████████| 100/100 [00:01<00:00, 71.31it/s]
# Folder exists or you do not have permissions
# Processed file could not be saved, probably exists.
# 11.599653244018555

# %%
df5x00
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_test = df500[df500.isin(df5x00)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7f88b50a4a97> in <module>
# ----> 1 df_test = df500[df500.isin(df5x00)]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in isin(self, values)
#    8453         elif isinstance(values, DataFrame):
#    8454             if not (values.columns.is_unique and values.index.is_unique):
# -> 8455                 raise ValueError("cannot compute isin with " "a duplicate axis.")
#    8456             return self.eq(values.reindex_like(self))
#    8457         else:
#
# ValueError: cannot compute isin with a duplicate axis.

# %%
# load the files
bead_date =20200320
bead_number = 1
dataset = "Shaking/Shaking2_20200403/"
FOI = "NoShaking_1"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
filename = "/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset + FOI

# %%
harmonics_processor_input(bead_date,bead_number,dataset,FOI,no_harmonics=15,max_file=10000,save_file=True)
