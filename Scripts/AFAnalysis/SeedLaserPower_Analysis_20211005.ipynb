# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
from matplotlib.ticker import MaxNLocator


plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
currentLowPLaser = [48,60,70,80,90,100,120,140,160,180,200,220,240,260,280,300,320,340]
currentLowPLaserIPG = np.arange(50,270,10)
currentHighPLaser = np.arange(40,310,10)

#signalLowPlaser = [160.5,475,730,1000,1260,1500,2030,2520,2950,3400,3850,4350,4750,5100,6500,7000,6800,6400]
powerLowPLaserUs = [0.09,0.26,0.41,0.56,0.70,0.83,1.13,1.40,1.64,1.89,2.14,2.42,2.64,2.83,3.61,3.89,3.78,3.56]
powerLowPLaserIPG = [0.13,0.29,0.46,0.63,0.8,0.95,1.11,1.26,1.42,1.57,1.73,1.88,2.03,2.16,2.29,2.42,2.53,2.67,2.8,2.95,3.1,3.13]
currentHighPLaserUs = [3,12.2,192,698,1200,1680,2150,2615,3080,3550,4020,4480,4900,5370,5800,6200,6600,7030,7400,7800,8100,8550,8900,9200,9550,9800,9950]
powerHighLaserUs = np.divide(currentHighPLaserUs,10000)*1/0.4*1/0.1*2

# %%
plt.plot(currentLowPLaser,powerLowPLaserUs,marker="$P$",linestyle="",label = "measured my PD setup",markersize="10")
plt.plot(currentLowPLaserIPG,powerLowPLaserIPG,marker="$P$",linestyle="", label="measured by IPG",markersize="10")
plt.xlabel("current [mA]")
plt.ylabel("power [mW]")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(currentHighPLaser,powerHighLaserUs,marker="$P$",linestyle="",label = "high Power (J02)",markersize="10")
plt.xlabel("current [mA]")
plt.ylabel("power [mW]")
plt.legend()
plt.grid()
plt.show()
