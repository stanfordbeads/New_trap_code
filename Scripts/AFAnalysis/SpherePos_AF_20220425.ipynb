# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

# %%
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
img = load_img_files("/data/SC_data/ImageAnalysis/20220425/height.bmp")
# Out:
# /data/SC_data/ImageAnalysis/20220425/height.bmp 0

# %%
plt.imshow(threshold_image(img[0],25,45))

# %%
t1 = threshold_image(img[0],25,45)
plt.plot(np.mean(t1,axis=1))
plt.xlim(600,800)
plt.axvline(626, c="red")
plt.axvline(790, c="red")
plt.axvline(790-(790-626)/2,c='black')

# %%
790 - 626
# Out:
# 164

# %%
790-164/2
# Out:
# 708.0
