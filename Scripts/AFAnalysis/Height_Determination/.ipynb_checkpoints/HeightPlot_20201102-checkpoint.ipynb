# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
height = load_dir_reduced_to_height("/data/new_trap/20201028/Bead2/HeightPictures/HeightMonitor5_20201029/","Discharge_",max_files=10000)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f1b8cd91c555> in <module>
# ----> 1 height = load_dir_reduced_to_height("/data/new_trap/20201028/Bead2/HeightPictures/HeightMonitor5_20201029/","Discharge_",max_files=10000)
#
# ~/New_trap_code/Tools/processor_tools.py in load_dir_reduced_to_height(dirname, file_prefix, max_files)
#     106     step_size = 100
#     107     for j in tqdm(np.arange(0,max_files,step_size)):
# --> 108         BDFs = [BDF.BeadDataFile(dirname+filename) for filename in files[j:j+step_size]]
#     109         [var_list.append(BDFs[k].bead_height) for k in range(len(BDFs))]
#     110     return var_list
#
# ~/New_trap_code/Tools/processor_tools.py in <listcomp>(.0)
#     106     step_size = 100
#     107     for j in tqdm(np.arange(0,max_files,step_size)):
# ...

# %%
plt.plot(height)
plt.ylabel("pixel")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-019ceb008a77> in <module>
# ----> 1 plt.plot(height)
#       2 plt.ylabel("pixel")
#
# NameError: name 'plt' is not defined

# %%
np.save("Results/Height_20201101.npy",height)

# %%
height = np.load("Results/Height_20201101.npy")

# %%
x = np.arange(0,len(height)*30,30)/3600
plt.plot(x,height,linestyle="",marker="*")
plt.ylabel("pixel")
plt.xlabel("time [h]")
# Out:
# Text(0.5, 0, 'time [h]')

# %%
height2 = load_dir_reduced_to_height("/home/data_transfer/data_from_windows/20201105/Bead1/HeightPictures/HeightMonitor0_20201105/","Discharge_",max_files=10000)
# Out:
# 100%|██████████| 100/100 [01:56<00:00,  1.16s/it]

# %%
time2 = load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201105/Bead1/HeightPictures/HeightMonitor0_20201105/","Discharge_",max_files=10000)
# Out:
# 100%|██████████| 100/100 [00:55<00:00,  1.82it/s]

# %%
x = (time2-time2[0])/3600
plt.plot(x,height2,marker="*",linestyle="")
plt.ylabel("pixel")
plt.xlabel("time [h]")
# Out:
# Text(0.5, 0, 'time [h]')

# %%
height3 = load_dir_reduced_to_height("/home/data_transfer/data_from_windows/20201106/Bead1/HeightPictures/HeightMonitor0_20201106/","Discharge_",max_files=3900)
# Out:
# 100%|██████████| 39/39 [02:59<00:00,  5.06s/it]

# %%
time3 = load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201106/Bead1/HeightPictures/HeightMonitor0_20201106/","Discharge_",max_files=3900)
# Out:
# 100%|██████████| 39/39 [00:54<00:00,  1.02s/it]

# %%
x = (time3-time3[0])/3600
plt.plot(x,height3,marker="*",linestyle="")
plt.ylabel("pixel")
plt.xlabel("time [h]")
# Out:
# Text(0.5, 0, 'time [h]')

# %%
height4 = load_dir_reduced_to_height("/home/data_transfer/data_from_windows/20201110/Bead1/HeightPictures/HeightMonitor0_20201110/","Discharge_",max_files=14400)
# Out:
# 100%|██████████| 144/144 [10:06<00:00,  3.32s/it]

# %%
time4 = load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201110/Bead1/HeightPictures/HeightMonitor0_20201110/","Discharge_",max_files=14400)
# Out:
# 100%|██████████| 144/144 [07:20<00:00,  3.96s/it]

# %%
x = (time4-time4[0])/3600
plt.plot(x,height4,marker="*",linestyle="")
plt.ylabel("pixel")
plt.xlabel("time [h]")
# Out:
# Text(0.5, 0, 'time [h]')

# %%
height5a = load_dir_reduced_to_height("/home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/","Discharge_",max_files=15000)
# Out:
# ...
# 100%|██████████| 150/150 [08:56<00:00,  3.58s/it]

# %%
time5a = load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/","Discharge_",max_files=15000)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
#
#
#
#   1%|          | 1/150 [00:05<14:22,  5.79s/it]
#
#
#
#   1%|▏         | 2/150 [00:09<13:01,  5.28s/it]
#
#
#
#   2%|▏         | 3/150 [00:17<14:25,  5.89s/it]
#
#
#
#   3%|▎         | 4/150 [00:26<16:31,  6.79s/it]
#
#
#
#   3%|▎         | 5/150 [00:34<17:38,  7.30s/it]
#
#
#
#   4%|▍         | 6/150 [00:42<18:14,  7.60s/it]
#
#
#
#   5%|▍         | 7/150 [00:50<18:27,  7.74s/it]
#
#
#
#   5%|▌         | 8/150 [00:59<18:52,  7.97s/it]
#
#
#
#   6%|▌         | 9/150 [01:06<17:58,  7.65s/it]
#
#
#
#   7%|▋         | 10/150 [01:15<18:37,  7.99s/it]
#
#
#
#   7%|▋         | 11/150 [01:21<17:22,  7.50s/it]
#
#
#
#   8%|▊         | 12/150 [01:29<17:30,  7.61s/it]
#
#
#
#   9%|▊         | 13/150 [01:36<17:22,  7.61s/it]
#
#
#
#   9%|▉         | 14/150 [01:45<17:32,  7.74s/it]
#
#
#
#  10%|█         | 15/150 [01:52<17:31,  7.79s/it]
#
#
#
#  11%|█         | 16/150 [02:02<18:51,  8.45s/it]
#
#
#
# ...

# %%
height5b = load_dir_reduced_to_height("/home/data_transfer/data_from_windows/20201116/Bead2/Discharge/","Discharge_",max_files=3000)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#   3%|▎         | 1/30 [01:01<29:45, 61.58s/it]
#
#
#
#   7%|▋         | 2/30 [01:48<26:40, 57.14s/it]
#
#
#
#  10%|█         | 3/30 [01:54<18:45, 41.70s/it]
#
#
#
#  13%|█▎        | 4/30 [01:59<13:24, 30.95s/it]
#
#
#
#  17%|█▋        | 5/30 [02:05<09:44, 23.38s/it]
#
#
#
#  20%|██        | 6/30 [02:11<07:17, 18.22s/it]
#
#
#
#  23%|██▎       | 7/30 [02:18<05:38, 14.73s/it]
#
#
#
#  27%|██▋       | 8/30 [02:24<04:27, 12.14s/it]
#
#
#
#  30%|███       | 9/30 [02:30<03:36, 10.32s/it]
#
#
#
#  33%|███▎      | 10/30 [02:40<03:24, 10.22s/it]
#
#
#
#  37%|███▋      | 11/30 [02:48<03:02,  9.62s/it]
#
#
#
#  40%|████      | 12/30 [02:54<02:34,  8.60s/it]
#
#
#
#  43%|████▎     | 13/30 [03:01<02:13,  7.84s/it]
#
#
#
#  47%|████▋     | 14/30 [03:04<01:43,  6.46s/it]
#
#
#
#  50%|█████     | 15/30 [03:06<01:19,  5.28s/it]
#
#
#
#  53%|█████▎    | 16/30 [03:09<01:02,  4.47s/it]
#
#
#
#  57%|█████▋    | 17/30 [03:11<00:50,  3.89s/it]
#
#
#
# ...

# %%
time5b =  load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201116/Bead2/Discharge/","Discharge_",max_files=3000)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#
#
#
#   3%|▎         | 1/30 [00:52<25:23, 52.52s/it]
#
#
#
#   7%|▋         | 2/30 [01:40<23:55, 51.26s/it]
#
#
#
#  10%|█         | 3/30 [01:48<17:08, 38.10s/it]
#
#
#
#  13%|█▎        | 4/30 [01:55<12:33, 29.00s/it]
#
#
#
#  17%|█▋        | 5/30 [02:05<09:38, 23.13s/it]
#
#
#
#  20%|██        | 6/30 [02:12<07:18, 18.26s/it]
#
#
#
#  23%|██▎       | 7/30 [02:20<05:47, 15.10s/it]
#
#
#
#  27%|██▋       | 8/30 [02:28<04:45, 12.96s/it]
#
#
#
#  30%|███       | 9/30 [02:35<03:55, 11.21s/it]
#
#
#
#  33%|███▎      | 10/30 [02:42<03:18,  9.94s/it]
#
#
#
#  37%|███▋      | 11/30 [02:47<02:42,  8.57s/it]
#
#
#
#  40%|████      | 12/30 [02:53<02:18,  7.69s/it]
#
#
#
#  43%|████▎     | 13/30 [02:59<02:04,  7.30s/it]
#
#
#
#  47%|████▋     | 14/30 [03:05<01:51,  6.98s/it]
#
#
#
#  50%|█████     | 15/30 [03:11<01:40,  6.67s/it]
#
#
#
#  53%|█████▎    | 16/30 [03:18<01:32,  6.61s/it]
#
#
#
#  57%|█████▋    | 17/30 [03:23<01:20,  6.21s/it]
#
#
#
# ...

# %%
x = (time5a-time5a[0])/3600
plt.plot(x,height5a,marker="*",linestyle="",color="blue")
x2 = (time5b-time5a[0])/3600
plt.plot(x2,height5b,marker="*",linestyle="",color = "blue")
plt.ylabel("pixel")
plt.xlabel("time [h]")
# Out:
# Text(0.5, 0, 'time [h]')

# %%
x = (time5b-time5a[0])/3600
plt.plot(x,height5b,marker="*",linestyle="")
plt.ylabel("pixel")
plt.xlabel("time [h]")
# Out:
# Text(0.5, 0, 'time [h]')

# %%
img5 = load_npy_files("/home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/*",max_files=2000)
# Out:
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_0.npy 0
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_1.npy 1
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_3.npy 2
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_4.npy 3
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_5.npy 4
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_6.npy 5
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_7.npy 6
# /home/data_transfer/data_from_windows/20201116/Bead2/HeightPictures/HeightMonitor0_20201116/Pictures/Discharge_8.npy 7
# ...

# %%
height7 = load_dir_reduced_to_height("/home/data_transfer/data_from_windows/20201125/Bead1/HeightPictures/HeightMonitor20201125/","Discharge_",max_files=150000)
# Out:
# 100%|██████████| 1500/1500 [02:09<00:00, 11.54it/s]

# %%
time7 = load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201125/Bead1/HeightPictures/HeightMonitor20201125/","Discharge_",max_files=150000)
# Out:
# 100%|██████████| 1500/1500 [01:02<00:00, 24.01it/s]

# %%
x = (time7-time7[0])/3600
plt.plot(x,height7,marker="*",linestyle="")
plt.ylabel("pixel")
plt.xlabel("time [h]")
# Out:
# Text(0.5, 0, 'time [h]')

# %%
img8 = load_npy_files("/home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/*",max_files=20000)
# Out:
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1694.npy 0
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1695.npy 1
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1696.npy 2
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1697.npy 3
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1698.npy 4
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1699.npy 5
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1700.npy 6
# /home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1701.npy 7
# ...

# %%
from skimage.registration import phase_cross_correlation as pcc

def shift_PCC(image,zeroth_image):
    zeroth=np.load(zeroth_image)
    height = 480-np.argmax(np.mean(zeroth,axis=1))
    shift,_,_ = pcc(zeroth,image,upsample_factor=100)
    return shift[0]#+height

# %%
height8 = []
for image in tqdm(img8):
    height8.append(shift_PCC(image,r"/home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/Pictures/Discharge_1694.npy"))
# Out:
# 100%|██████████| 19634/19634 [30:15<00:00, 10.68it/s]

# %%
time8 = load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201126/Bead1/HeightPictures/HeightMonitor20201126/","Discharge_",max_files=150000)
# Out:
# 100%|██████████| 1500/1500 [19:10<00:00,  1.30it/s]

# %%
plt.imshow(img8[1250])

# %%
plt.plot(height8)
#plt.xlim(0,100),
plt.show()

# %%
x = (time8-time8[0])/3600
plt.plot(x[0:len(height8)],height8,marker="*",linestyle="")
plt.ylabel("pixel")
plt.xlabel("time [h]")
plt.xlim(0,1)
plt.show()

# %%
sub_img_list = img8[0:25]

# %%
@gif.frame
def show_image(image):
    plt.imshow(image)
image_list = sub_img_list
frames = []
for images in image_list:
    frame =  show_image(images)
    frames.append(frame)
    #y2 = df_nos1["spin_fft"][i+2*step_size:i+3*step_size].mean()

gif.save(frames, "cockroft_first_25.gif", duration=1000)

# %%
img9 = load_npy_files("/home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/*",max_files=20000)
# Out:
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_0.npy 0
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_1.npy 1
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_2.npy 2
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_3.npy 3
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_4.npy 4
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_5.npy 5
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_6.npy 6
# /home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/Pictures/Discharge_7.npy 7
# ...

# %%
height9 = []
for image in tqdm(img9):
    height9.append(shift_PCC(image))
# Out:
# 100%|██████████| 1739/1739 [02:43<00:00, 10.61it/s]

# %%
time9 = load_dir_reduced_to_time("/home/data_transfer/data_from_windows/20201201/Bead2/HeightPictures/HeightMonitor20201202/","Discharge_",max_files=150000)
# Out:
#   1%|          | 8/1500 [00:21<1:14:43,  3.01s/it]

# %%
mean_list = []
for images in img5:
    mean_list.append(np.argmax(np.mean(images,axis=1)))

# %%
plt.plot(mean_list,marker="*",linestyle="")
plt.ylabel("main_pixel")
plt.xlabel("time [30s]")
# Out:
# Text(0.5, 0, 'time [30s]')
