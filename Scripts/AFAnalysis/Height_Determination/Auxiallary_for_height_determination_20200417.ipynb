# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# load the image files
bead_date =20200614
bead_number = 1
dataset = "/Shaking/"
FOI = "NoAttractorNoShaking1"
filename = "/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset + "Pictures_0/" + FOI
data = load_npy_files(path=filename+"*",max_files=10000)
# Out:
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/NoAttractorNoShaking1_0.npy 0
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/NoAttractorNoShaking1_1.npy 1
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/NoAttractorNoShaking1_2.npy 2
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/NoAttractorNoShaking1_3.npy 3
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/NoAttractorNoShaking1_4.npy 4
# /data/new_trap/20200614/Bead1//Shaking/Pictures_0/NoAttractorNoShaking1_5.npy 5

# %%
pixel_size_cal = 0.503 # obtained from attractor calibration data February2020, but cross checked during Wilson itself
attractor_0 = 241 # 0 position of attractor as extrapolated from image analysis of z=50 and z=27. Obtained from Wilson attractor screening.

# %%
ret,thresh = cv2.threshold(data[0],200,255,0)
plt.imshow(thresh)

# %%
height = [] # get the height using the shadow method
for i in tqdm(range(len(data))):
    mean, m = from_shadow_image_to_height(data[i],180,area_low_limits=[670,730],area_widths=[45,70],flb=430,fub=500,plot=True)
    height.append(pixel_to_height(mean,calibration=True,pix_size_from_calib=pixel_size_cal))
    print(m.values["sigma"])
    plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 3.5323001385520048
#  33%|███▎      | 1/3 [00:00<00:00,  6.07it/s]
# 3.8876479644980897
#  67%|██████▋   | 2/3 [00:00<00:00,  6.09it/s]
# 3.8790997609696087
# 100%|██████████| 3/3 [00:00<00:00,  6.10it/s]

# %%
height
# Out:
# [279.5965659538217, 279.5955518462256, 279.615573856012]
