# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# load the images
file = "/data/SC_data/ImageData/HeightData/20220509/Bead1/run/run/height_info.npy"

# %%
height = np.load(file)

# %%
plt.plot(height)
#plt.xlim(21000,26000)
#plt.xlim(7000,9000)

# %%
testimg =  "/data/SC_data/ImageData/HeightData/20220509/Bead1/run/run/image_test_26005.npy"
testimg0 =  "/data/SC_data/ImageData/HeightData/20220509/Bead1/run/run/image_test_0.npy"

# %%
img0 = np.load(testimg)
img1 = np.load(testimg0)
plt.imshow(img0-img1)
