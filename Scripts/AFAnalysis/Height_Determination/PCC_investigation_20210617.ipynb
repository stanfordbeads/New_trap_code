# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# load the images
dir_path = "/data/SC_data/ImageData/HeightData/20210616/run/i*npy"
test_images = load_npy_files(dir_path)
# Out:
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_0.npy 0
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_1.npy 1
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_2.npy 2
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_3.npy 3
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_4.npy 4
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_5.npy 5
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_6.npy 6
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_7.npy 7
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_8.npy 8
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_9.npy 9
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_10.npy 10
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_11.npy 11
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_12.npy 12
# /data/SC_data/ImageData/HeightData/20210616/run/image_test_13.npy 13
# ...

# %%
plt.imshow(threshold_image(test_images[25],50,150))

# %%
shiftlist3 = [pcc(threshold_image(test_images[0],100,256),threshold_image(test_images[img],100,256),upsample_factor=100)[0] for img in tqdm(range(250))]#test_images)]
# Out:
# 100%|██████████| 250/250 [01:11<00:00,  3.75it/s]

# %%
plt.plot(np.stack(shiftlist,axis=1)[0])
plt.plot(np.stack(shiftlist2,axis=1)[0])
plt.plot(np.stack(shiftlist3,axis=1)[0])
