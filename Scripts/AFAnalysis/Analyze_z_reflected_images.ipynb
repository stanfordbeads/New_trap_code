# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py


plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
img = load_npy_files("/data/SC_data/ImageData/HeightData/20220421/Bead1/*")
# Out:
# /data/SC_data/ImageData/HeightData/20220421/Bead1/img_0.npy 0
# /data/SC_data/ImageData/HeightData/20220421/Bead1/img_1.npy 1
# /data/SC_data/ImageData/HeightData/20220421/Bead1/img_2.npy 2
# /data/SC_data/ImageData/HeightData/20220421/Bead1/img_3.npy 3
# /data/SC_data/ImageData/HeightData/20220421/Bead1/img_4.npy 4
# /data/SC_data/ImageData/HeightData/20220421/Bead1/img_5.npy 5

# %%
imgheight = []
for i in range(5):
    imgheight.append(pcc(img[0],img[i+1],upsample_factor=400)[0][0])

# %%
plt.plot(imgheight,ls="",marker="*")

# %%
plt.imshow(images[1])

# %%
startr =time.time()
pcc(images[1],images[4],upsample_factor=100)
endr = time.time()
print(endr-startr)
# Out:
# 0.18850111961364746
