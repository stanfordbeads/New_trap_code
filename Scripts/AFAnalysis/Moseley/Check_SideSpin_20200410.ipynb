# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
#%matplotlib widget, remove below if used
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"

plt.rcParams['ytick.labelsize'] = 36

# %%
files = load_dir("/data/new_trap/20200930/NoBead/y210/","BeamProfileX0",max_file=100)
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  7.72it/s]
# 100  files in folder
# 100  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in range(100):
    BDF=files[i]
    data2 = BDF.xyz2
    data_det2=signal.detrend(data2)
    xpsd2, freqs2 = matplotlib.mlab.psd(data_det2[0], Fs = fsamp, NFFT = res,)
    ypsd2, freqs2 = matplotlib.mlab.psd(data_det2[1], Fs = fsamp, NFFT = res)
    zpsd2, freqs2 = matplotlib.mlab.psd(data_det2[2], Fs = fsamp, NFFT = reswindow=matplotlib.mlab.window_none))
    spsd2, freqs2_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor, NFFT = res*factor)
    sspsd2, freqs2_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
    plt.plot(freqs2_s,spsd2,alpha=0.5)
    plt.yscale("log")
    plt.plot(freqs2_ss,sspsd2)
    plt.xlim(0,100)
    #plt.show()

# %%
files_bkg = load_dir("/data/new_trap/20200930/Bead1/Shaking/Shaking345/","NoShakingNoSpin2",max_file=100)
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 147.10it/s]
# 500  files in folder
# 100  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in range(100):
    BDF=files_bkg[i]
    data = BDF.xyz2
    data_det=signal.detrend(data)
    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res)
    spsd, freqs_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor, NFFT = res*factor)
    sspsd, freqs_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
    plt.plot(freqs_s,spsd,alpha=0.5)
    plt.yscale("log")
    plt.plot(freqs_ss,sspsd)
    plt.xlim(1,1000)
    #plt.show()

# %%
files_10 = load_dir("/data/new_trap/20200930/NoBead/y210/","BeamProfileX4",max_file=100)
# Out:
# ...
# 100%|██████████| 100/100 [00:18<00:00,  5.25it/s]
# 100  files in folder
# 100  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in range(100):
    BDF=files_10[i]
    data3 = BDF.xyz2
    data_det3=signal.detrend(data3)
    xpsd3, freqs3 = matplotlib.mlab.psd(data_det3[0], Fs = fsamp, NFFT = res)
    ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
    zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
    spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
    sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
    #plt.loglog(freqs3_s,spsd3,alpha=0.5)
    plt.loglog(freqs3_ss,sspsd3)
    plt.xlim(1,1000)
    #plt.show()

# %%
files_test0 = load_dir("/data/new_trap/20200930/NoBead/SideSpin_Test/","TestShake0",max_file=100)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 118.02it/s]
# 101  files in folder
# 100  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in [8]:
    BDF=files_test0[i]
    data3 = BDF.xyz2
    data_det3=signal.detrend(data3)
    xpsd3, freqs3 = matplotlib.mlab.psd(data_det3[0], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor,window=matplotlib.mlab.window_none)
    sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor,window=matplotlib.mlab.window_none)
    plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
    plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
    plt.plot(freqs3,xpsd3,label="X from QPD")
    plt.xlim(1,50)
    plt.yscale("log")
    for i in np.arange(3,15,3):
        plt.axvline(i,color="red",linestyle="dotted",label="fundamental (3Hz)")
    plt.legend()
    plt.ylabel("PSD [a.u.]")
    plt.xlabel("frequency [Hz]")

    plt.show()
    #plt.show()
testshake_spsd_0 =spsd3 
testshake_sspsd_0 =sspsd3 
testshake_x_0  =xpsd3

# %%
fsamp = 5000
res = 5000
factor=10
data_temp=[]
data_temp2 = np.zeros(50000)
leng=5
for i in range(10):
    BDF=files_test0[i]
    data_temp.append(BDF.x2)
for i in range(10):
    data_temp2 = np.add(data_temp[i],data_temp2)
data3=data_temp2
data_det3=signal.detrend(data3)
xpsd3, freqs3 = matplotlib.mlab.psd(data_det3, Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
#ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
#zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor,window=matplotlib.mlab.window_none)
sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor,window=matplotlib.mlab.window_none)
plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
plt.plot(freqs3,xpsd3,label="X from QPD averaged over 10 files")
plt.xlim(1,50)
plt.yscale("log")
for i in np.arange(3,15,3):
    plt.axvline(i,color="red",linestyle="dotted",label="harmonic (%dHz)" %i)
plt.legend()
plt.ylabel("PSD [a.u.]")
plt.xlabel("frequency [Hz]")
plt.show()
testshake_x_0  =xpsd3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-71e51b4dabf1> in <module>
#       6 leng=5
#       7 for i in range(10):
# ----> 8     BDF=files_test0[i]
#       9     data_temp.append(BDF.x2)
#      10 for i in range(10):
#
# NameError: name 'files_test0' is not defined

# %%
files_test1 = load_dir("/data/new_trap/20200930/NoBead/SideSpin_Test/","TestShake1",max_file=100)
# Out:
# ...
# 100%|██████████| 11/11 [00:00<00:00, 119.76it/s]
# 11  files in folder
# 11  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in [5]:
    BDF=files_test1[i]
    data3 = BDF.xyz2
    data_det3=signal.detrend(data3)
    xpsd3, freqs3 = matplotlib.mlab.psd(data_det3[0], Fs = fsamp, NFFT = res)
    ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
    zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
    spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
    sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
    plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
    plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
    plt.plot(freqs3,xpsd3,label="X from QPD")
    plt.xlim(1,50)
    plt.yscale("log")
    for i in np.arange(3,15,3):
        plt.axvline(i,color="red",linestyle="dotted",label="fundamental (3Hz)")
    plt.legend()
    plt.ylabel("PSD [a.u.]")
    plt.xlabel("frequency [Hz]")

    plt.show()
    #plt.show()
testshake_spsd_1 =spsd3 
testshake_sspsd_1 =sspsd3 
testshake_x_1  =xpsd3

# %%
fsamp = 5000
res = 5000
factor=10
data_temp=[]
data_temp2 = np.zeros(50000)
leng=5
for i in range(10):
    BDF=files_test1[i]
    data_temp.append(BDF.x2)
for i in range(10):
    data_temp2 = np.add(data_temp[i],data_temp2)
data3=data_temp2
data_det3=signal.detrend(data3)
xpsd3, freqs3 = matplotlib.mlab.psd(data_det3, Fs = fsamp, NFFT = res)
#ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
#zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
plt.plot(freqs3,xpsd3,label="X from QPD averaged over 10 files")
plt.xlim(1,50)
plt.yscale("log")
for i in np.arange(3,15,3):
    plt.axvline(i,color="red",linestyle="dotted",label="harmonic (%dHz)" %i)
plt.legend()
plt.ylabel("PSD [a.u.]")
plt.xlabel("frequency [Hz]")
plt.show()
testshake_x_1  =xpsd3 
    #plt.show()

# %%
for i in range(50000):
    data_temp2np.add(data_temp[i])
# Out:
# array([-166937.92960604, -170195.37007453, -169358.86158875,
#        -166745.11809392, -156249.78409331, -154330.15538176,
#        -152728.3856772 , -148218.17648228, -149173.15192008,
#        -149068.74506621])

# %%
np.mean(data_temp,axis=1)
# Out:
# array([-3.33875859, -3.4039074 , -3.38717723, -3.33490236, -3.12499568,
#        -3.08660311, -3.05456771, -2.96436353, -2.98346304, -2.9813749 ])

# %%
files_test2 = load_dir("/data/new_trap/20200930/NoBead/SideSpin_Test/","TestShake2",max_file=100)
# Out:
# ...
# 100%|██████████| 11/11 [00:01<00:00, 10.73it/s]
# 11  files in folder
# 11  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in [7]:
    BDF=files_test2[i]
    data3 = BDF.xyz2
    data_det3=signal.detrend(data3)
    xpsd3, freqs3 = matplotlib.mlab.psd(data_det3[0], Fs = fsamp, NFFT = res)
    ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
    zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
    spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
    sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
    plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
    plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
    plt.plot(freqs3,xpsd3,label="X from QPD")
    plt.xlim(1,50)
    plt.yscale("log")
    for i in np.arange(3,6,3):
        plt.axvline(i,color="red",linestyle="dotted",label="fundamental (3Hz)")
    plt.legend()
    plt.ylabel("PSD [a.u.]")
    plt.xlabel("frequency [Hz]")

    plt.show()
testshake_spsd_2 =spsd3 
testshake_sspsd_2 =sspsd3 
testshake_x_2  =xpsd3

# %%
fsamp = 5000
res = 5000
factor=10
data_temp=[]
data_temp2 = np.zeros(50000)
leng=5
for i in range(10):
    BDF=files_test2[i]
    data_temp.append(BDF.x2)
for i in range(10):
    data_temp2 = np.add(data_temp[i],data_temp2)
data3=data_temp2
data_det3=signal.detrend(data3)
xpsd3, freqs3 = matplotlib.mlab.psd(data_det3, Fs = fsamp, NFFT = res)
#ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
#zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor,window=matplotlib.mlab.window_none)
plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
plt.plot(freqs3,xpsd3,label="X from QPD averaged over 10 files")
plt.xlim(1,50)
plt.yscale("log")
for i in np.arange(3,15,3):
    plt.axvline(i,color="red",linestyle="dotted",label="harmonic (%dHz)" %i)
plt.legend()
plt.ylabel("PSD [a.u.]")
plt.xlabel("frequency [Hz]")
plt.show()
testshake_x_2  =xpsd3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cd4892cd4bed> in <module>
#       6 leng=5
#       7 for i in range(10):
# ----> 8     BDF=files_test2[i]
#       9     data_temp.append(BDF.x2)
#      10 for i in range(10):
#
# NameError: name 'files_test2' is not defined

# %%
plt.title("X QPD - averaged over 10 files")
plt.plot(freqs3_s,testshake_spsd_0,label="X=384um")
plt.plot(freqs3_s,testshake_spsd_1, label="X=374um")
plt.plot(freqs3_s,testshake_spsd_2,label="X=344um")
for i in np.arange(3,15,3):
    plt.axvline(i,color="red",linestyle="dotted",label="fundamental (%dHz)" %i)
plt.yscale("log")
plt.xlim(0,50)
plt.ylabel("PSD [a.u.]")
plt.xlabel("frequency [Hz]")
plt.legend()
plt.show()

# %%
files_test6 = load_dir("/data/new_trap/20200930/NoBead/SideSpin_Test/","TestShake6",max_file=100)
# Out:
# 100%|██████████| 11/11 [00:01<00:00,  9.61it/s]
# 11  files in folder
# 11  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
print(len(detrend_test))
for i in [3]:
    BDF=files_test6[i]
    data3 = BDF.xyz2
    data_det3=signal.detrend(data3)
    xpsd3, freqs3 = matplotlib.mlab.psd(data_det3[0], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor,window=matplotlib.mlab.window_none)
    sspsd5, freqs5_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor,window=matplotlib.mlab.window_none)
   # detrend_test = signal.detrend(BDF.spin_data[1])
    sspsd3, freqs3_ss = matplotlib.mlab.psd(detrend_test, Fs = fsamp*factor, NFFT = res*factor)
    #plt.loglog(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
    plt.loglog(freqs5_ss,sspsd5,label="without window_none")
    plt.loglog(freqs3_ss,sspsd3,label="with window_none")

    #plt.loglog(freqs3,xpsd3,label="X from QPD")
    #plt.xlim(1,1000)
    for i in np.arange(11,22,11):
        plt.axvline(i,color="red",linestyle="dotted",label="fundamental (11Hz)")
    plt.legend()
    plt.ylabel("PSD [a.u.]")
    plt.xlabel("frequency [Hz]")

    plt.show()
   
    #plt.show()
# Out:
# 499999

# %%
fsamp = 5000
res = 5000
factor=10
print(len(detrend_test))
for i in [3]:
    BDF=files_test6[i]
    data3 = BDF.xyz2
    data_det3=signal.detrend(data3)
    xpsd3, freqs3 = matplotlib.mlab.psd(data_det3[0], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)
    spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor,window=matplotlib.mlab.window_none)
    sspsd5, freqs5_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor,window=matplotlib.mlab.window_none)
   # detrend_test = signal.detrend(BDF.spin_data[1])
    sspsd3, freqs3_ss = matplotlib.mlab.psd(detrend_test, Fs = fsamp*factor, NFFT = res*factor)

# %%
fsamp = 5000
res = 5000
factor=10
data_temp=[]
data_temp2 = np.zeros(50000)
leng=5
for i in range(10):
    BDF=files_test2[i]
    data_temp.append(BDF.x2)
for i in range(10):
    data_temp2 = np.add(data_temp[i],data_temp2)
data3=data_temp2
data_det3=signal.detrend(data3)
xpsd3, freqs3 = matplotlib.mlab.psd(data_det3, Fs = fsamp, NFFT = res)
#ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
#zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
plt.plot(freqs3,xpsd3,label="X from QPD averaged over 10 files")
plt.xlim(1,50)
plt.yscale("log")
for i in np.arange(3,15,3):
    plt.axvline(i,color="red",linestyle="dotted",label="harmonic (%dHz)" %i)
plt.legend()
plt.ylabel("PSD [a.u.]")
plt.xlabel("frequency [Hz]")
plt.show()

    #plt.show()

# %%
files_shake_examp = load_dir("/data/new_trap/20200930/Bead1/Shaking/Shaking345/","ShakingNoSpin0",max_file=100)
# Out:
# ...
# 100%|██████████| 100/100 [00:09<00:00, 10.19it/s]
# 1000  files in folder
# 100  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in [4]:
    BDF=files_shake_examp[i]
    data3 = BDF.xyz2
    data_det3=signal.detrend(data3)
    xpsd3, freqs3 = matplotlib.mlab.psd(data_det3[0], Fs = fsamp, NFFT = res)
    ypsd3, freqs3 = matplotlib.mlab.psd(data_det3[1], Fs = fsamp, NFFT = res)
    zpsd3, freqs3 = matplotlib.mlab.psd(data_det3[2], Fs = fsamp, NFFT = res)
    spsd3, freqs3_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
    sspsd3, freqs3_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
    plt.plot(freqs3_s,spsd3,alpha=1, label="Top Spin PD")
    plt.plot(freqs3_ss,sspsd3,label="Side Spin PD")
    plt.plot(freqs3,xpsd3,label="X from QPD")
    plt.xscale("log")
    plt.xlim(1,25000)
    plt.yscale("log")
    for i in np.arange(3,15,3):
        plt.axvline(i,color="red",linestyle="dotted",label="harmonic (%dHz)" %i)
    plt.legend()
    plt.ylabel("PSD [a.u.]")
    plt.xlabel("frequency [Hz]")
    plt.show()
    #for i in np.arange(11,110,11):
    #    plt.axvline(i,color="red")
    #plt.show()

# %%
files_shake_examp2 = load_dir("/data/new_trap/20200924/Bead1/Shaking/Shaking345/","NoSpinShaking0",max_file=100)
# Out:
# ...
# 100%|██████████| 100/100 [00:08<00:00, 11.30it/s]
# 1000  files in folder
# 100  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in [12]:
    BDF=files_shake_examp2[i]
    data4 = BDF.xyz2
    data_det4=signal.detrend(data4)
    xpsd4, freqs4 = matplotlib.mlab.psd(data_det4[0], Fs = fsamp, NFFT = res)
    ypsd4, freqs4 = matplotlib.mlab.psd(data_det4[1], Fs = fsamp, NFFT = res)
    zpsd4, freqs4 = matplotlib.mlab.psd(data_det4[2], Fs = fsamp, NFFT = res)
    spsd4, freqs4_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor)
    sspsd4, freqs4_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor)
    plt.plot(freqs4_s,spsd4,alpha=1, label="Top Spin PD")
    plt.plot(freqs4_ss,sspsd4,label="Side Spin PD")
    plt.plot(freqs4,xpsd4,label="X from QPD")
    plt.xlim(1,500)
    plt.yscale("log")
    for i in np.arange(3,15,3):
        plt.axvline(i,color="red",linestyle="dotted",label="harmonic (%dHz)" %i)
    plt.legend()
    plt.ylabel("PSD [a.u.]")
    plt.xlabel("frequency [Hz]")
    plt.show()

# %%
files_no_shake_examp = load_dir("/data/new_trap/20200924/Bead1/Shaking/Shaking345/","NoSpinNoShaking0",max_file=100)
# Out:
# ...
# 100%|██████████| 100/100 [00:09<00:00, 11.53it/s]
# 1000  files in folder
# 100  files loaded

# %%
fsamp = 5000
res = 5000
factor=10
for i in [15]:
    BDF=files_no_shake_examp[i]
    data4 = BDF.xyz2
    data_det4=signal.detrend(data4)
    xpsd4, freqs4 = matplotlib.mlab.psd(data_det4[0], Fs = fsamp, NFFT = res,window="None")
    ypsd4, freqs4 = matplotlib.mlab.psd(data_det4[1], Fs = fsamp, NFFT = res,window="None")
    zpsd4, freqs4 = matplotlib.mlab.psd(data_det4[2], Fs = fsamp, NFFT = res,window="None")
    spsd4, freqs4_s = matplotlib.mlab.psd(BDF.spin_data[0], Fs = fsamp*factor,NFFT = res*factor,window="None")
    sspsd4, freqs4_ss = matplotlib.mlab.psd(BDF.spin_data[1], Fs = fsamp*factor, NFFT = res*factor,window="None")
    plt.plot(freqs4_s,spsd4,alpha=1, label="Top Spin PD")
    plt.plot(freqs4_ss,sspsd4,label="Side Spin PD")
    plt.plot(freqs4,xpsd4,label="X from QPD")
    #plt.xscale("log")
    plt.xlim(1,500)
    plt.yscale("log")
    for i in np.arange(3,15,3):
        plt.axvline(i,color="red",linestyle="dotted",label="harmonic (%dHz)" %i)
    plt.legend()
    plt.ylabel("PSD [a.u.]")
    plt.xlabel("frequency [Hz]")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-400-4bf1087de8c7> in <module>
#       6     data4 = BDF.xyz2
#       7     data_det4=signal.detrend(data4)
# ----> 8     xpsd4, freqs4 = matplotlib.mlab.psd(data_det4[0], Fs = fsamp, NFFT = res,window="None")
#       9     ypsd4, freqs4 = matplotlib.mlab.psd(data_det4[1], Fs = fsamp, NFFT = res,window="None")
#      10     zpsd4, freqs4 = matplotlib.mlab.psd(data_det4[2], Fs = fsamp, NFFT = res,window="None")
#
# ~/.local/lib/python3.6/site-packages/matplotlib/mlab.py in psd(x, NFFT, Fs, detrend, window, noverlap, pad_to, sides, scale_by_freq)
#     699     Pxx, freqs = csd(x=x, y=None, NFFT=NFFT, Fs=Fs, detrend=detrend,
#     700                      window=window, noverlap=noverlap, pad_to=pad_to,
# --> 701                      sides=sides, scale_by_freq=scale_by_freq)
#     702     return Pxx.real, freqs
# ...
