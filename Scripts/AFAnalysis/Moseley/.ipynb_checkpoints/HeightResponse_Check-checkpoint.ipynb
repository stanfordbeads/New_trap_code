# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
def load_reduced_lists(dirname,file_prefix,max_files,xfb=True,zfb = True,Iz=True,height=True,x_mean=True,y_mean=True,z_mean=True,qpd_sum=True):
    x_fb_list,z_fb_list, height_list,Iz_list,x_mean_list,y_mean_list,z_mean_list,qpd_sum_list= [ [] for x in range(8)]
    files = []
   
    [files.append(file_) for file_ in os.listdir(dirname) if file_.startswith(file_prefix) if file_.endswith('.h5')]
    files.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))        
    step_size = 100
    for j in tqdm(np.arange(0,max_files,step_size)):
        BDFs = [BDF.BeadDataFile(dirname+filename) for filename in files[j:j+step_size]]
        for k in range(len(BDFs)):
            if(xfb==True):
                x_fb_list.append(BDFs[k].feedback[0].mean())
            if(zfb==True):
                z_fb_list.append(BDFs[k].feedback[2].mean())
            if(Iz==True):
                Iz_list.append(au_to_power(BDFs[k].Iz.mean()))
            if(height==True):
                height_list.append(BDFs[k].bead_height)
            if(x_mean==True):
                x_mean_list.append(BDFs[k].x2.mean())
            if(y_mean==True):
                y_mean_list.append(BDFs[k].y2.mean())
            if(z_mean==True):
                z_mean_list.append(BDFs[k].z2.mean())
            if(qpd_sum==True):
                qpd_sum_list.append(BDFs[k].quad_sum.mean())                
    return x_fb_list,z_fb_list,Iz_list,height_list,x_mean_list,y_mean_list,z_mean_list,qpd_sum_list

# %%
dirname="/data/new_trap/20200930/Bead1/Discharge/FineDischarge/HeightResponseCheck/"
file_prefix="Discharge"

# %%
load_reduced_lists(dirname=dirname,file_prefix=file_prefix,max_files=10000,xfb=True,zfb = True,Iz=True,height=False,x_mean=True,y_mean=True,z_mean=True,qpd_sum=True):

# %%
t= np.load("time_height_response_check.npy")

# %%
h=  np.load("height_height_response_check.npy")

# %%
in_phase = []
# load the files
for i in np.arange(0,3765,15):
    files_discharge = load_dir_sorted(dirname=dirname, 
                             start_file=i, max_file=15)

    # set the drive and settings for the correlation
    fdrive=71
    nsamp = 50000
    fsamp = 5000
    sigamp = 1
    tarr = np.arange(0, nsamp/fsamp, 1.0/fsamp)
    sig = sigamp * np.sin(2.0 * np.pi * fdrive * tarr)

    # get the in-phase response z
    corrs = [correlation(drive=sig, response=files.z2, fsamp=fsamp, fdrive=fdrive, filt=True, band_width=1) for files in tqdm(files_discharge)]
    indices = [np.argmax(cc) for cc in corrs]
    for cc in corrs:
        in_phase.append(cc[0])
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 195.28it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.24it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.58it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.05it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.59it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.47it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.35it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.73it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 203.66it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.57it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 198.68it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.60it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.52it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.60it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 204.17it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 204.34it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.72it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.90it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.86it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.73it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.09it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 198.70it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.77it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.96it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.23it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.39it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.88it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.15it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.43it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.37it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.69it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.35it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.66it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.77it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 203.95it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.06it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 186.18it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.20it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.74it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 188.13it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.24it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.35it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.97it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.08it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.75it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.89it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.37it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.92it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.80it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.80it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.17it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.91it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.66it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 204.35it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.61it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.42it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.33it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.29it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 198.54it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.48it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.25it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.90it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.93it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.57it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.56it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.90it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 187.80it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.84it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.05it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.12it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.45it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.22it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.75it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.72it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.93it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.98it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.29it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 186.43it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.22it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.63it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.22it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 198.59it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.25it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.87it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.89it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.91it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.39it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.36it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.07it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.54it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.63it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.65it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.06it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.46it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.77it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.50it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.48it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 204.11it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 204.55it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.70it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 197.80it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 198.29it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.50it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 163.39it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.58it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.45it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.70it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.52it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.40it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.11it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 187.86it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.44it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.41it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.11it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 197.37it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.59it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.30it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.84it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.47it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 186.68it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.32it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 188.21it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 172.61it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 170.76it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.62it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 175.45it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.51it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.94it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.79it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 181.34it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 188.84it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 203.27it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 184.62it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 182.98it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.38it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.76it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 197.06it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.92it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 182.54it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.23it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.86it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.86it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.91it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.99it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 203.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.11it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.67it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.18it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 186.67it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.64it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 203.11it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.25it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.89it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 184.93it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.77it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.04it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 188.68it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.41it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.64it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.75it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.77it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 188.32it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 204.12it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.77it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 183.84it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.07it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.88it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.16it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.89it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.94it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 203.43it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 187.74it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 186.09it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.71it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.77it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.66it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.68it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.85it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.67it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.94it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.20it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 187.96it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.08it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.74it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.74it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 180.98it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 178.08it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.57it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.01it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.26it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.32it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.04it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.82it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.74it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.35it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 190.36it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 203.21it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 201.39it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 183.78it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.05it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 188.63it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.90it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.49it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.42it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 181.94it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 188.76it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 187.69it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.56it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.69it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 198.68it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.34it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.08it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.05it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.45it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.72it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 187.68it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.62it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.67it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.58it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.51it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 197.00it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.46it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 187.27it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 185.80it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 197.36it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.94it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 194.61it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 175.95it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 193.75it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.87it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.83it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.11it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 192.83it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.33it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.75it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 191.93it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 202.55it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 199.43it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.55it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 162.20it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 185.83it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 200.09it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 196.46it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 195.63it/s]
# 3765  files in folder
# 15  files loaded
# 100%|██████████| 15/15 [00:00<00:00, 189.76it/s]
# 3765  files in folder
# 15  files loaded

# %%
#np.save("in_phase_z.npy",in_phase)
in_phase = np.load("in_phase_z.npy")

# %%
plt.plot(t,in_phase)
plt.plot(t,h)

# %%
df=pd.DataFrame()
df["Time_Epoch"] =t 
df["Height"] =h
df["Response"]=in_phase

# %%
# assume for same year and same month, it can have multiple days. get those
dt.datetime.fromtimestamp(df["Time_Epoch"][0])
year = dt.datetime.fromtimestamp(df["Time_Epoch"][0]).year
month = dt.datetime.fromtimestamp(df["Time_Epoch"][0]).month
#months = []
#months = set(months)
days = []
days = set(days)
for i in range(len(df)):
    days.add(dt.datetime.fromtimestamp(df["Time_Epoch"][i]).day)
    #months.add(dt.datetime.fromtimestamp(df["Time_Epoch"][i]).month)
print(days)
# Out:
# {1, 30}

# %%
plt.plot(df.Height/np.mean(df.Height))
plt.plot(df.Response/np.mean(df.Response))

# %%
days=[30]
bead_date=20200930
bead_number=1
# prepare the files to match the time stamp to extract the environmental data
fnw = []
month=9
for day in days:
    env_file = "/data/new_trap_processed/processed_files/{0}/Bead{1}/EnvData/{2}{3}{4}/wavemeter_data_{2}{3}{4}.pkl".format(bead_date,bead_number,year,str(month).zfill(2),str(day).zfill(2))
    fnw.append(env_file)
month=10
days=[1]
for day in days:
    env_file = "/data/new_trap_processed/processed_files/{0}/Bead{1}/EnvData/{2}{3}{4}/wavemeter_data_{2}{3}{4}.pkl".format(bead_date,bead_number,year,str(month).zfill(2),str(day).zfill(2))
    fnw.append(env_file)
    
df_temp_list = []
df_temp_list.extend([pd.read_pickle(f) for f in fnw]) # read the files in
df_temp = pd.concat([df_tempi for df_tempi in df_temp_list]).reset_index() # merge the dataframes, you can merge as much as you want since later the time stamps are anyway used. But maybe stay efficient, will ya?
wave_length,laser_freq,time_stamp_wm,values = [[] for i in range(4)]
for elements in tqdm(range(len(df))): # fun fact: faster than all the possible apply methods. Tried a lot but this is best. DO NOT PARLLELIZE with joblib
    values = df_temp.iloc[(df_temp['TIMESTAMP_WM_EPOCH']-df["Time_Epoch"][elements]).abs().argsort()[:1]][['WAVE_LENGTH','LASER_FREQ','TIMESTAMP_WM_EPOCH']].values[0]   # this one subtracts the time_epoch of the data set from the entire column and gets the minimum. Afterwards it adds it if the time difference is less than 10 seconds.
   # print(np.abs(values[2]-df["Time_Epoch"][elements]))
    #print(values[2])
    #print(df["Time_Epoch"][elements])
    if(np.abs(values[2]-df["Time_Epoch"][elements])<10):
        wave_length.append(values[0])
        laser_freq.append(values[1])
        time_stamp_wm.append(values[2])
    else:
        print("Time difference is to big!")
        wave_length.append(0)
        laser_freq.append(0)
        time_stamp_wm.append(values[2])
df["Wave_Length"] = wave_length
df["Time_Stamp_WN"] = time_stamp_wm
# Out:
#  26%|██▌       | 987/3765 [04:49<12:17,  3.77it/s]
# Time difference is to big!
#  26%|██▌       | 988/3765 [04:50<12:22,  3.74it/s]
# Time difference is to big!
#  26%|██▋       | 989/3765 [04:50<12:24,  3.73it/s]
# Time difference is to big!
# 100%|██████████| 3765/3765 [14:39<00:00,  6.87it/s]

# %%
plt.plot(df.Time_Stamp_WN,marker="*",linestyle="")
plt.plot(wvm.TIMESTAMP_WM_EPOCH,marker="*",linestyle="")

# %%
plt.plot(wvm.TIMESTAMP_WM_EPOCH-wvm.TIMESTAMP_WM_EPOCH[0]+wvm.TIMESTAMP_WM_EPOCH[0]-1601524575.342324,wvm.WAVE_LENGTH)
plt.plot(df.Time_Epoch-df.Time_Epoch[0],df.Wave_Length)
plt.ylim(1064.525,1064.53)
# Out:
# (1064.525, 1064.53)

# %%
plt.plot(df.Time_Epoch-df.Time_Epoch[0],df.Height,linestyle="",marker="*")
plt.plot(df.Time_Epoch-df.Time_Epoch[0],(df.Wave_Length-np.mean(df.Wave_Length)),linestyle="",marker="*")
plt.ylim(-15,15)
#plt.xlim(37800,38000)
    #plt.plot(df.Time_Epoch,df.Height)
# Out:
# (-15.0, 15.0)

# %%
file = 1
x = df.Time_Epoch-df.Time_Epoch[0]
avg = 1
data1=df.Height.ewm(span=avg,adjust=True).mean()
data2=df.Wave_Length.ewm(span=avg,adjust=True).mean()
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_title("height vs wave_length")
ax1.set_xlabel('time (s)')
ax1.set_ylabel("Height [um]", color=color)
ax1.plot(x,data1, color=color, alpha=0.5,linestyle="",marker="$H$",markersize=15)
#ax1.set_xlim(35000,)
    
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('$\lambda$ [nm]', color=color)  # we already handled the x-label with ax1
ax2.plot(x,data2, color=color, alpha=0.5,linestyle="",marker="$\lambda$",markersize=15)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(np.mean(data2)+0.847,np.mean(data2)+0.85)    

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
file = 1
x = df.Time_Epoch

data1=df.Response.ewm(span=100,adjust=True).mean()
data2=df.Wave_Length.ewm(span=1,adjust=True).mean()
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_title("response vs wave length")
ax1.set_xlabel('time (s)')
ax1.set_ylabel("Z Response [a.u.]", color=color)
ax1.plot(x,data1, color=color, alpha=0.5,linestyle="",marker="$X3$",markersize=15)

    
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('$\lambda$ [nm]', color=color)  # we already handled the x-label with ax1
ax2.plot(x,data2, color=color, alpha=0.5,linestyle="",marker="$P$",markersize=15)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(np.mean(data2)+0.847,np.mean(data2)+0.85)    

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
file = 1
x = df.Time_Epoch
data1=df.Height.ewm(span=1,adjust=True).mean()
data2=df.Response.ewm(span=100,adjust=True).mean()
fig, ax1 = plt.subplots()
color = 'tab:red'

ax1.set_title("height vs response")
ax1.set_xlabel('time (s)')
ax1.set_ylabel("Height [um]", color=color)
ax1.plot(x,data1, color=color, alpha=0.5,linestyle="",marker="$X3$",markersize=15)

    
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('z response [a.u.]', color=color)  # we already handled the x-label with ax1
ax2.plot(x,data2, color=color, alpha=0.5,linestyle="",marker="$P$",markersize=15)
ax2.tick_params(axis='y', labelcolor=color)
#ax2.set_ylim(np.mean(data2)+0.847,np.mean(data2)+0.85)    

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
df.Height.corr(df.Wave_Length)
# Out:
# -0.019878448762031486

# %%
df.Response.corr(df.Wave_Length)
# Out:
# 0.010031603629854113

# %%
df=pd.DataFrame()    
year=2020
month=9
days=[25,26,27,28,29,30]
bead_date=20200924
bead_number=1
# prepare the files to match the time stamp to extract the environmental data
fnw = []
month=9
for day in days:
    df_temp=pd.DataFrame()
    wvm = np.load("/data/new_trap_processed/processed_files/{0}/Bead{1}/EnvData/{2}{3}{4}/wavemeter_data_{2}{3}{4}.pkl".format(bead_date,bead_number,year,str(month).zfill(2),str(day).zfill(2)),allow_pickle=True)
    df_temp = wvm
    df=pd.concat([df,df_temp])
bead_date=20200930
bead_number=1  
month=10
days=[1]
for day in days:
    df_temp=pd.DataFrame()
    wvm = np.load("/data/new_trap_processed/processed_files/{0}/Bead{1}/EnvData/{2}{3}{4}/wavemeter_data_{2}{3}{4}.pkl".format(bead_date,bead_number,year,str(month).zfill(2),str(day).zfill(2)),allow_pickle=True)
    df_temp = wvm
    df=pd.concat([df,df_temp])

# %%
df = df.reset_index()
df = df[df.WAVE_LENGTH>1064]
df["MEASUREMENT_TIME"] = df.TIMESTAMP_WM_EPOCH-df.TIMESTAMP_WM_EPOCH[0]

# %%
plt.plot(df.TIMESTAMP_WM_EPOCH,linestyle="dashed")

# %%
plt.plot(df.MEASUREMENT_TIME,df.WAVE_LENGTH,linestyle='dashed')
plt.xlabel("Time [s]")
plt.ylabel("$\lambda$ [nm]")
plt.axvspan(t[0]-df.TIMESTAMP_WM_EPOCH[0],t[-1]-df.TIMESTAMP_WM_EPOCH[0],alpha=0.5,label="Moseley",color="red")
plt.ylim(1064.525,1064.533)
plt.show()

# %%
plt.plot(df.WAVE_LENGTH.ewm(span=100000,adjust=True).mean())

# %%
t= np.load("time_height_response_check.npy")

# %%
dt.datetime.fromtimestamp(df.TIMESTAMP_WM_EPOCH[0])
# Out:
# datetime.datetime(2020, 9, 25, 16, 53, 0, 44011)
