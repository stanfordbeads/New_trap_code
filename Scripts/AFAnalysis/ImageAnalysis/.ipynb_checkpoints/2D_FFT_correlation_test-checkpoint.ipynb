# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (12,9)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

from skimage import data
from skimage.registration import phase_cross_correlation
from skimage.registration._phase_cross_correlation import _upsampled_dft
from scipy.ndimage import fourier_shift

# %%
# load the files 
bead_date =20200713
bead_number = 1
dataset = "/Millicharge/WithSpin0714/"
FOI = "Discharge*"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset + "Pictures/"
filename = dirname + FOI

# %%
images =  load_npy_files(dirname+FOI,max_files=10)
# Out:
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_0.npy 0
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_1.npy 1
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_2.npy 2
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_3.npy 3
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_4.npy 4
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_5.npy 5
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_6.npy 6
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_7.npy 7
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_8.npy 8
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_9.npy 9

# %%
# make a set of offset images with random generation but store the true information
shift_list=[]
offset_images=[]

for i in tqdm(range(10)):
    image = images[0]
    shift = (1/1000*np.random.randn(),1/10*np.random.randn())
    shift_list.append(shift[0])
    offset_image = fourier_shift(np.fft.fftn(image), shift)
    offset_image = np.fft.ifftn(offset_image)
    offset_images.append(offset_image)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#  10%|█         | 1/10 [00:00<00:01,  5.14it/s]
#
#  20%|██        | 2/10 [00:00<00:01,  4.67it/s]
#
#  30%|███       | 3/10 [00:00<00:01,  4.28it/s]
#
#  40%|████      | 4/10 [00:00<00:01,  4.15it/s]
#
#  50%|█████     | 5/10 [00:01<00:01,  4.00it/s]
#
#  60%|██████    | 6/10 [00:01<00:01,  3.94it/s]
#
#  70%|███████   | 7/10 [00:01<00:00,  3.85it/s]
#
#  80%|████████  | 8/10 [00:02<00:00,  3.82it/s]
#
#  90%|█████████ | 9/10 [00:02<00:00,  3.77it/s]
#
# 100%|██████████| 10/10 [00:02<00:00,  3.78it/s]

# %%
start = time.time()
shift_z = []
argmax = []
gaus_list = []
image = images[0]
g = gaussian_bead_pos_fit(image,axis=0,low_x_lim=500,up_x_lim=700,low_y_lim=420,up_y_lim=550,upper_area=1000,up_lim_width=12)
for offset_image in offset_images:
    gfit = gaussian_bead_pos_fit(np.real(offset_image),axis=0,low_x_lim=500,up_x_lim=700,low_y_lim=420,up_y_lim=550,upper_area=1000,up_lim_width=12)
    gaus_list.append(g[1].values['mean']-gfit[1].values['mean'])
   # print(f"Detected pixel offset (y, x): {shift}")
    argmax.append(np.argmax(np.mean(image,axis=1))-np.argmax(np.mean(np.real(offset_image),axis=1)))
    # subpixel precision
    shift, error, diffphase = phase_cross_correlation(image, offset_image,
                                                      upsample_factor=10000)
    shift_z.append(shift[0])
end = time.time()
print(end-start)
# Out:
# 102.83619236946106

# %%
plt.plot(shift_z,linestyle="",marker="$PC$", label = "2D FFT PC")
plt.plot(argmax,linestyle="",marker="$AM$",label = "argmax")
plt.plot(gaus_list,linestyle="",marker="$G$",label ="1D Gaussian")

plt.plot(np.multiply(-1,shift_list),label="true value")
plt.ylabel("shift [pixel]")
plt.xlabel("sample")
plt.legend()
plt.show()

# %%
# now load an image series and see what happens

images_series =  load_npy_files(dirname+FOI,max_files=100)
# Out:
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_0.npy 0
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_1.npy 1
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_2.npy 2
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_3.npy 3
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_4.npy 4
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_5.npy 5
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_6.npy 6
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_7.npy 7
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_8.npy 8
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_9.npy 9
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_10.npy 10
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_11.npy 11
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_12.npy 12
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_13.npy 13
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_14.npy 14
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_15.npy 15
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_16.npy 16
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_17.npy 17
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_18.npy 18
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_19.npy 19
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_20.npy 20
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_21.npy 21
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_22.npy 22
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_23.npy 23
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_24.npy 24
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_25.npy 25
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_26.npy 26
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_27.npy 27
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_28.npy 28
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_29.npy 29
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_30.npy 30
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_31.npy 31
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_32.npy 32
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_33.npy 33
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_34.npy 34
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_35.npy 35
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_36.npy 36
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_37.npy 37
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_38.npy 38
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_39.npy 39
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_40.npy 40
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_41.npy 41
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_42.npy 42
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_43.npy 43
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_44.npy 44
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_45.npy 45
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_46.npy 46
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_47.npy 47
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_48.npy 48
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_49.npy 49
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_50.npy 50
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_51.npy 51
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_52.npy 52
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_53.npy 53
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_54.npy 54
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_55.npy 55
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_56.npy 56
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_57.npy 57
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_58.npy 58
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_59.npy 59
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_60.npy 60
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_61.npy 61
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_62.npy 62
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_63.npy 63
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_64.npy 64
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_65.npy 65
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_66.npy 66
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_67.npy 67
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_68.npy 68
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_69.npy 69
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_70.npy 70
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_71.npy 71
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_72.npy 72
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_73.npy 73
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_74.npy 74
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_75.npy 75
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_76.npy 76
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_77.npy 77
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_78.npy 78
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_79.npy 79
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_80.npy 80
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_81.npy 81
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_82.npy 82
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_83.npy 83
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_84.npy 84
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_85.npy 85
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_86.npy 86
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_87.npy 87
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_88.npy 88
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_89.npy 89
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_90.npy 90
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_91.npy 91
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_92.npy 92
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_93.npy 93
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_94.npy 94
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_95.npy 95
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_96.npy 96
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_97.npy 97
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_98.npy 98
# /data/new_trap/20200713/Bead1//Millicharge/WithSpin0714/Pictures/Discharge_99.npy 99

# %%
start = time.time()
shift_z = []
argmax = []
gaus_list = []
image = images_series[0]
g = gaussian_bead_pos_fit(image,axis=0,low_x_lim=500,up_x_lim=700,low_y_lim=420,up_y_lim=550,upper_area=1000,up_lim_width=12)
for images in images_series:
    gfit = gaussian_bead_pos_fit(images,axis=0,low_x_lim=500,up_x_lim=700,low_y_lim=420,up_y_lim=550,upper_area=1000,up_lim_width=12)
    gaus_list.append(g[1].values['mean']-gfit[1].values['mean'])
   # print(f"Detected pixel offset (y, x): {shift}")
    argmax.append(np.argmax(np.mean(image,axis=1))-np.argmax(np.mean(images,axis=1)))
    # subpixel precision
    shift, error, diffphase = phase_cross_correlation(image, images,
                                                      upsample_factor=1000)
    shift_z.append(shift[0])
end = time.time()
print(end-start)
# Out:
# 56.72544074058533

# %%
plt.plot(shift_z,linestyle="",marker="$PC$", label = "2D FFT PC")
plt.plot(argmax,linestyle="",marker="$AM$",label = "argmax")
plt.plot(gaus_list,linestyle="",marker="$G$",label ="1D Gaussian")

plt.ylabel("shift [pixel]")
plt.xlabel("sample")
plt.legend()
plt.show()

# %%
"/data/new_trap/20200614/Bead1/Shaking/NoAttractorNoShaking4"

# %%
# load the files 
bead_date =20200614
bead_number = 1
dataset = "Shaking/"
FOI = "NoAttractorNoShaking4*"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset + "Pictures_0/"
filename = dirname + FOI

# %%
images_shadow =  load_npy_files(dirname+FOI,max_files=100)
# Out:
# /data/new_trap/20200614/Bead1/Shaking/Pictures_0/NoAttractorNoShaking4
#  40%|████      | 10/25 [00:01<00:02,  5.36it/s]
#
#  44%|████▍     | 11/25 [00:02<00:02,  5.41it/s]
#
#  48%|████▊     | 12/25 [00:02<00:02,  5.38it/s]
#
#  52%|█████▏    | 13/25 [00:02<00:02,  5.41it/s]
#
#  56%|█████▌    | 14/25 [00:02<00:02,  5.38it/s]
#
#  60%|██████    | 15/25 [00:02<00:01,  5.43it/s]
#
#  64%|██████▍   | 16/25 [00:02<00:01,  5.40it/s]
#
#  68%|██████▊   | 17/25 [00:03<00:01,  5.41it/s]
#
#  72%|███████▏  | 18/25 [00:03<00:01,  5.40it/s]
#
#  76%|███████▌  | 19/25 [00:03<00:01,  5.43it/s]
#
#  80%|████████  | 20/25 [00:03<00:00,  5.39it/s]
#
#  84%|████████▍ | 21/25 [00:03<00:00,  5.46it/s]
#
#  88%|████████▊ | 22/25 [00:04<00:00,  5.44it/s]
#
#  92%|█████████▏| 23/25 [00:04<00:00,  5.48it/s]
#
#  96%|█████████▌| 24/25 [00:04<00:00,  5.44it/s]
#
# 100%|██████████| 25/25 [00:04<00:00,  5.45it/s]

# %%
start = time.time()
shift_z = []
argmax = []
gaus_list = []
image = images[0]
m0 = from_shadow_image_to_height(image,170,area_low_limits=[650,730],area_widths=[45,70],plot=False,flb=450)
for offset_image in offset_images:
    mean, m = from_shadow_image_to_height(offset_image,170,area_low_limits=[650,730],area_widths=[45,70],plot=False,flb=450)
    #plt.show()
    gaus_list.append(mean-m0)   
    #argmax.append(np.argmax(np.mean(image,axis=1))-np.argmax(np.mean(np.real(offset_image),axis=1)))
    # subpixel precision
    shift, error, diffphase = phase_cross_correlation(image, offset_image,
                                                      upsample_factor=10000)
    shift_z.append(shift[0])
end = time.time()
print(end-start)

# %%
df_H = np.load("/data/new_trap_processed/processed_files/20200614/Bead1/Shaking/NoAttractorNoShaking4_aux.pkl",allow_pickle=True)

# %%
start = time.time()
shift_z = []
argmax = []
gaus_list = []
image = images_shadow[0]
g = gaussian_bead_pos_fit(image,axis=0,low_x_lim=500,up_x_lim=700,low_y_lim=420,up_y_lim=550,upper_area=1000,up_lim_width=12)
for images in images_shadow:
    gfit = gaussian_bead_pos_fit(images,axis=0,low_x_lim=500,up_x_lim=700,low_y_lim=420,up_y_lim=550,upper_area=1000,up_lim_width=12)
    mean, m = from_shadow_image_to_height(images,170,area_low_limits=[650,730],area_widths=[45,70],plot=False,flb=450)
    #plt.show()
    gaus_list.append(mean)
   # print(f"Detected pixel offset (y, x): {shift}")
    argmax.append(np.argmax(np.mean(image,axis=1))-np.argmax(np.mean(images,axis=1)))
    # subpixel precision
    shift, error, diffphase = phase_cross_correlation(image, images,
                                                      upsample_factor=1000)
    shift_z.append(shift[0])
end = time.time()
print(end-start)
# Out:
# 17.693644046783447

# %%
plt.plot(shift_z,linestyle="",marker="$PC$", label = "2D FFT PC")
plt.plot(np.subtract(gaus_list,gaus_list[0]),linestyle="",marker="$G$",label ="1D Gaussian")
#plt.plot(df_H.height_raw[0:100]-df_H.height_raw[0],linestyle="",marker="$H$")
plt.ylabel("shift [pixel]")
plt.xlabel("sample")
plt.legend()
plt.show()
