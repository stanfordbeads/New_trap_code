# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (12,9)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# load the fileas 
bead_date =20200716
bead_number = 7
dataset = "/HeightPictures/TrapHeight"
FOI = "*"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
filename = dirname + FOI

# %%
t = load_img_files(filename)
# Out:
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/202007161438.bmp 0
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/2502007161523.bmp 1
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/m12_85mV_25kOhm_20200716.bmp 2
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/m11_106mV_25kOhm_20200716.bmp 3
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/m132_65mV_25kOhm_20200716.bmp 4
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/m85_190mv25kohm_20200716.bmp 5
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/m105_120mV_25kohm_20200716.bmp 6
# /data/new_trap/20200716/Bead7//HeightPictures/TrapHeight/m132_65mV_25kOhm_-500kzset_20200716_1252.bmp 7

# %%
plt.imshow(new+t[])
