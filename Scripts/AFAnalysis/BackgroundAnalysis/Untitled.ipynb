# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
#%matplotlib widget, remove below if used
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
dirname="/data/new_trap/20210317/Bead1/Discharge/ShortNeutrality/"
normfile = load_dir_sorted(dirname, file_prefix = 'Discharge_',start_file=0, max_file=500)
# Out:
# 99  files in folder
# 99  files loaded

# %%
dirname="/data/new_trap/20210317/Bead1/Discharge/FineDischarge/"
normfile = load_dir_sorted(dirname, file_prefix = 'Discharge_265',start_file=0, max_file=500)

# %%
normsum = 0
for elements in range(99):
        normsum+=normfile[elements].x2

# %%
plt.plot(normfile[3].x2)

# %%
data_det=data_det1=signal.detrend(normfile[0].x2)
fsamp=5000
res=50000
normpsd, normfreqs = matplotlib.mlab.psd(data_det, Fs = fsamp, NFFT = res)

# %%
dirname="/data/new_trap/20210317/Bead1/Shaking/"
first_shake = load_dir_sorted(dirname, file_prefix = 'ShakeNoAttr0',start_file=0, max_file=500)
# Out:
# 6  files in folder
# 6  files loaded

# %%
# 3 is bad apparently
data_det1=data_det1=signal.detrend(first_shake[1].x2)
fsamp=5000
res=50000
xpsd1, freqs1 = matplotlib.mlab.psd(data_det1, Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)

# %%
dirname="/data/new_trap/20210317/Bead1/Shaking/"
second_shake = load_dir_sorted(dirname, file_prefix = 'ShakeNoAttr1',start_file=0, max_file=500)
# Out:
# 6  files in folder
# 6  files loaded

# %%
# 3 is bad apparently
data_det2=signal.detrend(second_shake[5].x2)
fsamp=5000
res=50000
xpsd2, freqs2 = matplotlib.mlab.psd(data_det2, Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)

# %%
plt.plot(freqs1,xpsd1,label="10s shaking 3 Hz 50um stroke")
plt.plot(freqs2,xpsd2,label="10s shaking 3 Hz, 100um stroke")
plt.plot(normfreqs,normpsd,label="no_shaking")
plt.yscale("log")
plt.ylim(1e-14,1e-6)
plt.xlim(0,100)
plt.legend()
plt.xlabel("frequency [Hz]")
plt.ylabel("x psd [a.u]")
plt.show()

# %%
dirname="/data/new_trap/20210317/Bead1/Shaking/"
third_shake = load_dir_sorted(dirname, file_prefix = 'ShakeNoAttr2',start_file=0, max_file=500)
# Out:
# 6  files in folder
# 6  files loaded

# %%
# 3 is bad apparently
data_det3=signal.detrend(third_shake[4].x2)
fsamp=5000
res=50000
xpsd3, freqs3 = matplotlib.mlab.psd(data_det3, Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)

# %%
plt.plot(freqs3,xpsd3,label="10s shaking 13 Hz no servo ")
plt.plot(normfreqs,normpsd,label="no_shaking")
plt.yscale("log")
plt.xlim(0,100)
plt.ylim(1e-14,1e-6)
plt.legend()
plt.xlabel("frequency [Hz]")
plt.ylabel("x psd [a.u]")
plt.show()

# %%
plt.plot(freqs3,xpsd3,label="10s shaking 13 Hz no servo ")
plt.plot(normfreqs,normpsd,label="no_shaking")
plt.yscale("log")
plt.xlim(0,400)
plt.ylim(1e-14,1e-5)
plt.legend()
plt.xlabel("frequency [Hz]")
plt.ylabel("x psd [a.u]")
plt.show()

# %%
dirname="/data/new_trap/20210317/Bead1/Shaking/"
fourth_shake = load_dir_sorted(dirname, file_prefix = 'ShakeNoAttrlong',start_file=0, max_file=40)
# Out:
# 36  files in folder
# 36  files loaded

# %%
longsum = 0
for elements in range(30):
        longsum+=fourth_shake[elements].x2

# %%
# 3 is bad apparently
data_det_long=signal.detrend(longsum)
fsamp=5000
res=50000
xpsd_long, freqs_long = matplotlib.mlab.psd(data_det_long, Fs = fsamp, NFFT = res,window=matplotlib.mlab.window_none)

# %%
#test= np.abs(np.fft.rfft(data_det_long))
#x=np.arange(0,2500.1,0.1)

# %%
plt.plot(freqs_long,xpsd_long/30,label="300s shaking, 3 Hz, 100 um, servo on")
#plt.plot(freqs2,xpsd2,label="10s shaking 3 Hz, 100um stroke")
plt.plot(normfreqs,normpsd,label="no_shaking")
#plt.plot(x,test/5000**2)
plt.yscale("log")
plt.xlim(0,40)
plt.ylim(1e-14,1e-5)
plt.legend()
plt.show()

# %%
plt.plot(fourth_shake[33].xyz[2],marker="$P$")
plt.ylim(-305000,-296000)
# Out:
# (-305000.0, -296000.0)
