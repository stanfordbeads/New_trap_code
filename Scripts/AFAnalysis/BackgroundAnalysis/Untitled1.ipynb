# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
def make_psd_self(data_in,fsamp,res):
    data_det=signal.detrend(data_in)
    res = res
    fsamp = fsamp # stays hard coded for now
    freqs=np.linspace(0,int(fsamp/2),(int(res/2))+1)    # change
    xFFT=np.fft.rfft(data_det)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    xphase=np.angle(xFFT)
    return freqs,xpsd,xphase

# %%
# discharge10 not on, discharge11 on with battery adapter, discharge12 on with tapping
#discharge13 not on batteries in, discharge14 on, discharge15 on with tapping
folder="/home/data_transfer/data_from_windows/20210506/SeismoMeas/"
file=folder+"Discharge_13.h5"
BDF_b=BeadDataFile.BeadDataFile(file)
file2=folder+"Discharge_14.h5"
BDF_b2=BeadDataFile.BeadDataFile(file2)
file3=folder+"Discharge_15.h5"
BDF_b3=BeadDataFile.BeadDataFile(file3)

# %%
plt.plot(BDF_b.seismometer)
plt.plot(BDF_b2.seismometer)
plt.plot(BDF_b3.seismometer,alpha=0.5)

# %%
f,x,xp = make_psd_self(BDF_b.seismometer,fsamp=5000,res=50000)
f,x2,xp = make_psd_self(BDF_b2.seismometer,fsamp=5000,res=50000)
f,x3,xp = make_psd_self(BDF_b3.seismometer,fsamp=5000,res=50000)

# %%
plt.plot(f,x)
plt.plot(f,x2)
plt.plot(f,x3)
plt.yscale("log")
plt.xlim(0,2000)
#plt.xlim(600,700)
plt.ylim(1e-21,1)
plt.show()

# %%
f,x,xp = make_psd_self(BDF_b.seismometer,fsamp=5000,res=50000)
f,x2,xp = make_psd_self(BDF_b2.seismometer,fsamp=5000,res=50000)
f,x3,xp = make_psd_self(BDF_b3.seismometer,fsamp=5000,res=50000)

# %%
plt.plot(f,x)
plt.plot(f,x2)
plt.plot(f,x3)
plt.yscale("log")
plt.xlim(0,2000)
plt.xlim(1,700)
plt.ylim(1e-21,1)
plt.show()
