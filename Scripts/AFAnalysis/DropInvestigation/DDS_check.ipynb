# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
import tables
#%matplotlib widget, remove below if used
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
z_dds_off = []
for i in tqdm(range(1395)):
    with tables.File('/data/new_trap/20210224/Discharge_%d.h5' %i,'r') as h5f:
        z_dds_off.append(h5f.root.quad_data.read().reshape(-1,12).T[5:10][4])
zmeans = [np.mean(z_dds_off[i]) for i in range(len(z_dds_off))]
zstd  = [np.std(z_dds_off[i]) for i in range(len(z_dds_off))]        
zstd_detrend  = [np.std(signal.detrend(z_dds_off[i])) for i in range(len(z_dds_off))]
# Out:
# 100%|██████████| 1395/1395 [00:01<00:00, 789.56it/s]

# %%
plt.plot(zstd)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std [bits]")
plt.show()
plt.plot(zstd_detrend)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std after detrend [bits]")
plt.show()

# %%
z_dds_min_off = []
for i in tqdm(range(99)):
    with tables.File('/data/new_trap/20210224/Run3/Discharge_%d.h5' %(i),'r') as h5f:
        z_dds_min_off.append(h5f.root.quad_data.read().reshape(-1,12).T[5:10][4])
zmeans = [np.mean(z_dds_min_off[i]) for i in range(len(z_dds_min_off))]
zstd  = [np.std(z_dds_min_off[i]) for i in range(len(z_dds_min_off))]        
zstd_detrend  = [np.std(signal.detrend(z_dds_min_off[i])) for i in range(len(z_dds_min_off))]
# Out:
# 100%|██████████| 99/99 [00:03<00:00, 27.23it/s]

# %%
plt.plot(zstd)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std [bits]")
plt.show()
plt.plot(zstd_detrend)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std after detrend [bits]")
plt.show()

# %%
z_srs_min_off = []
for i in tqdm(range(99)):
    with tables.File('/data/new_trap/20210224/Run2/SRS_off/Discharge_%d.h5' %i,'r') as h5f:
        z_srs_min_off.append(h5f.root.quad_data.read().reshape(-1,12).T[5:10][4])
zmeans = [np.mean(z_srs_min_off[i]) for i in range(len(z_srs_min_off))]
zstd  = [np.std(z_srs_min_off[i]) for i in range(len(z_srs_min_off))]        
zstd_detrend  = [np.std(signal.detrend(z_srs_min_off[i])) for i in range(len(z_srs_min_off))]
# Out:
# 100%|██████████| 99/99 [00:03<00:00, 26.96it/s]

# %%
plt.plot(zstd)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std [bits]")
plt.show()
plt.plot(zstd_detrend)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std after detrend [bits]")
plt.show()

# %%
z_srs = []
for i in tqdm(range(99)):
    with tables.File('/data/new_trap/20210224/Run2/SRS_125kHz/Discharge_%d.h5' %i,'r') as h5f:
        z_srs.append(h5f.root.quad_data.read().reshape(-1,12).T[5:10][4])
zmeans = [np.mean(z_srs[i]) for i in range(len(z_srs))]
zstd  = [np.std(z_srs[i]) for i in range(len(z_srs))]        
zstd_detrend  = [np.std(signal.detrend(z_srs[i])) for i in range(len(z_srs))]
# Out:
# 100%|██████████| 99/99 [00:03<00:00, 25.45it/s]

# %%
plt.plot(zstd)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std [bits]")
plt.show()
plt.plot(zstd_detrend)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std after detrend [bits]")
plt.show()

# %%
z_dds_min_off_long = []
for i in tqdm(range(2998)):
    with tables.File('/data/new_trap/20210224/Run4/Discharge_%d.h5' %(i),'r') as h5f:
        z_dds_min_off_long.append(h5f.root.quad_data.read().reshape(-1,12).T[5:10][4])
zmean = [np.mean(z_dds_min_off_long[i]) for i in range(len(z_dds_min_off_long))]
zstd  = [np.std(z_dds_min_off_long[i]) for i in range(len(z_dds_min_off_long))]        
zstd_detrend  = [np.std(signal.detrend(z_dds_min_off_long[i])) for i in range(len(z_dds_min_off_long))]
# Out:
# 100%|██████████| 2998/2998 [00:04<00:00, 664.58it/s]

# %%
plt.plot(zstd)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std [bits]")
plt.show()
plt.plot(zstd_detrend)
plt.xlabel("Time [10s]")
plt.ylabel("Signal std after detrend [bits]")
plt.show()

# %%
n g
