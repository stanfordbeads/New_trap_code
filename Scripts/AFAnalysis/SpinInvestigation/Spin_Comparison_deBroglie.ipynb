# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# load the files for dB
bead_date =20200518
bead_number = 2
dataset = "Shaking/Shaking375/"
FOI = "Shaking375_7_"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
filename = dirname + FOI
base_proc = "/data/new_trap_processed/processed_files/" + str(bead_date) +  "/Bead%s/" %bead_number

# load dataframes: spin_reduced, data and data reduced

outputname = base_proc + dataset+FOI+"_spin_full_freq_only.pkl"
df_spin_red_dB = pd.read_pickle(outputname)
outputname = base_proc + dataset+FOI+"_main.pkl"
df_data_dB = pd.read_pickle(outputname)
df_data_red_dB =  reduced_df(df_data_dB)
# Out:
# 100%|██████████| 9/9 [00:01<00:00,  5.23it/s]

# %%
# load the files for Wilson
bead_date =20200320
bead_number = 1
dataset = "Shaking/Shaking378/"
FOI = "Shaking3"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
filename = dirname + FOI
base_proc = "/data/new_trap_processed/processed_files/" + str(bead_date) +  "/Bead%s/" %bead_number

# load dataframes: spin_reduced, data and data reduced

outputname = base_proc + dataset+FOI+"_spin_full_freq_only.pkl"
df_spin_red_W = pd.read_pickle(outputname)
outputname = base_proc + dataset+FOI+"_main.pkl"
df_data_W = pd.read_pickle(outputname)
df_data_red_W =  reduced_df(df_data_dB)
# Out:
# 100%|██████████| 9/9 [00:01<00:00,  5.20it/s]

# %%
# load background data for Wilson

dataset = "Shaking/Shaking2_20200403/"
FOI = "NoShaking_1"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
filename = dirname + FOI

outputname = base_proc + dataset+FOI+"_main.pkl"
df_data_W_b = pd.read_pickle(outputname)
outputname = base_proc + dataset+FOI+"_spin_full_freq_only.pkl"
df_spin_red_W_b = pd.read_pickle(outputname)
df_data_red_W_b =  reduced_df(df_data_W_b)
# Out:
# 100%|██████████| 9/9 [00:09<00:00,  1.31s/it]

# %%
plt.plot(np.divide(df_data_dB.x_mean.ewm(span=100).mean(),df_data_dB.x_mean.mean()))
plt.plot(np.divide(df_data_dB.y_mean.ewm(span=100).mean(),df_data_dB.y_mean.mean()))
plt.plot(np.divide(df_data_dB.z_mean.ewm(span=100).mean(),df_data_dB.z_mean.mean()))

print(df_data_dB.x_mean.corr(df_data_dB.y_mean))
print(df_data_dB.x_mean.corr(df_data_dB.z_mean))
print(df_data_dB.y_mean.corr(df_data_dB.z_mean))
# Out:
# 0.4759733516453847
# -0.5185331374601954
# -0.6730193855341932
