# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
#%matplotlib widget
# remove below if used
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36
from skimage.filters import window

# %%
zeroth_image =  load_img_files("/data/SC_data/ImageAnalysis/PositionCalibration/PositionCalibration_20200923/X0_TopZoom_1666_20.bmp")[0]
x340_image = load_img_files("/data/SC_data/ImageData/20200924/Bead1/attractor_x340_y211_z60_1666_20.bmp")[0]
# Out:
# /data/SC_data/ImageAnalysis/PositionCalibration/PositionCalibration_20200923/X0_TopZoom_1666_20.bmp 0
# /data/SC_data/ImageData/20200924/Bead1/attractor_x340_y211_z60_1666_20.bmp 0

# %%
plt.imshow(zeroth_image[150:400,165:450])

# %%
plt.imshow(x340_image[150:400,165:450])

# %%
img1= zeroth_image# * window('blackman', zeroth_image.shape)
img2= x340_image#*window('hamming',top_zoom_images[i].shape)
mean1=np.mean(img1,axis=1)
mean2=np.mean(img2,axis=1)

#print(np.argmin(mean1[240:280]))
#print(np.argmin(mean2[240:280]))

#plt.plot(mean1)
#plt.plot(mean2)
#plt.xlim(150,320)
#plt.show()

shift, error, diffphase = phase_cross_correlation(img1[150:400,165:415],img2[150:400,165:415],
                                                          upsample_factor=10)
print(shift)
# Out:
# [-21.7   0.1]

# %%
plt.plot(mean1/np.mean(mean1))
plt.plot(mean2/np.mean(mean2))
plt.xlim(190,400)
# Out:
# (190.0, 400.0)

# %%
plt.imshow(img2)
