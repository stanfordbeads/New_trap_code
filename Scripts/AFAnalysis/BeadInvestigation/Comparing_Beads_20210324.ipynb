# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
trap_power=[183,183.5,134.8,134.7,192.5,133.3,185.0]

# %%
dir_path = "/data/SC_data/ImageData/20210324/"
trap_images=load_img_files(dir_path+"*trap.bmp",max_files=129005)
# Out:
# /data/SC_data/ImageData/20210324/Bead1_trap.bmp 0
# /data/SC_data/ImageData/20210324/Bead2_trap.bmp 1
# /data/SC_data/ImageData/20210324/Bead3_trap.bmp 2
# /data/SC_data/ImageData/20210324/Bead4_trap.bmp 3
# /data/SC_data/ImageData/20210324/Bead5_trap.bmp 4
# /data/SC_data/ImageData/20210324/Bead6_trap.bmp 5
# /data/SC_data/ImageData/20210324/Bead7_trap.bmp 6

# %%
x=np.arange(0,1024,1)
i=0
for images in trap_images:
    i+=1
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    beadPosGuess_X=np.argmax(np.mean(images,axis=1))
    beadPosGuess_Y=np.argmax(np.mean(images,axis=0))
    plt.imshow(images[beadPosGuess_X-50:beadPosGuess_X+50,beadPosGuess_Y-50:beadPosGuess_Y+50])
    #plt.plot(100*np.mean(images,axis=1),x,color="red")
    plt.savefig("Results/bead%d_trap_appearance.jpg" %i)
    plt.show()

# %%
x=np.arange(0,1024,1)
for images in trap_images:
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    plt.imshow(images)
    plt.plot(100*np.mean(images,axis=1),x,color="red")
    print(np.argmax(np.mean(images,axis=1)))
plt.show()
    #plt.show()
# Out:
# 135
# 115
# 151
# 150
# 90
# 158
# 130

# %%
trap_heights = [135,115,151,150,90,158,130]

plt.plot(trap_power,(np.subtract(1024,trap_heights)),linestyle="",marker="*",markersize=12)
plt.ylabel("height in pixel")
plt.xlabel("trapping power in mV@2.kOhm")
# Out:
# Text(0.5, 0, 'trapping power in mV@2.kOhm')

# %%
dir_path = "/data/SC_data/ImageData/20210324/"
trap_images=load_img_files(dir_path+"B*catcher*.bmp",max_files=129005)
# Out:
# /data/SC_data/ImageData/20210324/Bead1_catcher_removed.bmp 0
# /data/SC_data/ImageData/20210324/Bead2_catcher_removed.bmp 1
# /data/SC_data/ImageData/20210324/Bead3_after_catcher_removal.bmp 2
# /data/SC_data/ImageData/20210324/Bead4_after_catcher_removal.bmp 3
# /data/SC_data/ImageData/20210324/Bead5_after_catcher_removal.bmp 4
# /data/SC_data/ImageData/20210324/Bead6_after_catcher_removal.bmp 5
# /data/SC_data/ImageData/20210324/Bead7_after_catcher_removal.bmp 6

# %%
x=np.arange(0,1024,1)
beadnr=[1,2,3,4,5,6,7]
i=0
for images in trap_images:
    i+=1 
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    beadPosGuess_X=np.argmax(np.mean(images,axis=1))
    beadPosGuess_Y=np.argmax(np.mean(images,axis=0))
    plt.imshow(images[beadPosGuess_X-50:beadPosGuess_X+50,beadPosGuess_Y-50:beadPosGuess_Y+50])
    #plt.plot(100*np.mean(images,axis=1),x,color="red")
    plt.savefig("Results/bead%d_appearance_catcher_removed.jpg" %beadnr[i-1])
    plt.show()

# %%
x=np.arange(0,1024,1)
for images in trap_images:
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    plt.imshow(images)
    plt.plot(100*np.mean(images,axis=1),x,color="red")
    print(np.argmax(np.mean(images,axis=1)))
plt.show()
    #plt.show()
# Out:
# 355
# 348
# 393
# 369
# 326
# 405
# 362

# %%
catcherRemovalHeights = [355,348,393,369,326,405,362]
ratio = (np.subtract(1024,trap_heights))/(np.subtract(1024,catcherRemovalHeights))
#plt.plot(trap_power,(np.subtract(1024,catcherRemovalHeights)),linestyle="",marker="*",markersize=12)
plt.plot(ratio,marker="*",linestyle="",markersize=12)
#plt.ylabel("height in pixel")
plt.ylabel("ratio trap/catcher removal")

plt.xlabel("trapping power in mV@2.kOhm")
plt.show()

# %%
x=np.arange(0,1024,1)
i=0
for images in trap_images:
    i+=1
    plt.ylabel("intensity")
    plt.xlabel("pixel")
    plt.plot(x,np.mean(images,axis=1),label="Bead%d" %i)
    plt.xlim(250,500)
    plt.legend()
plt.show()
    #plt.show()

# %%
dir_path = "/data/SC_data/ImageData/20210324/"
trap_images=load_img_files(dir_path+"B*0*.bmp",max_files=129005)
# Out:
# /data/SC_data/ImageData/20210324/Bead1_0dBm.bmp 0
# /data/SC_data/ImageData/20210324/Bead2_0dBm.bmp 1
# /data/SC_data/ImageData/20210324/Bead4_0dBm.bmp 2
# /data/SC_data/ImageData/20210324/Bead5_0dBm.bmp 3
# /data/SC_data/ImageData/20210324/Bead6_0dBm.bmp 4
# /data/SC_data/ImageData/20210324/Bead7_0dBm.bmp 5

# %%
x=np.arange(0,1024,1)
beadnr=[1,2,4,5,6,7]
i=0
for images in trap_images:
    i+=1 
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    beadPosGuess_X=np.argmax(np.mean(images,axis=1))
    beadPosGuess_Y=np.argmax(np.mean(images,axis=0))
    plt.imshow(images[beadPosGuess_X-50:beadPosGuess_X+50,beadPosGuess_Y-50:beadPosGuess_Y+50])
    #plt.plot(100*np.mean(images,axis=1),x,color="red")
    plt.savefig("Results/bead%d_appearance_0dBm.jpg" %beadnr[i-1])
    plt.show()

# %%
x=np.arange(0,1024,1)
for images in trap_images:
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    plt.imshow(images)
    plt.plot(100*np.mean(images,axis=1),x,color="red")
    print(np.argmax(np.mean(images,axis=1)))
plt.show()
    #plt.show()
# Out:
# 620
# 612
# 584
# 594
# 613
# 671

# %%
ZerodBmRemovalHeights = [620,612,584,594,613,671]
trap_power_0dBm=[146.5,147,145.5,146.5,144.4,140.7]

#ratio = (np.subtract(1024,trap_heights))/(np.subtract(1024,catcherRemovalHeights))
plt.plot(trap_power_0dBm,(np.subtract(1024,ZerodBmRemovalHeights)),linestyle="",marker="*",markersize=12)
#plt.plot(ratio,marker="*",linestyle="",markersize=12)
plt.ylabel("height in pixel")
#plt.ylabel("ratio trap/catcher removal")
plt.xlabel("trap power in mV@10kOhm")
plt.show()

# %%
x=np.arange(0,1024,1)
i=0
for images in trap_images:
    i+=1
    if(i==3):
        i+=1
    plt.ylabel("intensity")
    plt.xlabel("pixel")
    plt.plot(x,np.mean(images,axis=1),label="Bead%d" %i)
    plt.xlim(500,700)
    plt.legend()
plt.show()
    #plt.show()

# %%
def make_psd_self(data_in,fsamp,res):
    data_det=signal.detrend(data_in)
    res = res
    fsamp = fsamp # stays hard coded for now
    freqs=np.linspace(0,int(fsamp/2),(int(res/2))+1)    # change
    FFT=np.fft.rfft(data_det,n=res)
    norm = np.sqrt(2 / (res* fsamp))
    psd = norm**2 * (FFT * FFT.conj()).real
    phase=np.angle(FFT)
    return freqs,psd,phase

def plot_quick_spectrum(folder,beadnr,data,fsamp,res):
    fname = folder + "/Bead%d" %beadnr + "/InitialTest/Data%d.h5" %data
    BDF = BeadDataFile.BeadDataFile(fname)
    data=BDF.xyz
    trigger = BDF.trigger
    #print(trigger)
    data_det=signal.detrend(data)
    f,xs,xp = make_psd_self(data_in=data_det[0],fsamp=fsamp,res=res)  
    f,ys,yp = make_psd_self(data_in=data_det[1],fsamp=fsamp,res=res)  
    f,zs,zp = make_psd_self(data_in=data_det[2],fsamp=fsamp,res=res)  
    return f,xs,ys,zs,xp,yp,zp

def plot_psds(freqs,psd1,psd2,psd3,factor=100):
    _,ax = plt.subplots()
    ax.loglog(freqs, psd1, '.-', label="x",markersize=1,linewidth=0.5)
    ax.loglog(freqs, psd2*factor*10, '.-', label="y",markersize=1,linewidth=0.5,alpha=1)
    ax.loglog(freqs, psd3*factor, '.-', label="z",markersize=1,linewidth=0.5)
    ax.set_xlabel('Frequency [Hz]')
    ax.set_ylabel('PSD [a.u.]')
    #plt.xlim(1,2500)
    #plt.ylim(1e6,1e10)
    plt.grid(True)
    return None

# %%
def fft_norm(N, fsamp):
    "Factor to normalize FFT to ASD units"
    return np.sqrt(2 / (N * fsamp))

def damped_osc_amp(f, A, f0, g):
    '''Fitting function for AMPLITUDE of a damped harmonic oscillator
           INPUTS: f [Hz], frequency 
                   A, amplitude
                   f0 [Hz], resonant frequency
                   g [Hz], damping factor
           OUTPUTS: Lorentzian amplitude'''
    w = 2. * np.pi * f
    w0 = 2. * np.pi * f0
    gamma = 2. * np.pi * g
    denom = np.sqrt((w0**2 - w**2)**2 + w**2 * gamma**2)
    return A / denom

def fit_damped_osc_amp(sig, fsamp, fit_band=[], plot=False, \
                       sig_asd=False, linearize=False, asd_errs=[], \
                       gamma_guess=0, freq_guess=0, weight_lowf=False, \
                       weight_lowf_val=1.0, weight_lowf_thresh=100.0, \
                       maxfev=100000):
    '''Routine to fit the above defined damped HO amplitude spectrum
       to the ASD of some input signal, assumed to have a single
       resonance etc etc
           INPUTS: sig, signal to analyze 
                   fsamp [Hz], sampling frequency of input signal
                   fit_band [Hz], array-like with upper/lower limits
                   plot, boolean flag for plotting of fit results
                   sig_asd, boolean indicating if 'sig' is already an
                                an amplitude spectral density
                   linearize, try linearizing the fit
                   asd_errs, uncertainties to use in fitting
           OUTPUTS: popt, optimal parameters from curve_fit
                    pcov, covariance matrix from curve_fit'''

    ### Generate the frequencies and ASD values from the given time
    ### domain signal, or given ASD
    if not sig_asd:
        nsamp = len(sig)
        freqs = np.fft.rfftfreq(nsamp, d=1.0/fsamp)
        asd = np.abs( np.fft.rfft(sig) ) * fft_norm(nsamp, fsamp)
    else:
        asd = np.abs(sig)
        freqs = np.linspace(0, 0.5*fsamp, len(asd))

        
    ### Generate some initial guesses
    maxind = np.argmax(asd)
    print(maxind)
    if not freq_guess:
        freq_guess = freqs[maxind]
    if not gamma_guess:
        gamma_guess = 2e-3 * freq_guess
    amp_guess = asd[maxind] * gamma_guess * freq_guess * (2.0 * np.pi)**2
    print(amp_guess)

    ### Define some indicies for fitting and plotting
    if len(fit_band):
        inds = (freqs > fit_band[0]) * (freqs < fit_band[1])
        plot_inds = (freqs > 0.5 * fit_band[0]) * (freqs < 2.0 * fit_band[1])
    else:
        inds = (freqs > 0.1 * freq_guess) * (freqs < 10.0 * freq_guess)
        plot_inds = (freqs > 0.05 * freq_guess) * (freqs < 20.0 * freq_guess)

    ### Define the fitting function to use. Keeping this modular in case
    ### we ever want to make more changes/linearization attempts
    fit_x = freqs[inds]
    if linearize:
        fit_func = lambda f,A,f0,g: np.log(damped_osc_amp(f,A,f0,g))
        fit_y = np.log(asd[inds])
        if not len(asd_errs):
            errs = np.ones(len(fit_x))
            absolute_sigma = False
        else:
            errs = asd_errs[inds] / asd[inds]
            absolute_sigma = True
    else:
        fit_func = lambda f,A,f0,g: damped_osc_amp(f,A,f0,g)
        fit_y = asd[inds]
        if not len(asd_errs):
            errs = np.ones(len(fit_x))
            absolute_sigma = False
        else:
            errs = asd_errs[inds]
            absolute_sigma = True

    if weight_lowf:
        weight_inds = fit_x < weight_lowf_thresh
        errs[weight_inds] *= weight_lowf_val

    ### Fit the data
    p0 = [amp_guess, freq_guess, gamma_guess]
    try:
        popt, pcov = optimize.curve_fit(fit_func, fit_x, fit_y, maxfev=maxfev,\
                                        p0=p0, absolute_sigma=absolute_sigma, sigma=errs)
    except:
        print('BAD FIT')
        popt = p0
        pcov = np.zeros( (len(p0), len(p0)) )

    ### We know the parameters should be positive so enforce that here since
    ### the fit occasionally finds negative values (sign degeneracy in the 
    ### damped HO response function)
    popt = np.abs(popt)

    ### Plot!
    if plot:
        fit_freqs = np.linspace((freqs[inds])[0], (freqs[inds])[-1], \
                                10*len(freqs[inds])) 
        init_mag = damped_osc_amp(fit_freqs, *p0)
        fit_mag = damped_osc_amp(fit_freqs, *popt)
        plt.loglog(freqs[plot_inds], asd[plot_inds])
        plt.loglog(fit_freqs, init_mag, ls='--', color='k', label='init')
        plt.loglog(fit_freqs, fit_mag, ls='--', color='r', label='fit')
        plt.xlim((freqs[plot_inds])[0], (freqs[plot_inds])[-1])
        plt.ylim(0.5 * np.min(asd[plot_inds]), 2.0 * np.max(asd[plot_inds]))
        plt.legend()
        plt.show()
        # input()

    return popt, pcov

# %%
folder = "/data/new_trap/20210324/"
#folder1 = "/data/new_trap/20210325/"

beadnr = 1
datanr=1
f,x,y,z,xp,yp,zp= plot_quick_spectrum(folder,beadnr,datanr,5000,50000)
#beadnr2 = 7
#datanr2=0
#f,x2,y2,z2,xp,yp,zp= plot_quick_spectrum(folder,beadnr,datanr,5000,5000)

#f2,x2,y2,z2= plot_quick_spectrum(folder,beadnr,data)

plot_psds(f,x,y,z*10)#/1e21)
#plot_psds(f,x2,y2,z2*10)#/1e21)

plt.ylim(1e1)
print(1000+np.argmax(y[1000:]))
print(1000+np.argmax(x[1000:]))
plt.axvline((1000+np.argmax(x[1000:]))/10)
plt.show()
a,b = fit_damped_osc_amp(x, 5000, fit_band=[150,650],sig_asd=True,linearize=True,plot=True)
print(a[1])
a,b = fit_damped_osc_amp(y, 5000, fit_band=[150,500],sig_asd=True,linearize=True,plot=True)
print(a[1])
# Out:
# No seismometer data
# No z_set data
# No height data
# No electrodes data
# No cantilever data
# No laser power data
# 3945
# 3945
# 27
# 2311999815991.77
# 385.14676903939585
# 1
# 2319344177.109262
# 389.40636784497275

# %%
dir_path = "/data/SC_data/ImageData/20210324/"
trap_images=load_img_files(dir_path+"B*focus*.bmp",max_files=129005)
# Out:
# /data/SC_data/ImageData/20210324/Bead1_focus.bmp 0
# /data/SC_data/ImageData/20210324/Bead2_focus.bmp 1
# /data/SC_data/ImageData/20210324/Bead4_focus.bmp 2
# /data/SC_data/ImageData/20210324/Bead5_focus.bmp 3
# /data/SC_data/ImageData/20210324/Bead6_focus.bmp 4

# %%
x=np.arange(0,1024,1)
for images in trap_images:
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    plt.imshow(images)
    plt.plot(100*np.mean(images,axis=1),x,color="red")
    print(np.argmax(np.mean(images,axis=1)))
plt.show()
    #plt.show()
# Out:
# 620
# 612
# 584
# 594
# 613
# 671

# %%
dir_path = "/data/SC_data/ImageData/20210324/"
trap_images=load_img_files(dir_path+"*Data*.bmp",max_files=129005)
# Out:
# /data/SC_data/ImageData/20210324/Data12.bmp 0
# /data/SC_data/ImageData/20210324/Data14.bmp 1
# /data/SC_data/ImageData/20210324/Data15.bmp 2
# /data/SC_data/ImageData/20210324/Data16.bmp 3
# /data/SC_data/ImageData/20210324/Data17.bmp 4
# /data/SC_data/ImageData/20210324/Data18.bmp 5
# /data/SC_data/ImageData/20210324/Data19.bmp 6
# /data/SC_data/ImageData/20210324/Data20.bmp 7
# /data/SC_data/ImageData/20210324/Data21.bmp 8
# /data/SC_data/ImageData/20210324/Data22.bmp 9
# /data/SC_data/ImageData/20210324/Data23.bmp 10
# /data/SC_data/ImageData/20210324/Data24.bmp 11

# %%
x=np.arange(0,1024,1)
for images in trap_images:
    plt.ylabel("pixel")
    plt.xlabel("pixel")
    plt.imshow(images)
    plt.plot(75*np.mean(images,axis=1),x,color="red")
    plt.show()
    #plt.show()
