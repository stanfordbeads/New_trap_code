# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
sys.path.append('/home/analysis_user/New_trap_code/SensitivityFramework/')
from signal_model_utilities_v3 import *
from shutil import copyfile

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
def plotting(var_list,legend_list):
    i=0
    for var in var_list:
        i += 1
        x = range(len(var))
        plt.plot(x,var,linestyle="",marker="*",markersize=15,label=legend_list[i-1])
    plt.legend()    
    plt.show()
    return

# %%
file_path="/data/new_trap_processed/mockfiles/20200320/output/noise/Batch1/59/Noise_batch_0.h5"

# %%
with h5py.File(file_path, 'r') as f_in:
            quad_data_in = np.array(f_in['quad_data'])
            data_in = quad_data_in.reshape(-1,12).T[9]
            f_in.close()

# %%
file_path2="/data/new_trap_processed/mockfiles/20200320/raw/noise/NoShaking_1_200.h5"

# %%
with h5py.File(file_path2, 'r') as f_in:
            quad_data_in = np.array(f_in['quad_data'])
            data_inraw = quad_data_in.reshape(-1,12).T[9]
            f_in.close()

# %%
plt.plot(data_in - data_inraw,linestyle="-",marker="")
plt.xlim(0,5000)
# Out:
# (0.0, 5000.0)

# %%
file_path3="/data/new_trap_processed/mockfiles/20200320/output/noise/Batch1/40/Noise_batch_0.h5"
with h5py.File(file_path3, 'r') as f_in:
            quad_data_in = np.array(f_in['quad_data'])
            data_inzero = quad_data_in.reshape(-1,12).T[9]
            f_in.close()

# %%
data_inzero
# Out:
# array([-3248240, -3249541, -3249712, ..., -3248098, -3248179, -3247639], dtype=int32)

# %%
plt.plot(data_in)
plt.plot(data_inraw)
plt.plot(data_inzero,alpha=0.5)

# %%
plt.plot(np.abs(np.fft.rfft(data_in)))
plt.plot(np.abs(np.fft.rfft(data_inraw)))
plt.plot(np.abs(np.fft.rfft(data_inzero)))
plt.yscale("log")
plt.xlim(80,100)
plt.ylim(1e4,1e6)
# Out:
# (10000.0, 1000000.0)

# %%
print(max(np.divide(data_in,data_inzero)))
# Out:
# 0.99999478101

# %%
print(max(np.divide(data_in,data_inzero)))
# Out:
# 0.99999478101

# %%
0.999999693137/0.999999693001
# Out:
# 1.000000000136

# %%
fdir = "/home/afieguth/Documents/Batch1/"

# %%
run_no= np.load(fdir+"run_no.npy")
alpha_scale_in = np.load(fdir+"alpha_scale_in.npy")
lambda_val_in = np.load(fdir+"lambda_val_in.npy")
direction_in = np.load(fdir+"direction_in.npy")
phase_shift_in = np.load(fdir+"phase_shift_in.npy")

# %%
run_no[22]
# Out:
# 32

# %%
alpha_scale_in[22]/1e8
# Out:
# 7.8700000000000001

# %%
run_no_true = []
results_true = []
lambda_true = []
direction_true = []
phase_shift_true = []
for i in range(len(run_no)):
    run_no_true.append(run_no[i])
    results_true.append(alpha_scale_in[i])
    lambda_true.append(lambda_val_in[i])
    direction_true.append(direction_in[i])
    phase_shift_true.append(phase_shift_in[i])

# %%
# (l=5um, +) (l=5um, -) (l=10um, +) (l=10um, -) (l=25um, +) (l=25um, -)
# 95% CL
results_from_akio= np.loadtxt("Results_Noise_Batch1/AlphaForAlex.txt")

# %%
run_no_a = []
l5p = []
l5m = []
l10p = []
l10m = []
l25p = []
l25m = []

for results in results_from_akio:
    a,b,c,d,e,f,g = results
    run_no_a.append(a)
    l5p.append(b)
    l5m.append(c)
    l10p.append(d)
    l10m.append(e)
    l25p.append(f)
    l25m.append(g)

# %%
df_raw=pd.DataFrame()

# %%
df_raw["run_no_true"]=run_no_true
df_raw["alpha"]=results_true
df_raw["lambda"]=lambda_true
df_raw["direction"]=direction_true
df_raw["phase_val"]=phase_shift_true

# %%
df = df_raw.sort_values(by=['run_no_true']).reset_index()

# %%
df["akio_alpha_l5_p"]=l5p
df["akio_alpha_l10_p"]=l10p
df["akio_alpha_l25_p"]=l25p
df["akio_alpha_l5_n"]=l5m
df["akio_alpha_l10_n"]=l10m
df["akio_alpha_l25_n"]=l25m

# %%
df[df.alpha==max(df.alpha)]
# Out:
#     index  run_no_true        alpha  lambda direction phase_val  \
# 55     13           55  797000000.0      18      pull        TF
#
#     akio_alpha_l5_p  akio_alpha_l10_p  akio_alpha_l25_p  akio_alpha_l5_n  \
# 55     3.230000e+09       570000000.0       280000000.0     -940000000.0
#
#     akio_alpha_l10_n  akio_alpha_l25_n
# 55      -170000000.0       -80000000.0

# %%
df[df.index==32]
# Out:
#     index  run_no_true        alpha  lambda direction phase_val  \
# 32     22           32  787000000.0       5      pull        TF
#
#     akio_alpha_l5_p  akio_alpha_l10_p  akio_alpha_l25_p  akio_alpha_l5_n  \
# 32      460000000.0        90000000.0        40000000.0     -280000000.0
#
#     akio_alpha_l10_n  akio_alpha_l25_n
# 32       -50000000.0       -30000000.0

# %%
t0 = df.alpha[(df["lambda"]==20) & (df["direction"]=="pull") & (df['phase_val']=="TF") ]/1e8
print(t0)
print(len(t0))
# Out:
# 40    0.0
# Name: alpha, dtype: float64
# 1

# %%
a0a = df.akio_alpha_l10_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]/1e8
a0b = df.akio_alpha_l25_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]/1e8
print(a0a,a0b)
print(len(a0a),len(a0b))
# Out:
# 40    0.4
# Name: akio_alpha_l10_p, dtype: float64 40    0.2
# Name: akio_alpha_l25_p, dtype: float64
# 1 1

# %%
t1 = df.alpha[(df["lambda"]==5) & (df["direction"]=="pull") & (df['phase_val']=="TF") ]/1e8
print(t1)
print(len(t1))
# Out:
# 5     0.052
# 10    2.030
# 21    0.610
# 32    7.870
# 41    0.210
# 51    0.010
# 52    0.015
# 71    0.280
# 92    6.710
# Name: alpha, dtype: float64
# 9

# %%
a1 = df.akio_alpha_l5_p[(df["lambda"]==5) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]/1e8
print(a1)
print(len(a1))
# Out:
# 5     1.9
# 10    2.1
# 21    1.9
# 32    4.6
# 41    1.9
# 51    1.9
# 52    1.9
# 71    1.9
# 92    4.6
# Name: akio_alpha_l5_p, dtype: float64
# 9

# %%
plotting([a1,t1],["akio","truth"])

# %%
t2=df.alpha[(df["lambda"]==10)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(t2)
print(len(t2))
# Out:
# 6     0.230
# 16    0.020
# 28    5.610
# 33    0.670
# 35    0.650
# 46    0.029
# 56    0.730
# 59    7.900
# 63    6.500
# 65    0.190
# 68    0.044
# 75    2.620
# 82    4.190
# 86    0.043
# 90    0.065
# Name: alpha, dtype: float64
# 15

# %%
a2 = df.akio_alpha_l10_p[(df["lambda"]==10) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(a2)
print(len(a2))
# Out:
# 6     0.4
# 16    0.4
# 28    2.2
# 33    0.5
# 35    0.5
# 46    0.4
# 56    0.5
# 59    3.1
# 63    2.6
# 65    0.4
# 68    0.4
# 75    1.1
# 82    1.7
# 86    0.4
# 90    0.4
# Name: akio_alpha_l10_p, dtype: float64
# 15

# %%
plotting([a2,t2],["akio","truth"])

# %%
t3=df.alpha[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(t3)
print(len(t3))
# Out:
# 0     0.320
# 2     5.440
# 3     1.130
# 4     0.320
# 8     0.047
# 11    6.320
# 12    0.034
# 14    0.290
# 15    0.500
# 18    4.280
# 19    0.270
# 23    4.430
# 24    0.390
# 27    0.450
# 29    0.070
# 30    0.260
# 34    0.019
# 36    2.510
# 38    2.890
# 42    0.056
# 43    7.790
# 44    0.062
# 47    0.350
# 48    0.620
# 49    5.660
# 54    0.200
# 55    7.970
# 57    4.610
# 58    0.018
# 64    7.510
# 66    0.010
# 72    0.050
# 77    0.032
# 79    7.240
# 80    0.280
# 81    0.740
# 83    0.043
# 85    0.570
# 87    6.790
# 88    0.025
# 91    0.037
# 94    0.071
# 96    4.710
# 98    0.780
# 99    0.031
# Name: alpha, dtype: float64
# 45

# %%
a3a=df.akio_alpha_l10_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
a3b=df.akio_alpha_l25_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8

print(a3a,a3b)
print(len(a3a),len(a3b))
# Out:
# 0     0.5
# 2     3.9
# 3     0.9
# 4     0.5
# 8     0.4
# 11    4.5
# 12    0.4
# 14    0.5
# 15    0.6
# 18    3.1
# 19    0.6
# 23    3.2
# 24    0.5
# 27    0.8
# 29    0.4
# 30    0.5
# 34    0.4
# 36    1.8
# 38    2.1
# 42    0.4
# 43    5.6
# 44    0.4
# 47    0.7
# 48    0.9
# 49    4.1
# 54    0.5
# 55    5.7
# 57    3.3
# 58    0.4
# 64    5.4
# 66    0.4
# 72    0.4
# 77    0.4
# 79    5.2
# 80    0.6
# 81    0.9
# 83    0.4
# 85    0.9
# 87    4.9
# 88    0.4
# 91    0.4
# 94    0.4
# 96    3.4
# 98    0.9
# 99    0.4
# Name: akio_alpha_l10_p, dtype: float64 0     0.2
# 2     1.9
# 3     0.5
# 4     0.2
# 8     0.2
# 11    2.2
# 12    0.2
# 14    0.3
# 15    0.3
# 18    1.5
# 19    0.3
# 23    1.6
# 24    0.3
# 27    0.4
# 29    0.2
# 30    0.3
# 34    0.2
# 36    0.9
# 38    1.1
# 42    0.2
# 43    2.7
# 44    0.2
# 47    0.4
# 48    0.5
# 49    2.0
# 54    0.2
# 55    2.8
# 57    1.7
# 58    0.2
# 64    2.7
# 66    0.2
# 72    0.2
# 77    0.2
# 79    2.6
# 80    0.3
# ...

# %%
plotting([a3a,a3b,t3],["akio_10","akio_25","truth"])

# %%
t4=df.alpha[(df["lambda"]==31)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(t4)
print(len(t4))
# Out:
# 22    0.080
# 39    0.033
# 61    1.360
# 67    0.700
# 70    5.680
# 78    0.031
# Name: alpha, dtype: float64
# 6

# %%
a4 = df.akio_alpha_l25_p[(df["lambda"]==31) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(a4)
print(len(a4))
# Out:
# 22    0.2
# 39    0.2
# 61    0.6
# 67    0.5
# 70    2.4
# 78    0.2
# Name: akio_alpha_l25_p, dtype: float64
# 6

# %%
plotting([a4,t4],["akio","true"])

# %%
t3 = df.alpha[(df["lambda"]==12) & (df["direction"]=="pull") ]/1e8
print(t3)
print(len(t3))
# Out:
# 1     1.02
# 6     1.00
# 19    1.00
# 29    1.00
# 33    1.00
# 37    7.62
# 51    1.00
# 52    7.90
# 57    2.42
# 63    1.00
# 66    6.83
# 67    5.80
# 75    1.00
# 85    4.20
# 93    1.00
# 97    3.90
# Name: alpha, dtype: float64
# 16

# %%
a3a = df.akio_alpha_l10_p[(df["lambda"]==12) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
a3b = df.akio_alpha_l25_p[(df["lambda"]==12) & (df["direction"]=="pull")  & (df['phase_val']=="TF") ]/1e8

print(a3a, a3b)
print(len)
# Out:
# Series([], Name: akio_alpha_l10_p, dtype: float64) Series([], Name: akio_alpha_l25_p, dtype: float64)
# <built-in function len>
