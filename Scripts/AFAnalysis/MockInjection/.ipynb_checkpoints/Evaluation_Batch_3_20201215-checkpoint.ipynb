# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
sys.path.append('/home/analysis_user/New_trap_code/SensitivityFramework/')
from signal_model_utilities_v3 import *
from shutil import copyfile


plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
def plotting(var_list,legend_list,log_scale=False,Title=None):
    i=0
    for var in var_list:
        i += 1
        x = range(len(var))
        plt.plot(x,var,linestyle="",marker="*",markersize=15,label=legend_list[i-1])
    plt.legend()    
    plt.ylabel("alpha [1e8]")
    plt.xlabel("run")
    if(log_scale==True):plt.yscale("log")
    if(Title):plt.title(Title)
    plt.show()
    return

# %%
fdir = "/home/afieguth/Documents/Batch3/"

# %%
run_no= np.load(fdir+"run_no.npy")
alpha_scale_in = np.load(fdir+"alpha_scale_in.npy")
lambda_val_in = np.load(fdir+"lambda_val_in.npy")
direction_in = np.load(fdir+"direction_in.npy")
phase_shift_in = np.load(fdir+"phase_shift_in.npy")

# %%
run_no_true = []
results_true = []
lambda_true = []
direction_true = []
phase_shift_true = []
for i in range(len(run_no)):
    run_no_true.append(run_no[i])
    results_true.append(alpha_scale_in[i])
    lambda_true.append(lambda_val_in[i])
    direction_true.append(direction_in[i])
    phase_shift_true.append(phase_shift_in[i])

# %%
# (l=5um, +) (l=5um, -) (l=10um, +) (l=10um, -) (l=25um, +) (l=25um, -)
# 95% CL
results_from_akio= np.loadtxt("Results_Noise_Batch3/Akio_Batch3.txt")

# %%
results_from_Nadavn = pd.read_csv("Results_Noise_Batch3/Batch3_negative_NP.csv", header=None).transpose()
results_from_Nadavp = pd.read_csv("Results_Noise_Batch3/Batch3_positive_NP.csv", header=None).transpose()
results_from_Nadavn.columns = ["nadav_alpha_l5_n","nadav_alpha_l10_n","nadav_alpha_l25_n"]
results_from_Nadavp.columns = ["nadav_alpha_l5_p","nadav_alpha_l10_p","nadav_alpha_l25_p"]
results_from_Nadav = pd.concat([results_from_Nadavn,results_from_Nadavp],axis=1)

# %%
# I'll give you a pickle file with keys being the batch string (i.e. '0', '1', ...) and each element of 
#the dict will be a 3x2x3 array. first axis is response (x = 0, y = 1, z = 2), second axis is positive (0) 
#vs negative (1) mle cases, and third axis is sampled 90% CL alpha at lambda = 5um, lambda = 10um, and lambda = 25um
# [5,10,12,18,20,25,31]
#results_from_chas = np.load("Results_Noise_Batch3/signal_injection_batch3_conservative.p",allow_pickle=True)
results_from_chas = np.load("Results_Noise_Batch3/signal_injection_batch3_conservative_2.p",allow_pickle=True)

# %%
run_no_a = []
l5p = []
l5m = []
l10p = []
l10m = []
l25p = []
l25m = []

for results in results_from_akio:
    a,b,c,d,e,f,g = results
    run_no_a.append(a)
    l5p.append(b/1e8)
    l5m.append(c/1e8)
    l10p.append(d/1e8)
    l10m.append(e/1e8)
    l25p.append(f/1e8)
    l25m.append(g/1e8)

# %%
df_raw=pd.DataFrame()

# %%
df_raw["run_no_true"]=run_no_true
df_raw["alpha"]=results_true
df_raw["lambda"]=lambda_true
df_raw["direction"]=direction_true
df_raw["phase_val"]=phase_shift_true

# %%
df = df_raw.sort_values(by=['run_no_true']).reset_index()

# %%
df["akio_alpha_l5_p"]=l5p
df["akio_alpha_l10_p"]=l10p
df["akio_alpha_l25_p"]=l25p
df["akio_alpha_l5_n"]=l5m
df["akio_alpha_l10_n"]=l10m
df["akio_alpha_l25_n"]=l25m

# %%
df = pd.concat([df,results_from_Nadav],axis=1)

# %%
run_no_c = []
c5p = []
c5m = []
c10p = []
c10m = []
c12p = []
c12m = []
c18p = []
c18m = []
c20p = []
c20m = []
c25p = []
c25m = []
c31p = []
c31m = []

for i in range(100):
    run_no_c.append(i)
    c5p.append(results_from_chas['%d' %i][2][0][0]/1e8)
    c5m.append(results_from_chas['%d' %i][2][1][0]/1e8)
    
    c10p.append(results_from_chas['%d' %i][2][0][1]/1e8)
    c10m.append(results_from_chas['%d' %i][2][1][1]/1e8)
    
    c12p.append(results_from_chas['%d' %i][2][0][2]/1e8)
    c12m.append(results_from_chas['%d' %i][2][1][2]/1e8)
    
    c18p.append(results_from_chas['%d' %i][2][0][3]/1e8)
    c18m.append(results_from_chas['%d' %i][2][1][3]/1e8)
    
        
    c20p.append(results_from_chas['%d' %i][2][0][4]/1e8)
    c20m.append(results_from_chas['%d' %i][2][1][4]/1e8)
    
    
    c25p.append(results_from_chas['%d' %i][2][0][5]/1e8)
    c25m.append(results_from_chas['%d' %i][2][1][5]/1e8)
    
    c31p.append(results_from_chas['%d' %i][2][0][6]/1e8)
    c31m.append(results_from_chas['%d' %i][2][1][6]/1e8)

# %%
results_from_chas["12"]
# Out:
# array([[[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00],
#         [  2.48520010e+08,   4.16911722e+07,   3.09594915e+07,
#            2.26777978e+07,   2.14691245e+07,   2.02122729e+07,
#            1.92026832e+07]],
#
#        [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00],
#         [  2.65081316e+08,   3.13416621e+07,   2.17029350e+07,
#            1.46962286e+07,   1.37045648e+07,   1.26372830e+07,
#            1.17209179e+07]],
#
#        [[  1.26381129e+09,   2.21068415e+08,   1.65973633e+08,
#            1.23175521e+08,   1.16882974e+08,   1.10099586e+08,
#            1.04456464e+08],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00]]])

# %%
len(c18m)
# Out:
# 100

# %%
df["chas_alpha_l5_p"]=c5p
df["chas_alpha_l10_p"]=c10p
df["chas_alpha_l12_p"]=c12p
df["chas_alpha_l18_p"]=c18p
df["chas_alpha_l20_p"]=c20p
df["chas_alpha_l25_p"]=c25p
df["chas_alpha_l31_p"]=c31p
df["chas_alpha_l5_n"]=c5m
df["chas_alpha_l10_n"]=c10m
df["chas_alpha_l12_n"]=c12m
df["chas_alpha_l18_n"]=c18m
df["chas_alpha_l20_n"]=c20m
df["chas_alpha_l25_n"]=c25m
df["chas_alpha_l31_n"]=c31m

# %%
t0 = df.alpha[(df["lambda"]==20) & (df["direction"]=="pull") & (df['phase_val']=="TF") ]/1e8
print(t0)
print(len(t0))
# Out:
# 43    0.0
# Name: alpha, dtype: float64
# 1

# %%
a0a = df.akio_alpha_l10_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]
a0b = df.akio_alpha_l25_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]

n0a = df.nadav_alpha_l10_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]
n0b = df.nadav_alpha_l25_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]

c0a = df.chas_alpha_l10_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]
c0b = df.chas_alpha_l25_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]
c0c =  df.chas_alpha_l20_p[(df["lambda"]==20) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]

print(c0c)
print(a0a,a0b)
print(len(a0a),len(a0b))
print(n0a,n0b)
print(len(n0a),len(n0b))
print(c0a,c0b)
print(len(c0a),len(c0b))
# Out:
# 43    0.228798
# Name: chas_alpha_l20_p, dtype: float64
# 43    0.41
# Name: akio_alpha_l10_p, dtype: float64 43    0.2
# Name: akio_alpha_l25_p, dtype: float64
# 1 1
# 43    0.357405
# Name: nadav_alpha_l10_p, dtype: float64 43    0.171467
# Name: nadav_alpha_l25_p, dtype: float64
# 1 1
# 43    0.43269
# Name: chas_alpha_l10_p, dtype: float64 43    0.215554
# Name: chas_alpha_l25_p, dtype: float64
# 1 1

# %%
t1 = df.alpha[(df["lambda"]==5) & (df["direction"]=="pull") & (df['phase_val']=="TF") ]/1e8
print(t1)
print(len(t1))
# Out:
# 1     0.054
# 28    0.069
# 34    0.017
# 47    6.030
# 49    1.490
# 63    6.110
# 71    0.690
# 82    0.180
# 97    0.340
# Name: alpha, dtype: float64
# 9

# %%
a1 = df.akio_alpha_l5_p[(df["lambda"]==5) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]
n1 = df.nadav_alpha_l5_p[(df["lambda"]==5) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]
c1 = df.chas_alpha_l5_p[(df["lambda"]==5) & (df["direction"]=="pull")  & (df['phase_val']=="TF")  ]


print(a1,n1,c1)
print(len(a1),len(n1),len(c1))
# Out:
# 1     2.35
# 28    2.37
# 34    2.34
# 47    7.12
# 49    2.85
# 63    7.21
# 71    2.60
# 82    2.40
# 97    2.48
# Name: akio_alpha_l5_p, dtype: float64 1     2.160412
# 28    2.173889
# 34    2.128274
# 47    8.509227
# 49    3.704910
# 63    8.606201
# 71    2.873134
# 82    2.276774
# 97    2.443657
# Name: nadav_alpha_l5_p, dtype: float64 1     2.527899
# 28    2.542012
# 34    2.488217
# 47    8.423645
# 49    3.943205
# 63    8.503780
# 71    3.154772
# 82    2.652089
# 97    2.807071
# Name: chas_alpha_l5_p, dtype: float64
# 9 9 9

# %%
plotting([a1,t1,n1,c1],["akio","truth","nadav","chas"],Title="$\lambda$ 5 um")

# %%
plotting([np.divide(t1,a1),np.divide(t1,n1),np.divide(t1,c1)],["truth/akio","truth/nadav","truth/chas"])

# %%
t2=df.alpha[(df["lambda"]==10)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(t2)
print(len(t2))
# Out:
# 8     0.650
# 11    0.680
# 12    1.780
# 18    0.032
# 21    0.033
# 22    0.030
# 23    2.940
# 33    0.150
# 50    0.076
# 62    6.490
# 67    0.420
# 69    7.560
# 92    0.210
# 94    0.055
# 99    5.750
# Name: alpha, dtype: float64
# 15

# %%
a2 = df.akio_alpha_l10_p[(df["lambda"]==10) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
n2 = df.nadav_alpha_l10_p[(df["lambda"]==10) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
c2 = df.chas_alpha_l10_p[(df["lambda"]==10) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]


print(a2,n2,c2)
print(len(a2),len(n2),len(c2))
# Out:
# 8     0.81
# 11    0.84
# 12    2.03
# 18    0.42
# 21    0.43
# 22    0.42
# 23    3.16
# 33    0.47
# 50    0.44
# 62    6.42
# 67    0.61
# 69    7.15
# 92    0.49
# 94    0.43
# 99    5.79
# Name: akio_alpha_l10_p, dtype: float64 8     1.034707
# 11    1.065429
# 12    2.212478
# 18    0.391461
# 21    0.392547
# 22    0.389030
# 23    3.420804
# 33    0.514652
# 50    0.436702
# 62    7.116434
# 67    0.796205
# 69    8.228544
# 92    0.575635
# 94    0.415409
# 99    6.343854
# Name: nadav_alpha_l10_p, dtype: float64 8     1.082671
# 11    1.111725
# 12    2.210684
# 18    0.464849
# 21    0.466150
# 22    0.462856
# 23    3.370598
# 33    0.582466
# 50    0.508493
# 62    6.913230
# 67    0.852278
# 69    7.986119
# 92    0.642411
# 94    0.487727
# 99    6.174681
# Name: chas_alpha_l10_p, dtype: float64
# 15 15 15

# %%
plotting([a2,t2,n2,c2],["akio","truth","nadav","chas"],Title="$\lambda$ 10um")

# %%
plotting([np.divide(t2,a2),np.divide(t2,n2),np.divide(t2,c2)],["truth/akio","truth/nadav","truth/chas"])

# %%
t3=df.alpha[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(t3)
print(len(t3))
# Out:
# 0     0.670
# 3     0.049
# 4     0.480
# 5     0.012
# 6     3.810
# 7     0.580
# 9     4.340
# 10    0.240
# 13    2.850
# 16    0.620
# 17    1.490
# 19    0.240
# 20    0.400
# 24    5.120
# 27    0.270
# 32    0.079
# 35    0.046
# 37    0.068
# 41    0.037
# 44    1.430
# 46    0.057
# 48    0.031
# 51    0.220
# 52    0.072
# 53    4.670
# 54    5.250
# 57    6.050
# 58    4.710
# 59    0.030
# 61    0.980
# 64    7.400
# 66    0.015
# 68    0.029
# 72    0.490
# 76    0.590
# 77    0.020
# 79    3.030
# 80    0.038
# 81    5.480
# 84    4.760
# 85    0.071
# 87    0.510
# 89    0.740
# 90    0.610
# 96    0.200
# Name: alpha, dtype: float64
# 45

# %%
a3a=df.akio_alpha_l10_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
a3b=df.akio_alpha_l25_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]

n3a=df.nadav_alpha_l10_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
n3b=df.nadav_alpha_l25_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]

c3a=df.chas_alpha_l10_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
c3b=df.chas_alpha_l25_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
c3c=df.chas_alpha_l18_p[(df["lambda"]==18)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]

print(a3a,a3b,n3a,n3b,c3a,c3b)
print(len(a3a),len(a3b),len(n3a),len(n3b),len(c3b))
# Out:
# 0      1.41
# 3      0.45
# 4      1.04
# 5      0.42
# 6      6.65
# 7      1.25
# 9      7.29
# 10     0.62
# 13     5.28
# 16     1.33
# 17     4.00
# 19     0.61
# 20     0.88
# 24     8.04
# 27     0.66
# 32     0.47
# 35     0.45
# 37     0.46
# 41     0.44
# 44     2.80
# 46     0.45
# 48     0.44
# 51     0.59
# 52     0.46
# 53     7.67
# 54     8.20
# 57     9.12
# 58     7.66
# 59     0.43
# 61     2.01
# 64    10.94
# 66     0.42
# 68     0.43
# 72     1.06
# 76     1.27
# 77     0.43
# 79     5.56
# 80     0.44
# 81     8.49
# 84     7.72
# 85     0.46
# 87     1.10
# 89     1.55
# 90     1.31
# 96     0.56
# Name: akio_alpha_l10_p, dtype: float64 0     0.69
# 3     0.22
# 4     0.51
# 5     0.21
# 6     3.27
# 7     0.62
# 9     3.59
# 10    0.30
# 13    2.60
# 16    0.65
# 17    1.43
# 19    0.30
# 20    0.43
# 24    3.95
# 27    0.33
# 32    0.23
# 35    0.22
# 37    0.23
# 41    0.22
# 44    1.38
# 46    0.23
# 48    0.22
# 51    0.29
# 52    0.23
# 53    3.77
# 54    4.03
# 57    4.49
# 58    3.77
# 59    0.22
# 61    0.99
# 64    5.38
# 66    0.21
# 68    0.22
# 72    0.52
# 76    0.63
# 77    0.21
# 79    2.74
# 80    0.22
# 81    4.17
# 84    3.79
# 85    0.23
# 87    0.54
# 89    0.76
# 90    0.64
# 96    0.28
# Name: akio_alpha_l25_p, dtype: float64 0      1.616667
# 3      0.449378
# 4      1.258770
# 5      0.379539
# 6      7.512059
# 7      1.446505
# 9      8.507500
# 10     0.809320
# 13     5.710490
# 16     1.522733
# 17     3.154659
# 19     0.809372
# 20     1.109664
# 24          NaN
# 27     0.864401
# 32     0.507108
# 35     0.443503
# 37     0.485152
# 41     0.427822
# 44     3.042091
# 46     0.464260
# 48     0.416440
# 51     0.770105
# 52     0.493526
# 53     9.123898
# 54          NaN
# 57    11.445373
# 58     9.202314
# 59     0.414641
# 61     2.199589
# 64    14.124832
# 66     0.385512
# 68     0.412917
# 72     1.277517
# 76     1.465552
# 77     0.396277
# 79     6.045020
# 80     0.429390
# 81          NaN
# 84     9.295828
# 85     0.491317
# 87     1.316110
# 89     1.746530
# 90     1.504528
# 96     0.733510
# Name: nadav_alpha_l10_p, dtype: float64 0     0.791083
# 3     0.219520
# 4     0.616494
# 5     0.183537
# 6     3.680370
# 7     0.709205
# 9     4.167479
# 10    0.396307
# 13    2.800605
# 16    0.744921
# 17    1.545457
# 19    0.396343
# 20    0.542503
# 24    4.887106
# 27    0.423160
# 32    0.247083
# 35    0.216673
# 37    0.237413
# 41    0.208955
# 44    1.491051
# 46    0.227134
# 48    0.204049
# 51    0.374188
# 52    0.240803
# 53    4.471256
# 54    5.008388
# 57    5.740294
# 58    4.511188
# 59    0.203273
# 61    1.074100
# 64    6.983830
# 66    0.186829
# 68    0.202528
# 72    0.625834
# 76    0.717934
# 77    0.192775
# 79    2.961941
# 80    0.209745
# 81    5.219343
# 84    4.553948
# 85    0.239917
# 87    0.643693
# 89    0.854416
# 90    0.736404
# 96    0.356756
# Name: nadav_alpha_l25_p, dtype: float64 0      1.638445
# 3      0.522058
# 4      1.296357
# 5      0.454075
# 6      7.293960
# 7      1.477002
# 9      8.241405
# 10     0.865137
# 13     5.565455
# 16     1.549144
# 17     3.116225
# 19     0.864869
# 20     1.153360
# 24     9.653198
# 27     0.919159
# 32     0.575973
# 35     0.515698
# 37     0.558548
# 41     0.499480
# 44     3.008571
# 46     0.535409
# 48     0.488573
# 51     0.829389
# 52     0.562663
# 53     8.840226
# 54     9.882302
# 57    11.329533
# 58     8.910815
# 59     0.486399
# 61     2.195728
# 64    13.750617
# 66     0.459806
# 68     0.487358
# 72     1.314803
# 76     1.494455
# 77     0.468811
# 79     5.888939
# 80     0.500769
# 81    10.298797
# 84     8.998649
# 85     0.560490
# 87     1.351270
# 89     1.763085
# 90     1.531462
# 96     0.793155
# Name: chas_alpha_l10_p, dtype: float64 0     0.816026
# 3     0.260417
# 4     0.645669
# 5     0.226205
# 6     3.632402
# 7     0.735629
# 9     4.104217
# 10    0.430921
# 13    2.771633
# 16    0.771555
# 17    1.551946
# 19    0.430788
# 20    0.574457
# 24    4.807271
# 27    0.457824
# 32    0.286912
# 35    0.256895
# 37    0.278609
# 41    0.248818
# 44    1.498335
# 46    0.266712
# 48    0.243386
# 51    0.413118
# 52    0.280285
# 53    4.402422
# 54    4.921362
# 57    5.642063
# 58    4.437574
# 59    0.242640
# 61    1.093548
# 64    6.847721
# 66    0.229059
# 68    0.242782
# 72    0.654855
# 76    0.744320
# 77    0.233544
# 79    2.932721
# 80    0.249460
# 81    5.128771
# 84    4.481314
# 85    0.279203
# 87    0.673015
# 89    0.878096
# 90    0.762750
# 96    0.395073
# Name: chas_alpha_l25_p, dtype: float64
# 45 45 45 45 45

# %%
print(c3c-t3)
# Out:
# 0     0.242920
# 3     0.242296
# 4     0.242319
# 5     0.241020
# 6     0.254001
# 7     0.242969
# 9     0.251888
# 10    0.242055
# 13    0.250932
# 16    0.243165
# 17    0.246296
# 19    0.241906
# 20    0.242645
# 24    0.258495
# 27    0.242154
# 32    0.241939
# 35    0.241355
# 37    0.243230
# 41    0.241319
# 44    0.246314
# 46    0.241338
# 48    0.241242
# 51    0.242137
# 52    0.241523
# 53    0.255532
# 54    0.256145
# 57    0.262498
# 58    0.254863
# 59    0.241030
# 61    0.243422
# 64    0.261449
# 66    0.241213
# 68    0.242565
# 72    0.242597
# 76    0.242694
# 77    0.241231
# 79    0.251167
# 80    0.241037
# 81    0.258203
# 84    0.253801
# 85    0.241312
# 87    0.242915
# 89    0.242367
# 90    0.243313
# 96    0.241948
# dtype: float64

# %%
plotting([a3a,n3a,t3,c3a],["akio_10","nadav_10","truth","chas_10"],log_scale=True)
plotting([a3b,n3b,t3,c3b],["akio_25","nadav_25","truth","chas_25"])

# %%
plotting([np.divide(t3,a3a),np.divide(t3,n3a),np.divide(t3,c3a)],["truth/akio_10","truth/nadav_10","truth/chas_10"])
plotting([np.divide(t3,a3b),np.divide(t3,n3b),np.divide(t3,c3b)],["truth/akio_10","truth/nadav_25","truth/chas_25"])

# %%
t4=df.alpha[(df["lambda"]==31)  & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]/1e8
print(t4)
print(len(t4))
# Out:
# 25    0.110
# 30    7.440
# 65    2.120
# 70    0.066
# 86    0.018
# 91    0.180
# Name: alpha, dtype: float64
# 6

# %%
c4a = df.chas_alpha_l31_p[(df["lambda"]==31) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]

# %%
a4 = df.akio_alpha_l25_p[(df["lambda"]==31) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
n4 = df.nadav_alpha_l25_p[(df["lambda"]==31) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]
c4 = df.chas_alpha_l25_p[(df["lambda"]==31) & (df["direction"]=="pull") & (df['phase_val']=="TF")  ]

print(a4,n4,c4)
print(len(a4),len(n4),len(c4))
# Out:
# 25    0.25
# 30    6.20
# 65    2.30
# 70    0.23
# 86    0.21
# 91    0.28
# Name: akio_alpha_l25_p, dtype: float64 25    0.295130
# 30    8.294016
# 65    2.488649
# 70    0.246406
# 86    0.194314
# 91    0.368177
# Name: nadav_alpha_l25_p, dtype: float64 25    0.332395
# 30    8.087531
# 65    2.459614
# 70    0.285515
# 86    0.234664
# 91    0.406070
# Name: chas_alpha_l25_p, dtype: float64
# 6 6 6

# %%
plotting([a4,t4,n4,c4],["akio","true","nadav","chas"])

# %%
plotting([np.divide(t4,a4),np.divide(t4,n4),np.divide(t4,c4)],["truth/akio","truth/nadav","truth/chas"])

# %%
t5 = df.alpha[(df["lambda"]==12) & (df["direction"]=="push")& (df['phase_val']=="TF") ]/1e8
print(t5)
print(len(t5))
# Out:
# 14    3.85
# 29    0.32
# 39    7.63
# 56    0.10
# 73    0.29
# 74    2.37
# 83    5.06
# 95    6.04
# Name: alpha, dtype: float64
# 8

# %%
c5c=df.chas_alpha_l12_n[(df["lambda"]==12)  & (df["direction"]=="push") & (df['phase_val']=="TF")  ]

# %%
a5a=-df.akio_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="push") & (df['phase_val']=="TF")  ]
a5b=-df.akio_alpha_l25_n[(df["lambda"]==12)  & (df["direction"]=="push") & (df['phase_val']=="TF")  ]

n5a=-df.nadav_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="push") & (df['phase_val']=="TF")  ]
n5b=-df.nadav_alpha_l25_n[(df["lambda"]==12)  & (df["direction"]=="push") & (df['phase_val']=="TF")  ]

c5a=df.chas_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="push") & (df['phase_val']=="TF")  ]
c5b=df.chas_alpha_l25_n[(df["lambda"]==12)  & (df["direction"]=="push") & (df['phase_val']=="TF")  ]




print(a5a,a5b,n5a,n5b,c5a,c5b)
print(len(a5a),len(a5b),len(c5b))
# Out:
# 14     5.06
# 29     0.48
# 39    10.50
# 56     0.38
# 73     0.47
# 74     2.88
# 83     6.88
# 95     8.23
# Name: akio_alpha_l10_n, dtype: float64 14    2.48
# 29    0.24
# 39    5.15
# 56    0.19
# 73    0.23
# 74    1.41
# 83    3.37
# 95    4.03
# Name: akio_alpha_l25_n, dtype: float64 14     5.778814
# 29     0.867854
# 39    11.096886
# 56     0.561730
# 73     0.827090
# 74     3.720811
# 83     7.462308
# 95     8.826560
# Name: nadav_alpha_l10_n, dtype: float64 14    2.833758
# 29    0.425009
# 39    5.412210
# 56    0.271851
# 73    0.405291
# 74    1.823349
# 83    3.656793
# 95    4.327209
# Name: nadav_alpha_l25_n, dtype: float64 14     5.110237
# 29     0.405601
# 39    10.154790
# 56     0.000000
# 73     0.365383
# 74     3.138740
# 83     6.727610
# 95     8.032138
# Name: chas_alpha_l10_n, dtype: float64 14    2.544709
# 29    0.201902
# 39    5.056821
# 56    0.000000
# 73    0.181876
# 74    1.562934
# 83    3.350135
# 95    3.999771
# Name: chas_alpha_l25_n, dtype: float64
# 8 8 8

# %%
plotting([a5a,t5,n5a,c5a],["akio_10","truth","nadav_10","chas_10"])
plotting([a5b,t5,n5b,c5b],["akio_25","truth","nadav_25","chas_25"])

# %%
plotting([np.divide(t5,a5a),np.divide(t5,n5b),np.divide(t5,c5a)],["truth/akio_10","truth/nadav_25","truth/chas_10"])
plotting([np.divide(t5,a5a),np.divide(t5,n5b),np.divide(t5,c5b)],["truth/akio_10","truth/akio_25","truth/chas_25"])

# %%
t6 = df.alpha[(df["lambda"]==12) & (df["direction"]=="pull") & (df['phase_val']=="Flip") ]/1e8
print(t6)
print(len(t6))
# Out:
# 15    7.67
# 26    2.26
# 36    4.88
# 40    6.45
# 60    6.29
# 75    5.91
# 78    5.82
# 93    7.66
# Name: alpha, dtype: float64
# 8

# %%
a6a=df.akio_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Flip")  ]
a6b=-df.akio_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Flip")  ]

n6a=df.nadav_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Flip")  ]
n6b=-df.nadav_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Flip")  ]

c6a=df.chas_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Flip")  ]
c6b=df.chas_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Flip")  ]
c6c= df.chas_alpha_l12_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Flip")  ]

print(c6c)
print(a6a,a6b,n6a,n6b,c6a,c6b)
print(len(a6a),len(a6b),len(c6a))
# Out:
# 15    4.508754
# 26    1.558212
# 36    2.986836
# 40    3.843703
# 60    3.753014
# 75    3.548709
# 78    3.501636
# 93    4.503359
# Name: chas_alpha_l12_p, dtype: float64
# 15    1.06
# 26    0.89
# 36    1.07
# 40    1.23
# 60    1.24
# 75    1.25
# 78    1.25
# 93    1.32
# Name: akio_alpha_l10_p, dtype: float64 15    0.29
# 26    0.29
# 36    0.29
# 40    0.29
# 60    0.30
# 75    0.30
# 78    0.29
# 93    0.40
# Name: akio_alpha_l10_n, dtype: float64 15         NaN
# 26    3.156457
# 36    6.464115
# 40    8.467440
# 60    8.262797
# 75    7.777813
# 78    7.662775
# 93         NaN
# Name: nadav_alpha_l10_p, dtype: float64 15   NaN
# 26   NaN
# 36   NaN
# 40   NaN
# 60   NaN
# 75   NaN
# 78   NaN
# 93   NaN
# Name: nadav_alpha_l10_n, dtype: float64 15    6.005271
# 26    2.075405
# 36    3.978208
# 40    5.119481
# 60    4.998691
# 75    4.726574
# 78    4.663877
# 93    5.998085
# Name: chas_alpha_l10_p, dtype: float64 15    0.0
# 26    0.0
# 36    0.0
# 40    0.0
# 60    0.0
# 75    0.0
# 78    0.0
# 93    0.0
# Name: chas_alpha_l10_n, dtype: float64
# 8 8 8

# %%
plotting([a6a,t6,n6a,c6a,c6c],["akio_10p","truth","nadav_10p","chas_10p","chas_12p"],Title="$\lambda$=12um, TF phases flipped")
plotting([a6b,t6,n6b,c6b],["akio_10n","truth","nadav_10n","chas_10b"])

# %%
plotting([np.divide(t6,a6a),np.divide(t6,n6a),np.divide(t6,c6a)],["truth/akio_10p","truth/nadav_10p","truth/chas_10p"])
plotting([np.divide(t6,a6b),np.divide(t6,n6b),np.divide(t6,c6b)],["truth/akio_10n","truth/nadav_10n","truth/chas_10n"])

# %%
t7 = df.alpha[(df["lambda"]==12) & (df["direction"]=="pull") & (df['phase_val']=="Random") ]
print(t7)
print(len(t7))
# Out:
# 31    100000000.0
# 45    100000000.0
# 55    100000000.0
# 88    100000000.0
# Name: alpha, dtype: float64
# 4

# %%
a7a=df.akio_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random")  ]
a7b=-df.akio_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random")  ]

n7a=df.nadav_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random")  ]
n7b=-df.nadav_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random")  ]

c7a=df.chas_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random")  ]
c7b=df.chas_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random")  ]


print(a7a,a7b,n7a,n7b)
print(len(a7a),len(a7b))
# Out:
# 31    0.46
# 45    0.33
# 55    0.40
# 88    0.44
# Name: akio_alpha_l10_p, dtype: float64 31    0.38
# 45    0.48
# 55    0.43
# 88    0.36
# Name: akio_alpha_l10_n, dtype: float64 31    0.592133
# 45    0.420832
# 55         NaN
# 88    1.477102
# Name: nadav_alpha_l10_p, dtype: float64 31    0.684363
# 45         NaN
# 55    0.595197
# 88         NaN
# Name: nadav_alpha_l10_n, dtype: float64
# 4 4

# %%
plotting([a7a,n7b,t7,c7a],["akio_10p","nadav_10p","truth","chas_10p"])
plotting([a7b,n7b,t7,c7b],["akio_10n","nadav_10n","truth","chas_10n"])

# %%
t8 = df.alpha[(df["lambda"]==12) & (df["direction"]=="pull") & (df['phase_val']=="Random_TF") ]/1e8
print(t8)
print(len(t8))
# Out:
# 2     1.0
# 38    1.0
# 42    1.0
# 98    1.0
# Name: alpha, dtype: float64
# 4

# %%
a8a=df.akio_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random_TF")  ]
a8b=-df.akio_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random_TF")  ]

n8a = df.nadav_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random_TF")  ]
n8b= -df.nadav_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random_TF")  ]


c8a = df.chas_alpha_l10_p[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random_TF")  ]
c8b= df.chas_alpha_l10_n[(df["lambda"]==12)  & (df["direction"]=="pull") & (df['phase_val']=="Random_TF")  ]


print(a8a,a8b,n8a,n8b,c8a,c8b)
print(len(a8a),len(a8b))
# Out:
# 2     1.54
# 38    1.55
# 42    1.56
# 98    1.55
# Name: akio_alpha_l10_p, dtype: float64 2     0.29
# 38    0.29
# 42    0.29
# 98    0.30
# Name: akio_alpha_l10_n, dtype: float64 2     1.747108
# 38    1.746710
# 42    1.746785
# 98    1.747039
# Name: nadav_alpha_l10_p, dtype: float64 2    NaN
# 38   NaN
# 42   NaN
# 98   NaN
# Name: nadav_alpha_l10_n, dtype: float64 2     1.641697
# 38    1.642610
# 42    1.642755
# 98    1.642329
# Name: chas_alpha_l10_p, dtype: float64 2     0.0
# 38    0.0
# 42    0.0
# 98    0.0
# Name: chas_alpha_l10_n, dtype: float64
# 4 4

# %%
plotting([a8a,n8a,t8,c8a],["akio_10p","nadav_10p","truth","chas_10p"])
plotting([a8b,n8b,t8,c8b],["akio_10n","nadav_10n","truth","chas_10n"])
