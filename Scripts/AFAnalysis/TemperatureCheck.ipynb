# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
#%matplotlib widget
# remove below if used
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36
from skimage.filters import window

# %%
year = 2020
month = 10
start_day = 1
end_day = 19
bead_date = 20201006
bead_number = 1002
df=pd.DataFrame()
for day in np.arange(start_day,end_day+1,1):
    name = "/data/new_trap_processed/processed_files/{0}/Bead{1}/EnvData/{2}{3}{4}/environmental_data_{2}{3}{4}.pkl".format(bead_date,bead_number,year,str(month).zfill(2),str(day).zfill(2))
    print(name)
    df_example = pd.read_pickle(name)
    df = pd.concat([df,df_example])
    plt.plot(df_example.Time_Epoch,df_example.AirTemperature.ewm(span=100,adjust=True).mean()/22.8/10+0.9,linestyle="",marker="*")
    plt.plot(df_example.Time_Epoch,df_example.SurfaceTemperature.ewm(span=100,adjust=True).mean()/25,linestyle="",marker="*")
    #plt.plot(df_example.Time_Epoch,df_example.Pressure.ewm(span=10,adjust=True).mean(),linestyle="",marker="*")

    plt.show()
# Out:
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201001/environmental_data_20201001.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201002/environmental_data_20201002.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201003/environmental_data_20201003.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201004/environmental_data_20201004.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201005/environmental_data_20201005.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201006/environmental_data_20201006.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201007/environmental_data_20201007.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201008/environmental_data_20201008.pkl
# /data/new_trap_processed/processed_files/20201006/Bead1002/EnvData/20201009/environmental_data_20201009.pkl
# ...

# %%
df = df.reset_index()

# %%
plt.plot(df.Time_Epoch,df.AirTemperature.ewm(span=1000,adjust=True).mean(),linestyle="",marker="*")
plt.xlim(df.Time_Epoch[0],df.Time_Epoch[0]+80000)
# Out:
# (1598943600.0, 1599023600.0)
