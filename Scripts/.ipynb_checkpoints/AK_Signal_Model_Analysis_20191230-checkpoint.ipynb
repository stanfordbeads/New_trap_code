# %%
##this is derived from Signal_Model_Usage_Example_20191127.ipynb

# %%
import numpy as np
import pickle as pkl
import scipy.interpolate as interp
import scipy, sys, time
from bisect import bisect_left
import matplotlib.pyplot as plt
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile
from discharge_tools import load_dir
sys.path.append('/home/analysis_user/New_trap_code/SensitivityFramework/')
from signal_model_utilities import *

# %%
for i in range(0,70):
    L=pow(10,i/30.0-0.3)*1e-6
    D=8e-6
    test = force_vs_time(D,0e-6,300e-6,13,"x",L,yuk_or_grav="yuk",alpha=1e10)
    ofname = "/home/analysis_user/Results/AkioK/2019_12_30_SignalAnalysis/Signal2D%dumL%.02f_2.txt" % (D*1e6,L*1e6)
    
    fsamp=5000
    res=50000
    Nint=2
    Nave=3
    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    sphase=np.arctan(sFFT.imag/sFFT.real)
    Fshake=13
    f1 = open(ofname,"a")
    
    for i in range(1,int(fsamp/2/Fshake)+1):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
    
        for j in range(1,(Nint)):
            Ints+=sFFT[Fshake*10*i+j]+sFFT[Fshake*10*i-j]
            IntNSDs+=snsd[Fshake*10*i+j]+snsd[Fshake*10*i-j]
 
        AveNoiseX=0
        SigAmpX=IntNSDs-AveNoiseX*(Nint*2+1)
        SigPhaX=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, 0,0, SigPhaX, 0,0))
    f1.close()
# Out:
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.01e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.41e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.84e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.31e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.81e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.36e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.94e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 8.58e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 9.26e-07 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.08e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.17e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.26e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.36e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.47e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.58e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.71e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in true_divide
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.85e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.00e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.15e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.33e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.51e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.71e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.93e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.41e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.69e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.98e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.30e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.64e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.01e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.31e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.81e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.36e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.94e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 8.58e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 9.26e-06 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.00e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.17e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.26e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.36e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.47e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.58e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.00e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.15e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.33e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.51e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.71e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.93e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.16e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.41e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.69e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.98e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.30e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.64e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.01e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.41e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.84e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.31e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.81e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.36e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.94e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 8.58e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 9.26e-05 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.0e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 1.00e-05 is selected
# A height of 8.47e-21 is selected

# %%
#for z force
for i in range(0,70):
    L=pow(10,i/30.0-0.3)*1e-6
    D=11e-6
    test = force_vs_time(D,10e-6,300e-6,13,"z",L,yuk_or_grav="yuk",alpha=1e10)
    ofname = "/home/analysis_user/Results/AkioK/2019_12_30_SignalAnalysis/Signal2D%dumZL%.02f.txt" % (D*1e6,L*1e6)
    
    fsamp=5000
    res=50000
    Nint=2
    Nave=3
    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    sphase=np.arctan(sFFT.imag/sFFT.real)
    Fshake=13
    f1 = open(ofname,"a")
    
    for i in range(1,int(fsamp/2/Fshake)+1):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
    
        for j in range(1,(Nint)):
            Ints+=sFFT[Fshake*10*i+j]+sFFT[Fshake*10*i-j]
            IntNSDs+=snsd[Fshake*10*i+j]+snsd[Fshake*10*i-j]
 
        AveNoiseZ=0
        SigAmpZ=IntNSDs-AveNoiseX*(Nint*2+1)
        SigPhaZ=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, 0, 0,SigAmpZ, 0, 0,SigPhaZ))
    f1.close()
# Out:
# Your choice of lambda is not existing
# Taking 5.01e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.41e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.84e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.31e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.81e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.36e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.94e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 8.58e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 9.26e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.00e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.08e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.17e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.26e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.36e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.47e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.58e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.71e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.85e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.00e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.15e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.33e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.51e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.71e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.93e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.16e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.41e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.69e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in true_divide
# Your choice of lambda is not existing
# Taking 3.98e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.30e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.64e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.01e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.41e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.84e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.31e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.81e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.36e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.94e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# Your choice of lambda is not existing
# Taking 8.58e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 9.26e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.00e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.08e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.17e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.26e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.36e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.47e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.58e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.71e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.85e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.00e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.15e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.33e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.51e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.71e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.93e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.16e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.41e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.69e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.98e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.30e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.64e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.01e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.41e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.84e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.31e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.81e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.36e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.94e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 8.58e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 9.26e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected

# %%
#For 3Hz data
for i in range(0,70):
    L=pow(10,i/30.0-0.3)*1e-6
    D=11e-6
    test = force_vs_time(D,0e-6,100e-6,3,"x",L,yuk_or_grav="yuk",alpha=1e10)
    ofname = "/home/analysis_user/Results/AkioK/2019_12_30_SignalAnalysis/Signal2D%dum3HzL%.02f.txt" % (D*1e6,L*1e6)
    
    fsamp=5000
    res=50000
    Nint=2
    Nave=3
    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    sphase=np.arctan(sFFT.imag/sFFT.real)
    Fshake=3
    f1 = open(ofname,"a")
    
    for i in range(1,int(fsamp/2/Fshake)+1):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
    
        for j in range(1,(Nint)):
            Ints+=sFFT[Fshake*10*i+j]+sFFT[Fshake*10*i-j]
            IntNSDs+=snsd[Fshake*10*i+j]+snsd[Fshake*10*i-j]
 
        AveNoiseX=0
        SigAmpX=IntNSDs-AveNoiseX*(Nint*2+1)
        SigPhaX=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, 0,0, SigPhaX, 0,0))
    f1.close()
# Out:
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.01e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.41e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.84e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.31e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.81e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.36e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.94e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 8.58e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 9.26e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.08e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.17e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.26e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.36e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.47e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: divide by zero encountered in true_divide
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.58e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.71e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.85e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.00e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.15e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.33e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.51e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.71e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.93e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.41e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.69e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.98e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.30e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.64e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.01e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.31e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.81e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.36e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.94e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 8.58e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 9.26e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.00e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.17e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.26e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.36e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.47e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.58e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.00e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.15e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.33e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.51e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.71e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 2.93e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.16e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.41e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.69e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 3.98e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.30e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 4.64e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.01e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.41e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.84e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.31e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 6.81e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.36e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 7.94e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 8.58e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 9.26e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected

# %%
lambdas = np.logspace(-6.3, -3, 100)

# %%
print(lambdas)
# Out:
# [5.01187234e-07 5.41169527e-07 5.84341413e-07 6.30957344e-07
#  6.81292069e-07 7.35642254e-07 7.94328235e-07 8.57695899e-07
#  9.26118728e-07 1.00000000e-06 1.07977516e-06 1.16591440e-06
#  1.25892541e-06 1.35935639e-06 1.46779927e-06 1.58489319e-06
#  1.71132830e-06 1.84784980e-06 1.99526231e-06 2.15443469e-06
#  2.32630507e-06 2.51188643e-06 2.71227258e-06 2.92864456e-06
#  3.16227766e-06 3.41454887e-06 3.68694506e-06 3.98107171e-06
# 5.4116952654646346e-05
# 5.843414133735178e-05
# 6.309573444801932e-05
# 6.812920690579611e-05
# 7.356422544596409e-05
# 7.943282347242817e-05
# 8.57695898590894e-05
# 9.261187281287933e-05
# 9.999999999999994e-05

# %%
    L=5.01e-6
    D=11e-6
    test = force_vs_time(D,0e-6,100e-6,3,"x",L,yuk_or_grav="yuk",alpha=1e10)
    ofname = "/home/analysis_user/Results/AkioK/2019_12_30_SignalAnalysis/Signal2D%dumL%.02f_2.txt" % (D*1e6,L*1e6)
    
    fsamp=5000
    res=50000
    Nint=2
    Nave=3
    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    sphase=np.arctan(sFFT.imag/sFFT.real)
    Fshake=3
    f1 = open(ofname,"a")
    
    for i in range(1,int(fsamp/2/Fshake)+1):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
    
        for j in range(1,(Nint)):
            Ints+=sFFT[Fshake*10*i+j]+sFFT[Fshake*10*i-j]
            IntNSDs+=snsd[Fshake*10*i+j]+snsd[Fshake*10*i-j]
 
        AveNoiseX=0
        SigAmpX=IntNSDs-AveNoiseX*(Nint*2+1)
        SigPhaX=np.angle(Ints)         
        print(SigAmpX)
# Out:
# Your choice of separation or height is not existing
# Taking 1.1e-05 for separation
# Taking 8.5e-21 for height
# Your choice of lambda is not existing
# Taking 5.01e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 8.47e-21 is selected
# 3.00879105886556e-31
# 3.296333918824738e-16
# 9.331349526873257e-32
# 3.6119385676295434e-16
# 4.042331699442877e-31
# 3.23039307036682e-16
# 2.5059659172930505e-31
# 8.269686514432272e-17
# 6.693028041418881e-32
# 1.0566683726171728e-17
# 2.0625124916297074e-32
# 4.344846139133938e-18
# 3.9696279011083854e-32
# 4.198532840226643e-20
# 3.0844301064344764e-32
# 3.8780128638299686e-18
# 1.6857037901118167e-32
# 3.4436769722766545e-18
# 3.6748882901567585e-32
# 1.616351497620948e-18
# 6.025738449892048e-32
# 5.683810551145235e-19
# 1.163435957293935e-31
# 1.5818049023735226e-19
# 8.156039545060591e-32
# 2.2260736772123968e-20
# 5.570902708634182e-32
# 5.015288387468786e-20
# 1.9509173593270463e-31
# 3.480547231802979e-20
# 1.4069538132098357e-31
# 3.450894968014272e-20
# 7.616885493740579e-32
# 3.7335612508340275e-21
# 6.409355543072727e-32
# 1.2860134228750035e-20
# 5.523440195503445e-32
# 6.944097127040414e-21
# 1.2787289418283928e-31
# 7.623913375843226e-21
# 1.6204793604059162e-31
# 7.848250276531973e-21
# 3.444449071088777e-32
# 6.442218772731325e-21
# 3.5017001095180127e-32
# 6.312655943051044e-21
# 3.284032680981761e-33
# 5.222243049294056e-21
# 1.4575802575616337e-32
# 4.4438991356777165e-21
# 3.6675265630774433e-32
# 3.464114582760075e-21
# 3.394102527224213e-32
# 4.1002090190770016e-22
# 2.7855067691666415e-32
# 4.246741567716397e-22
# 1.116660685965556e-32
# 4.994525529684019e-22
# 2.554544959162699e-32
# 1.1457792442660184e-21
# 2.6301892947783997e-32
# 8.493209976617963e-22
# 1.715169731057031e-32
# 2.4497573244765553e-22
# 6.814745305010683e-33
# 9.857150180888687e-22
# 1.4217463773532345e-32
# 5.143478247612448e-22
# 1.56800640407045e-32
# 3.256011408587737e-22
# 1.9853534488130262e-32
# 4.752928652665668e-22
# 2.2189888613527828e-32
# 1.7016673365348454e-22
# 2.3783472734317814e-32
# 2.689508344779724e-22
# 1.7110527799387616e-32
# 9.508542277357612e-23
# 1.4362358819219453e-32
# 1.8992996834319473e-22
# 2.6639794678351544e-32
# 1.3064943530987622e-23
# 4.4562397410978684e-32
# 3.515436044500663e-22
# 3.221315584371265e-32
# 3.001573820179502e-22
# 3.9614634525221263e-32
# 4.235664240826791e-22
# 2.2855057647194763e-32
# 6.191562030300243e-22
# 2.3975751112009067e-32
# 2.6240864253617725e-22
# 3.8580926720446074e-32
# 8.877346580256877e-22
# 5.097335414580201e-32
# 4.920107156411133e-22
# 1.7171435341259514e-32
# 1.4144548494185696e-22
# 1.658429741106389e-32
# 5.405805579787993e-22
# 1.516673324090556e-32
# 5.803858833223393e-22
# 1.2371328833881466e-32
# 4.201199814608279e-22
# 5.2528638412253664e-33
# 3.3234522751178976e-22
# 1.0485266181099822e-32
# 1.0292320208630771e-23
# 2.1313566757988513e-32
# 6.047196732387782e-22
# 2.4771871857741704e-32
# 8.761512423359692e-22
# 1.5637976583661554e-32
# 4.35859204868927e-22
# 3.969006994421561e-32
# 4.217332555572478e-22
# 2.9868223610204116e-32
# 5.17620574672856e-22
# 2.503243213715835e-32
# 3.351814495137258e-22
# 6.303891379500119e-32
# 5.913927557091413e-23
# 5.025597627550292e-32
# 2.8237501749852307e-22
# 5.410762364233956e-32
# 3.373305189227837e-23
# 3.8011992721806743e-32
# 6.284468985988058e-23
# 2.0697077050031432e-32
# 3.8207931080398655e-23
# 3.8779394602382805e-32
# 1.9831138855378312e-22
# 4.130812774083684e-32
# 1.0301036486880813e-22
# 3.5263404721497664e-32
# 2.2411629158575924e-22
# 1.580645899654334e-32
# 6.270992875163182e-22
# 1.4835756154371555e-32
# 3.1827159921090706e-22
# 2.899805753997551e-32

# %%
#for z force with different height
for i in range(0,70):
    L=pow(10,i/30.0-0.3)*1e-6
    D=11e-6
    H=10e-6
    test = force_vs_time(D,H,300e-6,13,"z",L,yuk_or_grav="yuk",alpha=1e10)
    ofname = "/home/analysis_user/Results/AkioK/2020_01_06_SignalAnalysis/SignalD%dumH%dumL%.02f_2.txt" % (D*1e6,H*1e6,L*1e6)
    
    fsamp=5000
    res=50000
    Nint=2
    Nave=3
    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    sphase=np.arctan(sFFT.imag/sFFT.real)
    Fshake=13
    f1 = open(ofname,"a")
    
    for i in range(1,int(fsamp/2/Fshake)+1):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
    
        for j in range(1,(Nint)):
            Ints+=sFFT[Fshake*10*i+j]+sFFT[Fshake*10*i-j]
            IntNSDs+=snsd[Fshake*10*i+j]+snsd[Fshake*10*i-j]
 
        AveNoiseX=0
        SigAmpX=IntNSDs-AveNoiseX*(Nint*2+1)
        SigPhaX=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, 0,0, SigPhaX, 0,0))
    f1.close()
# Out:
# Your choice of lambda is not existing
# Taking 5.01e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.41e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.84e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.31e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.81e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.36e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.94e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 8.58e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 9.26e-07 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.00e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.08e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.17e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.26e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.36e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.47e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.58e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.71e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.85e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.00e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.15e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.33e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.51e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.71e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.93e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.16e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.41e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.69e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.98e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.30e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.64e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in true_divide
# Your choice of lambda is not existing
# Taking 5.01e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.41e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.84e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.31e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.81e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.36e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# Your choice of lambda is not existing
# Taking 7.94e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 8.58e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 9.26e-06 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.00e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.08e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.17e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.26e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.36e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.47e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.58e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.71e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.85e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.00e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.15e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.33e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.51e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.71e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 2.93e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.16e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.41e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.69e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 3.98e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.30e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 4.64e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.01e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.41e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 5.84e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.31e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 6.81e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.36e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 7.94e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 8.58e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 9.26e-05 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 1.10e-05 is selected
# A height of 1.00e-05 is selected

# %%
#for z force, 1/7 data: 9 um separation, 6 um height
for i in range(0,70):
    L=pow(10,i/30.0-0.3)*1e-6
    D=9e-6
    H=6e-6
    Fshake=3
    test = force_vs_time(D,H,100e-6,Fshake,"z",L,yuk_or_grav="yuk",alpha=1e10)
    ofname = "/home/analysis_user/Results/AkioK/2020_01_07_Bead3/SignalZD%dumH%dumL%.02f.txt" % (D*1e6,H*1e6,L*1e6)
    
    fsamp=5000
    res=50000
    Nint=2
    Nave=3
    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    sphase=np.arctan(sFFT.imag/sFFT.real)
   
    f1 = open(ofname,"a")
    
    for i in range(1,int(fsamp/2/Fshake)+1):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
    
        for j in range(1,(Nint)):
            Ints+=sFFT[Fshake*10*i+j]+sFFT[Fshake*10*i-j]
            IntNSDs+=snsd[Fshake*10*i+j]+snsd[Fshake*10*i-j]
 
        AveNoiseX=0
        SigAmpX=IntNSDs-AveNoiseX*(Nint*2+1)
        SigPhaX=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, 0,0, SigPhaX, 0,0))
    f1.close()
# Out:
# Your choice of lambda is not existing
# Taking 5.01e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.41e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.84e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 6.31e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in true_divide
# Your choice of lambda is not existing
# Taking 6.81e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 7.36e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 7.94e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 8.58e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 9.26e-07 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.08e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.17e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.26e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.36e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.47e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.58e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.71e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.85e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.00e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.15e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.33e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.51e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.71e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.93e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.16e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.41e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.69e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.98e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 4.30e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 4.64e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.01e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.41e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.84e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 6.31e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 6.81e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 7.36e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 7.94e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 8.58e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 9.26e-06 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.08e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.17e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.26e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.36e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.47e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.58e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.71e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.85e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.00e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.15e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.33e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.51e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.71e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 2.93e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.16e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.41e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.69e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 3.98e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 4.30e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 4.64e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.01e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.41e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 5.84e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 6.31e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 6.81e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 7.36e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 7.94e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 8.58e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 9.26e-05 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 9.00e-06 is selected
# A height of 6.00e-06 is selected

# %%
#for z force, 1/13 data: 8 um separation, 6 um height
for i in range(0,70):
    L=pow(10,i/30.0-0.3)*1e-6
    D=8e-6
    H=6e-6
    Fshake=3
    test = force_vs_time(D,H,100e-6,Fshake,"z",L,yuk_or_grav="yuk",alpha=1e10)
    ofname = "/home/analysis_user/Results/AkioK/2020_01_13_Bead3/SignalZD%dumH%dumL%.02f.txt" % (D*1e6,H*1e6,L*1e6)
    
    fsamp=5000
    res=50000
    Nint=2
    Nave=3
    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    
    f1 = open(ofname,"a")
    
    for i in range(1,int(fsamp/2/Fshake)+1):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
    
        for j in range(1,(Nint)):
            Ints+=sFFT[Fshake*10*i+j]+sFFT[Fshake*10*i-j]
            IntNSDs+=snsd[Fshake*10*i+j]+snsd[Fshake*10*i-j]
 
        AveNoiseX=0
        SigAmpX=IntNSDs-AveNoiseX*(Nint*2+1)
        SigPhaX=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, 0,0, SigPhaX, 0,0))
    f1.close()
