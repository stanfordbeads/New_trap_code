# %%
# import stuff
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
from scipy import signal
import h5py, time
from iminuit import Minuit, describe
from pprint import pprint # we use this to pretty print some stuff later

import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile
from discharge_tools import load_dir

# %%
def shift_correct(input_pos,idx):
    output_pos = np.insert(input_pos,0,np.linspace(0,0,idx))
    return output_pos

def gaussian(data_x,params=list):
    norm = (1/((1/2*params[2])*np.sqrt(np.pi * 2)))
    return params[0] * norm * np.exp(-(np.subtract(data_x,params[1])**2/(2*params[2]**2)))+params[3]

def gaussian_cdf(data_x,params=list):
    # for normalization a 1/sigma could be needed
    return params[0]*0.5*(1+scipy.special.erf((data_x-params[1])/(np.sqrt(2)*params[2])))+params[3]

def linear(data_x,params=list):
    return params[0]*data_x+params[1]

def chisquare_1d(function, functionparams, data_x, data_y,data_y_error):
    chisquarevalue=np.sum(np.power(np.divide(np.subtract(function(data_x,functionparams),data_y),data_y_error),2))
    ndf = len(data_y)-len(functionparams)
    #print(ndf)
    return (chisquarevalue, ndf)

def chisquare_linear(a,b):
    return chisquare_1d(function=linear,functionparams=[a,b],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]

def chisquare_gaussian(area,mean,sigma,constant):
    return chisquare_1d(function=gaussian,functionparams=[area,mean,sigma,constant],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]

def chisquare_gaussian_cdf(amp,mean,sigma,constant):
    return chisquare_1d(function=gaussian_cdf,functionparams=[amp,mean,sigma,constant],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]

# %%
pos_list=np.asarray([-0.007,4.968,9.91])
y_err=np.asarray([0.01,0.01,0.01])
val = np.asarray([0,250,500])
data_x=val
data_y=pos_list
data_y_error=y_err
m2=Minuit(chisquare_linear, 
     a = 100,
     b=0,
     errordef = 1,
     print_level=1)

m2.migrad()

print(m2.values["a"],m2.values["b"])
plt.plot(val,pos_list)
plt.plot(val,m2.values["a"]*val+m2.values["b"])
# Out:
# ------------------------------------------------------------------
# | FCN = 1.815                   |      Ncalls=35 (35 total)      |
# | EDM = 1.22E-11 (Goal: 1E-05)  |            up = 1.0            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# 0.019834000085488412 -0.0015000315197539749
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: InitialParamWarning: Parameter a is floating but does not have initial step size. Assume 1.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: InitialParamWarning: Parameter b is floating but does not have initial step size. Assume 1.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# calibration of the voltage - position conversion

def voltage_to_position(voltage,slope=0.019834000085488412,offset=-0.0015000315197539749,redo=False):
    if(redo==True):
        pos_list=np.asarray([-0.007,4.968,9.91])
        y_err=np.asarray([0.01,0.01,0.01])
        val = np.asarray([0,250,500])
        data_x=val
        data_y=pos_list
        data_y_error=y_err
        m2=Minuit(chisquare_linear, 
             a = 100,
             b=0,
             errordef = 1,
             print_level=1)
        m2.migrad()
        print(m2.values["a"],m2.values["b"])
        plt.plot(val,pos_list,marker="*")
        plt.plot(val,m2.values["a"]*val+m2.values["b"])
        slope = m2.values["a"]
        offset = m2.values["b"]
    position=(voltage-offset)/slope
    return position

# %%
# load the data
Day = "07"
Month = "01"
Year = "2020"
BeadNumber = 1
#RunNumber = 144
folder =  r"/home/data_transfer/data_from_windows/" + Year + Month + Day +"/Bead"+str(BeadNumber)+"/Shaking/"
#folder =  r"/home/data_transfer/data_from_windows/" + Year + Month + Day +"/NoBead"+"/Shaking/"
files = load_dir(folder, file_prefix = 'BeamProfiling', max_file=500)
pos_x = files[0].cant_pos[0]
pos_y = files[0].cant_pos[1]
pos_z = files[0].cant_pos[2]
quad_sum = files[0].quad_sum
# Out:
# 200  files in folder
# 200  files loaded

# %%
for i in np.arange(0,len(files),1):
    print(files[i].fname)
# Out:
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_0.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_0.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_1.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_1.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_2.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_2.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_3.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_3.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_4.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_4.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_5.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_5.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_6.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_6.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_7.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_7.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_8.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_8.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_9.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_9.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_10.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_10.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_11.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_11.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_12.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_12.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_13.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_13.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_14.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_14.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_15.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_15.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_16.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_16.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_17.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_17.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_18.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_18.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_19.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_19.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_20.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_20.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_21.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_21.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_22.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_22.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_23.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_23.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_24.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_24.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_25.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_25.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_26.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_26.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_27.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_27.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_28.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_28.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_29.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_29.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_30.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_30.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_31.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_31.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_32.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_32.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_33.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_33.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_34.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_34.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_35.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_35.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_36.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_36.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_37.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_37.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_38.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_38.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_39.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_39.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_40.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_40.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_41.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_41.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_42.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_42.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_43.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_43.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_44.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_44.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_45.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_45.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_46.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_46.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_47.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_47.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_48.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_48.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_49.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_49.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_50.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_50.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_51.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_51.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_52.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_52.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_53.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_53.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_54.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_54.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_55.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_55.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_56.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_56.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_57.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_57.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_58.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_58.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_59.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_59.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_60.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_60.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_61.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_61.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_62.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_62.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_63.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_63.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_64.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_64.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_65.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_65.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_66.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_66.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_67.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_67.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_68.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_68.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_69.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_69.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_70.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_70.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_71.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_71.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_72.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_72.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_73.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_73.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_74.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_74.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_75.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_75.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_76.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_76.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_77.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_77.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_78.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_78.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_79.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_79.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_80.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_80.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_81.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_81.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_82.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_82.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_83.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_83.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_84.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_84.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_85.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_85.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_86.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_86.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_87.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_87.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_88.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_88.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_89.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_89.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_90.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_90.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_91.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_91.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_92.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_92.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_93.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_93.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_94.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_94.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_95.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_95.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_96.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_96.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_97.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_97.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_98.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_98.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling1_99.h5
# /home/data_transfer/data_from_windows/20200107/Bead1/Shaking/BeamProfiling2_99.h5

# %%
len(quad_sum)
# Out:
# 5000

# %%
#Beam Profile for X
def get_average_mean_position(file_list):
    position_list = []
    sigma_list=[]
    def chisquare_gaussian_cdf(amp,mean,sigma,constant):
        return chisquare_1d(function=gaussian_cdf,functionparams=[amp,mean,sigma,constant],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]
    
    for i in np.arange(0,len(file_list),1):#len(file_list),1):
        print(i)
        data_x = file_list[i].cant_pos[0] # give x data
        data_y = file_list[i].quad_sum# give y data 
        data_y_error = np.sqrt(np.abs(data_y)) # give y uncertainty  
        m=Minuit(chisquare_gaussian_cdf, 
         amp = -1.7e9, # set start parameter
         #limit_area= (limit_lower,limit_upper) # if you want to limit things
         #limit_amp = (-3e-9,-1.5e-9), # you can also fix it
         mean = 7.9,
         #fix_mean = "True",
         #limit_mean = (3500,4500),
         sigma = 0.3e-1,
         constant = 1.0e9,
         #fix_constant="True",
         errordef = 1,
         print_level=0,pedantic=False)
         #print('Now proceed with the fit.')
        m.migrad(ncall=500000)
        print(m.values["amp"])
        position_list.append(voltage_to_position(m.values["mean"]))
        sigma_list.append(m.values["sigma"])
        plt.plot(voltage_to_position(data_x),data_y)
        plt.plot(voltage_to_position(data_x),gaussian_cdf(data_x,params=[m.values["amp"],(m.values["mean"]),m.values["sigma"],m.values["constant"]]),alpha=1)
        plt.show() 
    return position_list,np.mean(position_list),np.std(position_list),sigma_list

# %%
fit = get_average_mean_position(files[0:200])
# Out:
# 0
# -1676749422.0743656
# 1
# 10800293736701.512
# 2
# -1677103443.991462
# 3
# 7223996185865.75
# 4
# -1677656399.690836
# 5
# 6639273291402.487
# 6
# -1677431121.3567815
# 7
# 6315243649236.9375
# 8
# -1323255180.1422498
# 9
# 3979463868620.678
# 10
# -1986951466.719332
# 11
# 24409177397140.742
# 12
# -1674563478.2250583
# 13
# 7315719941192.941
# 14
# -1677237187.3770325
# 15
# 3483346747905.498
# 16
# -1197679929.6153936
# 17
# 17591205099091.438
# 18
# -1682357842.7582707
# 19
# 5342106200611.3125
# 20
# -390871506.7504488
# 21
# 21542197243712.973
# 22
# -676532289.8105581
# 23
# 8378483013476.293
# 24
# -803344642.8172733
# 25
# 10318507933254.477
# 26
# -1334980769.014333
# 27
# 4902181434438.94
# 28
# -1680435711.0167918
# 29
# 7473562300055.133
# 30
# -1681194449.1436107
# 31
# 13891790970560.19
# 32
# -1677458368.9231794
# 33
# 4808204867309.604
# 34
# -1249594421.7954648
# 35
# 6056572667751.977
# 36
# -1678140090.0726035
# 37
# 15788612701454.691
# 38
# -1677004978.8995209
# 39
# 4461038920291.203
# 40
# -1676287297.6671352
# 41
# 5339379113219.825
# 42
# -1677839555.2712479
# 43
# 29924460180788.086
# 44
# -1682956936.5328743
# 45
# 5712223247284.798
# 46
# -1683314962.9988952
# 47
# 25233798249640.496
# 48
# -1686387608.2174652
# 49
# 4133226125765.251
# 50
# -1681176581.7084515
# 51
# 15739016300976.125
# 52
# -1680989506.6536367
# 53
# 27430690264768.71
# 54
# -1684558855.4027991
# 55
# 9735516287105.35
# 56
# -1687456379.3792481
# 57
# 25319497498606.836
# 58
# -1689240589.5939186
# 59
# 3700703823030.0137
# 60
# -1688282559.162429
# 61
# 8660075961347.153
# 62
# -1686836358.5125935
# 63
# 5006685678199.645
# 64
# -1688366465.629281
# 65
# 16900683974293.773
# 66
# -1682095584.088746
# 67
# 6510488897116.242
# 68
# -1680145888.8018236
# 69
# 8288578524292.593
# 70
# -1680180028.3539505
# 71
# 16458484299653.299
# 72
# -1678399819.2245052
# 73
# 9319226692908.246
# 74
# -1679304676.0773475
# 75
# 4382159511850.639
# 76
# -1683824894.1082385
# 77
# 14325209801034.441
# 78
# -1684966771.5597987
# 79
# 7734108510330.882
# 80
# -1684987699.0789883
# 81
# 4061973014666.5586
# 82
# -1682167129.379148
# 83
# 8952827590040.979
# 84
# -1680946739.8597596
# 85
# 4697735865485.051
# 86
# -1682673250.2201004
# 87
# 16303211784406.266
# 88
# -1679278953.467614
# 89
# 11773551625947.705
# 90
# -1680620648.8042653
# 91
# 19874021009563.59
# 92
# -1679987770.534759
# 93
# 4286099577117.778
# 94
# -1678912736.8840787
# 95
# 5406997798739.108
# 96
# -1678020138.9285314
# 97
# 17618698803537.023
# 98
# -1396475087.4436345
# 99
# 8893996636858.488
# 100
# -1672962215.665086
# 101
# 7484015898669.609
# 102
# -1673149144.6627653
# 103
# 16143228590431.842
# 104
# -1673076671.0476732
# 105
# 25759107988162.46
# 106
# -1675293084.3553193
# 107
# 13547381364798.688
# 108
# -1677173928.2647917
# 109
# 10550824902697.441
# 110
# -1683283253.1911585
# 111
# 11068295100843.705
# 112
# -1686653973.2881951
# 113
# 22677408811484.92
# 114
# -1686008549.910652
# 115
# 12736558025225.707
# 116
# -1685055083.0074894
# 117
# 5032210101509.824
# 118
# -1686786831.4660826
# 119
# 5024238343497.814
# 120
# -1686906167.0945916
# 121
# 4330239869494.851
# 122
# -1686821293.402155
# 123
# 3942521107360.666
# 124
# -1693311298.2114854
# 125
# 27654172936835.586
# 126
# -1693563672.9832666
# 127
# 4867921635184.578
# 128
# -1690763400.224511
# 129
# 8121955851256.039
# 130
# -1688628894.0842464
# 131
# 21402823063815.562
# 132
# -1690976780.4379485
# 133
# 4967705486673.041
# 134
# -1692527618.8747654
# 135
# 13244966293698.926
# 136
# -1694749324.8318815
# 137
# 8548399131052.169
# 138
# -1695579116.546988
# 139
# 37104565815211.64
# 140
# -1696020010.5805392
# 141
# 12541742410455.291
# 142
# -1694286405.4655454
# 143
# 3634249532363.048
# 144
# -1692445367.4375505
# 145
# 66164613064330.32
# 146
# -1691474056.5784807
# 147
# 4943124811212.77
# 148
# -2023979894.9659536
# 149
# 5751010454506.17
# 150
# -1685806969.1678553
# 151
# 3694013835888.853
# 152
# -1683136012.5029714
# 153
# 9666806324084.068
# 154
# -1683465469.6864076
# 155
# 4237156441905.701
# 156
# -1685914299.7173872
# 157
# 6437040573784.219
# 158
# -1690550519.596039
# 159
# 4691745193961.607
# 160
# -1689498021.960707
# 161
# 14560369683763.957
# 162
# -1691653900.617646
# 163
# 7337384956803.976
# 164
# -1690106606.7151964
# 165
# 11317263577453.582
# 166
# -1684438928.8487897
# 167
# 7398255672675.98
# 168
# -1685702327.275367
# 169
# 6585595786302.93
# 170
# -1685635694.159628
# 171
# 11173451276004.613
# 172
# -1685292719.0929303
# 173
# 5830107057330.414
# 174
# -1688057100.821455
# 175
# 4323485952013.414
# 176
# -1689603229.9640417
# 177
# 10825632491563.36
# 178
# -1691439253.0297732
# 179
# 23338308609793.02
# 180
# -1692055709.3464718
# 181
# 4336205980596.261
# 182
# -1687387813.262676
# 183
# 6515061629276.494
# 184
# -1685308263.4211624
# 185
# 5482552514304.852
# 186
# -1686975038.4044046
# 187
# 6575871416831.317
# 188
# -1683630970.4344354
# 189
# 19066692020099.04
# 190
# -1685385751.05195
# 191
# 6044417038458.587
# 192
# -1689038989.2556505
# 193
# 6752845352772.367
# 194
# -1687463609.4329786
# 195
# 8136614901780.586
# 196
# -1686841883.3174288
# 197
# 4866484976632.016
# 198
# -1683371730.3038616
# 199
# 7194136102328.688

# %%
fit[3]
# Out:
# [0.04754978482879285,
#  8754.004059302386,
#  0.047926415725441256,
#  5717.594082553506,
#  0.04792223850624872,
#  5334.03596675721,
#  0.047939343038520786,
#  5042.265185079486,
#  0.0005657496565142919,
#  3114.7699634273927,
#  0.002041089094330414,
#  19932.134733541287,
#  0.04734587500572542,
#  5902.4717972438,
#  0.047602444662411036,
#  2748.728530311691,
#  0.00023752033958838667,
#  14069.942109577312,
#  0.04809547190944734,
#  4271.115891147873,
#  0.0038819010812478276,
#  17045.396876696504,
#  0.033522415793105775,
#  6621.518830409488,
#  0.059215188470150615,
#  8117.10285083667,
#  0.6618253853511435,
#  3909.978283003246,
#  0.04902251177287786,
#  5918.693115748845,
#  0.04921082687175505,
#  11389.530484783394,
#  0.04911382106780868,
#  3929.9963783854023,
#  0.2759715676839577,
#  4808.662369081208,
#  0.04884225675740285,
#  12548.836062737628,
#  0.04898038982206215,
#  3565.0763314727765,
#  0.04900310263920727,
#  4283.532511948877,
#  0.04914744087855766,
#  23595.312489314827,
#  0.04954460173143085,
#  4527.4453202544655,
#  0.04960722353168038,
#  19820.54705258443,
#  0.04973314452901851,
#  3233.001005885013,
#  0.05026671781492311,
#  12698.39536891973,
#  0.050880413555647444,
#  21644.70510644018,
#  0.05131171988279215,
#  7601.5978499971625,
#  0.05167478330320818,
#  19586.879044660698,
#  0.05182945293202895,
#  2893.9677797532,
#  0.05266013819438019,
#  6750.897023209454,
#  0.05339643554560935,
#  3912.967251539517,
#  0.05365048668716542,
#  13232.89390324559,
#  0.053904353110657895,
#  5075.6109014240565,
#  0.05480991619518768,
#  6401.612312144021,
#  0.055754144157532125,
#  12917.577616169683,
#  0.05623797972450385,
#  28.462985859269004,
#  0.0569068314268976,
#  3398.423753355829,
#  0.05765285485008115,
#  11257.74067252612,
#  0.058315152601300206,
#  6289.307444109274,
#  0.05882710553399223,
#  3278.074935874517,
#  0.05953521447593514,
#  7027.398469974502,
#  0.06023025659064182,
#  3661.535386771868,
#  0.06072645590570306,
#  12815.649078838973,
#  0.061334317805100305,
#  9289.08662608264,
#  0.062203782487163725,
#  15874.958802819301,
#  0.06261831907732726,
#  3436.7880996158156,
#  0.06341273808060068,
#  4333.604961354686,
#  0.06415129051592629,
#  14026.01753671333,
#  0.00774874759133537,
#  7113.945176326133,
#  0.06511584998605759,
#  5886.947385955786,
#  0.06587527493097471,
#  12579.773501177075,
#  0.06624821139059084,
#  20750.86180200911,
#  0.06694959009153713,
#  10797.240490770424,
#  0.06787850517956712,
#  8464.070950537127,
#  0.06863628375679309,
#  8671.606422297204,
#  0.0691568835461356,
#  18027.084574234646,
#  0.06917893341818475,
#  10033.563209206524,
#  0.06990656395193906,
#  3930.966607377436,
#  0.07080025685338044,
#  4018.4254628224935,
#  0.07141686607203732,
#  3510.758606851566,
#  0.07233691636011935,
#  3125.2251517915847,
#  0.07326656019855156,
#  21749.323547043346,
#  0.07311033208450603,
#  3912.9344714650315,
#  0.073960838452318,
#  6518.227912538861,
#  0.07496204866414047,
#  17449.833128201783,
#  0.07609996590191084,
#  4015.601941435434,
#  0.07645060511424079,
#  11062.297322775088,
#  0.07692605384271826,
#  6975.803567621628,
#  0.0773820154460269,
#  30287.597194539452,
#  0.07825741811513892,
#  10166.135784351343,
#  0.07908797317824791,
#  2934.8039021916616,
#  0.0798913919249213,
#  52421.385008309204,
#  0.08049286812876161,
#  3964.1873301248315,
#  0.01817946869916892,
#  4786.445463535192,
#  0.08214010578622162,
#  2985.806461193973,
#  0.08264437918071128,
#  7858.7239376165835,
#  0.083412363591991,
#  3359.0503643090306,
#  0.08387112147036915,
#  5152.762254540398,
#  0.08450720934727937,
#  3720.178018481137,
#  0.08482431286342022,
#  11944.41514239231,
#  0.08566684017621229,
#  6029.399617542465,
#  0.0866359925483268,
#  9337.325085530278,
#  0.08736445264898038,
#  5891.245654916447,
#  0.0880951563828586,
#  5358.884182201886,
#  0.08898414008530532,
#  9239.801379278064,
#  0.089431013432376,
#  4801.7897045209975,
#  0.08991553332098705,
#  3606.6368097842824,
#  0.09027700672891871,
#  9049.612927254606,
#  0.0910007634524055,
#  19492.48696814246,
#  0.09188773826034537,
#  3540.9490659491958,
#  0.09242917148201223,
#  5451.206983712227,
#  0.09353419236717858,
#  4554.493304014148,
#  0.09438885667574325,
#  5208.623319114454,
#  0.0947752984657512,
#  15818.405401004791,
#  0.09548135266969449,
#  4945.42913834547,
#  0.09590657540778393,
#  5398.460572760912,
#  0.09653351495425638,
#  6557.107770774754,
#  0.0971947551426907,
#  3976.355439491336,
#  0.09807240915503974,
#  5916.787334041881]

# %%
#Beam Profile for X
def get_average_mean_position(file_list):
    position_list = []
    sigma_list=[]
    def chisquare_gaussian_cdf(amp,mean,sigma,constant):
        return chisquare_1d(function=gaussian_cdf,functionparams=[amp,mean,sigma,constant],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]
    
    for i in np.arange(0,len(file_list),1):#len(file_list),1):
        print(i)
        data_x = file_list[i].cant_pos[1] # give x data
        data_y = file_list[i].quad_sum# give y data 
        data_y_error = np.sqrt(np.abs(data_y)) # give y uncertainty  
        m=Minuit(chisquare_gaussian_cdf, 
         amp = 1.7e9, # set start parameter
         #limit_area= (limit_lower,limit_upper) # if you want to limit things
         #limit_amp = (-3e-9,-1.5e-9), # you can also fix it
         mean = 7.9,
         #fix_mean = "True",
         #limit_mean = (3500,4500),
         sigma = 0.3e-1,
         constant = -1.0e9,
         #fix_constant="True",
         errordef = 1,
         print_level=0,pedantic=False)
         #print('Now proceed with the fit.')
        m.migrad(ncall=500000)
        print(m.values["amp"])
        position_list.append(voltage_to_position(m.values["mean"]))
        sigma_list.append(m.values["sigma"])
        plt.plot(voltage_to_position(data_x),data_y)
        plt.plot(voltage_to_position(data_x),gaussian_cdf(data_x,params=[m.values["amp"],(m.values["mean"]),m.values["sigma"],m.values["constant"]]),alpha=1)
        plt.show() 
    return position_list,np.mean(position_list),np.std(position_list),sigma_list

# %%
get_average_mean_position(files[0:2])
# Out:
# 0
# -1700000000.0
# 1
# -1700000000.0
# ([398.38156687822664, 466.4465055785007],
#  432.41403622836367,
#  34.032469350137035,
#  [0.03, 0.03])

# %%
fit[3]
# Out:
# [0.04754978482879285,
#  8754.004059302386,
#  0.047926415725441256,
#  5717.594082553506,
#  0.04792223850624872,
#  5334.03596675721,
#  0.047939343038520786,
#  5042.265185079486,
#  0.0005657496565142919,
#  3114.7699634273927,
#  0.002041089094330414,
#  19932.134733541287,
#  0.04734587500572542,
#  5902.4717972438,
#  0.047602444662411036,
#  2748.728530311691,
#  0.00023752033958838667,
#  14069.942109577312,
#  0.04809547190944734,
#  4271.115891147873,
#  0.0038819010812478276,
#  17045.396876696504,
#  0.033522415793105775,
#  6621.518830409488,
#  0.059215188470150615,
#  8117.10285083667,
#  0.6618253853511435,
#  3909.978283003246,
#  0.04902251177287786,
#  5918.693115748845,
#  0.04921082687175505,
#  11389.530484783394,
#  0.04911382106780868,
#  3929.9963783854023,
#  0.2759715676839577,
#  4808.662369081208,
#  0.04884225675740285,
#  12548.836062737628,
#  0.04898038982206215,
#  3565.0763314727765,
#  0.04900310263920727,
#  4283.532511948877,
#  0.04914744087855766,
#  23595.312489314827,
#  0.04954460173143085,
#  4527.4453202544655,
#  0.04960722353168038,
#  19820.54705258443,
#  0.04973314452901851,
#  3233.001005885013,
#  0.05026671781492311,
#  12698.39536891973,
#  0.050880413555647444,
#  21644.70510644018,
#  0.05131171988279215,
#  7601.5978499971625,
#  0.05167478330320818,
#  19586.879044660698,
#  0.05182945293202895,
#  2893.9677797532,
#  0.05266013819438019,
#  6750.897023209454,
#  0.05339643554560935,
#  3912.967251539517,
#  0.05365048668716542,
#  13232.89390324559,
#  0.053904353110657895,
#  5075.6109014240565,
#  0.05480991619518768,
#  6401.612312144021,
#  0.055754144157532125,
#  12917.577616169683,
#  0.05623797972450385,
#  28.462985859269004,
#  0.0569068314268976,
#  3398.423753355829,
#  0.05765285485008115,
#  11257.74067252612,
#  0.058315152601300206,
#  6289.307444109274,
#  0.05882710553399223,
#  3278.074935874517,
#  0.05953521447593514,
#  7027.398469974502,
#  0.06023025659064182,
#  3661.535386771868,
#  0.06072645590570306,
#  12815.649078838973,
#  0.061334317805100305,
#  9289.08662608264,
#  0.062203782487163725,
#  15874.958802819301,
#  0.06261831907732726,
#  3436.7880996158156,
#  0.06341273808060068,
#  4333.604961354686,
#  0.06415129051592629,
#  14026.01753671333,
#  0.00774874759133537,
#  7113.945176326133,
#  0.06511584998605759,
#  5886.947385955786,
#  0.06587527493097471,
#  12579.773501177075,
#  0.06624821139059084,
#  20750.86180200911,
#  0.06694959009153713,
#  10797.240490770424,
#  0.06787850517956712,
#  8464.070950537127,
#  0.06863628375679309,
#  8671.606422297204,
#  0.0691568835461356,
#  18027.084574234646,
#  0.06917893341818475,
#  10033.563209206524,
#  0.06990656395193906,
#  3930.966607377436,
#  0.07080025685338044,
#  4018.4254628224935,
#  0.07141686607203732,
#  3510.758606851566,
#  0.07233691636011935,
#  3125.2251517915847,
#  0.07326656019855156,
#  21749.323547043346,
#  0.07311033208450603,
#  3912.9344714650315,
#  0.073960838452318,
#  6518.227912538861,
#  0.07496204866414047,
#  17449.833128201783,
#  0.07609996590191084,
#  4015.601941435434,
#  0.07645060511424079,
#  11062.297322775088,
#  0.07692605384271826,
#  6975.803567621628,
#  0.0773820154460269,
#  30287.597194539452,
#  0.07825741811513892,
#  10166.135784351343,
#  0.07908797317824791,
#  2934.8039021916616,
#  0.0798913919249213,
#  52421.385008309204,
#  0.08049286812876161,
#  3964.1873301248315,
#  0.01817946869916892,
#  4786.445463535192,
#  0.08214010578622162,
#  2985.806461193973,
#  0.08264437918071128,
#  7858.7239376165835,
#  0.083412363591991,
#  3359.0503643090306,
#  0.08387112147036915,
#  5152.762254540398,
#  0.08450720934727937,
#  3720.178018481137,
#  0.08482431286342022,
#  11944.41514239231,
#  0.08566684017621229,
#  6029.399617542465,
#  0.0866359925483268,
#  9337.325085530278,
#  0.08736445264898038,
#  5891.245654916447,
#  0.0880951563828586,
#  5358.884182201886,
#  0.08898414008530532,
#  9239.801379278064,
#  0.089431013432376,
#  4801.7897045209975,
#  0.08991553332098705,
#  3606.6368097842824,
#  0.09027700672891871,
#  9049.612927254606,
#  0.0910007634524055,
#  19492.48696814246,
#  0.09188773826034537,
#  3540.9490659491958,
#  0.09242917148201223,
#  5451.206983712227,
#  0.09353419236717858,
#  4554.493304014148,
#  0.09438885667574325,
#  5208.623319114454,
#  0.0947752984657512,
#  15818.405401004791,
#  0.09548135266969449,
#  4945.42913834547,
#  0.09590657540778393,
#  5398.460572760912,
#  0.09653351495425638,
#  6557.107770774754,
#  0.0971947551426907,
#  3976.355439491336,
#  0.09807240915503974,
#  5916.787334041881]

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.plot(pos_x,quad_sum, '-', label="x",markersize=1,linewidth=1)

# %%
print(pos_x)
# Out:
# [2.98754468 2.98930561 2.99123855 ... 2.98272226 2.98474852 2.98666704]
