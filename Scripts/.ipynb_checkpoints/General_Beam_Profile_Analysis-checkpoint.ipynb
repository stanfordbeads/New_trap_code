# %%
# import stuff
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
from scipy import signal
import h5py, time
from iminuit import Minuit, describe
from pprint import pprint # we use this to pretty print some stuff later

import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile
from discharge_tools import load_dir

# %%
def shift_correct(input_pos,idx):
    output_pos = np.insert(input_pos,0,np.linspace(0,0,idx))
    return output_pos


def gaussian(data_x,params=list):
    norm = (1/((1/2*params[2])*np.sqrt(np.pi * 2)))
    return params[0] * norm * np.exp(-(np.subtract(data_x,params[1])**2/(2*params[2]**2)))+params[3]

def gaussian_cdf(data_x,params=list):
    # for normalization a 1/sigma could be needed
    return params[0]*0.5*(1+scipy.special.erf((data_x-params[1])/(np.sqrt(2)*params[2])))+params[3]

def chisquare_1d(function, functionparams, data_x, data_y,data_y_error):
    chisquarevalue=np.sum(np.power(np.divide(np.subtract(function(data_x,functionparams),data_y),data_y_error),2))
    ndf = len(data_y)-len(functionparams)
    #print(ndf)
    return (chisquarevalue, ndf)

def linear(data_x,params=list):
    return params[0]*data_x+params[1]

def chisquare_linear(a,b):
    return chisquare_1d(function=linear,functionparams=[a,b],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]

def chisquare_gaussian(area,mean,sigma,constant):
    return chisquare_1d(function=gaussian,functionparams=[area,mean,sigma,constant],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]

def chisquare_gaussian_cdf(amp,mean,sigma,constant):
    return chisquare_1d(function=gaussian_cdf,functionparams=[amp,mean,sigma,constant],data_x=data_x,data_y=data_y,data_y_error=data_y_error)[0]

# %%
# calibration of the voltage - position conversion

def voltage_to_position(voltage,slope=,offset=,redo=False):
pos_list=np.asarray([-0.007,4.968,9.91])
y_err=np.asarray([0.01,0.01,0.01])
val = np.asarray([0,250,500])


data_x=val
data_y=pos_list
data_y_error=y_err

m2=Minuit(chisquare_linear, 
         a = 100,
         b=0,# set start parameter
         #limit_area= (
         errordef = 1,
         print_level=1)
m2.migrad()

plt.plot(val,pos_list)
plt.plot(val,m2.values["a"]*val+m2.values["b"])

# %%
# load the data
Day = "12"
Month = "08"
Year = "2019"
BeadNumber = 1
RunNumber = 144
folder =  r"/home/data_transfer/data_from_windows/" + Year + Month + Day +"/Bead"+str(BeadNumber)+"/Shaking/"
files = load_dir(folder, file_prefix = 'BeamProfiling' + str(RunNumber), max_file=500)
pos_x = files[0].cant_pos[0]
pos_y = files[0].cant_pos[1]
pos_z = files[0].cant_pos[2]
quad_sum = files[0].quad_sum
# Out:
# 1  files in folder
# 1  files loaded

# %%
x = np.arange(0,len(pos_x)/5000,1/5000)
plt.plot(x,pos_x)
plt.plot(x,pos_y)
plt.plot(x,pos_z)

# %%
plt.plot(x,quad_sum)
plt.plot(x,quad_sum[0]/(pos_x[0])*pos_x)

# %%
pos_x
# Out:
# array([8.66623674, 8.66616484, 8.66621967, ..., 8.66521018, 8.66585587,
#        8.6664241 ])

# %%
data_x = pos_x # give x data
data_y = quad_sum # give y data 
data_y_error = np.sqrt(np.abs(quad_sum)) # give y uncertainty

# %%
m=Minuit(chisquare_gaussian_cdf, 
         amp = -1.75e9, # set start parameter
         #limit_area= (limit_lower,limit_upper) # if you want to limit things
         #limit_amp =  # you can also fix it
         mean = 7.6,
         #fix_mean = "True",
         #limit_mean = (3500,4500),
         sigma = 0.5e-1,
         constant = 1.75e9,
         #fix_constant="True",
         errordef = 1,
         print_level=1)
#print('Now proceed with the fit.')
m.migrad(ncall=500000)
#m.minos(), if you need fancy mapping
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: InitialParamWarning: Parameter amp is floating but does not have initial step size. Assume 1.
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: InitialParamWarning: Parameter mean is floating but does not have initial step size. Assume 1.
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: InitialParamWarning: Parameter sigma is floating but does not have initial step size. Assume 1.
#   if sys.path[0] == '':
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:12: InitialParamWarning: Parameter constant is floating but does not have initial step size. Assume 1.
#   if sys.path[0] == '':
# ------------------------------------------------------------------
# | FCN = 4.848E+10               |     Ncalls=167 (167 total)     |
# | EDM = 1.14E-08 (Goal: 1E-05)  |            up = 1.0            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# | FCN = 4.848E+10               |     Ncalls=167 (167 total)     |
# | EDM = 1.14E-08 (Goal: 1E-05)  |            up = 1.0            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# |   | Name     |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ----------------------------------------------------------------------------------------------
# | 0 | amp      | -1.791E9  |  0.000E9  |            |            |         |         |       |
# | 1 | mean     |  0.881E1  |  0.000E1  |            |            |         |         |       |
# | 2 | sigma    | 0.466E-1  | 0.000E-1  |            |            |         |         |       |
# | 3 | constant |  1.801E9  |  0.000E9  |            |            |         |         |       |
# ----------------------------------------------------------------------------------------------

# %%
(m.values["mean"]-m2.values["b"])/m2.values["a"]
# Out:
# 444.09168133765525

# %%
m.values["sigma"]*500/9.9
# Out:
# 3.073000537335025

# %%
plt.plot(pos_x,quad_sum)
plt.plot(data_x,norm_cdf(data_x,m.values["amp"],m.values["mean"],m.values["sigma"],m.values["constant"]))

# %%
m.draw_mnprofile('mean',bound = 5, bins = 100)
# Out:
# (array([7.675121  , 7.67512101, 7.67512102, 7.67512103, 7.67512104,
#         7.67512105, 7.67512106, 7.67512107, 7.67512108, 7.67512109,
#         7.6751211 , 7.67512111, 7.67512112, 7.67512113, 7.67512114,
#         7.67512115, 7.67512116, 7.67512117, 7.67512118, 7.67512119,
#         7.6751212 , 7.67512121, 7.67512122, 7.67512123, 7.67512124,
#         7.67512125, 7.67512126, 7.67512127, 7.67512128, 7.67512129,
#         7.6751213 , 7.67512131, 7.67512132, 7.67512133, 7.67512134,
#         7.67512135, 7.67512136, 7.67512137, 7.67512139, 7.6751214 ,
#         7.67512141, 7.67512142, 7.67512143, 7.67512144, 7.67512145,
#         7.67512146, 7.67512147, 7.67512148, 7.67512149, 7.6751215 ,
#         7.67512151, 7.67512152, 7.67512153, 7.67512154, 7.67512155,
#         7.67512156, 7.67512157, 7.67512158, 7.67512159, 7.6751216 ,
#         7.67512161, 7.67512162, 7.67512163, 7.67512164, 7.67512165,
#         7.67512166, 7.67512167, 7.67512168, 7.67512169, 7.6751217 ,
#         7.67512171, 7.67512172, 7.67512173, 7.67512174, 7.67512175,
#         7.67512176, 7.67512177, 7.67512178, 7.67512179, 7.6751218 ,
#         7.67512181, 7.67512182, 7.67512183, 7.67512184, 7.67512185,
#         7.67512186, 7.67512187, 7.67512188, 7.67512189, 7.67512191,
