# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# load the files
bead_date =20200320
bead_number = 1
dataset = "/Shaking/Shaking378/"
FOI = "Shaking3"
dirname ="/data/new_trap/" + str(bead_date) + "/Bead%s/" %bead_number +dataset
filename = dirname + FOI

# %%
base_proc = "/data/new_trap_processed/processed_files/" + str(bead_date) +  "/Bead%s/" %bead_number
outputname = base_proc + dataset+FOI+"_spin.pkl"
df = pd.read_pickle(outputname)

# %%
def freq_phase_extractor(df_spin,full=True):
    frequency = 3
    no_harmonics=15
    if(full==True): fq = np.arange(10,25000,10)
    if(full==False): fq= np.arange(frequency*10,no_harmonics*10*frequency,10)   
    for f in tqdm(fq):
        foi =[]
        poi=[]
        for i in range(len(df_spin)):
            foi.append(df_spin.spin_amp[i][f-5:f+5].mean())
            poi.append(df_spin.spin_amp[i][f-5:f+5].mean())
        df_spin["freq_%d" %(f/10)] = foi
        df_spin["phase_%d"%(f/10)] = poi
    return df_spin

# %%
def freq_phase_extractor(df_spin,full=True):
    frequency = 3
    no_harmonics=15
    if(full==True): fq = np.arange(10,25000,10)
    if(full==False): fq= np.arange(frequency*10,no_harmonics*10*frequency,10)   
    for f in tqdm(fq):
        foi =[]
        poi=[]
        for i in range(len(df_spin)):
            foi.append(df_spin.spin_amp[i][f-5:f+5].mean())
            poi.append(df_spin.spin_phase[i][f-5:f+5].mean())
        df_spin["freq_%d" %(f/10)] = foi
        df_spin["phase_%d"%(f/10)] = poi
    return df_spin

# %%
df_full= freq_phase_extractor(df,full=True)
# Out:
#   0%|          | 0/2499 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8811947274be> in <module>
# ----> 1 df_full= freq_phase_extractor(df,full=True)
#
# <ipython-input-21-705f69c55f17> in freq_phase_extractor(df_spin, full)
#      10             foi.append(df_spin.spin_amp[i][f-5:f+5].mean())
#      11             poi.append(df_spin.spin_phase[i][f-5:f+5].mean())
# ---> 12         df_spin["freq_%d" %(f/10)] = foi
#      13         df_spin["phase_%d"%(f/10)] = poi
#      14     return df_spin
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3562
#    3563         self._ensure_valid_index(value)
# -> 3564         value = self._sanitize_column(key, value)
#    3565         NDFrame._set_item(self, key, value)
#    3566
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3747
#    3748             # turn me into an ndarray
# -> 3749             value = sanitize_index(value, self.index, copy=False)
#    3750             if not isinstance(value, (np.ndarray, Index)):
#    3751                 if isinstance(value, list) and len(value) > 0:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
x = np.arange(0,2500.1,0.1)
plt.plot(x,df.spin_fft[0:1000].mean(),label="first 10k seconds")
plt.plot(x,df.spin_fft[1000:10000].mean(),label="all other data",alpha=0.5)
plt.yscale("log")
plt.xscale("log")
plt.xlabel("time [s]")
plt.ylim(1e-11,1e-3)
plt.xlim(1e0,100)
plt.ylabel("PSD [a.u.]")
plt.legend()
plt.show()

# %%
import gif
@gif.frame
def plot1(norm,x, y,inp):
    plt.figure(figsize=(16, 12), dpi=50)
    plt.plot(x,norm)
    plt.plot(x, y)
    plt.yscale("log")
    plt.ylim(1e-11,1e-3)
    plt.xlim(0,100)
    plt.xlabel("frequency [Hz]")
    plt.ylabel("PSD [a.u.]")
    plt.title("dataset %d" %inp)
    #plt.legend()

# %%
frames = []
x = np.arange(0,2500.1,0.1)
step_size=100
norm = df["spin_fft"][50]
for i in np.arange(0,10000,step_size):
    y1 = df["spin_fft"][i]
    frame =  plot1(norm,x,y1,i) 
    frames.append(frame)
    #y2 = df_nos1["spin_fft"][i+2*step_size:i+3*step_size].mean()

# %%
gif.save(frames, "Temporary_Plots/psd_super_zoom_data.gif", duration=500)

# %%
## plt.plot(df["freq0"].ewm(span=100, adjust=True).mean())
for i in np.arange(0,50,3):
    norm = df["freq%d" %i].mean()
    norm2 = df_nos1["freq%d" %i][0:1000].mean()
    val = df["freq%d" %i].ewm(span=200, adjust=True).mean()/norm
    val2 = df_nos1["freq%d" %i].ewm(span=200, adjust=True).mean()/norm2
    #plt.plot(val/val2,label="%d"%i)
    #plt.plot(val2,label="%d"%i)
    plt.plot(val,label="%d"%i)
    
plt.xlim(0,3000)
plt.ylim(0,15)
plt.legend()    
plt.show()

# %%
sum_list = []
for i in np.arange(0,5000,1):
    sum_list.append(df_nos1["spin_fft"][i:i+step_size].mean().sum())

# %%
x = np.arange(0,2500.1,0.1)
step_size = 1
plt.plot(x,np.sqrt(df_nos1["spin_fft"][1000:1000+step_size].mean()),label="quiet state (1000)",alpha=0.8)     
for i in [1070,1072,1140,1145]:#:np.arange(1070,1072,step_size):#[422,756,1018,1102,1402]:
    print(i,df_nos1["spin_fft"][i:i+step_size].mean().sum())
    y1 = df_nos1["spin_fft"][i:i+step_size].mean()
    #y2 = df_nos1["spin_fft"][i+2*step_size:i+3*step_size].mean()
    plt.plot(x,np.sqrt(y1),label="%d dataset"%(i),alpha=0.8) 
    plt.yscale("log")
    plt.ylim(1e-6,1e-1)
    plt.xlim(0,400)
    plt.xlabel("frequency [Hz]")
    plt.ylabel("PSD [a.u.]")
plt.legend()
plt.show()
# Out:
# 1070 0.0015527121521221178
# 1072 0.0014451978799549573
# 1140 0.001601630663384494
# 1145 0.001651952587665549

# %%
x = np.arange(0,2500.1,0.1)
step_size = 10
for i in np.arange(1130,1160,step_size):#[422,756,1018,1102,1402]:
    print(i)
    y1 = df_nos1["spin_fft"][i:i+step_size].mean()
    #y2 = df_nos1["spin_fft"][i+2*step_size:i+3*step_size].mean()
    plt.plot(x,np.sqrt(y1),label="%d dataset"%(i),alpha=0.8) 
    plt.yscale("log")
    #plt.xscale("log")
    plt.ylim(1e-6,1e-1)
    plt.xlim(500,2500)
    plt.xlabel("frequency [Hz]")
    plt.ylabel("PSD [a.u.]")
plt.legend()
plt.show()
# Out:
# 1130
# 1140
# 1150

# %%
x = np.arange(0,2500.1,0.1)
step_size = 10
for i in np.arange(1100,1150,step_size):#[422,756,1018,1102,1402]:
    print(i)
    figure, axes = plt.subplots(nrows=1, ncols=2)
    y1 = df_nos1["spin_fft"][i:i+step_size].mean()
    y2 = df_nos1["spin_fft"][i+2*step_size:i+3*step_size].mean()
    axes[0].plot(x,y1)
    axes[0].plot(x,y2)
    axes[1].plot(x,y1)
    axes[1].plot(x,y2)
#plt.plot(x,df_nos1["spin_fft"][1050:1100].mean())
#plt.plot(x,df_nos1["spin_fft"][1100:1142].mean())
    axes[0].set_yscale("log")
    axes[1].set_yscale("log")
    axes[0].set_ylim(1e-12,1e-3)
    axes[1].set_ylim(1e-12,1e-5)
    axes[0].set_xlim(0,500)
    axes[1].set_xlim(500,2550)
    plt.show()
    figure.tight_layout()
# Out:
# 1100
# 1110
# 1120
# 1130
# 1140

# %%
df_z = pd.DataFrame()
for j in range(15):
    list1 = []
    for i in range(len(df_data)):
        list1.append(df_data.amplitude_z[i][j])
    df_z["list%d"%j] = list1

# %%
df_x = pd.DataFrame()
for j in range(15):
    list1 = []
    for i in range(len(df_data)):
        list1.append(df_data.amplitude_x[i][j])
    df_x["list%d"%j] = list1

# %%
df_spin = pd.DataFrame()
for j in range(15):
    list2 =[]
    for i in range(len(df)):
        list2.append(df.spin_fft[i][(j+1)*30])
    df_spin["list%d"%j]=np.multiply(list2,1)

# %%
@gif.frame
def plot2(x, y1,y2,y3,inp):
    plt.figure(figsize=(16, 12), dpi=50)
    plt.plot(x, y1)
    plt.plot(x, y2)
    plt.plot(x, y3)
    #plt.yscale("log")
    plt.ylim(0.9*min(np.min(y1),np.min(y2),np.min(y3)),1.1*max(np.max(y1),np.max(y2),np.max(y3)))
    #plt.xlim(0,100)
    plt.xlabel("time [s]")
    plt.ylabel("PSD [a.u.]")
    plt.title("harmonic %d" %inp)
    #plt.legend()

# %%
frames = []
x = np.arange(0,100000,10)
for i in range(15):
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=200,adjust=True).mean())
    y3=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=200,adjust=True).mean())
    frame =  plot2(x,y1,y2,y3,i) 
    frames.append(frame)
    #y2 = df_nos1["spin_fft"][i+2*step_size:i+3*step_size].mean()

# %%
gif.save(frames, "Temporary_Plots/comparison.gif", duration=1000)

# %%
for i in [14]:
    x = np.arange(0,100000,10)
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=200,adjust=True).mean())
    y3=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=200,adjust=True).mean())
 
    plt.plot(x,y2,label="%d-th harmonic x, scaled"%(i+1))
    plt.plot(x,y1,label="%d-th harmonic z"%(i+1))
    plt.plot(x,y3,label="spin %ith, scaled" %(i+1))
plt.ylim(0.9*min(np.min(y1),np.min(y2),np.min(y3)),1.1*max(np.max(y1),np.max(y2),np.max(y3)))    
plt.xlabel("time [s]")
plt.ylabel("PSD [a.u]")
plt.legend()
plt.savefig("Temporary_Plots/%dth_comparison.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()

# %%
for i in [5]:
    fig, ax = plt.subplots()
    cm = plt.cm.get_cmap('viridis')
    caxis = df_z.index
    x = np.arange(0,100000,10)
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=200,adjust=True).mean())
    y3=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=200,adjust=True).mean())
 
    s=plt.scatter(y2,y3)#,c=caxis,cmap=cm,label="%dth x vs spin" %(i+1))
    #plt.scatter(y1,y3,label="z vs spin")
#plt.colorbar(s,label="time [10s]")
plt.ylabel("PSD spin [a.u.]")
plt.xlabel("PSD x [a.u.]")
plt.legend()
#plt.savefig("%dth_correlation_x_spin_20200519.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
@gif.frame
def plot3(index, y1,y2,inp):
    cm = plt.cm.get_cmap('viridis')
    caxis = df_z.index
    plt.figure(figsize=(16, 12), dpi=50)
    s = plt.scatter(y1,y2,c=caxis,cmap=cm)
    #plt.yscale("log")
   # plt.ylim(0.9*min(np.min(y1),np.min(y2),np.min(y3)),1.1*max(np.max(y1),np.max(y2),np.max(y3)))
    #plt.xlim(0,100)
    plt.colorbar(s,label="time [10s]")
    plt.ylabel("PSD spin [a.u.]")
    plt.xlabel("PSD z [a.u.]")
    plt.title("harmonic %d" %inp)
    #plt.legend()

# %%
frames = []
for i in range(15):
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=200,adjust=True).mean())
    frame =  plot3(df_z.index,y1,y2,(i+1)) 
    frames.append(frame)
    #y2 = df_nos1["spin_fft"][i+2*step_size:i+3*step_size].mean()

# %%
gif.save(frames, "Temporary_Plots/correlation_z_2d.gif", duration=1000)

# %%
for i in [5]:
    #fig, ax = plt.subplots()
    cm = plt.cm.get_cmap('viridis')
    caxis = df_z.indexa
    x = np.arange(0,100000,10)
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=10,adjust=True).mean())
    y3=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=10,adjust=True).mean())
 
    s=plt.scatter(y2,y3,c=caxis,cmap=cm,label="%dth x vs spin" %(i+1))
    #plt.scatter(y1,y3,label="z vs spin")
plt.colorbar(s,label="time [10s]")
plt.ylabel("PSD spin [a.u.]")
plt.xlabel("PSD x [a.u.]")
plt.legend()
plt.ylim(-5,200)
#plt.savefig("%dth_correlation_x_spin_20200519.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()

# %%
for i in [13]:
    fig, ax = plt.subplots()
    cm = plt.cm.get_cmap('viridis')
    caxis = df_z.index
    x = np.arange(0,100000,10)
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=200,adjust=True).mean())
    y3=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=200,adjust=True).mean())
 
    s=plt.scatter(y1,y3,c=caxis,cmap=cm,label="%dth z vs spin" %(i+1))
    #plt.scatter(y1,y3,label="z vs spin")
plt.colorbar(s,label="time [10s]")
plt.ylabel("PSD spin [a.u.]")
plt.xlabel("PSD z [a.u.]")
plt.legend()
plt.savefig("%dth_correlation_z_spin_20200519.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()

# %%
for i in [13]:
    fig, ax = plt.subplots()
    cm = plt.cm.get_cmap('viridis')
    caxis = df_z.index
    x = np.arange(0,100000,10)
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=200,adjust=True).mean())
    y3=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=200,adjust=True).mean())
 
    s=plt.scatter(y1,y3,c=caxis,cmap=cm,label="%dth z vs spin" %(i+1))
    #plt.scatter(y1,y3,label="z vs spin")
plt.colorbar(s,label="time [10s]")
plt.ylabel("PSD spin [a.u.]")
plt.xlabel("PSD z [a.u.]")
plt.legend()
plt.savefig("%dth_correlation_z_x_20200519.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()

# %%
for i in [8]:
    fig, ax = plt.subplots()
    cm = plt.cm.get_cmap('viridis')
    caxis = df_z.index
    x = np.arange(0,100000,10)
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=200,adjust=True).mean())
    y3=np.multiply(1/df_spin["list%d" %i].mean()*df_z["list%d"%i].mean(),df_spin["list%d" %i].ewm(span=200,adjust=True).mean())
 
    s=plt.scatter(y2,make_random,c=caxis,cmap=cm,label="%dth z vs spin" %(i+1))
    #plt.scatter(y1,y3,label="z vs spin")
plt.colorbar(s,label="time [10s]")
plt.ylabel("PSD spin [a.u.]")
plt.xlabel("PSD z [a.u.]")
plt.legend()
#plt.savefig("%dth_correlation_z_x_20200519.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()

# %%
for i in [7]:
    fig, ax = plt.subplots()
    cm = plt.cm.get_cmap('viridis')
    caxis = df_z.index
    x = np.arange(0,100000,10)
    y1=np.multiply(1,df_z["list%d"%i].ewm(span=200,adjust=True).mean())
    y2=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%i].ewm(span=200,adjust=True).mean()) 
    y3=np.multiply(1/df_x["list%d" %i].mean()*df_z["list%d"%i].mean(),df_x["list%d"%(i+1)].ewm(span=200,adjust=True).mean())

    s=plt.scatter(y2,y3,c=caxis,cmap=cm,label="%dth x vs %dth " %((i+1),(i+2)))
    #plt.scatter(y1,y3,label="z vs spin")
plt.colorbar(s,label="time [10s]")
plt.ylabel("PSD %d [a.u.]" %(i+2))
plt.xlabel("PSD %d [a.u.]" %(i+1))
plt.legend()
plt.savefig("%dth_correlation_x_x_20200519.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()

# %%
make_random = np.random.random(10000)
make_random2 = np.random.random(10000)

# %%
plt.scatter(make_random,make_random2)

# %%
df_random = pd.DataFrame()

# %%
df_random["C1"] = make_random
df_random["C2"] = make_random2

# %%
df_random = df_random.reset_index()

# %%
fig, ax = plt.subplots()
cm = plt.cm.get_cmap('viridis')
caxis = df_z.index
x = np.arange(0,100000,10)
y2= df_random.C1.ewm(span=1000,adjust=True).mean()
y3= df_random.C2.ewm(span=1000,adjust=True).mean()
s=plt.scatter(y2,y3,c=caxis,cmap=cm,label="%dth x vs %dth " %((i+1),(i+2)))
#plt.scatter(y1,y3,label="z vs spin")
plt.colorbar(s,label="time [10s]")
plt.ylabel("PSD %d [a.u.]" %(i+2))
plt.xlabel("PSD %d [a.u.]" %(i+1))
plt.legend()
plt.savefig("%dth_correlation_x_x_20200519.png" %(i+1),dpi=100,bbox_inches="tight")
plt.show()
