# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal

import h5py

# %%
# %matplotlib notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../../nadavp/new_trap/PythonScripts/')
import BeadDataFile
from discharge_tools import *

# %% [markdown]
# ## Test sychronization

# %%
fname = r'/data/new_trap/20190805/Bead2/Shaking/Shaking129_0.h5'
bdf = BeadDataFile.BeadDataFile(fname)

# %%
xpos = bdf.cant_pos[0]
xpos -= np.min(xpos)
xpos /= np.max(xpos)

qpdsum = np.sum(bdf.amp[:4], axis=0)
bdf.
# qpdsum.shape
qpdsum -= np.min(qpdsum)
qpdsum = qpdsum/np.max(qpdsum)

# %%
_,ax = plt.subplots()
ax.plot(np.arange(0,10,1/5000.), xpos)
ax.plot(np.arange(0,10,1/5000.), qpdsum)
# Out:
# <img src="data:image/png;base64,..." width="640">
