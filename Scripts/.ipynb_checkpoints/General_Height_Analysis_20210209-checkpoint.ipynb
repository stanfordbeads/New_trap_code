# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# either load image files or the height information from the h5 files
dir_path = "/data/new_trap/20210208/Bead2/HeightPictures/HeightStability/"
data_img = load_npy_files(dir_path+"Pictures/*.npy")
data_h5 = load_dir_reduced_to_height(dir_path,"Discharge_",max_files=150000)
# Out:
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_0.npy 0
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_2.npy 1
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_3.npy 2
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_4.npy 3
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_5.npy 4
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_6.npy 5
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_7.npy 6
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_8.npy 7
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_9.npy 8
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_10.npy 9
# /data/new_trap/20210208/Bead2/HeightPictures/HeightStability/Pictures/Discharge_11.npy 10
# ...

# %%
height_PCC = []
for img in tqdm(data):
    zeroth=data[0]
    height_PCC.append(position_shift_PCC(img,zeroth)[0])

# %%
plt.plot(height_PCC)
