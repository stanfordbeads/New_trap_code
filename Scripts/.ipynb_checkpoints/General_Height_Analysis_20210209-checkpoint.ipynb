# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py

plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
# either load image files or the height information from the h5 files
dir_path = "/data/new_trap/20210317/Bead1/HeightPictures/run/"
data_img = load_npy_files(dir_path+"i*.npy",max_files=129005)
time_info1=np.load(dir_path+"time_info.npy")
#height_h5 = load_dir_reduced_to_height(dir_path,"Discharge_",max_files=150000)
#time_h5 = load_dir_reduced_to_time(dir_path,"Discharge_",max_files=150)
# Out:
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_0.npy 0
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_1.npy 1
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_2.npy 2
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_3.npy 3
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_4.npy 4
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_5.npy 5
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_6.npy 6
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_7.npy 7
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_8.npy 8
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_9.npy 9
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_10.npy 10
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_11.npy 11
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_12.npy 12
# /data/new_trap/20210317/Bead1/HeightPictures/run/image_test_13.npy 13
# ...

# %%
height1 = np.load("height_20210325_7605.npy")

# %%
# either load image files or the height information from the h5 files
dir_path = "/data/SC_data/ImageAnalysis/20210325/run1/"
data_img2 = load_npy_files(dir_path+"i*.npy",print_list=False,max_files=129005)
time_info2=np.load(dir_path+"time_info.npy")
#height_h5 = load_dir_reduced_to_height(dir_path,"Discharge_",max_files=150000)
#time_h5 = load_dir_reduced_to_time(dir_path,"Discharge_",max_files=150)

# %%
#height_PCC = []
#for img in tqdm(data_img):
#    zeroth=data_img[0]
#   height_PCC.append(position_shift_PCC(img,zeroth)[0])

height_PCC2 = []
#for img in tqdm(data_img2):
for img in tqdm(range(len(data_img2))):
    #zeroth=data_img2[0]
    if(img>7605):
        height_PCC2.append(position_shift_PCC(data_img2[img],zeroth)[0])
# Out:
# 100%|██████████| 7959/7959 [01:13<00:00,  4.63it/s]

# %%
plt.plot(height_PCC2,marker="$5$")
#plt.ylim(-5,7)
#plt.xlim(2000,2635)

# %%
height_tot1 =[]

# %%
for element in height1:
    height_tot1.append(element)
for element in height_PCC2:
    height_tot1.append(element)

# %%
#time_tot = []

# %%
#zero = time_info2[0]
for times in time_info2:
    time_tot.append(times-time_info2[0])

# %%
plt.plot(time_tot[:-2],height_tot1)

# %%
totheight=[]
for element in height1:
    totheight.append(element)
for element in height_PCC2:
    totheight.append(element)

# %%
plt.plot(totheight)

# %%
x=1024-np.arange(0,1024)
plt.plot(x,np.mean(data_img2[0],axis=1))
plt.plot(x,np.mean(data_img2[-1],axis=1))

# %%
plt.imshow(data_img[80])

# %%
plt.plot((time_h5-time_h5[0])/60/60,height_h5,marker="*",linestyle="")
plt.xlabel("time[h]")
plt.ylabel("height shift [pixel]")
# Out:
# Text(0, 0.5, 'height shift [pixel]')
