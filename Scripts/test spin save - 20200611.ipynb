# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

from scipy import signal
import h5py, time

# %%
import sys
sys.path.append('../../../nadavp/new_trap/Tools/')
import BeadDataFile
from discharge_tools import *

# %%
# %matplotlib notebook

# %%
fname = r'/home/data_transfer/data_from_windows/Testdata/20200611/test6_0.h5'
bb = BeadDataFile.BeadDataFile(fname=fname)

# %%
_,ax = plt.subplots(figsize=(9.5,4))
ax.scatter(range(5000),bb.cant_pos[1])
bb.spin_data.shape
# Out:
# <img src="data:image/png;base64,..." width="950">
# (50000,)
