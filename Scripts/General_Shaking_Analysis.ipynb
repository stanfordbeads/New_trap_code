# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filename2 = "/home/analysis_user/Results/AkioK/2019_08_12_Bead1/ShakeNSDPhase138.txt"
filename1 = "/home/analysis_user/Results/AkioK/2019_08_12_Bead1/ShakeNSDPhase125.txt"

# %%
file1 = np.loadtxt(filename2)

# %%
frequency_list = []
x_amp_list =[]
x_phase_list=[]
y_amp_list =[]
y_phase_list=[]
z_amp_list =[]
z_phase_list=[]
for i in np.arange(0,len(file1)):
    frequency_list.append(file1[i][0])
    x_amp_list.append(file1[i][1])
    x_phase_list.append(file1[i][4])
    y_amp_list.append(file1[i][2])
    y_phase_list.append(file1[i][5])
    z_amp_list.append(file1[i][3])
    z_phase_list.append(file1[i][6])

# %%
plt.plot(frequency_list,x_amp_list)
plt.plot(frequency_list,y_amp_list)
plt.plot(frequency_list,z_amp_list)

plt.yscale("log")
plt.xscale("log")

# %%
plt.plot(frequency_list,x_phase_list, marker="*")
#plt.plot(frequency_list,y_phase_list, marker="*")
#plt.plot(frequency_list,z_phase_list,marker="*")
#plt.xlim(0,1600)
plt.xlim(0,400)
plt.xscale("linear")
