# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal

import h5py

# %%
# %matplotlib notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../nadavp/new_trap/PythonScripts/')
import BeadDataFile
from discharge_tools import *

# %% [markdown]
# ## Force calibration - X

# %%
foldername = r'/home/data_transfer/data_from_windows/20190701/Bead2/Discharge2/'
BDFs = load_dir(foldername, file_prefix='Discharge')
# Out:
# 10  files in folder
# 10  files loaded

# %%
freq = 23
responsesX = [B.response_at_freq('x',drive_freq=freq) for B in BDFs]
rrX = [np.std(resp_) for resp_ in responsesX]
_,ax = plt.subplots(figsize=(9,4))
ax.scatter(range(len(rrX)),rrX)
ii = [4,5]
ij = [0,1,6,7]
SNR = np.mean([rrX[i] for i in ii])/np.mean([rrX[i] for i in ij])
print(1.6e-19*20/8.6e-3/SNR*0.65, SNR)
# Out:
# <img src="data:image/png;base64,..." width="900">
# 1.7757565426567998e-17 13.620136505560572

# %%
bdfX = BDFs[-1]
respX = bdfX.response_at_freq('y', drive_freq=23)
_,ax = plt.subplots()
ax.plot(np.arange(50000)*0.1,respX)
# ax.plot(np.arange(50000)*0.1,bdfX.x2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Force calibration Y

# %%
freq = 23
responsesY = [B.response_at_freq('y',drive_freq=freq) for B in BDFs]
rrY = [np.std(resp_) for resp_ in responsesY]
_,ax = plt.subplots(figsize=(9,4))
ax.scatter(range(len(rrY)),rrY)
ii = [8,9]
ij = [0,1,6,7]
SNR = np.mean([rrY[i] for i in ii])/np.mean([rrY[i] for i in ij])
print(1.6e-19*20/8.6e-3/SNR*0.65, SNR)
# Out:
# <img src="data:image/png;base64,..." width="900">
# 1.2934709223996319e-17 18.698562211787674

# %% [markdown]
# ## Force calibration Z

# %%
freq = 23
responsesZ = [B.response_at_freq('z',drive_freq=freq) for B in BDFs]
rrZ = [np.std(resp_) for resp_ in responsesZ]
_,ax = plt.subplots(figsize=(9,4))
ax.scatter(range(len(rrZ)),rrZ)
ii = [2,3]
ij = [0,1,6,7]
SNR = np.mean([rrZ[i] for i in ii])/np.mean([rrZ[i] for i in ij])
print(1.6e-19*20/8.6e-3/SNR*0.65, SNR)
# Out:
# <img src="data:image/png;base64,..." width="900">
# 1.30135792696333e-17 18.585237781634095

# %%
_,ax = plt.subplots(3,1,sharex=True, figsize=(9.5,8))
ax[0].scatter(range(len(rrX)),rrX)
ax[1].scatter(range(len(rrY)),rrY)
ax[2].scatter(range(len(rrZ)),rrZ)
ax[0].set(ylabel='X-axis')
ax[1].set(ylabel='Y-axis')
ax[2].set(ylabel='Z-axis')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [Text(0, 0.5, 'Z-axis')]

# %% [markdown]
# ## Transfer function
