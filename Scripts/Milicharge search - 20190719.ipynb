# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal

import h5py

# %%
# %matplotlib notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# !pwd
# Out:
# /home/analysis_user/New_trap_code/Scripts

# %%
import sys
sys.path.append('../../../nadavp/new_trap/PythonScripts/')
import BeadDataFile
from discharge_tools import *

# %% [markdown]
# ## Milicharge 151Hz data

# %%
fname = '/home/data_transfer/data_from_windows/20190719/Bead1/Discharge/Discharge_{}.h5'
files = [fname.format(ff_) for ff_ in range(200,400)]
bdf_mc = [BeadDataFile.BeadDataFile(fname_) for fname_ in files]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
[ax[0].semilogy(*BDF_.welch_psd('x', res = 5000)) for BDF_ in bdf_mc[::2]]
[ax[1].semilogy(*BDF_.welch_psd('z', res = 5000)) for BDF_ in bdf_mc[::2]]
ax[0].set_title('X')
ax[1].set_title('Z')
[a.set(xlim=(100,200),xlabel='freq. [Hz]') for a in ax]
ax[0].legend()
# Out:
# <img src="data:image/png;base64,..." width="950">
# No handles with labels found to put in legend.

# %% [markdown]
# #### Data 400-600

# %%
fname = '/home/data_transfer/data_from_windows/20190719/Bead1/Discharge/Discharge_{}.h5'
files = [fname.format(ff_) for ff_ in range(400,600)]
bdf_mc400 = [BeadDataFile.BeadDataFile(fname_) for fname_ in files]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
[ax[0].semilogy(*BDF_.welch_psd('x', res = 5000)) for BDF_ in bdf_mc400[::2]]
[ax[1].semilogy(*BDF_.welch_psd('z', res = 5000)) for BDF_ in bdf_mc400[::2]]
ax[0].set_title('X')
ax[1].set_title('Z')
[a.set(xlim=(100,200),xlabel='freq. [Hz]') for a in ax]
ax[0].legend()
# Out:
# <img src="data:image/png;base64,..." width="950">
# No handles with labels found to put in legend.

# %% [markdown]
# #### Data 600-800

# %%
fname = '/home/data_transfer/data_from_windows/20190719/Bead1/Discharge/Discharge_{}.h5'
files = [fname.format(ff_) for ff_ in range(600,800)]
bdf_mc600 = [BeadDataFile.BeadDataFile(fname_) for fname_ in files]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
[ax[0].semilogy(*BDF_.welch_psd('x', res = 5000)) for BDF_ in bdf_mc600[::2]]
[ax[1].semilogy(*BDF_.welch_psd('z', res = 5000)) for BDF_ in bdf_mc600[::2]]
ax[0].set_title('X')
ax[1].set_title('Z')
[a.set(xlim=(100,200),xlabel='freq. [Hz]') for a in ax]
ax[0].legend()
# Out:
# <img src="data:image/png;base64,..." width="950">
# No handles with labels found to put in legend.

# %% [markdown]
# #### Data 800-1000

# %%
fname = '/home/data_transfer/data_from_windows/20190719/Bead1/Discharge/Discharge_{}.h5'
files = [fname.format(ff_) for ff_ in range(800,1000)]
bdf_mc800 = [BeadDataFile.BeadDataFile(fname_) for fname_ in files]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
[ax[0].semilogy(*BDF_.welch_psd('x', res = 5000)) for BDF_ in bdf_mc800[::2]]
[ax[1].semilogy(*BDF_.welch_psd('z', res = 5000)) for BDF_ in bdf_mc800[::2]]
ax[0].set_title('X')
ax[1].set_title('Z')
[a.set(xlim=(100,200),xlabel='freq. [Hz]') for a in ax]
ax[0].legend()
# Out:
# <img src="data:image/png;base64,..." width="950">
# No handles with labels found to put in legend.

# %% [markdown]
# #### Data 1000-1200

# %%
fname = '/home/data_transfer/data_from_windows/20190719/Bead1/Discharge/Discharge_{}.h5'
files = [fname.format(ff_) for ff_ in range(1000,1200)]
bdf_mc1000 = [BeadDataFile.BeadDataFile(fname_) for fname_ in files]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
[ax[0].semilogy(*BDF_.welch_psd('x', res = 5000)) for BDF_ in bdf_mc1000[::2]]
[ax[1].semilogy(*BDF_.welch_psd('z', res = 5000)) for BDF_ in bdf_mc1000[::2]]
ax[0].set_title('X')
ax[1].set_title('Z')
[a.set(xlim=(100,200),xlabel='freq. [Hz]') for a in ax]
ax[0].set(ylabel='psd [a.u.]')
ax[0].legend()
# Out:
# <img src="data:image/png;base64,..." width="950">
# No handles with labels found to put in legend.

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
[ax[0].semilogy(*BDF_.psd2('x', res = 5000)) for BDF_ in bdf_mc1000[::2]]
[ax[1].semilogy(*BDF_.psd3('x', res = 5000)) for BDF_ in bdf_mc1000[::2]]
ax[0].set_title('X-amp')
ax[1].set_title('X-phase')
[a.set(xlim=(100,200),xlabel='freq. [Hz]') for a in ax]
ax[0].set(ylabel='psd [a.u.]')
ax[0].legend()
# Out:
# <div id='d39e8575-b1d4-4b5c-a72e-193efc63a06d'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-98a3ccf45163> in <module>()
#       1 _,ax = plt.subplots(1,2,figsize=(9.5,4))
#       2 [ax[0].semilogy(*BDF_.psd2('x', res = 5000)) for BDF_ in bdf_mc1000[::2]]
# ----> 3 [ax[1].semilogy(*BDF_.psd3('x', res = 5000)) for BDF_ in bdf_mc1000[::2]]
#       4 ax[0].set_title('X-amp')
#       5 ax[1].set_title('X-phase')
#
# <ipython-input-31-98a3ccf45163> in <listcomp>(.0)
#       1 _,ax = plt.subplots(1,2,figsize=(9.5,4))
#       2 [ax[0].semilogy(*BDF_.psd2('x', res = 5000)) for BDF_ in bdf_mc1000[::2]]
# ----> 3 [ax[1].semilogy(*BDF_.psd3('x', res = 5000)) for BDF_ in bdf_mc1000[::2]]
#       4 ax[0].set_title('X-amp')
#       5 ax[1].set_title('X-phase')
#
# AttributeError: 'BeadDataFile' object has no attribute 'psd3'

# %% [markdown]
# ### Real X movment

# %%
fname = '/home/data_transfer/data_from_windows/20190801/Bead3/Discharge/Discharge_{}.h5'
files = [fname.format(ff_) for ff_ in range(300,310)]
bdf_x = [BeadDataFile.BeadDataFile(fname_) for fname_ in files]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
[ax[0].semilogy(*BDF_.welch_psd('x', res = 5000)) for BDF_ in bdf_x[::]]
[ax[1].semilogy(*BDF_.welch_psd('z', res = 5000)) for BDF_ in bdf_x[::]]
ax[0].set_title('X')
ax[1].set_title('Z')
[a.set(xlim=(100,200),xlabel='freq. [Hz]',ylim=(1e-13,1e-5)) for a in ax]
ax[0].set(ylabel='psd [a.u.]')
ax[0].legend()
# Out:
# <img src="data:image/png;base64,..." width="950">
# No handles with labels found to put in legend.

# %% [markdown]
# ## Response function

# %%
freq = 151
responses = [B.response_at_freq2('x',drive_freq=freq) for B in bdf_mc]
responses_sideband = [B.response_at_freq2('x',drive_freq=freq+3) for B in bdf_mc]

responses1000 = [B.response_at_freq2('x',drive_freq=freq) for B in bdf_mc1000]
responses_sideband1000 = [B.response_at_freq2('x',drive_freq=freq+3) for B in bdf_mc1000]

response_x = [B.response_at_freq2('x',drive_freq=freq) for B in bdf_x]
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
freq = 151
responses_phase = [B.response_at_freq3('x',drive_freq=freq) for B in bdf_mc]
responses_sideband_phase = [B.response_at_freq3('x',drive_freq=freq+3) for B in bdf_mc]

responses1000_phase = [B.response_at_freq3('x',drive_freq=freq) for B in bdf_mc1000]
responses_sideband1000_phase = [B.response_at_freq3('x',drive_freq=freq+3) for B in bdf_mc1000]

response_x_phase = [B.response_at_freq3('x',drive_freq=freq) for B in bdf_x]
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
rr = np.array([np.std(response) for response in  responses])
rr_sb = np.array([np.std(response) for response in  responses_sideband])

rr1000 = np.array([np.std(response) for response in  responses1000])
rr_sb1000 = np.array([np.std(response) for response in  responses_sideband1000])

rr_x = np.array([np.std(response) for response in  response_x])

# %%
rr_phase = np.array([np.std(response) for response in  responses_phase])
rr_sb_phase = np.array([np.std(response) for response in  responses_sideband_phase])

rr1000_phase = np.array([np.std(response) for response in  responses1000_phase])
rr_sb1000_phase = np.array([np.std(response) for response in  responses_sideband1000_phase])

rr_x_phase = np.array([np.std(response) for response in  response_x_phase])

# %%
_,ax = plt.subplots()
ax.scatter(range(200),rr*1e5, label='Data200-400')
ax.scatter(range(200),rr_sb*1e5, label='Noise')

ax.scatter(range(200),rr1000*1e5, label='Data1000-1200')

ax.scatter(range(10),rr_x*1e5, label='Data-X')
ax.legend()
ax.set(ylim=(0,3), ylabel='X-response [a.u]', xlabel = 'dataset')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(0, 3), Text(0, 0.5, 'X-response [a.u]'), Text(0.5, 0, 'dataset')]

# %%
_,ax = plt.subplots()
ax.scatter(rr*1e5,rr_phase, label='Data200-400')
ax.scatter(rr_sb*1e5,rr_sb_phase, label='Noise')

ax.scatter(rr1000*1e5,rr1000_phase, label='Data1000-1200')

ax.scatter(rr_x*1e5,rr_x_phase, label='Data-X')
ax.set(xlabel='X-response-amplitude [a.u.]', ylabel='X-response-phase [a.u.]')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import math 
import scipy
fsamp = 5000
def response_at_phase(data,drive_freq, phase=0):
    points = int(fsamp/drive_freq)*10
    t = np.linspace(0, 1/drive_freq, points)
    optimize_func = lambda x: x[0]*np.sin(2*math.pi*drive_freq*t+x[1]) + x[2] - data[:points]/np.max(data[:points])
    est_amp, est_phase, est_mean = scipy.optimize.leastsq(optimize_func, [1, 0, 0])[0]
    return est_phase

# %%
def get_angle(data, drive_freq):
    spectrum = np.fft.fft(data)
    angle = np.angle(spectrum)
    freq = np.fft.fftfreq(len(data), d=1./5000)
    return angle[freq==151]

# %%
angles = [get_angle(bdf_.x2, drive_freq=151) for bdf_ in bdf_mc1000]
angles_x = [get_angle(bdf_.x2, drive_freq=151) for bdf_ in bdf_x]

# %%
angles1 = [get_angle(bdf_.y2, drive_freq=151) for bdf_ in bdf_mc1000]
angles1_x = [get_angle(bdf_.y2, drive_freq=151) for bdf_ in bdf_x]

# %%
_,ax = plt.subplots()
# ax.scatter(range(200),angles, label='Data1000-1200')
# ax.scatter(range(10),angles1_x, label='Data-X')
ax.scatter(angles, angles1, label='phases-mc')
ax.scatter(angles_x, angles1_x, label='phases-X')
ax.set(xlabel='X-phase', ylabel='Y-phase')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rr1000_noPhase = np.array([response_at_phase(response,drive_freq=freq) for response in  responses1000])
rr_sb1000_noPhase = np.array([response_at_phase(response,drive_freq=freq) for response in  responses_sideband1000])

# %%
_,ax = plt.subplots()
ax.scatter(range(200),rr1000_noPhase)
# ax.scatter(range(200),rr_sb1000_noPhase*1e5, label='Noise')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fname = r'/data/new_trap/20190705/Bead1/Discharge/Discharge_111.h5'
bdf_x = BeadDataFile.BeadDataFile(fname)
fname = r'/data/new_trap/20190705/Bead1/Discharge/Discharge_112.h5'
bdf_x2 = BeadDataFile.BeadDataFile(fname)

# %%
fname = r'/data/new_trap/20190719/Bead1/Discharge/Discharge_1139.h5'
bdf_xx = BeadDataFile.BeadDataFile(fname)

# %%
f = 23
response_at_phase(bdf_x.response_at_freq2('x',drive_freq=f),drive_freq=f)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# 1.5235094974169985

# %%
tmp = bdf_x[0].response_at_freq2('x',drive_freq=151)
tmp2 = bdf_x[3].response_at_freq2('x',drive_freq=151)
_,ax = plt.subplots()
ax.plot(range(len(tmp)),tmp, '.--')
ax.plot(range(len(tmp2)),tmp2, '.--')
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Chas' correlation function

# %%
def correlation(drive, response, fsamp, fdrive, filt = False, band_width = 1):
    '''Compute the full correlation between drive and response,
       correctly normalized for use in step-calibration.

       INPUTS:   drive, drive signal as a function of time
                 response, resposne signal as a function of time
                 fsamp, sampling frequency
                 fdrive, predetermined drive frequency
                 filt, boolean switch for bandpass filtering
                 band_width, bandwidth in [Hz] of filter

       OUTPUTS:  corr_full, full and correctly normalized correlation'''

    # First subtract of mean of signals to avoid correlating dc
    drive = drive-np.mean(drive)
    response = response-np.mean(response)

    # bandpass filter around drive frequency if desired.
    if filt:
        b, a = signal.butter(3, [2.*(fdrive-band_width/2.)/fsamp, \
                             2.*(fdrive+band_width/2.)/fsamp ], btype = 'bandpass')
        drive = signal.filtfilt(b, a, drive)
        response = signal.filtfilt(b, a, response)
    
    # Compute the number of points and drive amplitude to normalize correlation
    lentrace = len(drive)
    drive_amp = np.sqrt(2)*np.std(drive)

    # Define the correlation vector which will be populated later
    corr = np.zeros(int(fsamp/fdrive))

    # Zero-pad the response
    response = np.append(response, np.zeros(int(fsamp / fdrive) - 1) )

    # Build the correlation
    n_corr = len(drive)
    for i in range(len(corr)):
        # Correct for loss of points at end
        correct_fac = 2.0*n_corr/(n_corr-i) # x2 from empirical test
        corr[i] = np.sum(drive*response[i:i+n_corr])*correct_fac

    return corr * (1.0 / (lentrace * drive_amp))

# %%
tt = np.arange(0,1,1./5000)
template = -np.sin(2*np.pi*tt*151+np.pi/4)

# %%
temp_spectrum = np.fft.rfft(template)
temp_angle = np.angle(temp_spectrum)
temp_freq = np.fft.fftfreq(len(template), d=1./5000)

# %%
temp_freq.shape
# Out:
# (5000,)

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].semilogy(temp_freq[:2500],np.abs(temp_spectrum[:2500]),'.--')
ax[0].set(xlim=(100,200))
ax[1].semilogy(temp_freq[:2500],np.angle(temp_spectrum[:2500]),'.')
ax[1].set(xlim=(100,200))
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(100, 200)]

# %%
xx = bdf_x[0].x2
xx2 = bdf_mc1000[139].x2

# %%
xx_fft = np.abs(np.fft.rfft(xx))
xx2_fft = np.abs(np.fft.rfft(xx2[:5000]))
xx_freq = np.fft.rfftfreq(5000, d=1/5000.)
_,ax = plt.subplots()
ax.semilogy(xx_freq, xx_fft)
ax.semilogy(xx_freq, xx2_fft)
ax.set(xlim=(100,200))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(100, 200)]

# %%
conv_fft = np.abs((xx_fft * temp_spectrum.conj()))
conv_fft2 = np.abs((xx2_fft * temp_spectrum.conj()))

conv_fft_real = (xx_fft * temp_spectrum.conj()).real
conv_fft2_real = (xx2_fft * temp_spectrum.conj()).real

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].semilogy(temp_freq[:2501], conv_fft)
ax[0].semilogy(temp_freq[:2501], conv_fft2,'.--')
ax[0].set(xlim=(100,200))

ax[1].semilogy(temp_freq[:2501], conv_fft_real)
ax[1].semilogy(temp_freq[:2501], conv_fft2_real,'.--')
ax[1].set(xlim=(100,200))
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(100, 200)]
