# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %%
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ### Load data

# %%
foldername = r'/data/new_trap/20200107/Bead3/Discharge/'
bdf_discharge = load_dir(dirname=foldername)
# Out:
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# 135  files in folder
# 135  files loaded

# %%
bb = bdf_discharge[0]
response_x = [np.std(bb.response_at_freq('z',drive_freq=151)) for bb in bdf_discharge]
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
_, ax = plt.subplots()
ax.scatter(range(len(response_x)), response_x/response_x[128])
ax.set(xlim=(1,None))
print(response_x[48])
# Out:
# <img src="data:image/png;base64,..." width="640">
# 622.1951118233993

# %%
bdf_z = bdf_discharge[48:53]
bdf_x = bdf_discharge[38:43]
bdf_y = bdf_discharge[43:48]
charges = 20
m1s_z = gfw.build_z_response(bdf_z, drive_freq=151,charges=charges, bandwidth=2, decimate=10, include_sigma=True)
# m1s_x = gfw.build_x_response(bdf_x, drive_freq=151,charges=charges)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# Z2-amplitude:  7.38e+03
# reduced chi2:  5.063546487432639
# ***************************************************
# Z2-amplitude:  7.44e+03
# reduced chi2:  5.435332000593003
# ***************************************************
# Z2-amplitude:  7.49e+03
# reduced chi2:  5.585452161406938
# ***************************************************
# Z2-amplitude:  7.52e+03
# reduced chi2:  5.677822067091985
# ***************************************************
# Z2-amplitude:  7.53e+03
# reduced chi2:  5.777992736886147
# Z2 response (amplitude): 7473.548356330126

# %%
m1s_z5 = np.array([gfw.build_z_response(bdf_z, drive_freq=i,charges=charges, bandwidth=2, decimate=10, include_sigma=True) for i in range(13,25)])
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# Z2-amplitude:  3.71e+00
# reduced chi2:  7.885453642178447
# ***************************************************
# Z2-amplitude:  1.60e+01
# reduced chi2:  7.420780037713393
# ***************************************************
# Z2-amplitude:  5.64e+00
# reduced chi2:  8.799341480107106
# ***************************************************
# Z2-amplitude:  8.16e+00
# reduced chi2:  7.307465022985961
# ***************************************************
# Z2-amplitude:  4.90e+00
# reduced chi2:  6.894797614245099
# Z2 response (amplitude): 5.725391270416003
# ***************************************************
# Z2-amplitude:  7.80e+00
# reduced chi2:  7.366189066528732
# ***************************************************
# Z2-amplitude:  3.40e+00
# reduced chi2:  7.879395565208277
# ***************************************************
# Z2-amplitude:  1.57e+01
# reduced chi2:  8.908891272780027
# ***************************************************
# Z2-amplitude:  1.02e+01
# reduced chi2:  6.766312174487878
# ***************************************************
# Z2-amplitude:  3.33e+00
# reduced chi2:  6.661036011873866
# Z2 response (amplitude): -0.880673850903986
# ***************************************************
# Z2-amplitude:  1.81e+00
# reduced chi2:  7.648340710503422
# ***************************************************
# Z2-amplitude:  2.33e+00
# reduced chi2:  7.759786780348238
# ***************************************************
# Z2-amplitude:  4.20e+00
# reduced chi2:  8.569019257509487
# ***************************************************
# Z2-amplitude:  1.15e+00
# reduced chi2:  6.853247847654352
# ***************************************************
# Z2-amplitude:  7.59e+00
# reduced chi2:  6.433662934757042
# Z2 response (amplitude): 3.4153330838191325
# ***************************************************
# Z2-amplitude:  4.00e+00
# reduced chi2:  7.611487906447296
# ***************************************************
# Z2-amplitude:  1.20e+01
# reduced chi2:  7.021119467499963
# ***************************************************
# Z2-amplitude:  8.24e+00
# reduced chi2:  8.150557502426757
# ***************************************************
# Z2-amplitude:  3.94e+00
# reduced chi2:  6.816024714690865
# ***************************************************
# Z2-amplitude:  1.91e+00
# reduced chi2:  6.782999954357941
# Z2 response (amplitude): 6.0158430128580225
# ***************************************************
# Z2-amplitude:  1.92e+01
# reduced chi2:  7.7089114500073626
# ***************************************************
# Z2-amplitude:  6.40e+00
# reduced chi2:  6.376864165272492
# ***************************************************
# Z2-amplitude:  1.18e+01
# reduced chi2:  7.921491270409422
# ***************************************************
# Z2-amplitude:  3.30e+00
# reduced chi2:  6.636548226372624
# ***************************************************
# Z2-amplitude:  1.06e+01
# reduced chi2:  7.002587180478751
# Z2 response (amplitude): 2.156594196464721
# ***************************************************
# Z2-amplitude:  1.13e+00
# reduced chi2:  7.648854419372369
# ***************************************************
# Z2-amplitude:  7.82e+00
# reduced chi2:  6.54542009041702
# ***************************************************
# Z2-amplitude:  5.48e+00
# reduced chi2:  7.8020125082917
# ***************************************************
# Z2-amplitude:  4.87e+00
# reduced chi2:  6.900541283061805
# ***************************************************
# Z2-amplitude:  1.16e+01
# reduced chi2:  7.127249052796898
# Z2 response (amplitude): -6.183217580221753
# ***************************************************
# Z2-amplitude:  1.09e+01
# reduced chi2:  7.4594019846473305
# ***************************************************
# Z2-amplitude:  5.40e+00
# reduced chi2:  6.937567749043963
# ***************************************************
# Z2-amplitude:  2.73e+00
# reduced chi2:  7.715868200088507
# ***************************************************
# Z2-amplitude:  9.04e+00
# reduced chi2:  6.7987867510126465
# ***************************************************
# Z2-amplitude:  3.08e+00
# reduced chi2:  7.0582946199551575
# Z2 response (amplitude): 6.220841616855614
# ***************************************************
# Z2-amplitude:  5.72e+00
# reduced chi2:  7.436728108861642
# ***************************************************
# Z2-amplitude:  4.51e+00
# reduced chi2:  7.0146300128253785
# ***************************************************
# Z2-amplitude:  5.42e+00
# reduced chi2:  7.744158538110066
# ***************************************************
# Z2-amplitude:  3.77e+00
# reduced chi2:  6.94828156363331
# ***************************************************
# Z2-amplitude:  1.02e+01
# reduced chi2:  6.755836006190251
# Z2 response (amplitude): -2.6208732752002106
# ***************************************************
# Z2-amplitude:  2.91e+00
# reduced chi2:  6.958259551751538
# ***************************************************
# Z2-amplitude:  6.11e+00
# reduced chi2:  6.954281963508895
# ***************************************************
# Z2-amplitude:  8.22e+00
# reduced chi2:  7.6901562410596025
# ***************************************************
# Z2-amplitude:  3.47e-01
# reduced chi2:  7.089967499691141
# ***************************************************
# Z2-amplitude:  3.45e+00
# reduced chi2:  6.944338093205807
# Z2 response (amplitude): 3.043725492615704
# ***************************************************
# Z2-amplitude:  4.26e+00
# reduced chi2:  6.962864637855474
# ***************************************************
# Z2-amplitude:  1.58e+01
# reduced chi2:  6.908985941746968
# ***************************************************
# Z2-amplitude:  9.84e+00
# reduced chi2:  7.170495754525783
# ***************************************************
# Z2-amplitude:  1.80e+00
# reduced chi2:  7.101791700611007
# ***************************************************
# Z2-amplitude:  5.28e+00
# reduced chi2:  7.657168142793579
# Z2 response (amplitude): -1.3457159417393996
# ***************************************************
# Z2-amplitude:  9.88e+00
# reduced chi2:  7.413652695860923
# ***************************************************
# Z2-amplitude:  6.23e+00
# reduced chi2:  7.584647518671672
# ***************************************************
# Z2-amplitude:  1.06e+01
# reduced chi2:  7.347688238356468
# ***************************************************
# Z2-amplitude:  6.44e+00
# reduced chi2:  7.1640921781137115
# ***************************************************
# Z2-amplitude:  8.55e+00
# reduced chi2:  7.683127966671605
# Z2 response (amplitude): -4.922959120231463
# ***************************************************
# Z2-amplitude:  6.95e+00
# reduced chi2:  7.547068481122286
# ***************************************************
# Z2-amplitude:  8.63e+00
# reduced chi2:  7.545341696888844
# ***************************************************
# Z2-amplitude:  6.87e+00
# reduced chi2:  7.675772661886102
# ***************************************************
# Z2-amplitude:  1.00e+01
# reduced chi2:  6.821414451480693
# ***************************************************
# Z2-amplitude:  1.03e+01
# reduced chi2:  7.334243681410046
# Z2 response (amplitude): 0.9902607171996352

# %%
sigmas = [m1_.values[3] for m1_ in m1s_z5.flatten()]
amps = [m1_.values[0] for m1_ in m1s_z5.flatten()]
_,ax = plt.subplots(1,2,figsize=(9,4))
ax[0].scatter(range(len(sigmas)), sigmas)
ax[1].scatter(amps, sigmas)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
sigma1 = [m1s_.values[3] for m1s_ in m1s_z]
sigma2 = [m1s_.values[3] for m1s_ in m1s_z2]
sigma3 = [m1s_.values[3] for m1s_ in m1s_z3]
sigma4 = [m1s_.values[3] for m1s_ in m1s_z4]
sigma5 = [m1s_.values[3] for m1s_ in m1s_z5]
_,ax = plt.subplots()
ax.scatter(range(len(sigma1)), sigma1, label = '151')
ax.scatter(range(len(sigma1)), sigma2, label = '100')
ax.scatter(range(len(sigma1)), sigma3, label = '90')
ax.scatter(range(len(sigma1)), sigma4, label = '40')
ax.scatter(range(len(sigma1)), sigma5, label = '18')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_,ax = plt.subplots()
[ax.semilogy(*bb.psd('z')) for bb in bdf_z]
ax.set(xlim=(1,200))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(1, 200)]

# %% [markdown]
# ### Transfer function

# %%
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_X_1.h5'
tf_x = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_Y_2.h5'
tf_y = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_Z_3.h5'
tf_z = BeadDataFile.BeadDataFile(fname=fname)
tf_list = [tf_x, tf_y, tf_z]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data

# %%
gfw.build_transfer_function(tf_list, plot=True)
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
# foldername = r'/data/new_trap/20200107/Bead3/InitialTest/'
foldername = r'/data/new_trap/20200107/Bead3/Shaking/Shaking380/'
datasets_num = 100
gfw.BDFs = load_dir(foldername, file_prefix='Shaking13',max_file=datasets_num)
# Out:
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# 1000  files in folder
# 100  files loaded

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4),sharex=True)
for bb in gfw.BDFs[32::2]:
    ax[0].semilogy(*bb.psd('z'))
    ax[1].semilogy(*bb.psd2('x'))
ax[0].set(xlim=(2,100),xlabel='frequency [Hz.]', title='Z signal psd')
ax[1].set(xlim=(2,100),xlabel='frequency [Hz.]', title='X signal psd')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(2, 100), Text(0.5, 0, 'frequency [Hz.]'), Text(0.5, 1.0, 'X signal psd')]

# %%
gfw.build_noise_array(sideband_freq=20, bandwidth=1)
gfw.build_noise_array_z(sideband_freq=20, bandwidth=1)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# x2 noise rms:  0.32614027358654896
# x3 noise rms:  0.07239215854707944
# z2 noise rms:  17.464442695545255

# %%
fit_kwargs = {'alpha': 1e-2, 'phase': 0, 'error_alpha': 0.01, 'error_phase': 1,
              'errordef': 1,
              'limit_alpha': [1e-5, 10], 'limit_phase': [-5000,5000],
              'fix_alpha': False, 'fix_phase': False, 'print_level': 0}
min_18_z2 = []
datasets_num = 100
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num)
    min_18_z2.append(gfw.get_alpha_2d(bdf=bb, center_freq=14, bandwidth=16, direction1='z', direction2='z',
                          x_focous=389.0, frequency=3, lambda_par=0.0001, height=6e-6, decimate=100, suppress_print=False,
                          **fit_kwargs)[2])
# Out:
# 0 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.71e-03
# reduced chi2:  1086.4598055732702
# 1 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.17e-03
# reduced chi2:  651.3946972701125
# 2 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.28e-03
# reduced chi2:  627.9392881843387
# 3 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.09e-02
# reduced chi2:  493.3104864497621
# 4 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.00e-05
# reduced chi2:  792.8901488565607
# 5 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# alpha:  6.14e-03
# reduced chi2:  578.4935474685274
# 6 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.46e-03
# reduced chi2:  660.0627783891165
# 7 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.24e-03
# reduced chi2:  725.5518311886682
# 8 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.42e-03
# reduced chi2:  926.2126647536536
# 9 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.62e-03
# reduced chi2:  739.9657172455841
# 10 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.93e-03
# reduced chi2:  1251.1907520550826
# 11 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.70e-03
# reduced chi2:  967.8099957394634
# 12 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.68e-03
# reduced chi2:  1016.8292564331349
# 13 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.06e-03
# reduced chi2:  829.7995979130618
# 14 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.22e-03
# reduced chi2:  2404.518186264495
# 15 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.63e-03
# reduced chi2:  1799.2934039127892
# 16 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.01e-02
# reduced chi2:  1937.591126971259
# 17 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.03e-03
# reduced chi2:  1940.8713138796084
# 18 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.02e-02
# reduced chi2:  2528.9350727614315
# 19 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.20e-02
# reduced chi2:  3203.1584603282026
# 20 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.56e-02
# reduced chi2:  3327.8642512929314
# 21 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.10e-03
# reduced chi2:  1659.5197041087397
# 22 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.50e-02
# reduced chi2:  3290.3081592501926
# 23 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.54e-03
# reduced chi2:  1770.6086447165599
# 24 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.17e-03
# reduced chi2:  367.67964897396325
# 25 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.77e-04
# reduced chi2:  689.5613133549714
# 26 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.26e-03
# reduced chi2:  397.854910079923
# 27 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.10e-03
# reduced chi2:  619.3211136635626
# 28 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.57e-03
# reduced chi2:  571.803134880953
# 29 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.41e-02
# reduced chi2:  1106.424779137182
# 30 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.80e-02
# reduced chi2:  1395.5816969042398
# 31 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.14e-02
# reduced chi2:  1830.0526400719295
# 32 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.56e-02
# reduced chi2:  1879.0484342298867
# 33 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.08e-03
# reduced chi2:  705.7232466751623
# 34 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.28e-03
# reduced chi2:  430.1193915269015
# 35 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.18e-02
# reduced chi2:  550.7489828952478
# 36 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.04e-02
# reduced chi2:  790.8686077712672
# 37 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.33e-02
# reduced chi2:  737.5716640022395
# 38 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.81e-02
# reduced chi2:  858.5620494523479
# 39 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.16e-02
# reduced chi2:  748.1832809120014
# 40 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.57e-03
# reduced chi2:  318.12137943241083
# 41 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.31e-03
# reduced chi2:  381.9862757786462
# 42 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.30e-02
# reduced chi2:  400.13004984713973
# 43 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.49e-03
# reduced chi2:  569.2163308989537
# 44 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.34e-03
# reduced chi2:  661.9402331378973
# 45 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.60e-03
# reduced chi2:  280.6378931300832
# 46 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.19e-03
# reduced chi2:  134.86662096398067
# 47 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.06e-02
# reduced chi2:  300.3910530605896
# 48 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.71e-03
# reduced chi2:  167.59069958869398
# 49 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.76e-03
# reduced chi2:  325.58724978168425
# 50 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.26e-02
# reduced chi2:  291.6406476121372
# 51 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.21e-02
# reduced chi2:  424.9217273379296
# 52 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.21e-02
# reduced chi2:  1191.801921967852
# 53 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.10e-03
# reduced chi2:  964.4662222884447
# 54 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.28e-02
# reduced chi2:  1468.7074582447383
# 55 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.29e-03
# reduced chi2:  1991.3998904119167
# 56 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.45e-02
# reduced chi2:  2124.454672708574
# 57 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.45e-02
# reduced chi2:  2430.401075515491
# 58 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.35e-03
# reduced chi2:  831.4899641228451
# 59 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.34e-03
# reduced chi2:  1166.3467418535006
# 60 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.06e-03
# reduced chi2:  2131.683948781994
# 61 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.21e-03
# reduced chi2:  2011.479871768433
# 62 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.74e-03
# reduced chi2:  1078.740025199259
# 63 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.87e-03
# reduced chi2:  1543.969146742023
# 64 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.70e-03
# reduced chi2:  1259.7376268726055
# 65 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.58e-03
# reduced chi2:  724.1280282528045
# 66 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.78e-03
# reduced chi2:  868.9788012049125
# 67 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.04e-03
# reduced chi2:  967.8076888054816
# 68 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.43e-03
# reduced chi2:  631.7171637007779
# 69 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.84e-03
# reduced chi2:  523.6601500453
# 70 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.40e-03
# reduced chi2:  604.7335946023024
# 71 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.37e-03
# reduced chi2:  464.3931287646302
# 72 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.97e-03
# reduced chi2:  245.71346651230328
# 73 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.37e-03
# reduced chi2:  264.5961881292617
# 74 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.92e-03
# reduced chi2:  282.39048152461055
# 75 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.33e-03
# reduced chi2:  283.734746747665
# 76 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.89e-03
# reduced chi2:  282.18570006839855
# 77 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.40e-03
# reduced chi2:  200.0638243637303
# 78 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.55e-03
# reduced chi2:  256.76212613998837
# 79 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.22e-03
# reduced chi2:  201.72586213833915
# 80 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.58e-03
# reduced chi2:  238.08452418199278
# 81 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.87e-03
# reduced chi2:  132.92150981944516
# 82 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.50e-03
# reduced chi2:  164.61264465818962
# 83 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.22e-03
# reduced chi2:  182.76821577435848
# 84 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.26e-03
# reduced chi2:  126.06196347718638
# 85 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.42e-03
# reduced chi2:  75.89149377069603
# 86 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.18e-03
# reduced chi2:  47.280485638568564
# 87 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.40e-03
# reduced chi2:  85.27501458125728
# 88 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.38e-03
# reduced chi2:  68.48809866191637
# 89 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.25e-03
# reduced chi2:  60.100539914481196
# 90 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.94e-03
# reduced chi2:  57.081069539452145
# 91 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.05e-02
# reduced chi2:  79.74182637154152
# 92 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.43e-03
# reduced chi2:  64.31896919778842
# 93 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.43e-02
# reduced chi2:  78.51758563816149
# 94 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.08e-03
# reduced chi2:  59.82907892212448
# 95 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.02e-03
# reduced chi2:  86.33587828771854
# 96 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.65e-03
# reduced chi2:  70.8468081206094
# 97 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.29e-03
# reduced chi2:  79.95833233651186
# 98 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.15e-02
# reduced chi2:  103.84861618327851
# 99 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.92e-03
# reduced chi2:  132.08862260662613

# %%
# m_x2 = [m_.values[0] for m_ in min_20_x2]
m_z = [m_.values[0] for m_ in min_18_z]
m_z2 = [m_.values[0] for m_ in min_18_z2]

# m_x3 = [m_.values[0] for m_ in min_20_x3]

_,ax = plt.subplots(1,2,figsize=(9.5,4))
# ax[0].scatter(range(100), m_x2, label='X2 only')
# ax[0].scatter(range(100), m_x3, label='X3 only')
ax[0].scatter(range(100), m_z, label='Z - with tf')
ax[0].scatter(range(100), m_z2, label='Z - with tf - no decimate')
ax[0].legend()

# ax[1].scatter(m_x2, m_z)

# print('x2 only - mean: ', np.mean(m_x2), ', std: ', np.std(m_x2))
# print('x3 only - mean: ', np.mean(m_x2), ', std: ', np.std(m_x3))
print('z only - mean: ', np.mean(m_z), ', std: ', np.std(m_z)*2*1e10/np.sqrt(1e5))
print('z only - mean: ', np.mean(m_z), ', std: ', np.std(m_z2)*2*1e10/np.sqrt(1e5))
# Out:
# <img src="data:image/png;base64,..." width="950">
# z only - mean:  0.008814841086397199 , std:  337767.67674132326
# z only - mean:  0.008814841086397199 , std:  273695.983234959

# %%
m_noise_xx = [m_.values[0] for m_ in min_3_6_xx]

# %%
_, ax = plt.subplots(figsize=(9,4))
ax.semilogy(np.arange(100), np.array(m_3_6)*1e10, '.', label=r'X & Z')
ax.semilogy(np.arange(100), np.array(m_3_6_x)*1e10, '.', label=r'X only')
ax.semilogy(np.arange(100), np.array(m_3_6_z)*1e10, '.', label=r'Z only')
ax.semilogy(np.arange(15), np.array(m_noise[-15:])*1e10, '.', label=r'InitData - noise level - X and Z')
ax.semilogy(np.arange(15), np.array(m_noise_zx3[-15:])*1e10, '.', label=r'InitData - noise level - X3 and Z')
ax.semilogy(np.arange(15), np.array(m_noise_xx[-15:])*1e10, '.', label=r'InitData - noise level - X only')
ax.set(ylim=(1e7,5e10), xlabel='time [sec.]', ylabel=r'$\alpha$', title=r'$\lambda=100 \mu m $ - 6th harmonic')
ax.legend()
print('mean alpha (all): ', np.mean(m_3_6), 'std: ', np.std(m_3_6))
print('mean alpha (X-only): ', np.mean(m_3_6_x), 'std: ', np.std(m_3_6_x))
print('mean alpha (Z-only): ', np.mean(m_3_6_z), 'std: ', np.std(m_3_6_z))
print('mean alpha noise (Z-only): ', np.mean(m_noise[-15:]), 'std: ', np.std(m_3_6_z[-15:]))
# Out:
# <img src="data:image/png;base64,..." width="900">
# mean alpha (all):  0.011011721321739585 std:  0.006202859498670212
# mean alpha (X-only):  0.33172914416158017 std:  0.10375595476105456
# mean alpha (Z-only):  0.01075695602593762 std:  0.006110601362293406
# mean alpha noise (Z-only):  0.0031017019021576564 std:  0.00619360483794931

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].semilogy(np.arange(350), np.array(m_3_5)*1e10, '.', label=r'6th harmonic')
ax[0].semilogy(np.arange(350), np.array(m_3_noise)*1e10, '.', label=r'noise')
ax[0].set(ylim=(1e7,5e10), xlabel='time [sec.]', ylabel=r'$\alpha$', title=r'$\lambda=100 \mu m $')
ax[0].legend()
ax[1].hist(m_3_5,bins=20,alpha=0.5)
ax[1].hist(m_3_noise,bins=20,alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="950">
# (array([16., 24., 31., 49., 35., 36., 40., 26., 27., 21., 20.,  9.,  7.,
#          3.,  3.,  2.,  0.,  0.,  0.,  1.]),
#  array([0.00075839, 0.00239923, 0.00404007, 0.00568091, 0.00732175,
#         0.00896259, 0.01060343, 0.01224427, 0.01388511, 0.01552595,
#         0.01716679, 0.01880763, 0.02044847, 0.02208931, 0.02373014,
#         0.02537098, 0.02701182, 0.02865266, 0.0302935 , 0.03193434,
#         0.03357518]),
#  <a list of 20 Patch objects>)

# %%
print('6th hsrmonic mean: ',np.mean(m_3_5), ' error: ', np.std(m_3_5)/np.sqrt(350))
print('noise mean: ',np.mean(m_3_noise), ' error: ', np.std(m_3_noise)/np.sqrt(350))
print('estimated limit: ', format(np.std(m_3_5)/np.sqrt(350)*2*1e10,"5.2e"))
# Out:
# 6th hsrmonic mean:  0.010176552255184384  error:  0.0003071952786798577
# noise mean:  0.010498701965504337  error:  0.0002957590986695374
# estimated limit:  6.14e+06

# %% [markdown]
# ### profile likelihood

# %%
fit_kwargs = {'alpha': 1e-2, 'phase': 0, 'error_alpha': 0.01, 'error_phase': 1,
              'errordef': 1,
              'limit_alpha': [1e-5, 10], 'limit_phase': [-5000,5000],
              'fix_alpha': False, 'fix_phase': False, 'print_level': 0}
min_18_x3 = []
datasets_num = 100
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num)
    min_18_x3.append(gfw.get_alpha_2d(bdf=bb, center_freq=18, bandwidth=1, direction1='z', direction2='z',
                          x_focous=389.0, frequency=3, lambda_par=0.0001, height=6e-6, suppress_print=False,
                          **fit_kwargs)[2])
# Out:
# 0 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# alpha:  2.92e-03
# reduced chi2:  359.46162471462384
# 1 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.06e-02
# reduced chi2:  220.1641486041576
# 2 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.87e-02
# reduced chi2:  537.7147441920262
# 3 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.22e-02
# reduced chi2:  449.68981385305676
# 4 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.14e-02
# reduced chi2:  261.14378941630514
# 5 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.20e-02
# reduced chi2:  446.33179387703035
# 6 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.39e-03
# reduced chi2:  347.1000204973145
# 7 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.89e-03
# reduced chi2:  364.45150091845653
# 8 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.36e-03
# reduced chi2:  518.8801189400955
# 9 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.56e-03
# reduced chi2:  299.29443625944367
# 10 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.97e-02
# reduced chi2:  726.8577660376374
# 11 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.28e-02
# reduced chi2:  378.3233306803883
# 12 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.92e-03
# reduced chi2:  399.2069005394704
# 13 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.59e-03
# reduced chi2:  295.874225076734
# 14 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.39e-03
# reduced chi2:  323.0616099106194
# 15 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.25e-03
# reduced chi2:  588.0954603852585
# 16 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.47e-03
# reduced chi2:  235.53390734216012
# 17 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.69e-02
# reduced chi2:  455.3617840938278
# 18 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.10e-02
# reduced chi2:  403.8055044436339
# 19 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.38e-03
# reduced chi2:  419.0227888809367
# 20 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.55e-02
# reduced chi2:  432.64612516624646
# 21 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.65e-03
# reduced chi2:  661.8515671154867
# 22 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.55e-02
# reduced chi2:  1250.7392824199515
# 23 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.69e-03
# reduced chi2:  257.8237973998838
# 24 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.00e-02
# reduced chi2:  424.24063223006704
# 25 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.28e-02
# reduced chi2:  362.22419172954693
# 26 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.67e-02
# reduced chi2:  400.5544878432116
# 27 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.99e-03
# reduced chi2:  333.21271357375923
# 28 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.97e-03
# reduced chi2:  349.21541934131494
# 29 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.03e-03
# reduced chi2:  417.7159845970665
# 30 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.77e-03
# reduced chi2:  599.6920981137163
# 31 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.11e-03
# reduced chi2:  218.17999059475358
# 32 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.16e-02
# reduced chi2:  752.0844145874727
# 33 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.65e-03
# reduced chi2:  278.5870893109377
# 34 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.76e-03
# reduced chi2:  300.4232014148012
# 35 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.16e-03
# reduced chi2:  1026.2332304859492
# 36 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.08e-02
# reduced chi2:  719.4019764126635
# 37 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.03e-03
# reduced chi2:  380.6171725081524
# 38 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.09e-03
# reduced chi2:  600.6378592509362
# 39 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.55e-02
# reduced chi2:  574.023213128228
# 40 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.61e-03
# reduced chi2:  196.04637296889757
# 41 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.01e-03
# reduced chi2:  296.98673014813227
# 42 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.14e-03
# reduced chi2:  297.57254737990985
# 43 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.14e-02
# reduced chi2:  451.74166593429874
# 44 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.99e-02
# reduced chi2:  387.5122653705649
# 45 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.76e-03
# reduced chi2:  466.64617228575736
# 46 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.79e-02
# reduced chi2:  343.89317153951237
# 47 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.25e-02
# reduced chi2:  292.46969780745144
# 48 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.55e-02
# reduced chi2:  202.68010679991502
# 49 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.73e-02
# reduced chi2:  285.2222634231847
# 50 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.33e-03
# reduced chi2:  315.0996197565471
# 51 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.67e-02
# reduced chi2:  145.2161423170726
# 52 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.02e-02
# reduced chi2:  382.300665885043
# 53 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.53e-03
# reduced chi2:  344.6278632957367
# 54 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.43e-02
# reduced chi2:  399.67014500733126
# 55 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.24e-03
# reduced chi2:  258.48153675362596
# 56 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.71e-02
# reduced chi2:  226.47152723002355
# 57 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.06e-02
# reduced chi2:  170.19194714899473
# 58 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.08e-02
# reduced chi2:  125.6117187574564
# 59 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.37e-03
# reduced chi2:  391.84949929706164
# 60 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.78e-02
# reduced chi2:  731.0375469133746
# 61 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.01e-02
# reduced chi2:  201.36127931846366
# 62 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.07e-02
# reduced chi2:  259.1538046209662
# 63 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.30e-03
# reduced chi2:  339.61313855150706
# 64 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.27e-02
# reduced chi2:  315.2199635695788
# 65 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.32e-03
# reduced chi2:  173.1011182965359
# 66 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.46e-02
# reduced chi2:  139.51082251945425
# 67 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.16e-02
# reduced chi2:  414.53748501988923
# 68 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.96e-03
# reduced chi2:  268.82220029001576
# 69 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.07e-03
# reduced chi2:  342.76666978505637
# 70 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.26e-03
# reduced chi2:  418.88246121046734
# 71 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.98e-03
# reduced chi2:  401.52406318944327
# 72 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.74e-03
# reduced chi2:  532.0895163617611
# 73 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.88e-03
# reduced chi2:  148.49350343479782
# 74 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.02e-03
# reduced chi2:  275.61181075690666
# 75 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.96e-03
# reduced chi2:  308.1138217457299
# 76 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.45e-02
# reduced chi2:  231.39801262630468
# 77 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.25e-03
# reduced chi2:  296.31673747864073
# 78 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.06e-02
# reduced chi2:  172.52435119930138
# 79 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.15e-03
# reduced chi2:  282.44245251712437
# 80 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.13e-03
# reduced chi2:  442.86981395316184
# 81 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.37e-03
# reduced chi2:  388.41828709487083
# 82 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.15e-02
# reduced chi2:  266.9165463951523
# 83 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.48e-03
# reduced chi2:  146.91155374954937
# 84 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.92e-03
# reduced chi2:  472.30146012285593
# 85 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.75e-02
# reduced chi2:  455.72701204712484
# 86 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.79e-02
# reduced chi2:  337.65861113390486
# 87 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.98e-03
# reduced chi2:  398.1842206762144
# 88 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.23e-02
# reduced chi2:  281.9544435097122
# 89 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.77e-02
# reduced chi2:  175.33673925524502
# 90 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.18e-02
# reduced chi2:  205.75017369030797
# 91 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.07e-02
# reduced chi2:  405.98382247572414
# 92 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.93e-03
# reduced chi2:  388.29897725330636
# 93 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.92e-02
# reduced chi2:  526.3214010344536
# 94 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.00e-03
# reduced chi2:  501.1633295538985
# 95 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.64e-02
# reduced chi2:  257.170244985259
# 96 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.38e-03
# reduced chi2:  201.96108408284263
# 97 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.37e-02
# reduced chi2:  149.42550033120992
# 98 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.76e-02
# reduced chi2:  195.57213262727151
# 99 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.45e-03
# reduced chi2:  344.31230983226567

# %%
fit_kwargs = {'alpha': 1e-2, 'phase': 0, 'sigma': 17.4, 'error_alpha': 0.01, 'error_phase': 1, 'error_sigma': 1,
              'errordef': 1,
              'limit_alpha': [-100, 100], 'limit_phase': [-5000,5000], 'limit_sigma': [0.1,500],
              'fix_alpha': False, 'fix_phase': False, 'fix_sigma': False, 'print_level': 0}
min_18_z = []
datasets_num = 100
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num)
    min_18_z.append(gfw.get_alpha_mle_pl(bdf=bb, center_freq=18, noise_freq=20, bandwidth=1, direction1='z',
                          x_focous=389.0, frequency=3, lambda_par=0.0001, height=6e-6, suppress_print=False,
                          **fit_kwargs)[2])
# Out:
# 0 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.99e+00
# sigma mle:  1.65e+00
# reduced chi2:  -223236.7795743582
# 1 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# alpha mle:  -9.97e+00
# sigma mle:  1.65e+00
# reduced chi2:  -216224.00984151213
# 2 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.91e+01
# sigma mle:  4.55e+00
# reduced chi2:  -31564.39824158126
# 3 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.91e+01
# sigma mle:  3.25e+00
# reduced chi2:  -60773.1288356066
# 4 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.42e+01
# sigma mle:  3.25e+00
# reduced chi2:  -57190.438645811766
# 5 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.99e+00
# sigma mle:  1.65e+00
# reduced chi2:  -220992.612689626
# 6 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.00e+02
# sigma mle:  1.00e-01
# reduced chi2:  -58899214.68627045
# 7 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.00e+02
# sigma mle:  1.00e-01
# reduced chi2:  -57277459.16313122
# 8 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.91e+01
# sigma mle:  3.25e+00
# reduced chi2:  -57081.702759518506
# 9 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.99e+00
# sigma mle:  1.65e+00
# reduced chi2:  -219619.12511671652
# 10 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.00e-02
# sigma mle:  1.65e+00
# reduced chi2:  -220571.97990648897
# 11 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.99e+00
# sigma mle:  1.65e+00
# reduced chi2:  -222627.57986858927
# 12 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.99e+00
# sigma mle:  1.65e+00
# reduced chi2:  -214218.73795015528
# 13 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.42e+01
# sigma mle:  3.25e+00
# reduced chi2:  -54041.0384611126
# 14 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.42e+01
# sigma mle:  3.25e+00
# reduced chi2:  -59324.40370058364
# 15 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.91e+01
# sigma mle:  3.25e+00
# reduced chi2:  -55872.420742713344
# 16 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.99e+00
# sigma mle:  1.65e+00
# reduced chi2:  -207620.2415271807
# 17 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.03e+01
# sigma mle:  1.00e-01
# reduced chi2:  -59869448.75847071
# 18 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.97e+00
# sigma mle:  1.65e+00
# reduced chi2:  -233805.1137787355
# 19 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.00e-02
# sigma mle:  1.65e+00
# reduced chi2:  -226956.0010060543
# 20 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.97e+01
# sigma mle:  1.00e-01
# reduced chi2:  -56140924.67103806
# 21 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.97e+00
# sigma mle:  1.65e+00
# reduced chi2:  -232637.28610261137
# 22 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.00e+02
# sigma mle:  1.00e-01
# reduced chi2:  -60188334.36969195
# 23 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.97e+01
# sigma mle:  1.00e-01
# reduced chi2:  -57066476.14692587
# 24 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.00e+02
# sigma mle:  1.00e-01
# reduced chi2:  -59243877.53922545
# 25 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.42e+01
# sigma mle:  3.25e+00
# reduced chi2:  -58144.78732229984
# 26 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.97e+00
# sigma mle:  1.65e+00
# reduced chi2:  -211382.51506040158
# 27 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.00e+02
# sigma mle:  1.00e-01
# reduced chi2:  -54233394.31699131
# 28 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.00e+02
# sigma mle:  1.00e-01
# reduced chi2:  -53856038.58163194
# 29 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.91e+01
# sigma mle:  3.25e+00
# reduced chi2:  -51240.60658836692
# 30 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.42e+01
# sigma mle:  3.25e+00
# reduced chi2:  -55809.76211008106
# 31 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.00e+02
# sigma mle:  1.00e-01
# reduced chi2:  -68976845.19871886
# 32 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.42e+01
# sigma mle:  3.25e+00
# reduced chi2:  -64406.529762409366
# 33 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected

# %%
m_z_ls = [m_.values[0] for m_ in min_18_x3]
m_z_pl = [m_.values[0] for m_ in min_18_z]
m_z_pl_sigma = [m_.errors[2] for m_ in min_18_z]

_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].scatter(range(100), np.array(m_z_ls))
ax[0].scatter(range(100), np.array(m_z_pl))
ax[1].scatter(m_z_pl, m_z_pl_sigma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-42160616c471> in <module>()
# ----> 1 m_z_ls = [m_.values[0] for m_ in min_18_x3]
#       2 m_z_pl = [m_.values[0] for m_ in min_18_z]
#       3 m_z_pl_sigma = [m_.errors[2] for m_ in min_18_z]
#       4
#       5 _,ax = plt.subplots(1,2,figsize=(9.5,4))
#
# NameError: name 'min_18_x3' is not defined

# %%
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_X_1.h5'
tf_x = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_Y_2.h5'
tf_y = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_Z_3.h5'
tf_z = BeadDataFile.BeadDataFile(fname=fname)
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].loglog(*tf_x.psd2('x'))
ax[0].loglog(*tf_y.psd2('y'))
ax[1].loglog(*tf_z.psd2('z'))
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
freq, fft = tf_x.psd2('x')
freqs = [freq==7*i for i in range(1,50)]
bbb = [i==1 for i in np.sum(freqs,axis=0)]
freq[bbb]
build_transfer_function([tf_x,tf_y,tf_z], plot=True, scale_freq=20)
# Out:
# <img src="data:image/png;base64,..." width="950">
