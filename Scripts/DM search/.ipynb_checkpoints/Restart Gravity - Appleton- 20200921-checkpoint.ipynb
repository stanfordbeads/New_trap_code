# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

# %%
# %matplotlib widget

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ## Discahrge

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20200917/Bead1/Discharge/Discharge_Z/FineDischarge/')
# Out:
# 260  files in folder
# 260  files loaded

# %%
bb = bdf_discharge[0]
bb.electrode_channels
# Out:
# array([1, 2], dtype=uint16)

# %%
dis_z = [np.std(bb.response_at_freq2('z', drive_freq=71)) for bb in bdf_discharge]

# %%
ch = [bb.electrode_channels[0] for bb in bdf_discharge]

# %%
_,ax = plt.subplots(figsize=(9.1,4))
ax.scatter(range(len(dis_z)), dis_z/dis_z[0], label='std')
ax.scatter(range(len(dis_z)), amps/amps[0], label='fit')
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bdf_discharge_z = [bb for bb,ch_ in zip(bdf_discharge, ch)  if ch_==1 ]
bdf_discharge_x = [bb for bb,ch_ in zip(bdf_discharge, ch)  if ch_==4 ]

# %%
index_z = [bb for bb,ch_ in zip(range(len(bdf_discharge)), ch)  if ch_==1 ]
index_x = [bb for bb,ch_ in zip(range(len(bdf_discharge)), ch)  if ch_==4 ]

# %%
m1 = gfw.build_z_response(bdf_discharge_z, drive_freq=71, charges=1, bandwidth=1, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  1.15e+03
# reduced chi2:  2205.6509113213065
# ***************************************************
# Z2-amplitude:  1.15e+03
# reduced chi2:  3937.275582259109
# ***************************************************
# Z2-amplitude:  1.14e+03
# reduced chi2:  2965.8697276222542
# ***************************************************
# Z2-amplitude:  1.18e+03
# reduced chi2:  2837.07309995681
# ***************************************************
# Z2-amplitude:  1.15e+03
# reduced chi2:  2458.209653530363
# ***************************************************
# Z2-amplitude:  1.18e+03
# reduced chi2:  3441.5636762126655
# ***************************************************
# Z2-amplitude:  1.18e+03
# reduced chi2:  2436.600036573812
# ***************************************************
# Z2-amplitude:  1.23e+03
# reduced chi2:  3491.192288427835
# ***************************************************
# Z2-amplitude:  1.18e+03
# reduced chi2:  1622.2624175669519
# ***************************************************
# Z2-amplitude:  1.17e+03
# reduced chi2:  2954.3522341034536
# ***************************************************
# Z2-amplitude:  9.38e+02
# reduced chi2:  4525.3092665595195
# ***************************************************
# Z2-amplitude:  9.55e+02
# reduced chi2:  1598.7857465737957
# ***************************************************
# Z2-amplitude:  9.43e+02
# reduced chi2:  2076.8047511917453
# ***************************************************
# Z2-amplitude:  9.49e+02
# reduced chi2:  1399.8421511974932
# ***************************************************
# Z2-amplitude:  9.49e+02
# reduced chi2:  1817.8215284404944
# ***************************************************
# Z2-amplitude:  6.86e+02
# reduced chi2:  3444.8164816598983
# ***************************************************
# Z2-amplitude:  7.21e+02
# reduced chi2:  4554.5313247148515
# ***************************************************
# Z2-amplitude:  7.17e+02
# reduced chi2:  1465.0813774221442
# ***************************************************
# Z2-amplitude:  7.00e+02
# Z2-amplitude:  3.50e+02
# reduced chi2:  2198.882932208183
# ***************************************************
# Z2-amplitude:  3.10e+02
# reduced chi2:  1192.0062863938058
# ***************************************************
# Z2-amplitude:  3.80e+02
# reduced chi2:  1581.3849156070528
# ***************************************************
# Z2-amplitude:  3.66e+02
# reduced chi2:  1468.2229202833844
# ***************************************************
# Z2-amplitude:  3.69e+02
# reduced chi2:  2730.3363938313614
# ***************************************************
# Z2-amplitude:  3.73e+02
# reduced chi2:  2167.6927403374616
# ***************************************************
# Z2-amplitude:  3.52e+02
# reduced chi2:  1975.2160768887127
# ***************************************************
# Z2-amplitude:  3.46e+02
# reduced chi2:  1089.1721202280048
# ***************************************************
# Z2-amplitude:  3.60e+02
# reduced chi2:  1243.0387476725768
# ***************************************************
# Z2-amplitude:  3.82e+02
# reduced chi2:  1463.643427640539
# ***************************************************
# Z2-amplitude:  3.58e+02
# reduced chi2:  654.7927149195372
# ***************************************************
# Z2-amplitude:  3.51e+02
# reduced chi2:  1182.5231661172368
# ***************************************************
# Z2-amplitude:  3.39e+02
# reduced chi2:  1385.2837532148797
# ***************************************************
# Z2-amplitude:  2.82e+02
# reduced chi2:  2391.4554347418175
# ***************************************************
# Z2-amplitude:  2.80e+02
# reduced chi2:  2824.2811799177043
# ***************************************************
# Z2-amplitude:  2.86e+02
# reduced chi2:  1334.0939895330298
# ***************************************************
# Z2-amplitude:  3.01e+02
# reduced chi2:  2198.0040586835453
# ***************************************************
# Z2-amplitude:  3.02e+02
# reduced chi2:  2124.599067653483
# ***************************************************
# Z2-amplitude:  2.17e+02
# reduced chi2:  1969.5514443256625
# ***************************************************
# Z2-amplitude:  2.29e+02
# reduced chi2:  1271.6523958108503
# ***************************************************
# Z2-amplitude:  1.93e+02
# reduced chi2:  3289.4973523058184
# ***************************************************
# Z2-amplitude:  2.32e+02
# reduced chi2:  784.0113585901207
# ***************************************************
# Z2-amplitude:  2.53e+02
# reduced chi2:  1179.5749285398524
# ***************************************************
# Z2-amplitude:  1.79e+02
# reduced chi2:  1349.2104409745725
# ***************************************************
# Z2-amplitude:  2.34e+02
# reduced chi2:  1658.7422465348202
# ***************************************************
# Z2-amplitude:  2.15e+02
# reduced chi2:  1423.6959569546282
# ***************************************************
# Z2-amplitude:  1.92e+02
# reduced chi2:  2144.4944754072567
# ***************************************************
# Z2-amplitude:  2.13e+02
# reduced chi2:  1700.5493536239903
# ***************************************************
# Z2-amplitude:  1.57e+02
# reduced chi2:  1166.647120039064
# ***************************************************
# Z2-amplitude:  1.36e+02
# reduced chi2:  2095.3934586778955
# ***************************************************
# Z2-amplitude:  1.45e+02
# reduced chi2:  2329.8019647354295
# ***************************************************
# Z2-amplitude:  1.42e+02
# reduced chi2:  2605.255582325573
# ***************************************************
# Z2-amplitude:  1.52e+02
# reduced chi2:  1060.8110209394497
# ***************************************************
# Z2-amplitude:  2.32e+00
# reduced chi2:  2199.2463971217494
# ***************************************************
# Z2-amplitude:  1.70e+01
# reduced chi2:  1033.8113995701667
# ***************************************************
# Z2-amplitude:  1.75e+00
# reduced chi2:  1193.3191164426469
# ***************************************************
# Z2-amplitude:  7.56e+00
# reduced chi2:  1622.9433278270405
# ***************************************************
# Z2-amplitude:  5.02e+00
# reduced chi2:  2183.4776260811395
# ***************************************************
# Z2-amplitude:  5.33e+00
# reduced chi2:  2088.8937497805387
# ***************************************************
# Z2-amplitude:  2.27e+01
# reduced chi2:  1680.6801253667074
# ***************************************************
# Z2-amplitude:  9.07e+00
# reduced chi2:  2763.401331801502
# ***************************************************
# Z2-amplitude:  5.80e+00
# reduced chi2:  1811.610118082476
# ***************************************************
# Z2-amplitude:  8.52e+00
# reduced chi2:  2000.8861981540263
# ***************************************************
# Z2-amplitude:  3.43e+01
# reduced chi2:  1678.1413016726972
# ***************************************************
# Z2-amplitude:  6.36e+00
# reduced chi2:  851.8776767031541
# ***************************************************
# Z2-amplitude:  2.38e+01
# reduced chi2:  1824.6848508962314
# ***************************************************
# Z2-amplitude:  1.68e+01
# reduced chi2:  2336.342525385543
# ***************************************************
# Z2-amplitude:  9.22e+00
# reduced chi2:  1364.9217653438661
# ***************************************************
# Z2-amplitude:  8.78e+01
# reduced chi2:  3177.0407317886197
# ***************************************************
# Z2-amplitude:  6.36e+01
# reduced chi2:  2690.0171817278906
# ***************************************************
# Z2-amplitude:  1.53e+01
# reduced chi2:  2828.780282307916
# ***************************************************
# Z2-amplitude:  1.09e+02
# reduced chi2:  2517.9034179726114
# ***************************************************
# Z2-amplitude:  8.83e+01
# reduced chi2:  1311.3995194720576
# ***************************************************
# Z2-amplitude:  2.89e+02
# reduced chi2:  1852.5460164947044
# ***************************************************
# Z2-amplitude:  3.01e+02
# reduced chi2:  1350.1488704825847
# ***************************************************
# Z2-amplitude:  2.96e+02
# reduced chi2:  2613.7759953317754
# ***************************************************
# Z2-amplitude:  3.05e+02
# reduced chi2:  2908.246680434352
# ***************************************************
# Z2-amplitude:  3.09e+02
# reduced chi2:  2993.4812760896016
# ***************************************************
# Z2-amplitude:  3.12e+02
# reduced chi2:  3055.0597674550836
# ***************************************************
# Z2-amplitude:  2.62e+02
# reduced chi2:  1417.3430128208154
# ***************************************************
# Z2-amplitude:  2.87e+02
# reduced chi2:  1750.2418009247708
# ***************************************************
# Z2-amplitude:  2.69e+02
# reduced chi2:  1656.0754177292758
# ***************************************************
# Z2-amplitude:  2.94e+02
# reduced chi2:  969.8299542383321
# ***************************************************
# Z2-amplitude:  4.40e+01
# reduced chi2:  2350.9096040318077
# ***************************************************
# Z2-amplitude:  8.78e+01
# reduced chi2:  1806.523507459542
# ***************************************************
# Z2-amplitude:  8.46e+01
# reduced chi2:  3693.055315925671
# ***************************************************
# Z2-amplitude:  8.91e+01
# reduced chi2:  2024.4176908968534
# ***************************************************
# Z2-amplitude:  6.52e+01
# reduced chi2:  1786.350815103881
# ***************************************************
# Z2-amplitude:  2.95e+02
# reduced chi2:  1522.0681104412763
# ***************************************************
# Z2-amplitude:  2.69e+02
# reduced chi2:  1354.3338893498171
# ***************************************************
# Z2-amplitude:  3.03e+02
# reduced chi2:  1939.8809943883841
# ***************************************************
# Z2-amplitude:  2.88e+02
# reduced chi2:  2398.7124980227786
# ***************************************************
# Z2-amplitude:  3.23e+02
# reduced chi2:  1793.5071470834125
# ***************************************************
# Z2-amplitude:  2.98e+02
# reduced chi2:  955.5116220855095
# ***************************************************
# Z2-amplitude:  2.82e+02
# reduced chi2:  1857.4308072909917
# ***************************************************
# Z2-amplitude:  3.10e+02
# reduced chi2:  1792.272551670688
# ***************************************************
# Z2-amplitude:  2.87e+02
# reduced chi2:  1545.1878481153906
# ***************************************************
# Z2-amplitude:  3.01e+02
# reduced chi2:  692.0756880470287
# ***************************************************
# Z2-amplitude:  1.62e+02
# reduced chi2:  2039.1813757224488
# ***************************************************
# Z2-amplitude:  1.63e+02
# reduced chi2:  2743.9681512607613
# ***************************************************
# Z2-amplitude:  1.54e+02
# reduced chi2:  2523.843118210916
# ***************************************************
# Z2-amplitude:  1.44e+02
# reduced chi2:  1526.5922202277745
# ***************************************************
# Z2-amplitude:  1.51e+02
# reduced chi2:  4520.76028621287
# ***************************************************
# Z2-amplitude:  1.68e+02
# reduced chi2:  1713.1200501968688
# ***************************************************
# Z2-amplitude:  1.76e+02
# reduced chi2:  2868.3392597899356
# ***************************************************
# Z2-amplitude:  1.07e+02
# reduced chi2:  2268.2652996603583
# ***************************************************
# Z2-amplitude:  1.59e+02
# reduced chi2:  1378.0791348147045
# ***************************************************
# Z2-amplitude:  1.72e+02
# reduced chi2:  1779.8852048202184
# ***************************************************
# Z2-amplitude:  5.47e+01
# reduced chi2:  3780.1971807591176
# ***************************************************
# Z2-amplitude:  7.63e+01
# reduced chi2:  1886.8801140022554
# ***************************************************
# Z2-amplitude:  7.20e+01
# reduced chi2:  3034.554921825342
# ***************************************************
# Z2-amplitude:  8.28e+01
# reduced chi2:  2542.3027284753903
# ***************************************************
# Z2-amplitude:  8.75e+01
# reduced chi2:  1294.4963512364593
# ***************************************************
# Z2-amplitude:  4.28e+01
# reduced chi2:  1574.9660280844769
# ***************************************************
# Z2-amplitude:  1.18e+01
# reduced chi2:  3816.436488266781
# ***************************************************
# Z2-amplitude:  1.06e+01
# reduced chi2:  1365.562131891834
# ***************************************************
# Z2-amplitude:  6.61e+00
# reduced chi2:  1462.6927561106424
# ***************************************************
# Z2-amplitude:  7.82e+00
# reduced chi2:  1532.7361707559505
# Z2 response (amplitude): 328.3515251570552

# %%
m2 = gfw.build_x_response(bdf_discharge_x, drive_freq=71, charges=1, bandwidth=1)
# Out:
# ***************************************************
# X2-amplitude:  1.06e+00
# reduced chi2:  601.6548776585977
# ***************************************************
# X2-amplitude:  1.48e+01
# reduced chi2:  411.2645183381076
# ***************************************************
# X2-amplitude:  6.51e+00
# reduced chi2:  63.73260213495974
# ***************************************************
# X2-amplitude:  3.92e+00
# reduced chi2:  11.366819524913414
# ***************************************************
# X2-amplitude:  1.42e+01
# reduced chi2:  65.70942080967149
# ***************************************************
# X2-amplitude:  1.93e+01
# reduced chi2:  1356.3303797451117
# ***************************************************
# X2-amplitude:  4.04e+01
# reduced chi2:  3048.2880871395064
# ***************************************************
# X2-amplitude:  7.40e+00
# reduced chi2:  3438.684909055599
# ***************************************************
# X2-amplitude:  1.35e+01
# reduced chi2:  9093.346208575056
# ***************************************************
# X2-amplitude:  6.66e+01
# reduced chi2:  10374.974074938544
# ***************************************************
# X2-amplitude:  1.51e+01
# reduced chi2:  6376.502355562288
# ***************************************************
# X2-amplitude:  2.47e+00
# reduced chi2:  8577.360985159745
# ***************************************************
# X2-amplitude:  9.79e+00
# reduced chi2:  3547.838308874263
# ***************************************************
# X2-amplitude:  9.02e+00
# reduced chi2:  3974.5117086116684
# ***************************************************
# X2-amplitude:  3.04e+01
# reduced chi2:  12517.774840369228
# ***************************************************
# X2-amplitude:  4.22e+01
# reduced chi2:  12755.943789363058
# ***************************************************
# X2-amplitude:  4.42e+01
# reduced chi2:  9493.939633796037
# ***************************************************
# X2-amplitude:  4.92e+01
# reduced chi2:  8720.581044287454
# ***************************************************
# X2-amplitude:  1.72e-01
# reduced chi2:  3398.010467133379
# ***************************************************
# X2-amplitude:  3.17e+00
# reduced chi2:  2714.521929363072
# ***************************************************
# X2-amplitude:  2.32e-02
# reduced chi2:  0.0064592524165778
# ***************************************************
# X2-amplitude:  3.11e-02
# reduced chi2:  0.00717881933162086
# ***************************************************
# X2-amplitude:  5.31e-03
# reduced chi2:  0.003940033018041308
# ***************************************************
# X2-amplitude:  5.59e-02
# reduced chi2:  0.01063745325413359
# ***************************************************
# X2-amplitude:  1.67e-02
# reduced chi2:  0.008723689467477069
# ***************************************************
# X2-amplitude:  7.29e-02
# reduced chi2:  0.006037662946891652
# ***************************************************
# X2-amplitude:  6.75e-03
# reduced chi2:  0.011207044767560417
# ***************************************************
# X2-amplitude:  3.64e-02
# reduced chi2:  0.007718163722108966
# ***************************************************
# X2-amplitude:  4.43e-03
# reduced chi2:  0.006079256909814798
# ***************************************************
# X2-amplitude:  2.47e-02
# reduced chi2:  0.009356722413104509
# ***************************************************
# X2-amplitude:  8.23e-01
# reduced chi2:  0.005130744530706598
# ***************************************************
# X2-amplitude:  8.11e-01
# reduced chi2:  0.011202768619337814
# ***************************************************
# X2-amplitude:  7.26e-01
# reduced chi2:  0.010867044409497118
# ***************************************************
# X2-amplitude:  8.70e-01
# reduced chi2:  0.016389285695783122
# ***************************************************
# X2-amplitude:  8.10e-01
# reduced chi2:  0.006623138975086395
# ***************************************************
# X2-amplitude:  4.67e+00
# reduced chi2:  7.399707129782938
# ***************************************************
# X2-amplitude:  2.87e+00
# reduced chi2:  5.106960078165323
# ***************************************************
# X2-amplitude:  3.18e+00
# reduced chi2:  0.05483488503913881
# ***************************************************
# X2-amplitude:  3.12e+00
# reduced chi2:  0.017048715419650903
# ***************************************************
# X2-amplitude:  3.01e+00
# reduced chi2:  2.588337282987719
# ***************************************************
# X2-amplitude:  3.20e+00
# reduced chi2:  0.037760054820683946
# ***************************************************
# X2-amplitude:  3.15e+00
# reduced chi2:  0.03549641278327543
# ***************************************************
# X2-amplitude:  3.26e+00
# reduced chi2:  0.018920592402870983
# ***************************************************
# X2-amplitude:  3.28e+00
# reduced chi2:  0.01439690300412129
# ***************************************************
# X2-amplitude:  3.22e+00
# reduced chi2:  0.018709196413728115
# ***************************************************
# X2-amplitude:  1.58e+00
# reduced chi2:  0.01036256295197792
# ***************************************************
# X2-amplitude:  1.57e+00
# reduced chi2:  0.0051899533184786295
# ***************************************************
# X2-amplitude:  1.59e+00
# reduced chi2:  0.008745776937049227
# ***************************************************
# X2-amplitude:  1.60e+00
# reduced chi2:  0.011318176177803656
# ***************************************************
# X2-amplitude:  1.58e+00
# reduced chi2:  0.010473411463561
# ***************************************************
# X2-amplitude:  1.51e+00
# reduced chi2:  0.02304756850558604
# ***************************************************
# X2-amplitude:  2.35e+00
# reduced chi2:  2.191195027809808
# ***************************************************
# X2-amplitude:  2.45e+00
# reduced chi2:  5.788935845486704
# ***************************************************
# X2-amplitude:  1.64e+00
# reduced chi2:  0.009164122115793422
# ***************************************************
# X2-amplitude:  1.63e+00
# reduced chi2:  0.008057395621429854
# ***************************************************
# X2-amplitude:  6.30e-02
# reduced chi2:  2.1267130454914267
# ***************************************************
# X2-amplitude:  5.69e-01
# reduced chi2:  3.6416646922538742
# ***************************************************
# X2-amplitude:  1.83e+00
# reduced chi2:  3.5750548597320058
# ***************************************************
# X2-amplitude:  8.42e-01
# reduced chi2:  8.530584166194277
# ***************************************************
# X2-amplitude:  1.04e+00
# reduced chi2:  18.723592529309865
# ***************************************************
# X2-amplitude:  6.73e-02
# reduced chi2:  0.006452442287309505
# ***************************************************
# X2-amplitude:  2.40e-02
# reduced chi2:  0.01143037748946591
# ***************************************************
# X2-amplitude:  1.10e-02
# reduced chi2:  0.009873827325537715
# ***************************************************
# X2-amplitude:  2.81e-02
# reduced chi2:  0.003915109915740121
# ***************************************************
# X2-amplitude:  1.86e-02
# reduced chi2:  0.011235167480725446
# X3 to X2 ratio: 0.21
# X2 response (amplitude): -2.559984247951965
# X2 response (amplitude): -2.559984247951965

# %%
ampsx = np.array([m_.values[0] for m_ in m2])
phasesx = np.array([m_.values[5] for m_ in m2])
_, ax = plt.subplots(1,2,figsize=(9.1,4))
ax[0].scatter(range(len(ampsx)), ampsx)
ax[1].scatter(range(len(ampsx)), phasesx)
# np.mean(phases[80:110])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
_,ax = plt.subplots(figsize=(9.5,4))
scale = 74
scaleX = -0.8

# Perrinf
ax.scatter(index_z, amps/scale, label='fit fixed-phase')
ax.scatter(index_x, ampsx/scaleX, label='X-pos fit fixed-phases')

ax.legend()
ax.set(xlabel='dataset', ylabel='Charges', ylim=(None,None), xlim=(None,None))
ax.grid(axis='y')
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.legend()
from matplotlib.ticker import MaxNLocator
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## TF

# %%
# 7.6um German bead
fname = r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFuncX2_1Hz_300s.h5'
tf_x = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFuncY1_1Hz_100s.h5'
tf_y = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFuncZ2_1Hz_300s.h5'
tf_z = BeadDataFile.BeadDataFile(fname=fname)
tf_list = [tf_x, tf_y, tf_z]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
_,ax = plt.subplots(1,3, figsize=(9,3))
bb = tf_z
ax[0].semilogy(*bb.psd2('x'))
ax[1].semilogy(*bb.psd2('y'))
ax[2].semilogy(*bb.psd2('z'))
[a.set(xlim=(0,100)) for a in ax]
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [[(0.0, 100.0)], [(0.0, 100.0)], [(0.0, 100.0)]]

# %%
names = ['Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8', 'Y9']
names = ['Y7', 'Y8', 'Y9', 'Y11']
fnames = [r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFunc'+y_+'_7Hz_10s.h5' for y_ in names]
bbs = [BeadDataFile.BeadDataFile(fname_) for fname_ in fnames]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
_,ax = plt.subplots()
[ax.semilogy(*bb.psd2('y'), label=name_) for bb,name_ in zip(bbs,names)]
ax.legend()
ax.set(xlim=(100,1000))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [(100.0, 1000.0)]

# %% [markdown]
# ## Nois floor

# %%
bdf_z = bdf_discharge[210:215]
bdf_x = bdf_discharge[215:220]

freq = bdf_z[0].psd2('z')[0]
z_scale1 = bdf_z[0].psd2('z')[1][freq==71]
for bb in bdf_z:
    z_scale1 += bb.psd2('z')[1][freq==71]
z_scale1 /= len(bdf_z)

x_scale1 = bdf_x[0].psd2('x')[1][freq==71]
for bb in bdf_x:
    x_scale1 += bb.psd2('x')[1][freq==71]
x_scale1 /= len(bdf_x)

charges = 4
force = charges * 1.6e-19 * 20 / 8.6e-3 * 0.63 * np.sqrt(10) # in Newtons/sqrt(Hz)
z_scale1 = force/np.sqrt(z_scale1)
x_scale1 = force/np.sqrt(x_scale1)

# %%
## 100 files of shaking data for nose floor
data_bdfs = load_dir(dirname='/home/data_transfer/data_from_windows/20200917/Bead1/Discharge/Discharge_Z/FineDischarge/', 
                         file_prefix='Discharge_', start_file=210, max_file=5)
freq = data_bdfs[0].psd2('x')[0]
fftx1 = data_bdfs[0].psd2('x')[1]
ffty1 = data_bdfs[0].psd2('y')[1]

fftz1 = data_bdfs[0].psd2('z')[1]
for i in range(1,5):
    fftx1 += data_bdfs[i].psd2('x')[1]
    fftz1 += data_bdfs[i].psd2('z')[1]
    ffty1 += data_bdfs[i].psd2('y')[1]
fftx1/=5
ffty1/=5
fftz1/=5
# Out:
# 260  files in folder
# 5  files loaded

# %%
_,ax = plt.subplots(1,2,figsize=(9.1,4))
# tf_freq = np.interp(freq, gfw.tf_freq, gfw.tf_ffts[2])
ax[0].semilogy(freq, np.sqrt(fftx1)*x_scale1)
ax[1].semilogy(freq, np.sqrt(fftz1)*z_scale1)
ax[0].set(xlim=(1,500), ylim=(9e-18,1e-14), xlabel='Frequency [Hz.]', ylabel=r'ASD [N/$\sqrt{Hz}$]', title='X force')
_ = ax[1].set(xlim=(1,500), ylim=(9e-18,1e-14), xlabel='Frequency [Hz.]', title=r'Z force')
# print(np.sqrt(fftx1[freq==18])*x_scale/np.sqrt(10), np.sqrt(fftz1[freq==18])*z_scale/np.sqrt(10))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
