# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %%
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ### Load data

# %%
foldername = r'/data/new_trap/20200107/Bead3/Discharge/'
bdf_discharge = load_dir(dirname=foldername)
# Out:
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# 135  files in folder
# 135  files loaded

# %%
bb = bdf_discharge[0]
response_x = [np.std(bb.response_at_freq('z',drive_freq=151)) for bb in bdf_discharge]
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
_, ax = plt.subplots()
ax.scatter(range(len(response_x)), response_x/response_x[128])
print(response_x[48])
ax.set(xlim=(38,None), ylim=(0,30))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 622.1951118233993
# [(0, 30), (38, 140.70665322580643)]

# %%
bdf_z = bdf_discharge[48:53]
bdf_x = bdf_discharge[38:43]
bdf_y = bdf_discharge[43:48]
charges = 21
m1s_z = gfw.build_z_response(bdf_z, drive_freq=151,charges=charges, bandwidth=2, decimate=10, include_sigma=True)
m1s_x = gfw.build_x_response(bdf_x, drive_freq=151,charges=charges, bandwidth=2, decimate=10)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# Z2-amplitude:  7.38e+03
# reduced chi2:  10.127092974361348
# ***************************************************
# Z2-amplitude:  7.44e+03
# reduced chi2:  10.870664000909414
# ***************************************************
# Z2-amplitude:  7.49e+03
# reduced chi2:  11.170904322732255
# ***************************************************
# Z2-amplitude:  7.52e+03
# reduced chi2:  11.3556441330054
# ***************************************************
# Z2-amplitude:  7.53e+03
# reduced chi2:  11.555985450218252
# Z2 response (amplitude): 7473.542759183928
# ***************************************************
# X2-amplitude:  1.33e+02
# reduced chi2:  6.141314932858894
# ***************************************************
# X2-amplitude:  1.32e+02
# reduced chi2:  5.020474343174825
# ***************************************************
# X2-amplitude:  1.36e+02
# reduced chi2:  7.472857585545926
# ***************************************************
# X2-amplitude:  1.34e+02
# reduced chi2:  5.633470777989857
# ***************************************************
# X2-amplitude:  1.36e+02
# reduced chi2:  4.608247483542295
# X3 to X2 ratio: 0.18524745572192636
# X2 response (amplitude): 134.2323281417718

# %%
_,ax = plt.subplots()
[ax.semilogy(*bb.psd('z')) for bb in bdf_z]
ax.set(xlim=(1,200))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(1, 200)]

# %% [markdown]
# ### Transfer function

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].loglog(*tf_x.psd2('x'))
ax[0].loglog(*tf_y.psd2('y'))
ax[1].loglog(*tf_z.psd2('z'))
[a.set(xlim=(3,1000)) for a in ax]
# Out:
# <img src="data:image/png;base64,..." width="950">
# [[(3, 1000)], [(3, 1000)]]

# %%
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_X_1.h5'
tf_x = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_Y_2.h5'
tf_y = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200107/Bead3/TransFunc/TransFunc_Z_3.h5'
tf_z = BeadDataFile.BeadDataFile(fname=fname)
tf_list = [tf_x, tf_y, tf_z]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data

# %%
gfw.build_transfer_function(tf_list, plot=True)
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
# foldername = r'/data/new_trap/20200107/Bead3/InitialTest/'
foldername = r'/data/new_trap/20200107/Bead3/Shaking/Shaking380/'
datasets_num = 350
gfw.BDFs = load_dir(foldername, file_prefix='Shaking13',max_file=datasets_num)
# Out:
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# No height data
# 1000  files in folder
# 350  files loaded

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4),sharex=True)
for bb in gfw.BDFs[32::2]:
    ax[0].semilogy(*bb.psd('z'))
    ax[1].semilogy(*bb.psd2('x'))
ax[0].set(xlim=(2,100),xlabel='frequency [Hz.]', title='Z signal psd')
ax[1].set(xlim=(2,100),xlabel='frequency [Hz.]', title='X signal psd')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(2, 100), Text(0.5, 0, 'frequency [Hz.]'), Text(0.5, 1.0, 'X signal psd')]

# %%
gfw.build_noise_array(sideband_freq=20, bandwidth=1)
gfw.build_noise_array_z(sideband_freq=20, bandwidth=1)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# x2 noise rms:  0.32614027358654896
# x3 noise rms:  0.07239215854707944
# z2 noise level:  17.464442695545255  std:  3.921217403761746

# %%
fit_kwargs = {'alpha': 1e-2, 'phase': 0, 'error_alpha': 0.01, 'error_phase': 1,
              'errordef': 1,
              'limit_alpha': [1e-5, 10], 'limit_phase': [-5000,5000],
              'fix_alpha': False, 'fix_phase': False, 'print_level': 0}
min_18_xz = []
datasets_num = 350
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num)
    min_18_xz.append(gfw.get_alpha_2d(bdf=bb, center_freq=18, bandwidth=2, direction1='x', direction2='z',
                          x_focous=389.0, frequency=3, lambda_par=0.0001, height=6e-6, decimate=10, suppress_print=False,
                          **fit_kwargs)[2])
# Out:
# 0 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.28e-03
# reduced chi2:  76.24012100984234
# 1 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.38e-03
# reduced chi2:  44.55315544934568
# 2 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1
/ 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.39e-03
# reduced chi2:  39.12075678598973
# 100 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.83e-02
# reduced chi2:  39.114113952357606
# 101 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.03e-03
# reduced chi2:  30.831203813418266
# 102 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.41e-03
# reduced chi2:  32.573429753112414
# 103 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.21e-02
# reduced chi2:  45.45287609535361
# 104 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.24e-02
# reduced chi2:  41.3614398798628
# 105 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.43e-03
# reduced chi2:  38.12198767377819
# 106 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.09e-03
# reduced chi2:  44.7849746481731
# 107 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.15e-03
# reduced chi2:  31.744589757818634
# 108 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# ...
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.52e-03
# reduced chi2:  36.87988283581638
# 119 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.06e-03
# reduced chi2:  50.80520610450153
# 120 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.39e-03
# reduced chi2:  48.37540107595311
# 121 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.21e-03
# reduced chi2:  42.28674738761911
# 122 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.02e-02
# reduced chi2:  56.239211689430924
# 123 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.36e-03
# reduced chi2:  66.98214475551246
# 124 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.55e-03
# reduced chi2:  54.91500221135811
# 125 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.38e-02
# reduced chi2:  75.12703321876367
# 126 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.44e-03
# reduced chi2:  28.45880660149866
# 127 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.05e-03
# reduced chi2:  65.68145571689034
# 128 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.99e-02
# reduced chi2:  55.93205959337771
# 129 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.39e-03
# reduced chi2:  52.846279886189365
# 130 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.36e-02
# reduced chi2:  41.00409709463628
# 131 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.65e-03
# reduced chi2:  47.09291497476539
# 132 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.29e-04
# reduced chi2:  62.496712315801474
# 133 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.12e-03
# reduced chi2:  61.58131022257904
# 134 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.03e-02
# reduced chi2:  38.94637307309206
# 135 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.85e-03
# reduced chi2:  29.21523863149909
# 136 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.15e-03
# reduced chi2:  49.06341806352449
# 137 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.07e-03
# reduced chi2:  62.77550627622399
# 138 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.64e-04
# reduced chi2:  41.87090127079496
# 139 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.76e-03
# reduced chi2:  35.43587424805171
# 140 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.26e-02
# reduced chi2:  69.22072795823105
# 141 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.41e-03
# reduced chi2:  46.30306542539985
# 142 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.37e-03
# reduced chi2:  41.47567923530915
# 143 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.14e-03
# reduced chi2:  38.46161430371715
# 144 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.22e-03
# reduced chi2:  71.84084047722982
# 145 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.48e-03
# reduced chi2:  64.58700878984295
# 146 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.09e-02
# reduced chi2:  30.752653915910393
# 147 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.68e-03
# reduced chi2:  60.201297758973276
# 148 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.63e-04
# reduced chi2:  51.08911217313853
# 149 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.26e-03
# reduced chi2:  36.743726735491386
# 150 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.71e-03
# reduced chi2:  50.5525876292057
# 151 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.25e-02
# reduced chi2:  44.422437367235744
# 152 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.37e-03
# reduced chi2:  79.63811662669558
# 153 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.91e-03
# reduced chi2:  53.35953936992053
# 154 / 350
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected

# %%
m_18_z = [m_.values[0] for m_ in min_18_z]
m_18_x = [m_.values[0] for m_ in min_18_x]
m_18_xz = [m_.values[0] for m_ in min_18_xz]
m_18_noise = [m_.values[0] for m_ in min_18_noise]

_, ax = plt.subplots(figsize=(9,4))
ax.semilogy(np.arange(350), np.array(m_18_noise)*1e10, '.', label=r'Z noise')
ax.semilogy(np.arange(350), np.array(m_18_x)*1e10, '.', label=r'X only')
ax.semilogy(np.arange(350), np.array(m_18_z)*1e10, '.', label=r'Z only')
ax.semilogy(np.arange(350), np.array(m_18_xz)*1e10, '.', label=r'X & Z')
ax.legend()
print('mean alpha (Z-only): ', np.mean(m_18_z), 'std: ', np.std(m_18_z)/np.sqrt(350)*2)
print('mean alpha (Z-only): ', np.mean(m_18_x), 'std: ', np.std(m_18_x)/np.sqrt(350)*2)
print('mean alpha (Z-only) Noise: ', np.mean(m_18_noise), 'std: ', np.std(m_18_noise)/np.sqrt(350)*2)
# Out:
# <img src="data:image/png;base64,..." width="900">
# mean alpha (Z-only):  0.008765721263628037 std:  0.0005567211458290538
# mean alpha (Z-only):  0.5339918336145545 std:  0.013352261421536124
# mean alpha (Z-only) Noise:  0.009309796057930026 std:  0.0005467743820297394

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].semilogy(np.arange(350), np.array(m_18_z)*1e10, '.', label=r'6th harmonic')
ax[0].semilogy(np.arange(350), np.array(m_18_noise)*1e10, '.', label=r'noise')
ax[0].set(ylim=(1e7,5e10), xlabel='time [sec.]', ylabel=r'$\alpha$', title=r'$\lambda=100 \mu m $')
ax[0].legend()
ax[1].hist(m_18_z,bins=20,alpha=0.5)
ax[1].hist(m_18_noise,bins=20,alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="950">
# (array([18., 25., 31., 46., 42., 37., 39., 30., 24., 13., 20., 12.,  5.,
#          3.,  4.,  0.,  0.,  0.,  0.,  1.]),
#  array([0.00036835, 0.00192331, 0.00347827, 0.00503323, 0.00658819,
#         0.00814315, 0.00969811, 0.01125307, 0.01280803, 0.01436299,
#         0.01591795, 0.01747291, 0.01902787, 0.02058283, 0.02213779,
#         0.02369275, 0.02524771, 0.02680267, 0.02835763, 0.02991259,
#         0.03146755]),
#  <a list of 20 Patch objects>)

# %%
print('6th hsrmonic mean: ',np.mean(m_18_z), ' error: ', np.std(m_18_z)/np.sqrt(350))
print('noise mean: ',np.mean(m_18_noise), ' error: ', np.std(m_18_noise)/np.sqrt(350))
print('estimated limit: ', format(np.std(m_18_noise)/np.sqrt(350)*2*1e10,"5.2e"))
# Out:
# 6th hsrmonic mean:  0.008765721263628037  error:  0.0002783605729145269
# noise mean:  0.009309796057930026  error:  0.0002733871910148697
# estimated limit:  5.47e+06
