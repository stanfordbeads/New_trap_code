# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework

# %% [markdown]
# ### Load data

# %%
foldername = r'/data/new_trap/20191204/Bead1/Discharge/'
bdf_discharge = load_dir(dirname=foldername)
# Out:
# 100  files in folder
# 100  files loaded

# %%
bdf_x = bdf_discharge[52:57]
charges = 15

# %%
fname = r'/data/new_trap/20191204/Bead1/TransFunc/TransFunc_X_4.h5'
fname2 = r'/data/new_trap/20191204/Bead1/TransFunc/TransFunc_X_4.h5'
bdf_tf_x = BeadDataFile.BeadDataFile(fname=fname)
bdf_tf_x2 = BeadDataFile.BeadDataFile(fname=fname2)
# Out:
# No cantilever data
# Error loading spinning data
# No cantilever data
# Error loading spinning data

# %%
gfw = GravityFramework.GravityFramework()
foldername = r'/data/new_trap/20191204/Bead1/Shaking/Shaking370/'
datasets_num = 1000
gfw.BDFs = load_dir(foldername,file_prefix='Shaking1',max_file=datasets_num)
# Out:
# 1000  files in folder
# 1000  files loaded

# %%
gfw.build_noise_array(sideband_freq=75)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# x2 noise rms:  0.25009553527107703
# x3 noise rms:  0.05368823668568375

# %%
m1s = gfw.build_x_response(bdf_x, drive_freq=151,charges=charges)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# X2-amplitude:  8.84e+01
# reduced chi2:  8.357675355729913
# ***************************************************
# X2-amplitude:  8.84e+01
# reduced chi2:  7.973775203336449
# ***************************************************
# X2-amplitude:  8.84e+01
# reduced chi2:  8.482895486910035
# ***************************************************
# X2-amplitude:  8.89e+01
# reduced chi2:  8.090453486511798
# ***************************************************
# X2-amplitude:  8.96e+01
# reduced chi2:  8.22476709014919
# X3 to X2 ratio: 0.18682062835025937
# X2 response (amplitude): 88.73777942864784

# %%
_,ax = plt.subplots()
ax.semilogy(range(len(gfw.noise_list_x2)),gfw.noise_list_x2/gfw.scale_X2,'.')
ax.set(ylim=(1e-18,1e-15))
# Out:
# <div id='d751da0e-4b94-4c31-94d0-1c7d352d57c5'></div>
# [(1e-18, 1e-15)]

# %%
gfw.plot_dataset(bdf_i=10)
# Out:
# <div id='706b80c4-4b24-4c46-969d-d8ac3f6ebad4'></div>

# %%
fit_kwargs = {'alpha': 0.6, 'phase': 0, 'error_alpha': 0.1, 'error_phase': 10,
              'errordef': 1,
              'limit_alpha': [0, 1000], 'limit_phase': [-500,500],
              'fix_alpha': False, 'fix_phase': False, 'print_level': 0}
mm = [gfw.get_alpha(bdf=gfw.BDFs[i],center_freq=150, bandwidth=100, separation=14.5e-6, 
              lambda_par=100e-6, stroke=318e-6,**fit_kwargs)[0] for i in range(datasets_num)]
# Out:
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# alpha:  1.11e+00
# reduced chi2:  468.0657134169689
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.57e+00
# reduced chi2:  529.9319023676026
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  7.10e-01
# reduced chi2:  261.8258950214201
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.29e-01
# reduced chi2:  340.3929902654185
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.80e-02
# reduced chi2:  396.1313960990813
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  2.62e-03
# reduced chi2:  282.6204547825596
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  2.10e-01
# reduced chi2:  261.094876061744
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  0.00e+00
# reduced chi2:  236.33569594784169
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  4.03e-04
# reduced chi2:  285.87359635583283
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  2.21e-01
# reduced chi2:  277.1693233678953
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.00e+00
# reduced chi2:  209.33058987788175
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.08e+00
# reduced chi2:  178.18519538258894
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.36e-01
# reduced chi2:  273.32486341193646
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.16e+00
# reduced chi2:  178.8629405942159
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.40e-01
# reduced chi2:  289.22683783139
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  9.80e-01
# reduced chi2:  226.01982346078987
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  5.58e-01
# reduced chi2:  302.1257684047703
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.15e+00
# reduced chi2:  197.63588719569145
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  5.15e-03
# reduced chi2:  268.06580782929103
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  2.15e-01
# reduced chi2:  304.8603144916918
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.28e+00
# reduced chi2:  193.20497176063785
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.36e-01
# reduced chi2:  230.21095059412085
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  6.26e-01
# reduced chi2:  280.49819299840954
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  4.88e-01
# reduced chi2:  269.9611874171996
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  6.95e-02
# reduced chi2:  309.96085893734505
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.16e+00
# reduced chi2:  177.58857221745055
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  4.08e-01
# reduced chi2:  226.25960582216194
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  3.91e-01
# reduced chi2:  277.9352258518116
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  0.00e+00
# reduced chi2:  300.11321165013413
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.10e-01
# reduced chi2:  272.36888689967583
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  7.78e-01
# reduced chi2:  228.1584161715849
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.58e-01
# reduced chi2:  290.2970057091819
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  3.74e-02
# reduced chi2:  285.6396948245752
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.79e-01
# reduced chi2:  224.88557169717896
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  8.27e-01
# reduced chi2:  201.55462993150488
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  2.04e+00
# reduced chi2:  248.8889598783379
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  5.90e-01
# reduced chi2:  288.2198561659916
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  6.76e-02
# reduced chi2:  300.9425797015598
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.38e+00
# reduced chi2:  169.46358742185916
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  2.89e-01
# reduced chi2:  271.6710872741292
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  9.80e-01
# reduced chi2:  181.90215916031215
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  1.22e+00
# reduced chi2:  139.98650666209227
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  7.46e-01
# reduced chi2:  191.18510157740488
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  7.95e-01
# reduced chi2:  241.5672787970329
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  7.75e-01
# reduced chi2:  258.73067333913536
# Your choice of separation or height is not existing
# Taking 1.5e-05 for separation
# Taking 8.5e-21 for height
# A separation of 1.45e-05 is selected
# A height of 8.47e-21 is selected
# ***************************************************
# alpha:  9.44e-02
# reduced chi2:  340.08345230648763

# %%
_, ax = plt.subplots()
ax.semilogy(np.arange(datasets_num)*10, np.array(mm)*1e10, '.')
ax.set(ylim=(1e8,1e13), xlabel='time [sec.]', ylabel=r'$\alpha$', title=r'$\lambda=100 \mu m $')
print(np.mean(mm))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.735236052106358

# %%
import bootstrapped.bootstrap as bs
import bootstrapped.stats_functions as bs_stats

# %%
samples = np.array(mm)
print('C.I. ', bs.bootstrap(samples, stat_func=bs_stats.mean, num_iterations=10000, alpha=0.05, is_pivotal=False))
# Out:
# C.I.  0.7349983605836174    (0.7021973397773251, 0.7698897276151877)
