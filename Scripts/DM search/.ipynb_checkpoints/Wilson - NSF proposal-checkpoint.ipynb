# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

from joblib import Parallel, delayed
from tqdm import tqdm

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

sys.path.append('/home/analysis_user/New_trap_code/SensitivityFramework/')
from signal_model_utilities import *

# %%
# %matplotlib widget

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Take a look at the phase

# %%
def getPhases(i):
    print(i,'  ******************')
    fname = r'/data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_'+str(i)+'.h5'
    bb = BeadDataFile.BeadDataFile(fname=fname)
    x = bb.z2
    fft_ = np.fft.rfft(x,norm='ortho')
    freq_ = np.fft.rfftfreq(len(x), d=1./5000)
    return [np.angle(fft_[freq_==harm*3]) for harm in range(1,14)]

# %%
test_phase = np.array(Parallel(n_jobs=20)(delayed(getPhases)(i) for i in tqdm(range(10000)))).T[0]
# Out:
# 100%|██████████| 10000/10000 [02:18<00:00, 72.26it/s]

# %%
test_phasez = np.array(Parallel(n_jobs=20)(delayed(getPhases)(i) for i in tqdm(range(10000)))).T[0]
# Out:
# 100%|██████████| 10000/10000 [00:24<00:00, 440.64it/s]

# %%
## force template
dist = 11.4
z_sep = -15.85
y_offset = 4.9
test = force_vs_time(dist*1e-6,z_sep*1e-6,100e-6,3,"z",10e-6, yuk_or_grav="yuk",offset_y=y_offset*1e-6, 
                     alpha=1e8, bead_size=3.8e-6)

def fft_norm(N, fsamp):
    "Factor to normalize FFT to ASD units"
    return np.sqrt(2 / (N * fsamp))
scale = np.sqrt(2)*fft_norm(5000, 5000)

_,ax = plt.subplots()
x = test[1]
# x2 = test2[1]
fft = np.abs(np.fft.rfft(x))*scale*1.85/1.55
freq = np.fft.rfftfreq(len(x), d=1./5000)
angles = np.angle(np.fft.rfft(x))
phases_th = [angles[freq==freq_] for freq_ in 3*np.arange(14)]
# fft2 = np.abs(np.fft.rfft(x2))*scale
ax.semilogy(freq, fft, label='7.6 $\mu m$ sphere - Z force')
# ax.semilogy(freq, fft2, label='7.6 $\mu m$ sphere - Z force', alpha=0.5)
ax.set(xlim=(1,100), ylim=(None,None), xlabel='frequency [Hz]', ylabel='Force [N]', title=r'$\alpha=1x10^{8}$')
ax.legend()
print('Z force [N] at 36Hz.:', fft[freq==36])
print('sensitivity [alpha]:', 1e-17/fft[freq==36]*1e8)
# Out:
# Your choice of separation or height is not existing
# Taking 3.8e-06 for bead_size
# Taking 1.2e-05 for separation
# Taking -1.5e-05 for height
# order
# A bead size of 3.80e-06 is selected
# 3.8e-06
# 3.8e-06
# A bead size of 3.80e-06 is selected
# 3.8e-06
# posvec
# A bead size of 3.80e-06 is selected
# 3.8e-06
# A separation of 1.15e-05 is selected
# A height of -1.50e-05 is selected
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Z force [N] at 36Hz.: [9.65433374e-21]
# sensitivity [alpha]: [1.03580426e+11]

# %%
fig, ax = plt.subplots(3,4,figsize=(9,8.5), sharex=True)
i = 0
# _ = [a.hist(test_phase[j][:3000], label=str(np.arange(1,13)[j]*3)+'Hz.', density=True, bins=60, range=(-np.pi,np.pi)) for j,a in enumerate(ax.flatten())]
_ = [a.hist(test_phasez[j][:3000], label=str(np.arange(1,13)[j]*3)+'Hz.', density=True, bins=60, range=(-np.pi,np.pi)) for j,a in enumerate(ax.flatten())]
_ = [a.legend() for a in ax.flatten()]
_ = [a.axvline(phases_th[j], color='r', linestyle='dashed', linewidth=3) for j,a in enumerate(ax.flatten())]
_ = [a.set(xlabel='phase [rad]') for a in ax[2][:].flatten()]
_ = [a.set(ylabel='[a.u.]') for a in ax.flatten()[::4]]
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Gravity results

# %%
fname = r'/data/new_trap/20200320/Bead1/TransFunc/Repeat_TransFunc_20200104/TransFunc_X_m300k_250s_1hz.h5'
tf_x = BeadDataFile.BeadDataFile(fname)
fname = r'/data/new_trap/20200320/Bead1/TransFunc/Repeat_TransFunc_20200104/TransFunc_Y_m300k_250s_1hz.h5'
tf_y = BeadDataFile.BeadDataFile(fname)
fname = r'/data/new_trap/20200320/Bead1/TransFunc/Repeat_TransFunc_20200104/TransFunc_Z_m300k_250s_1hz.h5'
tf_z = BeadDataFile.BeadDataFile(fname)
gfw.build_transfer_function([tf_x, tf_y, tf_z], base_freq=1, number_of_harmonics=90, scale_freq=71, plot=False)
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20200320/Bead1/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403/',
                         start_file=230, max_file=40)
bdf_z = bdf_discharge[5:35]
# Out:
# 530  files in folder
# 40  files loaded

# %%
bandwidth = 2
m1_zscale = gfw.build_z_response(bdf_z, drive_freq=71, charges=6, bandwidth=bandwidth, decimate=10)
# Out:
# ***************************************************
# Z2-amplitude:  2.69e+02
# reduced chi2:  288.98586212705186
# ***************************************************
# Z2-amplitude:  2.60e+02
# reduced chi2:  658.9340028864549
# ***************************************************
# Z2-amplitude:  2.74e+02
# reduced chi2:  486.49073911245125
# ***************************************************
# Z2-amplitude:  2.78e+02
# reduced chi2:  662.0476432309312
# ***************************************************
# Z2-amplitude:  2.80e+02
# reduced chi2:  581.29439966364
# ***************************************************
# Z2-amplitude:  2.74e+02
# reduced chi2:  610.1516298108376
# ***************************************************
# Z2-amplitude:  2.70e+02
# reduced chi2:  341.72862648819574
# ***************************************************
# Z2-amplitude:  2.66e+02
# reduced chi2:  319.23470715664763
# ***************************************************
# Z2-amplitude:  2.66e+02
# reduced chi2:  482.87048405227034
# ***************************************************
# Z2-amplitude:  2.68e+02
# reduced chi2:  572.3808781081232
# ***************************************************
# Z2-amplitude:  2.69e+02
# reduced chi2:  393.3016008789175
# ***************************************************
# Z2-amplitude:  2.68e+02
# reduced chi2:  651.5431890881895
# ***************************************************
# Z2-amplitude:  2.66e+02
# reduced chi2:  837.3092290465291
# ***************************************************
# Z2-amplitude:  2.60e+02
# reduced chi2:  533.3920790790161
# ***************************************************
# Z2-amplitude:  2.66e+02
# reduced chi2:  368.5085424903292
# ***************************************************
# Z2-amplitude:  2.59e+02
# reduced chi2:  555.1231537639599
# ***************************************************
# Z2-amplitude:  2.68e+02
# reduced chi2:  745.6625642557611
# ***************************************************
# Z2-amplitude:  2.70e+02
# reduced chi2:  347.84760405152247
# ***************************************************
# Z2-amplitude:  2.68e+02
# reduced chi2:  453.97980818387003
# ***************************************************
# Z2-amplitude:  2.77e+02
# reduced chi2:  561.8119183541804
# ***************************************************
# Z2-amplitude:  2.82e+02
# reduced chi2:  474.20113888118
# ***************************************************
# Z2-amplitude:  2.73e+02
# reduced chi2:  353.85435659878726
# ***************************************************
# Z2-amplitude:  2.78e+02
# reduced chi2:  408.8805051267125
# ***************************************************
# Z2-amplitude:  2.74e+02
# reduced chi2:  406.29259344214404
# ***************************************************
# Z2-amplitude:  2.70e+02
# reduced chi2:  526.1643048167273
# ***************************************************
# Z2-amplitude:  2.60e+02
# reduced chi2:  439.2274329734673
# ***************************************************
# Z2-amplitude:  2.62e+02
# reduced chi2:  842.0440005045637
# ***************************************************
# Z2-amplitude:  2.74e+02
# reduced chi2:  599.8696978333775
# ***************************************************
# Z2-amplitude:  2.69e+02
# reduced chi2:  383.96223661058264
# ***************************************************
# Z2-amplitude:  2.70e+02
# reduced chi2:  597.3219749580621
# Z2 response (amplitude): -269.58341993010276

# %%
## likelihood calculator stuff
gravity_freqs = np.array([36, 33, 24, 18, 9])
gravity_scales = np.array([gfw.scale_Z2])* np.interp(gravity_freqs, gfw.tf_freq, gfw.tf_ffts[2])

# %%
# noise estimation
data_bdfs2 = load_dir(dirname='/data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/',
                         file_prefix='NoShaking_1', start_file=0, max_file=100)

# ## noise estimation
# data_bdfs2 = load_dir(dirname='/data/new_trap/20200320/Bead1/Shaking/Shaking378/',
#                          file_prefix='Shaking3', start_file=0, max_file=100)
# Out:
# 6905  files in folder
# 100  files loaded

# %%
noises_std = np.ones(len(gravity_freqs))

# gravity_freqs2 = gravity_freqs+1.5
# noises_std1 =[]
# for freq_ in gravity_freqs2:
#     tmp_list = []
#     for bb in data_bdfs2:
#         tmp_list.append(np.std(bb.response_at_freq2('z', drive_freq=freq_, bandwidth=bandwidth)))
#     noises_std1.append(np.std(tmp_list))

# gravity_freqs2 = gravity_freqs-1.5
# noises_std2 =[]
# for freq_ in gravity_freqs2:
#     tmp_list = []
#     for bb in data_bdfs2:
#         tmp_list.append(np.std(bb.response_at_freq2('z', drive_freq=freq_, bandwidth=bandwidth)))
#     noises_std2.append(np.std(tmp_list))

# noises_std = np.array([np.mean([n1, n2]) for n1,n2 in zip(noises_std1,noises_std2)])**2

# %%
noises_std, gravity_freqs
# Out:
# (array([1., 1., 1., 1., 1.]), array([36, 33, 24, 18,  9]))

# %%
i = 100
fname = r'/data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_'+str(i)+'.h5'
bb = BeadDataFile.BeadDataFile(fname=fname)
np.std(bb.cant_pos[1])*np.sqrt(2)*50
bb.cant_freq
# Out:
# 3.0

# %%
ll = likelihood_analyser.LikelihoodAnalyser()
def func2(i):
    print(i,'  ******************')
    fname = r'/data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_'+str(i)+'.h5'
    bb = BeadDataFile.BeadDataFile(fname=fname)

    fit_kwargs = {'A': 0, 'phi': 0.2, 'sigma':13.85,
              'error_A': 1, 'error_phi': 0.5, 'errordef': 1, 'error_sigma': 10,
              'limit_phi': [0, 2 * np.pi],
              'limit_A': [-1000, 1000], 'limit_sigma': [0, 1000000],
              'print_level': 0, 'fix_A': False, 'fix_phi': True, 'fix_sigma': False}
    
    ## force template
    dist = 392.4-np.mean(bb.cant_pos[0])*50-7.6/2+1
    z_sep = -15.85
    y_offset = 4.9
    stroke = np.std(bb.cant_pos[1])*np.sqrt(2)*50
    G_lambda = 10
    
    test_shaking378 = force_vs_time(dist*1e-6,z_sep*1e-6,stroke*1e-6,bb.cant_freq,"z",G_lambda*1e-6, 
                                    yuk_or_grav="yuk",offset_y=y_offset*1e-6, alpha=1e8, bead_size=3.8e-6)
    shaking378_template = np.array(test_shaking378[1])*1.85/1.55

    jj = i//100
    noises_std = np.array([sideband_36_std[jj],sideband_33_std[jj],sideband_24_std[jj],sideband_18_std[jj],sideband_9_std[jj]])**2

    mm_tmp = ll.find_mle_multiHarmoincs(x=bb.z2, template=shaking378_template, scales=gravity_scales, 
                                          signal_freqs=gravity_freqs, bandwidth=bandwidth, noises=noises_std/noises_std[0],
                                          decimate=10, **fit_kwargs)

    return mm_tmp.values[0]

# %%
mm_mle_All_lambda_10 = np.array(Parallel(n_jobs=40)(delayed(func2)(i) for i in tqdm(range(10000))))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#
#   0%|          | 40/10000 [00:02<09:08, 18.15it/s]
#
#   1%|          | 80/10000 [00:02<07:19, 22.59it/s]
#
#   1%|          | 120/10000 [00:04<06:52, 23.97it/s]
#
#   1%|          | 123/10000 [00:04<06:28, 25.40it/s]
#
#   1%|▏         | 126/10000 [00:04<06:22, 25.78it/s]
#
#   2%|▏         | 160/10000 [00:05<05:01, 32.62it/s]
#
#   2%|▏         | 200/10000 [00:05<04:10, 39.10it/s]
#
#   2%|▏         | 240/10000 [00:06<03:38, 44.65it/s]
#
#   3%|▎         | 280/10000 [00:06<03:07, 51.72it/s]
#
#   3%|▎         | 320/10000 [00:07<02:50, 56.81it/s]
#
#   3%|▎         | 327/10000 [00:07<02:49, 56.91it/s]
#
#   4%|▎         | 360/10000 [00:07<02:30, 64.21it/s]
#
#   4%|▍         | 400/10000 [00:08<02:27, 65.03it/s]
#
#   4%|▍         | 440/10000 [00:08<02:20, 68.01it/s]
#
#   5%|▍         | 480/10000 [00:09<02:17, 69.33it/s]
#
#   5%|▌         | 520/10000 [00:09<02:09, 72.93it/s]
#
#   6%|▌         | 560/10000 [00:10<02:16, 68.98it/s]
#
#   6%|▌         | 568/10000 [00:10<02:30, 62.71it/s]
#
#   6%|▌         | 600/10000 [00:10<02:10, 71.86it/s]
#
#   6%|▋         | 640/10000 [00:11<02:08, 72.62it/s]
#
#   7%|▋         | 680/10000 [00:12<02:18, 67.34it/s]
#
#   7%|▋         | 720/10000 [00:12<02:16, 67.96it/s]
#
#   8%|▊         | 760/10000 [00:13<02:13, 69.42it/s]
#
#   8%|▊         | 800/10000 [00:13<02:04, 73.90it/s]
#
#   8%|▊         | 808/10000 [00:13<02:05, 73.36it/s]
#
#   8%|▊         | 840/10000 [00:14<02:07, 71.59it/s]
#
#   8%|▊         | 848/10000 [00:14<02:27, 61.91it/s]
#
#   9%|▉         | 880/10000 [00:14<02:08, 71.02it/s]
#
#   9%|▉         | 888/10000 [00:14<02:12, 68.98it/s]
#
#   9%|▉         | 896/10000 [00:15<02:07, 71.48it/s]
#
#   9%|▉         | 920/10000 [00:15<02:08, 70.91it/s]
#
#  10%|▉         | 960/10000 [00:15<02:07, 70.73it/s]
#
#  10%|█         | 1000/10000 [00:16<01:57, 76.61it/s]
#
#  10%|█         | 1040/10000 [00:16<01:58, 75.54it/s]
#
#  11%|█         | 1080/10000 [00:17<02:12, 67.49it/s]
#
#  11%|█         | 1120/10000 [00:18<01:56, 76.11it/s]
#
#  12%|█▏        | 1160/10000 [00:18<01:53, 77.65it/s]
#
#  12%|█▏        | 1200/10000 [00:19<01:55, 76.47it/s]
#
#  12%|█▏        | 1240/10000 [00:19<01:55, 75.88it/s]
#
#  12%|█▏        | 1248/10000 [00:19<01:59, 73.24it/s]
#
#  13%|█▎        | 1280/10000 [00:20<01:59, 73.02it/s]
#
#  13%|█▎        | 1288/10000 [00:20<02:02, 71.07it/s]
#
#  13%|█▎        | 1320/10000 [00:20<01:57, 73.62it/s]
#
#  14%|█▎        | 1360/10000 [00:21<01:59, 72.38it/s]
#
#  14%|█▍        | 1400/10000 [00:21<01:58, 72.31it/s]
#
#  14%|█▍        | 1408/10000 [00:21<02:17, 62.33it/s]
#
#  14%|█▍        | 1415/10000 [00:22<02:23, 59.92it/s]
#
#  14%|█▍        | 1440/10000 [00:22<01:57, 72.77it/s]
#
#  15%|█▍        | 1480/10000 [00:22<01:55, 73.51it/s]
#
#  15%|█▌        | 1520/10000 [00:23<01:56, 72.91it/s]
#
#  16%|█▌        | 1560/10000 [00:23<01:52, 74.97it/s]
#
#  16%|█▌        | 1569/10000 [00:23<01:54, 73.70it/s]
#
#  16%|█▌        | 1577/10000 [00:24<01:52, 74.89it/s]
#
#  16%|█▌        | 1600/10000 [00:24<01:51, 75.41it/s]
#
#  16%|█▋        | 1640/10000 [00:24<01:50, 75.67it/s]
#
#  17%|█▋        | 1680/10000 [00:25<01:55, 72.11it/s]
#
#  17%|█▋        | 1720/10000 [00:26<01:54, 72.61it/s]
#
#  17%|█▋        | 1728/10000 [00:26<01:55, 71.85it/s]
#
#  17%|█▋        | 1736/10000 [00:26<01:55, 71.57it/s]
#
#  18%|█▊        | 1760/10000 [00:26<01:43, 79.23it/s]
#
#  18%|█▊        | 1800/10000 [00:27<01:48, 75.59it/s]
#
#  18%|█▊        | 1808/10000 [00:27<02:03, 66.38it/s]
#
#  18%|█▊        | 1816/10000 [00:27<02:08, 63.78it/s]
#
#
#  96%|█████████▌| 9600/10000 [02:23<00:05, 73.66it/s]
#
#  96%|█████████▋| 9640/10000 [02:24<00:05, 64.13it/s]
#
#  97%|█████████▋| 9680/10000 [02:24<00:04, 79.43it/s]
#
#  97%|█████████▋| 9720/10000 [02:25<00:03, 79.36it/s]
#
#  98%|█████████▊| 9760/10000 [02:25<00:03, 69.03it/s]
#
#  98%|█████████▊| 9800/10000 [02:26<00:02, 78.16it/s]
#
#  98%|█████████▊| 9840/10000 [02:26<00:02, 72.63it/s]
#
#  98%|█████████▊| 9849/10000 [02:26<00:02, 73.06it/s]
#
#  99%|█████████▉| 9880/10000 [02:27<00:01, 77.22it/s]
#
#  99%|█████████▉| 9889/10000 [02:27<00:01, 73.49it/s]
#
#  99%|█████████▉| 9897/10000 [02:27<00:01, 68.81it/s]
#
#  99%|█████████▉| 9920/10000 [02:28<00:01, 58.18it/s]
#
# 100%|█████████▉| 9960/10000 [02:28<00:00, 70.96it/s]
#
# 100%|█████████▉| 9969/10000 [02:28<00:00, 65.45it/s]
#
# 100%|██████████| 10000/10000 [02:28<00:00, 72.14it/s]

# %%
data = mm_mle_All_lambda_10

_,ax = plt.subplots()
avg = np.mean(data)
var = np.var(data)
# From that, we know the shape of the fitted Gaussian.
pdf_x = np.linspace(-50,50,100)
pdf_y = 1.0/np.sqrt(2*np.pi*var)*np.exp(-0.5*(pdf_x-avg)**2/var)

n, bins, patches = ax.hist(data, range=(-50,50), bins=30, density=True)
ax.set(xlim=(-50,50), xlabel=r'$\hat{\alpha} \,[10^{8}]$')
ax.plot(pdf_x,pdf_y,'k--')

print(avg, np.std(data), np.std(data)/np.sqrt(len(data)))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# -0.025255402975600735 22.665689804219113 0.22665689804219114

# %%
def func_sideband(i):
    print(i,'  ******************')
    fname = r'/data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_'+str(i)+'.h5'
    bb = BeadDataFile.BeadDataFile(fname=fname)
    freq_tmp = 9
    return np.std(bb.response_at_freq2('z', drive_freq=freq_tmp+1.5, bandwidth=bandwidth))

# %%
sideband_9 = np.array(Parallel(n_jobs=40)(delayed(func_sideband)(i) for i in tqdm(range(10000))))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   2%|▏         | 160/10000 [00:00<00:13, 741.36it/s]
#   2%|▏         | 240/10000 [00:00<00:13, 721.21it/s]
#   3%|▎         | 320/10000 [00:00<00:13, 709.57it/s]
#   4%|▍         | 400/10000 [00:00<00:13, 714.80it/s]
#   5%|▍         | 480/10000 [00:00<00:13, 707.26it/s]
#   6%|▌         | 560/10000 [00:00<00:13, 693.43it/s]
#   6%|▋         | 640/10000 [00:00<00:13, 701.51it/s]
#   7%|▋         | 720/10000 [00:01<00:13, 696.47it/s]
#   8%|▊         | 800/10000 [00:01<00:13, 696.60it/s]
#   9%|▉         | 880/10000 [00:01<00:13, 681.08it/s]
#  10%|▉         | 960/10000 [00:01<00:12, 704.90it/s]
#  10%|█         | 1040/10000 [00:01<00:12, 710.94it/s]
#  11%|█         | 1120/10000 [00:01<00:12, 730.14it/s]
#  12%|█▏        | 1200/10000 [00:01<00:12, 721.52it/s]
#  77%|███████▋  | 7680/10000 [00:10<00:03, 725.57it/s]
#  78%|███████▊  | 7840/10000 [00:11<00:03, 702.34it/s]
#  80%|████████  | 8000/10000 [00:11<00:02, 715.43it/s]
#  82%|████████▏ | 8160/10000 [00:11<00:02, 774.36it/s]
#  83%|████████▎ | 8320/10000 [00:11<00:02, 697.61it/s]
#  85%|████████▍ | 8480/10000 [00:12<00:02, 739.85it/s]
#  86%|████████▋ | 8640/10000 [00:12<00:01, 693.75it/s]
#  88%|████████▊ | 8800/10000 [00:12<00:01, 728.54it/s]
#  90%|████████▉ | 8960/10000 [00:12<00:01, 676.53it/s]
#  91%|█████████ | 9120/10000 [00:13<00:01, 675.91it/s]
#  93%|█████████▎| 9280/10000 [00:13<00:01, 690.20it/s]
#  94%|█████████▍| 9440/10000 [00:13<00:00, 668.14it/s]
#  96%|█████████▌| 9600/10000 [00:13<00:00, 681.16it/s]
#  98%|█████████▊| 9760/10000 [00:13<00:00, 692.37it/s]
#  99%|█████████▉| 9920/10000 [00:14<00:00, 687.47it/s]
# 100%|██████████| 10000/10000 [00:14<00:00, 703.64it/s]

# %%
np.mean(alphas_mean), len(np.arange(0,10000,1000))
# Out:
# (0.10491668595038561, 10)

# %%
from matplotlib import gridspec

alphas_mean = [np.mean(mm_mle_All_lambda_20[i*1:(i+1)*1]) for i in range(10000)]
alphas_std = [np.std(mm_mle_All_lambda_20[i*1:(i+1)*1])/np.sqrt(1) for i in range(10000)]

fig = plt.figure(figsize=(9.5, 3.5)) 
gs = gridspec.GridSpec(1, 2, width_ratios=[2.5, 1]) 
gs.update(wspace=0.0, hspace=0.05) # set the spacing between axes. 

ax0 = plt.subplot(gs[0])
ax0.errorbar((np.arange(0,10000,1))*10/60, alphas_mean, yerr=alphas_std, fmt='o', zorder=0)
ax0.plot(np.arange(-100,10000,100)*10/60, np.arange(-100,10000,100)*0, 'r--', zorder=10)
ax0.set(xlabel='Time [minute]', ylabel=r'$\alpha \,[10^{8}]$', ylim=(-50,50))

ax1 = plt.subplot(gs[1])
ax1.hist(alphas_mean, range=(-50,50), bins=20, orientation="horizontal", alpha=1.)
ax1.set_yticklabels([])
ax1.set_xticklabels([])

ax1.set(ylim=(-50,50))

# Create a duplicate of the original xaxis, giving you an additional axis object
ax2 = ax0.twinx()
# Set the limits of the new axis from the original axis limits
ax2.set_ylim(ax0.get_ylim())
ax2.set_yticklabels([])

# ax1.plot(pdf_x_sig,pdf_y_sig,'k--')

fig.savefig("wilson_alpha_lambda_20_downsample_1.pdf", bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from matplotlib import gridspec

sideband_9_mean = [np.mean(sideband_9[i*100:(i+1)*100]) for i in range(100)]
sideband_9_std = [np.std(sideband_9[i*100:(i+1)*100])/np.sqrt(100) for i in range(100)]

fig = plt.figure(figsize=(9, 4)) 
gs = gridspec.GridSpec(1, 2, width_ratios=[2.5, 1]) 

ax0 = plt.subplot(gs[0])
ax0.errorbar((np.arange(0,10000,100)+50)*10/60, sideband_36_mean, yerr=sideband_36_std, fmt='o')
ax0.errorbar((np.arange(0,10000,100)+50)*10/60, sideband_33_mean, yerr=sideband_33_std, fmt='o')
ax0.errorbar((np.arange(0,10000,100)+50)*10/60, sideband_24_mean, yerr=sideband_24_std, fmt='o')
ax0.errorbar((np.arange(0,10000,100)+50)*10/60, sideband_18_mean, yerr=sideband_18_std, fmt='o')
# ax0.errorbar((np.arange(0,10000,100)+50)*10/60, sideband_9_mean, yerr=sideband_9_std, fmt='o')
# ax0.plot(np.arange(-100,10000,100)*10/60, np.arange(-100,10000,100)*0, 'r--')
# ax0.set(xlabel='Time [minute]', ylabel=r'$\alpha \,[10^{8}]$', ylim=(-15,15))

ax1 = plt.subplot(gs[1])
ax1.hist(sideband_36_mean, range=(17,28), bins=10, density=True)
# ax1.set(xlim=(-15,15), xlabel=r'$\hat{\alpha} \,[10^{8}]$')
# ax1.plot(pdf_x_sig,pdf_y_sig,'k--')

# fig.savefig("wilson_results.pdf", bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (array([0.        , 0.        , 0.00909091, 0.24545455, 0.38181818,
#         0.19090909, 0.05454545, 0.02727273, 0.        , 0.        ]),
#  array([17. , 18.1, 19.2, 20.3, 21.4, 22.5, 23.6, 24.7, 25.8, 26.9, 28. ]),
#  <BarContainer object of 10 artists>)

# %%
2110//100
# Out:
# 21

# %% [markdown]
# ### Figure of background phases

# %%
import numpy as np
import matplotlib.pyplot as plt

def multiple_formatter(denominator=2, number=np.pi, latex='\pi'):
    def gcd(a, b):
        while b:
            a, b = b, a%b
        return a
    def _multiple_formatter(x, pos):
        den = denominator
        num = np.int(np.rint(den*x/number))
        com = gcd(num,den)
        (num,den) = (int(num/com),int(den/com))
        if den==1:
            if num==0:
                return r'$0$'
            if num==1:
                return r'$%s$'%latex
            elif num==-1:
                return r'$-%s$'%latex
            else:
                return r'$%s%s$'%(num,latex)
        else:
            if num==1:
                return r'$\frac{%s}{%s}$'%(latex,den)
            elif num==-1:
                return r'$\frac{-%s}{%s}$'%(latex,den)
            else:
                return r'$\frac{%s%s}{%s}$'%(num,latex,den)
    return _multiple_formatter

class Multiple:
    def __init__(self, denominator=2, number=np.pi, latex='\pi'):
        self.denominator = denominator
        self.number = number
        self.latex = latex

    def locator(self):
        return plt.MultipleLocator(self.number / self.denominator)

    def formatter(self):
        return plt.FuncFormatter(multiple_formatter(self.denominator, self.number, self.latex))

# %%
fig2, ax = plt.subplots(1,3,figsize=(13,3), sharey=True)
jj = [5,7,10,11]
_ = [a.hist(test_phase[j]-0.16, density=False, bins=60, range=(-np.pi,np.pi)) for a,j in zip(ax,jj)]

_ = [a.axvline(phases_th[j], color='r', linestyle='dashed', linewidth=3) for j,a in zip(jj,ax)]
# _ = [a.legend() for a in ax.flatten()]
_ = [a.set(xlabel='phase [rad]', title=str(np.arange(1,13)[j]*3)+'Hz.') for a,j in zip(ax,jj)]
ax[0].set(ylabel='[a.u.]')
for a in ax:
    a.grid(True)
    a.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))
    a.xaxis.set_minor_locator(plt.MultipleLocator(np.pi / 12))
    a.xaxis.set_major_formatter(plt.FuncFormatter(multiple_formatter()))
plt.show()

fig2.savefig("wilson_phases.pdf", bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
