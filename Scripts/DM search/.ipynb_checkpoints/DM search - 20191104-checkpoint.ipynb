# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py

# %%
# %matplotlib notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *
from likelihood_calculator import likelihood_analyser

# %%
lc_i = likelihood_analyser.LikelihoodAnalyser()

# %% [markdown]
# ### Load data

# %%
foldername = r'/data/new_trap/20191104/Bead1/DMdata/'
bdf_DMdata = load_dir(foldername)
foldername = r'/data/new_trap/20191104/Bead1/DMdata2/'
bdf_DMdata2 = load_dir(foldername)
# Out:
# 30  files in folder
# 30  files loaded
# 30  files in folder
# 30  files loaded

# %%
foldername = r'/data/new_trap/20191104/Bead1/Discharge4/'
bdf_discharge2 = load_dir(foldername)
# Out:
# 103  files in folder
# 103  files loaded

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4), sharex=True, sharey=True)
[ax[0].loglog(*bb.welch_psd('x')) for bb in bdf_DMdata]
ax[0].set(xlim=(5,None))
[ax[1].loglog(*bb.welch_psd('x')) for bb in bdf_DMdata2]
ax[1].set(xlim=(5,None))
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(5, 3660.214239864062)]

# %%
freq = bdf_discharge2[3].welch_psd('x')[0]
psds = [bb.welch_psd('x')[1] for bb in bdf_discharge2[3:]]

# %%
bdf_sum = np.mean(psds, axis=0)
_,ax = plt.subplots(1,2,figsize=(9.5,4), sharex=True, sharey=True)
ax[0].semilogy(*bdf_discharge2[3].welch_psd('x'))
ax[1].semilogy(freq,bdf_sum)
ax[0].set(xlim=(10,500))
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(10, 500)]

# %%
filename = r'/home/data_transfer/data_from_windows/20191107/Bead1/DMdata/Discharge_180.h5'
filename = r'/home/data_transfer/data_from_windows/20191107/Bead1/DMdata2/Discharge_114.h5'
filename = r'/home/data_transfer/data_from_windows/20191112/Bead1/Discharge/Discharge_86.h5'
bb = BeadDataFile.BeadDataFile(filename)
xx = bb.response_at_freq2('x',151, bandwidth=10)*50000
analytic_signal = signal.hilbert(xx)
amplitude_envelope = np.abs(analytic_signal)

xx3 = bb.response_at_freq3('x',151, bandwidth=10)/6
analytic_signal3 = signal.hilbert(xx3)
amplitude_envelope3 = np.abs(analytic_signal3)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,3))
t = np.arange(50000)/5000
ax[0].plot(t, xx, label='signal')
ax[0].plot(t, amplitude_envelope, label='envelope')

ax[1].plot(t, xx3, label='signal')
ax[1].plot(t, amplitude_envelope3, label='envelope')
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
t_sub = t[5000:-5000]
average = np.mean(amplitude_envelope3[5000:-5000])
std = np.std(amplitude_envelope3[5000:-5000])
envelope3_subtracted = amplitude_envelope3-average
envelope3_subtracted = envelope3_subtracted[5000:-5000]

# %%
np.mean(t_sub.reshape(-1,100),axis=1)
np.mean(np.std(envelope3_subtracted.reshape(-1,100),axis=1))
# Out:
# 0.0303143382265932

# %%
_,ax = plt.subplots(figsize=(9.5,4))
ax.scatter(t_sub, envelope3_subtracted)
print('average: ', average)
print('std: ', std)
t_sub_avg = np.mean(t_sub.reshape(-1,50),axis=1)
envelope3_avg = np.mean(envelope3_subtracted.reshape(-1,50),axis=1)
envelope3_std = np.std(envelope3_subtracted.reshape(-1,50),axis=1)

ax.scatter(t_sub_avg, envelope3_avg)
# Out:
# <img src="data:image/png;base64,..." width="950">
# average:  46.53758720215993
# std:  0.48955765144027197

# %%
freq = 1
fit_kwargs = {'A': 0, 'f': freq, 'phi': np.pi,
              'error_A': 0.01, 'error_f': 1, 'error_phi': 0.5, 'errordef': 1,
              'limit_phi': [0, 2 * np.pi], 'limit_A': [-1,1],
              'print_level': 0, 'fix_f': True, 'fix_phi': False}

empirical_rms = std
m1 = lc_i.find_mle_sin(envelope3_avg, fsamp=10, noise_rms=empirical_rms, plot=True, suppress_print=False, **fit_kwargs)
# Out:
# Data overall time:  80.0  sec.
# bandpass time:  3.337860107421875e-06
# minimization time:  0.00403904914855957
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |  0.10E-2  |  2.45E-2  |            |            |   -1    |    1    |       |
# | 1 | f    |    1.0    |    1.0    |            |            |         |         |  yes  |
# | 2 | phi  |    3.1    |    4.7    |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# <img src="data:image/png;base64,..." width="950">
# reduced chi2:  1.0010031626800306

# %%
delta_alpha = m1.values[0]/average
print('sensitivity: ', '{:.2e}'.format(np.abs(delta_alpha)))
# Out:
# sensitivity:  2.16e-05

# %%
foldername = r'/data/new_trap/20191107/Bead1/DMdata/'
bdf_DMdata_7 = load_dir(foldername)
# Out:
# 200  files in folder
# 200  files loaded

# %%
foldername = r'/data/new_trap/20191107/Bead1/DMdata2/'
bdf_DMdata2_7 = load_dir(foldername)[6:36]
# Out:
# 85  files in folder
# 85  files loaded

# %%
bdf_DMdata2_7[-1].fname
# Out:
# '/data/new_trap/20191107/Bead1/DMdata2/Discharge_129.h5'

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4), sharey=True, sharex=True)
for bb in bdf_DMdata2_7:
    fft, freq = matplotlib.mlab.psd(bb.x2,Fs=5000, detrend='linear', NFFT=300000)
    fft3, freq3 = matplotlib.mlab.psd(bb.x3,Fs=5000, detrend='linear', NFFT=300000)
    fft_c, freq = matplotlib.mlab.csd(bb.x2, bb.x3,Fs=5000, detrend='linear', NFFT=300000)
    fft /= fft[freq==151]
    fft_c /= fft_c[freq==151]
    fft3 /= fft3[freq==151]
    ax[0].semilogy(freq, np.sqrt(fft))
    ax[1].semilogy(freq, np.sqrt(fft3))
ax[0].set(xlim=(100,200))
ax[1].set(xlim=(100,200))
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(100, 200)]

# %%
## fit all data
m1_all = []
t_sub = t[5000:-5000]
freq = 0.01
fit_kwargs = {'A': 0, 'f': freq, 'phi': np.pi,
              'error_A': 0.01, 'error_f': 1, 'error_phi': 0.5, 'errordef': 1,
              'limit_phi': [0, 2 * np.pi], 'limit_A': [-1,1],
              'print_level': 0, 'fix_f': True, 'fix_phi': False}

for i,bb in enumerate(bdf_DMdata2_7):
    xx3 = bb.response_at_freq3('x',151, bandwidth=10)/6
    analytic_signal3 = signal.hilbert(xx3)
    amplitude_envelope3 = np.abs(analytic_signal3)
    
    average = np.mean(amplitude_envelope3[5000:-5000])
    std = np.std(amplitude_envelope3[5000:-5000])
    envelope3_subtracted = amplitude_envelope3-average
    envelope3_subtracted = envelope3_subtracted[5000:-5000]
    
    empirical_rms = std
    m1_tmp = lc_i.find_mle_sin(envelope3_subtracted, fsamp=5000, noise_rms=empirical_rms, plot=False, suppress_print=False, **fit_kwargs)
    delta_alpha = m1_tmp.values[0]/average
    print(i, 'sensitivity: ', '{:.2e}'.format(np.abs(delta_alpha)))
    m1_all.append(m1_tmp)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# Data overall time:  58.0  sec.
# bandpass time:  1.1920928955078125e-06
# minimization time:  2.928781270980835
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.695   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |  0.427E1  |  0.000E1  |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.4467988425367008
# 0 sensitivity:  9.77e-03
# Data overall time:  58.0  sec.
# bandpass time:  4.5299530029296875e-06
# minimization time:  2.3489272594451904
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.929   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |  0.457E1  |  0.000E1  |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.3150501279767197
# 1 sensitivity:  1.29e-02
# Data overall time:  58.0  sec.
# bandpass time:  1.1920928955078125e-06
# minimization time:  2.269667863845825
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.381   |   0.001   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   4.391   |   0.004   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.6746502251977202
# 2 sensitivity:  5.20e-03
# Data overall time:  58.0  sec.
# bandpass time:  1.430511474609375e-06
# minimization time:  1.9931395053863525
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.539   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   4.016   |   0.003   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.6097889627309072
# 3 sensitivity:  7.23e-03
# Data overall time:  58.0  sec.
# bandpass time:  1.9073486328125e-06
# minimization time:  1.9161109924316406
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.439   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   3.577   |   0.004   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.7303480730519696
# 4 sensitivity:  5.84e-03
# Data overall time:  58.0  sec.
# bandpass time:  1.430511474609375e-06
# minimization time:  1.872631311416626
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    | 3.120E-1  | 0.017E-1  |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   2.669   |   0.005   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.8796092552326369
# 5 sensitivity:  4.08e-03
# Data overall time:  58.0  sec.
# bandpass time:  1.6689300537109375e-06
# minimization time:  2.176055908203125
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    | 2.684E-1  | 0.014E-1  |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   2.306   |   0.005   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.8755167862456182
# 6 sensitivity:  3.49e-03
# Data overall time:  58.0  sec.
# bandpass time:  1.9073486328125e-06
# minimization time:  2.533048152923584
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.616   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |  0.452E1  |  0.000E1  |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.5503950902575055
# 7 sensitivity:  7.97e-03
# Data overall time:  58.0  sec.
# bandpass time:  1.1920928955078125e-06
# minimization time:  2.3918421268463135
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.380   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   4.491   |   0.005   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.8223785203569508
# 8 sensitivity:  4.86e-03
# Data overall time:  58.0  sec.
# bandpass time:  1.6689300537109375e-06
# minimization time:  1.8608927726745605
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    | 2.151E-1  | 0.022E-1  |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   3.495   |   0.010   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.966976293646718
# 9 sensitivity:  2.74e-03
# Data overall time:  58.0  sec.
# bandpass time:  4.76837158203125e-06
# minimization time:  2.8101718425750732
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.619   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |  0.449E1  |  0.000E1  |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.4698903031837977
# 10 sensitivity:  7.87e-03
# Data overall time:  58.0  sec.
# bandpass time:  9.5367431640625e-07
# minimization time:  2.3552258014678955
# ------------------------------------------------------------------------------------------
# |   | Name |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |   0.474   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |   2.135   |   0.004   |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.7357484747097119
# 11 sensitivity:  6.03e-03
# Data overall time:  58.0  sec.
# bandpass time:  1
   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# ------------------------------------------------------------------------------------------
# | 0 | A    |  -0.666   |   0.002   |            |            |   -1    |    1    |       |
# | 1 | f    |   0.010   |   1.000   |            |            |         |         |  yes  |
# | 2 | phi  |  0.430E1  |  0.000E1  |            |            |    0    | 6.28319 |       |
# ------------------------------------------------------------------------------------------
# reduced chi2:  0.33719415803943464
# 29 sensitivity:  9.83e-03

# %%
_,ax = plt.subplots()
all_vals = [m_.values[0]/average for m_ in m1_all]
all_errors = np.array([m_.errors[0]/average for m_ in m1_all])/1000
ax.errorbar(range(30), all_vals, all_errors, fmt='o')
print('avergae: ', np.mean(all_vals), 'std: ', np.std(all_vals))
print('standard error: ', np.std(all_vals)/np.sqrt(len(all_vals)))
# ax.errorbar(range(30), m1_avg, m1_std, fmt='o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# avergae:  0.0014299740024999233 std:  0.006825182266821934
# standard error:  0.0012461020955408723

# %%
10**0.7
# Out:
# 5.011872336272722

# %%
## fit all data - x2 and x3
m2_all = []
t_sub = t[5000:-5000]
freq = 0.05

for i,bb in enumerate(bdf_DMdata2_7):
    xx3 = bb.response_at_freq3('x',151, bandwidth=10)/6
    analytic_signal3 = signal.hilbert(xx3)
    amplitude_envelope3 = np.abs(analytic_signal3)
    average3 = np.mean(amplitude_envelope3[5000:-5000])
    std3 = np.std(amplitude_envelope3[5000:-5000])
    envelope3_subtracted = amplitude_envelope3-average3
    envelope3_subtracted = envelope3_subtracted[5000:-5000]
    
    xx2 = bb.response_at_freq2('x',151, bandwidth=10)*50000
    analytic_signal2 = signal.hilbert(xx2)
    amplitude_envelope2 = np.abs(analytic_signal2)
    average2 = np.mean(amplitude_envelope2[5000:-5000])
    std2 = np.std(amplitude_envelope2[5000:-5000])
    envelope2_subtracted = amplitude_envelope2-average2
    envelope2_subtracted = envelope2_subtracted[5000:-5000]
    
    fit_kwargs = {'A': 0, 'f': freq, 'phi': 0, 'A2': average2/average3, 'f2': freq, 'delta_phi': 0,
              'error_A': 0.01, 'error_f': 1, 'error_phi': 0.1, 'errordef': 1,
              'error_A2': 2, 'error_f2': 10, 'error_delta_phi': 0.1,
              'limit_phi': [0, 2 * np.pi],'limit_delta_phi': [-0.1, 0.1],
              'limit_A': [-1,1], #'limit_A2': [1.8,2.2],
              'print_level': 0, 'fix_f': True, 'fix_phi': False, 'fix_f2': True, 'fix_delta_phi': True, 'fix_A2': True}

    empirical_rms = 1
    m1_tmp = lc_i.find_mle_2sin(envelope3_subtracted, envelope2_subtracted, fsamp=5000, noise_rms=std3, noise_rms2=std2,
                                plot=False, suppress_print=False, **fit_kwargs)
    delta_alpha = m1_tmp.values[0]/average3
    print(i, 'sensitivity: ', '{:.2e}'.format(np.abs(delta_alpha)))
    m2_all.append(m1_tmp)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# Data overall time:  58.0  sec.
# bandpass time:  4.76837158203125e-06
# minimization time:  3.8337292671203613
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         
|    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |   1.532   |   0.006   |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.9601032531969614
# 22 sensitivity:  2.36e-03
# Data overall time:  58.0  sec.
# bandpass time:  2.384185791015625e-06
# minimization time:  4.373814105987549
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         | 0.727E-1  | 0.010E-1  |            |            |   -1    |    1    |       |
# | 1 | A2        |    0.9    |    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |   0.804   |   0.014   |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.9911535047004565
# 23 sensitivity:  1.04e-03
# Data overall time:  58.0  sec.
# bandpass time:  4.5299530029296875e-06
# minimization time:  4.918413877487183
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         | 1.798E-1  | 0.013E-1  |            |            |   -1    |    1    |       |
# | 1 | A2        |    0.9    |    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |   0.149   |   0.007   |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.9656914777360739
# 24 sensitivity:  2.61e-03
# Data overall time:  58.0  sec.
# bandpass time:  5.9604644775390625e-06
# minimization time:  4.808046817779541
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         | 1.365E-1  | 0.011E-1  |            |            |   -1    |    1    |       |
# | 1 | A2        |    0.9    |    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |   0.640   |   0.008   |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.9709797240195405
# 25 sensitivity:  1.98e-03
# Data overall time:  58.0  sec.
# bandpass time:  7.3909759521484375e-06
# minimization time:  5.838985204696655
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         | 3.149E-1  | 0.012E-1  |            |            |   -1    |    1    |       |
# | 1 | A2        |    0.8    |    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |   0.549   |   0.004   |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.8886225257708349
# 26 sensitivity:  4.59e-03
# Data overall time:  58.0  sec.
# bandpass time:  2.6226043701171875e-06
# minimization time:  2.731210231781006
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         | 0.578E-1  | 0.011E-1  |            |            |   -1    |    1    |       |
# | 1 | A2        |    0.8    |    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |  0.0E-3   |  0.5E-3   |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.9954610614729847
# 27 sensitivity:  8.47e-04
# Data overall time:  58.0  sec.
# bandpass time:  2.384185791015625e-06
# minimization time:  3.062947988510132
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         | -0.396E-1 |  0.011E-1 |            |            |   -1    |    1    |       |
# | 1 | A2        |    0.8    |    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |  0.000E1  |  0.000E1  |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.997549659425626
# 28 sensitivity:  5.78e-04
# Data overall time:  58.0  sec.
# bandpass time:  5.0067901611328125e-06
# minimization time:  6.763376712799072
# -----------------------------------------------------------------------------------------------
# |   | Name      |   Value   | Hesse Err | Minos Err- | Minos Err+ | Limit-  | Limit+  | Fixed |
# -----------------------------------------------------------------------------------------------
# | 0 | A         | 1.775E-1  | 0.016E-1  |            |            |   -1    |    1    |       |
# | 1 | A2        |    0.8    |    2.0    |            |            |         |         |  yes  |
# | 2 | f         |   0.05    |   1.00    |            |            |         |         |  yes  |
# | 3 | f2        |   0.05    |   10.00   |            |            |         |         |  yes  |
# | 4 | phi       |   0.358   |   0.009   |            |            |    0    | 6.28319 |       |
# | 5 | delta_phi |   0.00    |   0.10    |            |            |  -0.1   |   0.1   |  yes  |
# -----------------------------------------------------------------------------------------------
# reduced chi2:  0.9780057657661081
# 29 sensitivity:  2.62e-03

# %%
_,ax = plt.subplots()
all_vals = [m_.values[0]/average3 for m_ in m2_all]
all_errors = np.array([m_.errors[0]/average for m_ in m2_all])/1000
ax.errorbar(range(30), all_vals, all_errors, fmt='o')
print('avergae: ', np.mean(all_vals), 'std: ', np.std(all_vals))
print('standard error: ', np.std(all_vals)/np.sqrt(len(all_vals)))
# Out:
# <img src="data:image/png;base64,..." width="640">
# avergae:  -0.00010894533899700242 std:  0.003328381728470225
# standard error:  0.0006076765842237257
