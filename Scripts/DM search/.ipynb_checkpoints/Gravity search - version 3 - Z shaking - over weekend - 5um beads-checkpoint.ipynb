# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %%
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ### Load data

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20200226/Bead1/Discharge/')
# Out:
# 91  files in folder
# 91  files loaded

# %%
dis_z = [np.std(bb.response_at_freq2('z', drive_freq=71)) for bb in  bdf_discharge]
dis_x = [np.std(bb.response_at_freq2('x', drive_freq=71)) for bb in  bdf_discharge]
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
bdf_z = bdf_discharge[44:48]
bdf_x = bdf_discharge[48:53]

m1s_z = gfw.build_z_response(bdf_z, drive_freq=71,charges=13, bandwidth=2, decimate=100, include_sigma=False)
m1s_x = gfw.build_x_response(bdf_x, drive_freq=71,charges=13, bandwidth=2, decimate=100)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# Z2-amplitude:  3.78e+03
# reduced chi2:  4508.738370786036
# ***************************************************
# Z2-amplitude:  3.87e+03
# reduced chi2:  6199.230566294556
# ***************************************************
# Z2-amplitude:  3.83e+03
# reduced chi2:  6457.660291667214
# ***************************************************
# Z2-amplitude:  3.93e+03
# reduced chi2:  7219.321151755275
# Z2 response (amplitude): 3854.1137226501196
# ***************************************************
# X2-amplitude:  5.77e+01
# ...

# %% [markdown]
# ### Transfer function

# %%
fname = r'/data/new_trap/20200210/Bead2/TransFunc/TransFunc_X_3.h5'
tf_x = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200210/Bead2/TransFunc/TransFunc_Y_3.h5'
tf_y = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200210/Bead2/TransFunc/TransFunc_Z_3.h5'
tf_z = BeadDataFile.BeadDataFile(fname=fname)
tf_list = [tf_x, tf_y, tf_z]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data

# %%
gfw.build_transfer_function(tf_list, plot=True)
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
# Normal feedback values
foldername = r'/data/new_trap/20200226/Bead1/Shaking/Shaking385/'
datasets_num = 1000
data_bdfs = load_dir(foldername, file_prefix='Shaking3', start_file=5000, max_file=datasets_num)
# Out:
# 22500  files in folder
# 1000  files loaded

# %%
gfw.BDFs = data_bdfs

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4),sharex=True)
for i,bb in enumerate(data_bdfs[::100]):
    ax[0].semilogy(*bb.psd2('z'))
ax[0].set(xlim=(1,50),xlabel='frequency [Hz.]')

for i,bb in enumerate(data_bdfs[::100]):
    ax[1].semilogy(*bb.psd2('x'))
ax[1].set(xlim=(1,50),xlabel='frequency [Hz.]')
# Out:
# <img src="data:image/png;base64,..." width="1295.454517376325">
# [(1, 50), Text(0.5, 0, 'frequency [Hz.]')]

# %%
gfw.build_noise_array(sideband_freq=20, bandwidth=2)
gfw.build_noise_array_z(sideband_freq=20, bandwidth=2)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# x2 noise rms:  4.618910611668213
# x3 noise rms:  0.7452341518184736
# z2 noise level:  27.05887771166748  std:  8.07064204150212

# %% [markdown]
# ### profile likelihood fit

# %%
fit_kwargs2 = {'alpha': 0, 'phase': 0, 'sigma': 17, 'error_alpha': 0.001, 'error_phase': 1, 'error_sigma': 1,
              'errordef': 1,
              'limit_alpha': [-1, 1], 'limit_phase': [-3,3], 'limit_sigma': [0,None],
              'fix_alpha': False, 'fix_phase': False, 'fix_sigma': False, 'print_level': 0}

min_18_z_5 = []
min_20_z_5 = []
datasets_num = 1000
bandwidth = 2
center_freq = 18
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num) 
    min_18_z_5.append(gfw.get_alpha_mle_pl(bdf=bb, center_freq=center_freq, noise_freq=center_freq+bandwidth, 
                                             bandwidth=bandwidth, decimate=100, direction1='z',
                          x_focous=393.17, frequency=3, lambda_par=0.0001, height=6e-6, suppress_print=False,
                          **fit_kwargs2)[2])
    min_20_z_5.append(gfw.get_alpha_mle_pl(bdf=bb, center_freq=20, noise_freq=22, 
                                         bandwidth=bandwidth, decimate=100, direction1='z',
                      x_focous=394.5, frequency=5, lambda_par=0.0001, height=6e-6, suppress_print=False,
                      **fit_kwargs2)[2])

# %%
m_18_alpha_20 = [m1_.values[0] for m1_ in min_18_z_20]
m_18_sigma_20 = [m1_.values[2] for m1_ in min_18_z_20]

m_18_alpha_5 = [m1_.values[0] for m1_ in min_18_z_5]
m_18_sigma_5 = [m1_.values[2] for m1_ in min_18_z_5]

# m_18_alpha_3 = [m1_.values[0] for m1_ in min_18_z_3]
# m_18_sigma_3 = [m1_.values[2] for m1_ in min_18_z_3]

# m_18_alpha_4 = [m1_.values[0] for m1_ in min_18_z_4]
# m_18_sigma_4 = [m1_.values[2] for m1_ in min_18_z_4]

# m_18_alpha_5 = [m1_.values[0] for m1_ in min_18_z_5]
# m_18_sigma_5 = [m1_.values[2] for m1_ in min_18_z_5]

m_20_alpha_20 = [m1_.values[0] for m1_ in min_20_z_20]
m_20_sigma_20 = [m1_.values[2] for m1_ in min_20_z_20]

m_20_alpha_5 = [m1_.values[0] for m1_ in min_20_z_5]
m_20_sigma_5 = [m1_.values[2] for m1_ in min_20_z_5]

# m_20_alpha_3 = [m1_.values[0] for m1_ in min_20_z_3]
# m_20_sigma_3 = [m1_.values[2] for m1_ in min_20_z_3]

# m_20_alpha_4 = [m1_.values[0] for m1_ in min_20_z_4]
# m_20_sigma_4 = [m1_.values[2] for m1_ in min_20_z_4]

# m_20_alpha_5 = [m1_.values[0] for m1_ in min_20_z_5]
# m_20_sigma_5 = [m1_.values[2] for m1_ in min_20_z_5]

m_18_alpha = m_18_alpha_20#+m_18_alpha_2+m_18_alpha_3+m_18_alpha_4+m_18_alpha_5
m_20_alpha = m_20_alpha_20#+m_20_alpha_2+m_20_alpha_3+m_20_alpha_4+m_20_alpha_5
m_18_sigma = m_18_sigma_20#+m_18_sigma_2+m_18_sigma_3+m_18_sigma_4+m_18_sigma_5

# %%
sys.getsizeof(min_20_z_5)
# Out:
# 9024

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].hist(np.array((m_18_alpha))*1e10, normed=True, range=(-0.05*1e10,0.05*1e10), bins=100, label=r'20k - signal')
ax[0].hist(np.array((m_20_alpha))*1e10, normed=True, range=(-0.05*1e10,0.05*1e10), alpha=0.5, bins=100, label=r'20k - noise')
ax[0].hist(np.array((m_18_alpha_5))*1e10, normed=True, range=(-0.05*1e10,0.05*1e10), alpha=0.5, bins=100, label=r'5k - signal')
ax[1].hist(m_18_sigma_20,range=(10,50),bins=30,alpha=0.5,normed=True, label=r'20k - noise')
ax[1].hist(m_18_sigma_5,range=(10,50),bins=30,alpha=0.5,normed=True, label=r'5k - signal')
[a.legend() for a in ax]
N_data = len(m_18_alpha)
print('6th hsrmonic mean: ',np.mean(np.abs(m_18_alpha)), ' error: ', np.std(np.abs(m_18_alpha))/np.sqrt(N_data))
# print('noise mean: ',np.mean(np.abs(m_20_alpha)), ' error: ', np.std(np.abs(m_20_alpha))/np.sqrt(N_data))
print('estimated limit: ', format(np.mean(np.abs(m_18_alpha))*1e10,"5.2e"))
# Out:
# <img src="data:image/png;base64,..." width="950">
# 6th hsrmonic mean:  21.050013918228004  error:  0.7432039951390672
# estimated limit:  2.11e+11
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# ...

# %%
_, ax = plt.subplots(figsize=(9.5,4))
ax.plot(range(len(m_18_alpha_20)),np.array(m_18_alpha_20)*1e10,'.')
# ax.plot(range(len(m_18_alpha_20)),np.array(m_20_alpha_20)*1e10,'.')
ax.plot(range(len(m_18_alpha_20)),np.array(m_18_alpha_5)*1e10,'.')
ax.set(xlabel='dataset', ylabel=r'Likelihoo-fit', title=r'$\lambda=100 \mu m $')
ax.set(ylim=(-4e8,4e8))
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(-400000000.0, 400000000.0)]

# %%
AF_data = np.loadtxt("/data/new_trap/20200226/Bead1/Shaking/Shaking385/height_from_gauss.txt")
_,ax = plt.subplots(figsize=(9.5,4))
ax.scatter(range(len(AF_data)), AF_data)
# Out:
# <img src="data:image/png;base64,..." width="950">

# %% [markdown]
# ### Load and process multpule 1000 datasets

# %%
fit_kwargs2 = {'alpha': 0, 'phase': 0, 'sigma': 17, 'error_alpha': 0.001, 'error_phase': 1, 'error_sigma': 1,
              'errordef': 1,
              'limit_alpha': [-1, 1], 'limit_phase': [-3,3], 'limit_sigma': [0,None],
              'fix_alpha': False, 'fix_phase': False, 'fix_sigma': False, 'print_level': 0}


fit_kwargs2_x = {'alpha': 0, 'phase': 0, 'sigma': 17, 'error_alpha': 0.001, 'error_phase': 1, 'error_sigma': 1,
              'errordef': 1,
              'limit_alpha': [-20, 20], 'limit_phase': [-3,3], 'limit_sigma': [0,None],
              'fix_alpha': False, 'fix_phase': False, 'fix_sigma': False, 'print_level': 0}

min_18_z = []
min_18_x = []
min_10_z = []
datasets_num = 1000
bandwidth = 2
center_freq = 18
noise_freq = 22.5
# Normal feedback values
foldername = r'/data/new_trap/20200226/Bead1/Shaking/Shaking385/'
datasets_num = 1000
Nj = 23

for j in range(Nj):
    
    t = time.time()
    print(j,'/',Nj)
    del gfw.BDFs
    gfw.BDFs = load_dir(foldername, file_prefix='Shaking3', start_file=j*1000, max_file=datasets_num)
    
    for i,bb in enumerate(gfw.BDFs):
        try:
            with io.capture_output() as captured:
                min_18_z.append(gfw.get_alpha_mle_pl(bdf=bb, center_freq=center_freq, noise_freq=noise_freq, 
                                                     bandwidth=bandwidth, decimate=100, direction1='z',
                                  x_focous=393.17, frequency=3, offset_y=10e-6, lambda_par=0.0001, height=6e-6, suppress_print=False,
                                  **fit_kwargs2)[2])
    #             min_10_z.append(gfw.get_alpha_mle_pl(bdf=bb, center_freq=20, noise_freq=10, 
    #                                              bandwidth=bandwidth, decimate=100, direction1='z',
    #                           x_focous=393.17, frequency=5, lambda_par=0.0001, height=6e-6, suppress_print=False,
    #                           **fit_kwargs2)[2])
                min_18_x.append(gfw.get_alpha_mle_pl(bdf=bb, center_freq=center_freq, noise_freq=noise_freq, 
                                                     bandwidth=bandwidth, decimate=100, direction1='x',
                                  x_focous=393.17, frequency=3, offset_y=10e-6, lambda_par=0.0001, height=6e-6, suppress_print=False,
                                  **fit_kwargs2_x)[2])
        except:
            min_18_z.append(0)
            min_18_x.append(0)
    print('elapsed time: ',time.time() - t)
# Out:
# 0 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  140.5429003238678
# 1 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  133.99896836280823
# 2 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  123.6907160282135
# 3 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  121.46760249137878
# 4 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  128.15525555610657
# 5 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  134.87522315979004
# 6 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  120.24425220489502
# 7 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  111.52973866462708
# 8 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  118.35772109031677
# 10 / 23
# 22500  files in folder
# 1000  files loaded
# elapsed time:  115.13978981971741
# 11 / 23
# 22500  files in folder
# 1000  files loaded
# ...

# %%
bb = gfw.BDFs[300]
gfw.get_alpha_mle_pl(bdf=bb, center_freq=center_freq, noise_freq=noise_freq, 
                                                     bandwidth=bandwidth, decimate=100, direction1='z',
                                  x_focous=393.17, frequency=3, offset_y=10e-6, lambda_par=0.0001, height=6e-6, suppress_print=False,
                                  **fit_kwargs2)[2]
# Out:
# Separation (face to face):  5.151810937028619
# Stroke:  100.46401036799773
# Time:  10.0
# Your choice of separation or height is not existing
# Taking 2.4e-06 for bead_size
# Taking 5.0e-06 for separation
# Taking 6.0e-06 for height
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 5.00e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.98e-01
# sigma mle:  1.60e+04
# reduced chi2:  1.7384826569421397
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
m_18_alpha = np.array([m1_.values[0] for m1_ in min_18_z])
m_18_sigma = np.array([m1_.values[2] for m1_ in min_18_z])

m_12_alpha = np.array([m1_.values[0] for m1_ in min_12_z])
m_12_sigma = np.array([m1_.values[2] for m1_ in min_12_z])

m_10_alpha = np.array([m1_.values[0] for m1_ in min_10_z])
m_10_sigma = np.array([m1_.values[2] for m1_ in min_10_z])

m_20_alpha = np.array([m1_.values[0] for m1_ in min_20_z])
m_20_sigma = np.array([m1_.values[2] for m1_ in min_20_z])

m_18_alpha_x = np.array([m1_.values[0] for m1_ in min_18_x])
m_18_sigma_x = np.array([m1_.values[2] for m1_ in min_18_x])
m_18_phase_x = np.array([m1_.values[1] for m1_ in min_18_x])

m_12_alpha_x = np.array([m1_.values[0] for m1_ in min_12_x])
m_12_sigma_x = np.array([m1_.values[2] for m1_ in min_12_x])
len(m_18_sigma_x)
# Out:
# 17825

# %%
m_6_alpha_x = np.array([m1_.values[0] for m1_ in min_6_x])
m_6_sigma_x = np.array([m1_.values[2] for m1_ in min_6_x])

m_6_alpha_z = np.array([m1_.values[0] for m1_ in min_6_z])
m_6_sigma_z = np.array([m1_.values[2] for m1_ in min_6_z])

# %%
mmm = np.array([m_18_alpha_x, m_18_sigma_x])
mmm = mmm.T

# %%
len(m_18_alpha), len(m_10_alpha)
# Out:
# (21322, 18001)

# %%
np.save(r'/data/new_trap/20200226/Bead1/Shaking/Shaking385/X_data_18_3',mmm)

# %%
_, ax = plt.subplots(figsize=(9.5,4))
ax.scatter(range(len(m_18_alpha)), m_18_alpha)
ax.scatter(range(len(m_12_alpha)), m_12_alpha)
# ax.scatter(range(len(m_18_alpha)), m_20_alpha)
# ax.scatter(range(len(m_10_alpha)), m_10_alpha)
ax.set(xlabel='dataset', ylabel=r'$\alpha_z\,[10^{10}]$')
# Out:
# <img src="data:image/png;base64,..." width="949.6969148059663">
# [Text(0, 0.5, '$\\alpha_z\\,[10^{10}]$'), Text(0.5, 0, 'dataset')]

# %%
_, ax = plt.subplots(figsize=(9.5,4))
ax.scatter(range(len(m_18_alpha)), m_18_sigma)
ax.scatter(range(len(m_18_alpha)), m_20_sigma)
ax.set(xlabel='dataset', ylabel=r'$\sigma_z$')
ax.set(ylim=(0,200))
# Out:
# <img src="data:image/png;base64,..." width="1295.454517376325">
# [(0, 200)]

# %%
_, ax = plt.subplots(2,1,figsize=(9.5,6),sharex=True)
ax[0].scatter(range(len(m_18_alpha_x)), m_18_alpha_x)
ax[0].scatter(range(len(m_12_alpha_x)), m_12_alpha_x)
ax[0].set(ylabel=r'$\alpha_x\,[10^{10}]$')
ax[1].scatter(range(len(AF_data)), AF_data)
ax[1].set(xlabel='dataset', ylabel=r'Height $[\mu m]$')
# Out:
# <img src="data:image/png;base64,..." width="949.6969148059663">
# [Text(0, 0.5, 'Height $[\\mu m]$'), Text(0.5, 0, 'dataset')]

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].hist(np.array(np.abs(m_18_alpha[5000:14000]))*1e10, normed=True, range=(-0.*1e10,0.1*1e10), bins=100, label=r'signal')
ax[0].hist(np.array(np.abs(m_20_alpha[5000:14000]))*1e10, normed=True, range=(-0.*1e10,0.1*1e10), alpha=0.5, bins=100, label=r'noise')
ax[1].hist(m_18_sigma[5000:14000],range=(0,50),bins=300,alpha=0.5,normed=True, label=r'signal')
ax[1].hist(m_20_sigma[5000:14000],range=(0,50),bins=300,alpha=0.5,normed=True, label=r'nosie')
# Out:
# <img src="data:image/png;base64,..." width="949.999979409305">
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """
# ...

# %%
from matplotlib.colors import LogNorm

_,ax = plt.subplots()
# ax.loglog(np.abs(m_18_alpha_x), np.abs(m_18_alpha),'.')
ax.hist2d(np.abs(m_18_alpha_x), np.abs(m_18_alpha),bins=300,norm=LogNorm())
ax.set(xscale='log', yscale='log')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [None, None]
