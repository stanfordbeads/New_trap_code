# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ### Load data

# %%
foldername = r'/data/new_trap/20200107/Bead3/Discharge/'
bdf_discharge = load_dir(dirname=foldername)
# Out:
# 135  files in folder
# 135  files loaded

# %%
bb = bdf_discharge[0]
response_x = [np.std(bb.response_at_freq('z',drive_freq=151)) for bb in bdf_discharge]
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
_, ax = plt.subplots()
ax.scatter(range(len(response_x)), response_x/response_x[128])
ax.set(xlim=(1,None))
print(response_x[48])
# Out:
# <img src="data:image/png;base64,..." width="640">
# 622.1951118233993

# %%
bdf_z = bdf_discharge[48:53]
bdf_x = bdf_discharge[38:43]
bdf_y = bdf_discharge[43:48]
charges = 20
m1s_z = gfw.build_z_response(bdf_z, drive_freq=151,charges=charges)
m1s_x = gfw.build_x_response(bdf_x, drive_freq=151,charges=charges)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# Z2-amplitude:  7.43e+03
# reduced chi2:  24751.242951209864
# ***************************************************
# Z2-amplitude:  7.49e+03
# reduced chi2:  31490.46667322269
# ***************************************************
# Z2-amplitude:  7.54e+03
# reduced chi2:  46404.62363280694
# ***************************************************
# Z2-amplitude:  7.57e+03
# reduced chi2:  30795.54847734461
# ***************************************************
# Z2-amplitude:  7.58e+03
# reduced chi2:  39410.20145424921
# Z2 response (amplitude): 7521.23238842297
# ***************************************************
# X2-amplitude:  1.34e+02
# reduced chi2:  12.25045844180057
# ***************************************************
# X2-amplitude:  1.33e+02
# reduced chi2:  9.685634443700467
# ***************************************************
# X2-amplitude:  1.37e+02
# reduced chi2:  14.498602847459116
# ***************************************************
# X2-amplitude:  1.35e+02
# reduced chi2:  11.294484371937761
# ***************************************************
# X2-amplitude:  1.37e+02
# reduced chi2:  10.452530448433828
# X3 to X2 ratio: 0.18524726822830573
# X2 response (amplitude): 135.09092749212488

# %%
# foldername = r'/data/new_trap/20200107/Bead3/InitialTest/'
foldername = r'/data/new_trap/20200107/Bead3/Shaking/Shaking380/'
datasets_num = 100
gfw.BDFs = load_dir(foldername, file_prefix='Shaking13',max_file=datasets_num)
# Out:
# 1000  files in folder
# 100  files loaded

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4),sharex=True)
for bb in gfw.BDFs[32::2]:
    ax[0].semilogy(*bb.psd('z'))
    ax[1].semilogy(*bb.psd2('x'))
ax[0].set(xlim=(2,100),xlabel='frequency [Hz.]', title='Z signal psd')
ax[1].set(xlim=(2,100),xlabel='frequency [Hz.]', title='X signal psd')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(2, 100), Text(0.5, 0, 'frequency [Hz.]'), Text(0.5, 1.0, 'X signal psd')]

# %%
gfw.build_noise_array(sideband_freq=20, bandwidth=1)
gfw.build_noise_array_z(sideband_freq=20, bandwidth=1)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# x2 noise rms:  0.32614027358654896
# x3 noise rms:  0.07239215854707944
# z2 noise rms:  17.464442695545255

# %%
fit_kwargs = {'alpha': 1e-2, 'phase': 0, 'error_alpha': 0.01, 'error_phase': 1,
              'errordef': 1,
              'limit_alpha': [1e-5, 10], 'limit_phase': [-5000,5000],
              'fix_alpha': False, 'fix_phase': False, 'print_level': 0}
min_18_x3 = []
datasets_num = 100
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num)
    min_18_x3.append(gfw.get_alpha_2d(bdf=bb, center_freq=20, bandwidth=1, direction1='x3', direction2='x3',
                          x_focous=389.0, frequency=5, lambda_par=0.0001, height=6e-6, suppress_print=False,
                          **fit_kwargs)[2])
# Out:
# 0 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# alpha:  3.94e-03
# reduced chi2:  0.011220803784382918
# 1 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.16e-03
# reduced chi2:  0.012288517277456473
# 2 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.47e-03
# reduced chi2:  0.008733679938928759
# 3 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.59e-03
# reduced chi2:  0.007703787986003737
# 4 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.66e-03
# reduced chi2:  0.00420741702055866
# 5 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.88e-03
# reduced chi2:  0.0025993317308726518
# 6 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.42e-03
# reduced chi2:  0.006171194054163754
# 7 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.05e-04
# reduced chi2:  0.007125703112934292
# 8 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.74e-03
# reduced chi2:  0.007826263412256543
# 9 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.48e-03
# reduced chi2:  0.006521962572631691
# 10 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.62e-03
# reduced chi2:  0.01075932766049234
# 11 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.09e-03
# reduced chi2:  0.004264215219980483
# 12 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.48e-03
# reduced chi2:  0.008558997064201573
# 13 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.13e-03
# reduced chi2:  0.0044759242038290735
# 14 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.59e-03
# reduced chi2:  0.0076154173245867535
# 15 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.42e-03
# reduced chi2:  0.005690806818961216
# 16 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.36e-03
# reduced chi2:  0.004045202059664733
# 17 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.04e-03
# reduced chi2:  0.005197428643114072
# 18 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.03e-03
# reduced chi2:  0.010150129705249322
# 19 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.65e-03
# reduced chi2:  0.008560148958810304
# 20 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.02e-03
# reduced chi2:  0.0031873502185853528
# 21 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.56e-03
# reduced chi2:  0.011787741307630889
# 22 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.73e-03
# reduced chi2:  0.004828476982990185
# 23 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.50e-04
# reduced chi2:  0.007888930782388224
# 24 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.11e-03
# reduced chi2:  0.013331809260560764
# 25 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.25e-03
# reduced chi2:  0.004820085838473559
# 26 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.59e-03
# reduced chi2:  0.007473531851127012
# 27 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.94e-03
# reduced chi2:  0.007163827725813189
# 28 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.55e-03
# reduced chi2:  0.005588832193105912
# 29 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.49e-03
# reduced chi2:  0.0063282043441742165
# 30 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.23e-03
# reduced chi2:  0.0059862000510562865
# 31 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.98e-03
# reduced chi2:  0.0037456576787156704
# 32 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.43e-03
# reduced chi2:  0.005287213605292344
# 33 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.33e-03
# reduced chi2:  0.005571484792445003
# 34 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.12e-03
# reduced chi2:  0.007917967031005505
# 35 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.88e-03
# reduced chi2:  0.00697716801462732
# 36 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.57e-03
# reduced chi2:  0.015417726169784
# 37 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.61e-03
# reduced chi2:  0.010089269162724474
# 38 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.04e-03
# reduced chi2:  0.00586037755542858
# 39 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.11e-03
# reduced chi2:  0.007124866150605468
# 40 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.32e-03
# reduced chi2:  0.005991640963234553
# 41 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.77e-03
# reduced chi2:  0.005418756527814365
# 42 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.77e-03
# reduced chi2:  0.0036788331984068012
# 43 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.75e-04
# reduced chi2:  0.004523691527558948
# 44 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.44e-03
# reduced chi2:  0.00751107322544474
# 45 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.27e-03
# reduced chi2:  0.004645004947278614
# 46 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.77e-03
# reduced chi2:  0.0064653374097819365
# 47 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.49e-03
# reduced chi2:  0.005253518963535727
# 48 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.26e-03
# reduced chi2:  0.004359435874199765
# 49 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.65e-03
# reduced chi2:  0.005731765066777826
# 50 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.04e-03
# reduced chi2:  0.008455972893026019
# 51 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.05e-04
# reduced chi2:  0.007057909869494479
# 52 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.14e-03
# reduced chi2:  0.0062760766931413275
# 53 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.40e-03
# reduced chi2:  0.013551001874234785
# 54 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.92e-03
# reduced chi2:  0.005949892929019969
# 55 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.33e-03
# reduced chi2:  0.007954651756034463
# 56 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.21e-03
# reduced chi2:  0.01154335164695157
# 57 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.40e-03
# reduced chi2:  0.005854460002066193
# 58 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.61e-04
# reduced chi2:  0.007441511599649464
# 59 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.17e-03
# reduced chi2:  0.006168216356354191
# 60 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.67e-03
# reduced chi2:  0.004793183960993022
# 61 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.55e-03
# reduced chi2:  0.00986894888127644
# 62 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.22e-03
# reduced chi2:  0.006742121999953272
# 63 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.84e-03
# reduced chi2:  0.005696852668678414
# 64 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.17e-03
# reduced chi2:  0.009823733714297416
# 65 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.71e-03
# reduced chi2:  0.01506641298988456
# 66 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.40e-03
# reduced chi2:  0.007413703802975591
# 67 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.20e-03
# reduced chi2:  0.005876920120787646
# 68 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.16e-03
# reduced chi2:  0.011159540601854308
# 69 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.94e-03
# reduced chi2:  0.0076929874556316185
# 70 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.39e-03
# reduced chi2:  0.006910564796983509
# 71 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.46e-03
# reduced chi2:  0.012438950352447634
# 72 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.05e-02
# reduced chi2:  0.028570429967258962
# 73 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.25e-03
# reduced chi2:  0.0030379888269725917
# 74 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.34e-03
# reduced chi2:  0.004260016283960029
# 75 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.10e-03
# reduced chi2:  0.008926717079572766
# 76 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  6.56e-03
# reduced chi2:  0.005610274981241573
# 77 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.76e-03
# reduced chi2:  0.006230659491768195
# 78 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  9.44e-04
# reduced chi2:  0.007071977351697216
# 79 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  7.29e-03
# reduced chi2:  0.009348986647819772
# 80 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.48e-04
# reduced chi2:  0.008280769304000103
# 81 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.93e-03
# reduced chi2:  0.006523204817069173
# 82 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.20e-03
# reduced chi2:  0.014097805560863918
# 83 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.73e-03
# reduced chi2:  0.005896650468573595
# 84 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.93e-03
# reduced chi2:  0.006744344468958685
# 85 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.36e-04
# reduced chi2:  0.011423326148697774
# 86 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.15e-03
# reduced chi2:  0.013581535171781145
# 87 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.25e-03
# reduced chi2:  0.01194229563708448
# 88 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  4.12e-03
# reduced chi2:  0.00988109515711408
# 89 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.70e-03
# reduced chi2:  0.021275018281811834
# 90 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.00e-03
# reduced chi2:  0.00838165401906723
# 91 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.78e-03
# reduced chi2:  0.00528572202305439
# 92 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  8.03e-03
# reduced chi2:  0.012330529909171203
# 93 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.31e-03
# reduced chi2:  0.009797577600976467
# 94 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.46e-03
# reduced chi2:  0.0048288971076130265
# 95 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  3.49e-03
# reduced chi2:  0.0050423313269250545
# 96 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.82e-03
# reduced chi2:  0.006437424887747055
# 97 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  1.33e-03
# reduced chi2:  0.004625718526474921
# 98 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  5.82e-03
# reduced chi2:  0.0055796798194217645
# 99 / 100
# Separation (face to face):  6.5
# Stroke:  100
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# A separation of 6.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha:  2.31e-03
# reduced chi2:  0.005812410837345504

# %%
m_x2 = [m_.values[0] for m_ in min_20_x2]
m_z = [m_.values[0] for m_ in min_20_z]
m_x3 = [m_.values[0] for m_ in min_20_x3]

_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].scatter(range(100), m_x2, label='X2 only')
ax[0].scatter(range(100), m_x3, label='X3 only')
ax[0].scatter(range(100), m_z, label='Z only')
ax[0].legend()

ax[1].scatter(m_x2, m_z)

print('x2 only - mean: ', np.mean(m_x2), ', std: ', np.std(m_x2))
print('x3 only - mean: ', np.mean(m_x2), ', std: ', np.std(m_x3))
print('z only - mean: ', np.mean(m_z), ', std: ', np.std(m_z))
# Out:
# <img src="data:image/png;base64,..." width="950">
# x2 only - mean:  0.0030363171904296614 , std:  0.0013777809380663476
# x3 only - mean:  0.0030363171904296614 , std:  0.001847199995370785
# z only - mean:  0.008458783111975298 , std:  0.004582206824846688

# %%
m_noise_xx = [m_.values[0] for m_ in min_3_6_xx]

# %%
_, ax = plt.subplots(figsize=(9,4))
ax.semilogy(np.arange(100), np.array(m_3_6)*1e10, '.', label=r'X & Z')
ax.semilogy(np.arange(100), np.array(m_3_6_x)*1e10, '.', label=r'X only')
ax.semilogy(np.arange(100), np.array(m_3_6_z)*1e10, '.', label=r'Z only')
ax.semilogy(np.arange(15), np.array(m_noise[-15:])*1e10, '.', label=r'InitData - noise level - X and Z')
ax.semilogy(np.arange(15), np.array(m_noise_zx3[-15:])*1e10, '.', label=r'InitData - noise level - X3 and Z')
ax.semilogy(np.arange(15), np.array(m_noise_xx[-15:])*1e10, '.', label=r'InitData - noise level - X only')
ax.set(ylim=(1e7,5e10), xlabel='time [sec.]', ylabel=r'$\alpha$', title=r'$\lambda=100 \mu m $ - 6th harmonic')
ax.legend()
print('mean alpha (all): ', np.mean(m_3_6), 'std: ', np.std(m_3_6))
print('mean alpha (X-only): ', np.mean(m_3_6_x), 'std: ', np.std(m_3_6_x))
print('mean alpha (Z-only): ', np.mean(m_3_6_z), 'std: ', np.std(m_3_6_z))
print('mean alpha noise (Z-only): ', np.mean(m_noise[-15:]), 'std: ', np.std(m_3_6_z[-15:]))
# Out:
# <img src="data:image/png;base64,..." width="900">
# mean alpha (all):  0.011011721321739585 std:  0.006202859498670212
# mean alpha (X-only):  0.33172914416158017 std:  0.10375595476105456
# mean alpha (Z-only):  0.01075695602593762 std:  0.006110601362293406
# mean alpha noise (Z-only):  0.0031017019021576564 std:  0.00619360483794931

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].semilogy(np.arange(350), np.array(m_3_5)*1e10, '.', label=r'6th harmonic')
ax[0].semilogy(np.arange(350), np.array(m_3_noise)*1e10, '.', label=r'noise')
ax[0].set(ylim=(1e7,5e10), xlabel='time [sec.]', ylabel=r'$\alpha$', title=r'$\lambda=100 \mu m $')
ax[0].legend()
ax[1].hist(m_3_5,bins=20,alpha=0.5)
ax[1].hist(m_3_noise,bins=20,alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="950">
# (array([16., 24., 31., 49., 35., 36., 40., 26., 27., 21., 20.,  9.,  7.,
#          3.,  3.,  2.,  0.,  0.,  0.,  1.]),
#  array([0.00075839, 0.00239923, 0.00404007, 0.00568091, 0.00732175,
#         0.00896259, 0.01060343, 0.01224427, 0.01388511, 0.01552595,
#         0.01716679, 0.01880763, 0.02044847, 0.02208931, 0.02373014,
#         0.02537098, 0.02701182, 0.02865266, 0.0302935 , 0.03193434,
#         0.03357518]),
#  <a list of 20 Patch objects>)

# %%
print('6th hsrmonic mean: ',np.mean(m_3_5), ' error: ', np.std(m_3_5)/np.sqrt(350))
print('noise mean: ',np.mean(m_3_noise), ' error: ', np.std(m_3_noise)/np.sqrt(350))
print('estimated limit: ', format(np.std(m_3_5)/np.sqrt(350)*2*1e10,"5.2e"))
# Out:
# 6th hsrmonic mean:  0.010176552255184384  error:  0.0003071952786798577
# noise mean:  0.010498701965504337  error:  0.0002957590986695374
# estimated limit:  6.14e+06

# %% [markdown]
# ### profile likelihood

# %%
fit_kwargs = {'alpha': 1e-2, 'phase': 0, 'error_alpha': 0.01, 'error_phase': 1,
              'errordef': 1,
              'limit_alpha': [1e-5, 10], 'limit_phase': [-5000,5000],
              'fix_alpha': False, 'fix_phase': False, 'print_level': 0}
min_18_x3 = []
datasets_num = 100
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num)
    min_18_x3.append(gfw.get_alpha_2d(bdf=bb, center_freq=18, bandwidth=1, direction1='z', direction2='z',
                          x_focous=389.0, frequency=3, lambda_par=0.0001, height=6e-6, suppress_print=False,
                          **fit_kwargs)[2])
