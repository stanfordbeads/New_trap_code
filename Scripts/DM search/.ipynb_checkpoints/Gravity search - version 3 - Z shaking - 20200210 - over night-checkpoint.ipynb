# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %%
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ### Load data

# %%
foldername = r'/data/new_trap/20200210/Bead2/Discharge/'
bdf_discharge = load_dir(dirname=foldername)
# Out:
# 57  files in folder
# 57  files loaded

# %%
bb = bdf_discharge[0]
response_z = [np.std(bb.response_at_freq('z',drive_freq=151)) for bb in bdf_discharge]
response_x = [np.std(bb.response_at_freq('x',drive_freq=151)) for bb in bdf_discharge]
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
_, ax = plt.subplots()
ax.scatter(range(len(response_x)), response_z/response_z[47])
ax.scatter(range(len(response_x)), response_x/response_x[15]*17)
ax.set(xlim=(13,53), ylim=(0,20))
print(response_x[48])
# Out:
# <img src="data:image/png;base64,..." width="640">
# 4460.518682913541

# %%
bdf_z = bdf_discharge[40:46]
bdf_x = bdf_discharge[14:19]
m1s_z = gfw.build_z_response(bdf_z, drive_freq=151,charges=3, bandwidth=1, decimate=10, include_sigma=True)
m1s_x = gfw.build_x_response(bdf_x, drive_freq=151,charges=17, bandwidth=1)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# Z2-amplitude:  1.07e+03
# reduced chi2:  7.911945610906001
# ***************************************************
# Z2-amplitude:  1.06e+03
# reduced chi2:  7.666345824446441
# ***************************************************
# Z2-amplitude:  1.05e+03
# reduced chi2:  7.6955109990331545
# ***************************************************
# Z2-amplitude:  1.04e+03
# reduced chi2:  7.706021260335391
# ***************************************************
# Z2-amplitude:  1.05e+03
# reduced chi2:  7.726927610265385
# ***************************************************
# Z2-amplitude:  1.05e+03
# reduced chi2:  7.705681054763986
# Z2 response (amplitude): 1052.9094942729869
# ***************************************************
# X2-amplitude:  9.32e+01
# reduced chi2:  8.871076115573855
# ***************************************************
# X2-amplitude:  9.45e+01
# reduced chi2:  8.633933863134763
# ***************************************************
# X2-amplitude:  9.44e+01
# reduced chi2:  8.94014741570214
# ***************************************************
# X2-amplitude:  9.38e+01
# reduced chi2:  9.682929153021108
# ***************************************************
# X2-amplitude:  9.30e+01
# reduced chi2:  9.282856152461832
# X3 to X2 ratio: 0.22250304802410303
# X2 response (amplitude): 93.7848917905116

# %%
_,ax = plt.subplots()
[ax.semilogy(*bb.psd('z')) for bb in bdf_z]
ax.set(xlim=(1,200))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(1, 200)]

# %% [markdown]
# ### Transfer function

# %%
fname = r'/data/new_trap/20200210/Bead2/TransFunc/TransFunc_X_3.h5'
tf_x = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200210/Bead2/TransFunc/TransFunc_Y_3.h5'
tf_y = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200210/Bead2/TransFunc/TransFunc_Z_3.h5'
tf_z = BeadDataFile.BeadDataFile(fname=fname)
tf_list = [tf_x, tf_y, tf_z]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data

# %%
_,ax = plt.subplots()
[ax.semilogy(*bb.psd('y')) for bb in tf_list]
ax.set(xlim=(1,300))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(1, 300)]

# %%
gfw.build_transfer_function(tf_list, plot=True)
# Out:
# <img src="data:image/png;base64,..." width="950">

# %%
# foldername = r'/data/new_trap/20200107/Bead3/InitialTest/'
foldername = r'/data/new_trap/20200210/Bead2/Shaking/Shaking382/'
# foldername = r'/data/new_trap/20200210/Bead2/Shaking/Shaking_spin/'
datasets_num = 1000
data_bdfs = load_dir(foldername, file_prefix='Shaking0', start_file=4000, max_file=datasets_num)
# Out:
# 5000  files in folder
# 1000  files loaded

# %%
gfw.BDFs = data_bdfs

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4),sharex=True)
for i,bb in enumerate(data_bdfs[:1250:100]):
    ax[0].semilogy(*bb.psd2('z'), label=i)
ax[0].set(xlim=(1,50),xlabel='frequency [Hz.]', title='first quarter of data')

for i,bb in enumerate(data_bdfs[1250:2500:100]):
    ax[1].semilogy(*bb.psd2('z'), label=i)
ax[1].set(xlim=(1,50),xlabel='frequency [Hz.]', title='second quarter of data')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(1, 50),
#  Text(0.5, 0, 'frequency [Hz.]'),
#  Text(0.5, 1.0, 'second quarter of data')]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4),sharex=True)

for i,bb in enumerate(data_bdfs[:1250:100]):
    ax[0].semilogy(*bb.psd2('z'), label=i)
ax[0].set(xlim=(1,50),xlabel='frequency [Hz.]', title='third quarter of data')

for i,bb in enumerate(data_bdfs[1250:2500:100]):
    ax[1].semilogy(*bb.psd2('z'), label=i)
ax[1].set(xlim=(1,50),xlabel='frequency [Hz.]', title='fourth quarter of data')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(1, 50),
#  Text(0.5, 0, 'frequency [Hz.]'),
#  Text(0.5, 1.0, 'fourth quarter of data')]

# %%
gfw.build_noise_array(sideband_freq=20, bandwidth=2)
# gfw.BDFs = data_bdfs
gfw.build_noise_array_z(sideband_freq=20, bandwidth=2)

# %%
m1s_z5 = gfw.build_z_response(bdf_z, drive_freq=151,charges=3, bandwidth=2, decimate=100, include_sigma=True)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# Z2-amplitude:  1.06e+03
# reduced chi2:  7.804653856156323
# ***************************************************
# Z2-amplitude:  1.05e+03
# reduced chi2:  7.428520404699444
# ***************************************************
# Z2-amplitude:  1.04e+03
# reduced chi2:  7.476885055525826
# ***************************************************
# Z2-amplitude:  1.04e+03
# reduced chi2:  7.478576400031851
# ***************************************************
# Z2-amplitude:  1.04e+03
# reduced chi2:  7.507181811455073
# ***************************************************
# Z2-amplitude:  1.05e+03
# reduced chi2:  7.5682824195810685
# Z2 response (amplitude): 1046.7015015293352

# %%
np.mean([m1_.values[3] for m1_ in m1s_z5]), np.std([m1_.values[3] for m1_ in m1s_z5])
# Out:
# (152.85431011865384, 32.41170236769793)

# %%
gfw.scale_Z2, gfw.tf_ffts[2]
# Out:
# (2049781582428802.0,
#  array([1.13370116, 1.30761381, 1.12879453, 1.30412491, 0.67349737,
#         0.92065544, 0.78698129, 0.65996182, 0.90722819, 0.80740429,
#         0.81568378, 0.88174077, 0.9975739 , 0.9638038 , 0.94236515,
#         1.00410001, 0.97825629, 1.01369981, 1.01159055, 0.98463149,
#         0.9941386 , 1.00439605, 1.00477528, 1.03610635, 0.98737038,
#         1.01430075, 1.03989577, 1.03819126, 1.05205843, 1.03848771,
#         1.08148211, 1.04797809, 1.0148529 , 0.97768474, 0.94334023,
#         0.91603735, 0.85543115, 0.73856123, 0.64484303, 0.94733709,
#         1.7493425 , 1.89980454, 1.91967978, 1.62809113, 1.45505277,
#         1.27743966, 1.30707363, 1.1933053 , 1.10434401, 1.09722203]))

# %%
gfw.fsamp
# Out:
# 5000

# %% [markdown]
# ### profile likelihood

# %%
fit_kwargs = {'alpha': 0, 'phase': 0, 'sigma': 17, 'error_alpha': 0.01, 'error_phase': 1, 'error_sigma': 1,
              'errordef': 1,
              'limit_alpha': [-100, 100], 'limit_phase': [-10,10], 'limit_sigma': [0,None],
              'fix_alpha': True, 'fix_phase': True, 'fix_sigma': False, 'print_level': 0}

fit_kwargs2 = {'alpha': 0, 'phase': 0, 'sigma': 17, 'error_alpha': 0.01, 'error_phase': 1, 'error_sigma': 1,
              'errordef': 1,
              'limit_alpha': [-100, 100], 'limit_phase': [-5,5], 'limit_sigma': [0,None],
              'fix_alpha': False, 'fix_phase': False, 'fix_sigma': False, 'print_level': 0}
min_18_z_5 = []
min_18_z_denom = []
datasets_num = 1000
bandwidth = 2
center_freq = 18
for i,bb in enumerate(gfw.BDFs):
    print(i,'/',datasets_num) 
    min_18_z_5.append(gfw.get_alpha_mle_pl(bdf=bb, center_freq=center_freq, noise_freq=center_freq+bandwidth, 
                                             bandwidth=bandwidth, decimate=100, direction1='z',
                          x_focous=389.0, frequency=3, lambda_par=0.0001, height=6e-6, suppress_print=False,
                          **fit_kwargs2)[2])
# Out:
# 0 / 1000
# Separation (face to face):  4.4764624903160435
# Stroke:  100.45771662655719
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.35e-02
# sigma mle:  1.06e+02
# reduced chi2:  0.16531429148363716
# 1 / 1000
# Separation (face to face):  4.475564283134338
# Stroke:  100.45697775314648
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  2.73e-03
# sigma mle:  1.07e+02
# reduced chi2:  0.16565197698106016
# 2 / 1000
# Separation (face to face):  4.476180135668789
# Stroke:  100.45768901418248
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.54e-03
# sigma mle:  5.88e+01
# reduced chi2:  0.14639769408598402
# 3 / 1000
# Separation (face to face):  4.477418763374862
# Stroke:  100.45771146903266
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# ***************************************************
# alpha mle:  8.91e-03
# sigma mle:  1.17e+02
# reduced chi2:  0.1684725935096464
# 4 / 1000
# Separation (face to face):  4.47560097184604
# Stroke:  100.457828675938
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  4.00e-03
# sigma mle:  8.79e+01
# reduced chi2:  0.15942992560587518
# 5 / 1000
# Separation (face to face):  4.47588244124629
# Stroke:  100.45710822856297
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.47e-03
# sigma mle:  5.51e+01
# reduced chi2:  0.14430126353179526
# 6 / 1000
# Separation (face to face):  4.4759206894067685
# Stroke:  100.4569584371414
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -3.35e-03
# sigma mle:  1.14e+02
# reduced chi2:  0.16750995733453183
# 7 / 1000
# Separation (face to face):  4.473867658166432
# Stroke:  100.4576976272494
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.20e-03
# sigma mle:  5.93e+01
# reduced chi2:  0.1466601049349572
# 8 / 1000
# Separation (face to face):  4.474056464941873
# Stroke:  100.45771405213276
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -6.08e-03
# sigma mle:  6.29e+01
# reduced chi2:  0.14854199241182747
# 9 / 1000
# Separation (face to face):  4.474525967764157
# Stroke:  100.45721883321522
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.26e-03
# sigma mle:  9.68e+01
# reduced chi2:  0.16234242772638383
# 10 / 1000
# Separation (face to face):  4.476486866215486
# Stroke:  100.45699116495815
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.09e-03
# sigma mle:  6.27e+01
# reduced chi2:  0.14844439407659923
# 11 / 1000
# Separation (face to face):  4.473924889947773
# Stroke:  100.45776416220751
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.50e-02
# sigma mle:  8.27e+01
# reduced chi2:  0.1573055806559027
# 12 / 1000
# Separation (face to face):  4.4752522718401675
# Stroke:  100.457814919037
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.39e-02
# sigma mle:  1.12e+02
# reduced chi2:  0.16691168412229743
# 13 / 1000
# Separation (face to face):  4.474268357808887
# Stroke:  100.45772618044492
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.34e-02
# sigma mle:  6.36e+01
# reduced chi2:  0.14887445071243852
# 14 / 1000
# Separation (face to face):  4.475624260024835
# Stroke:  100.45801214350091
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -6.96e-02
# sigma mle:  9.19e+01
# reduced chi2:  0.16068110227603205
# 15 / 1000
# Separation (face to face):  4.4762682715663455
# Stroke:  100.45802010242458
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.01e-01
# sigma mle:  8.90e+01
# reduced chi2:  0.15962847726197188
# 16 / 1000
# Separation (face to face):  4.475558469616294
# Stroke:  100.45758976977008
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  5.61e-03
# sigma mle:  6.63e+01
# reduced chi2:  0.15020336285521754
# 17 / 1000
# Separation (face to face):  4.474728831215691
# Stroke:  100.45729872695789
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.00e-02
# sigma mle:  1.13e+02
# reduced chi2:  0.1674163101168854
# 18 / 1000
# Separation (face to face):  4.47357987773305
# Stroke:  100.45745266687759
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.53e-02
# sigma mle:  1.25e+02
# reduced chi2:  0.17061537032045876
# 19 / 1000
# Separation (face to face):  4.474417340689831
# Stroke:  100.4570057889117
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  7.07e-03
# sigma mle:  5.98e+01
# reduced chi2:  0.14689790399991995
# 20 / 1000
# Separation (face to face):  4.474772535676641
# Stroke:  100.4578592344892
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  7.40e-03
# sigma mle:  1.06e+02
# reduced chi2:  0.16536645715431952
# 21 / 1000
# Separation (face to face):  4.473442930988744
# Stroke:  100.45793833081724
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -6.21e-03
# sigma mle:  8.25e+01
# reduced chi2:  0.15720658434943344
# 22 / 1000
# Separation (face to face):  4.47237557359407
# Stroke:  100.45804603388066
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.36e-02
# sigma mle:  4.54e+01
# reduced chi2:  0.13937109443229365
# 23 / 1000
# Separation (face to face):  4.47183099209966
# Stroke:  100.45805051319174
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.73e-03
# sigma mle:  5.01e+01
# reduced chi2:  0.1419858039317306
# 24 / 1000
# Separation (face to face):  4.472201618689075
# Stroke:  100.45761596829848
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -6.84e-03
# sigma mle:  4.48e+01
# reduced chi2:  0.13769460588570318
# 25 / 1000
# Separation (face to face):  4.4717807193069685
# Stroke:  100.4581345199312
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -7.25e-03
# sigma mle:  3.25e+01
# reduced chi2:  0.1273747672277083
# 26 / 1000
# Separation (face to face):  4.471228651101148
# Stroke:  100.45790083036876
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -4.62e-03
# sigma mle:  3.80e+01
# reduced chi2:  0.13240551765113254
# 27 / 1000
# Separation (face to face):  4.473765591997369
# Stroke:  100.45722239018065
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  6.64e-03
# sigma mle:  3.63e+01
# reduced chi2:  0.13092050829475016
# 28 / 1000
# Separation (face to face):  4.474017827481964
# Stroke:  100.4577878633769
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.69e-03
# sigma mle:  4.23e+01
# reduced chi2:  0.13586353721311661
# 29 / 1000
# Separation (face to face):  4.475090210379994
# Stroke:  100.45804787187677
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -6.24e-03
# sigma mle:  3.09e+01
# reduced chi2:  0.12577025218650997
# 30 / 1000
# Separation (face to face):  4.475976002781385
# Stroke:  100.45752048672131
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.84e-03
# sigma mle:  3.51e+01
# reduced chi2:  0.12984023945065282
# 31 / 1000
# Separation (face to face):  4.476536187453155
# Stroke:  100.4574748353817
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -6.02e-03
# sigma mle:  3.53e+01
# reduced chi2:  0.13009085292606418
# 32 / 1000
# Separation (face to face):  4.476525266505837
# Stroke:  100.45742012762399
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.45e-03
# sigma mle:  4.12e+01
# reduced chi2:  0.13500870110891222
# 33 / 1000
# Separation (face to face):  4.476302803612759
# Stroke:  100.45656069905057
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.44e-03
# sigma mle:  3.84e+01
# reduced chi2:  0.13271729299077958
# 34 / 1000
# Separation (face to face):  4.476639842844326
# Stroke:  100.4566826693787
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  2.24e-03
# sigma mle:  3.61e+01
# reduced chi2:  0.13077083866510897
# 35 / 1000
# Separation (face to face):  4.474406928241853
# Stroke:  100.45687441070709
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.54e-03
# sigma mle:  3.75e+01
# reduced chi2:  0.13195347966356796
# 36 / 1000
# Separation (face to face):  4.476150211755771
# Stroke:  100.45701074519818
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.65e-03
# sigma mle:  3.96e+01
# reduced chi2:  0.13371576346565667
# 37 / 1000
# Separation (face to face):  4.475644189750062
# Stroke:  100.45782377724217
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  5.88e-03
# sigma mle:  3.85e+01
# reduced chi2:  0.13279451666607459
# 38 / 1000
# Separation (face to face):  4.475772857687025
# Stroke:  100.45698754882784
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.08e-02
# sigma mle:  4.12e+01
# reduced chi2:  0.13496717865678723
# 39 / 1000
# Separation (face to face):  4.477356433470652
# Stroke:  100.4567181773199
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.42e-03
# sigma mle:  3.92e+01
# reduced chi2:  0.1334466063172651
# 40 / 1000
# Separation (face to face):  4.4757853728762935
# Stroke:  100.45699682858195
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.01e-04
# sigma mle:  3.41e+01
# reduced chi2:  0.12890312628708017
# 41 / 1000
# Separation (face to face):  4.474809158190487
# Stroke:  100.4565071883109
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.52e-03
# sigma mle:  3.66e+01
# reduced chi2:  0.13123663567240487
# 42 / 1000
# Separation (face to face):  4.474749379614343
# Stroke:  100.45735515852643
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.02e-04
# sigma mle:  3.90e+01
# reduced chi2:  0.1332394280130109
# 43 / 1000
# Separation (face to face):  4.474678546433415
# Stroke:  100.45753309758702
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  4.83e-03
# sigma mle:  3.80e+01
# reduced chi2:  0.13243945735428378
# 44 / 1000
# Separation (face to face):  4.476083995102021
# Stroke:  100.45722503572716
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.25e-04
# sigma mle:  3.73e+01
# reduced chi2:  0.1318514359677372
# 45 / 1000
# Separation (face to face):  4.474733477713391
# Stroke:  100.45763686400453
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.93e-03
# sigma mle:  3.66e+01
# reduced chi2:  0.13119849321232038
# 46 / 1000
# Separation (face to face):  4.4779219181604955
# Stroke:  100.45711129200953
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.90e-03
# sigma mle:  3.85e+01
# reduced chi2:  0.13285350163936308
# 47 / 1000
# Separation (face to face):  4.477559324644892
# Stroke:  100.45711738532789
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  6.81e-03
# sigma mle:  4.24e+01
# reduced chi2:  0.13592213277210638
# 48 / 1000
# Separation (face to face):  4.476268443433787
# Stroke:  100.4577493075908
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  4.79e-03
# sigma mle:  4.13e+01
# reduced chi2:  0.13509839168190008
# 49 / 1000
# Separation (face to face):  4.477316417270833
# Stroke:  100.45749468165798
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.29e-03
# sigma mle:  4.11e+01
# reduced chi2:  0.13492548824322245
# 50 / 1000
# Separation (face to face):  4.47724706119269
# Stroke:  100.45736591030264
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -7.86e-03
# sigma mle:  3.83e+01
# reduced chi2:  0.13269171537693172
# 51 / 1000
# Separation (face to face):  4.476188531904176
# Stroke:  100.45721840419715
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -3.09e-04
# sigma mle:  3.42e+01
# reduced chi2:  0.12905913359791707
# 52 / 1000
# Separation (face to face):  4.477374825737433
# Stroke:  100.4568302506458
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  6.76e-03
# sigma mle:  3.69e+01
# reduced chi2:  0.13149243790302975
# 53 / 1000
# Separation (face to face):  4.47620004151114
# Stroke:  100.45721725165173
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.40e-03
# sigma mle:  4.66e+01
# reduced chi2:  0.13890430677618035
# 54 / 1000
# Separation (face to face):  4.476398259908569
# Stroke:  100.45698627961046
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -7.33e-03
# sigma mle:  4.02e+01
# reduced chi2:  0.13423596135699722
# 55 / 1000
# Separation (face to face):  4.477819301864008
# Stroke:  100.4563131513513
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.25e-02
# sigma mle:  4.29e+01
# reduced chi2:  0.13627472906500265
# 56 / 1000
# Separation (face to face):  4.478142832468086
# Stroke:  100.45635324390763
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.47e-03
# sigma mle:  4.37e+01
# reduced chi2:  0.13684426034763167
# 57 / 1000
# Separation (face to face):  4.478693729381382
# Stroke:  100.45710107292166
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.63e-03
# sigma mle:  3.57e+01
# reduced chi2:  0.13038008167304543
# 58 / 1000
# Separation (face to face):  4.479670954612322
# Stroke:  100.45743358886769
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.63e-03
# sigma mle:  3.97e+01
# reduced chi2:  0.13381982256466424
# 59 / 1000
# Separation (face to face):  4.479089924193749
# Stroke:  100.45724388510624
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.55e-02
# sigma mle:  4.37e+01
# reduced chi2:  0.13687642582267032
# 60 / 1000
# Separation (face to face):  4.478227312799367
# Stroke:  100.45757098755921
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.96e-03
# sigma mle:  3.47e+01
# reduced chi2:  0.12949135742228382
# 61 / 1000
# Separation (face to face):  4.479087988608262
# Stroke:  100.45693904509484
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  2.39e-03
# sigma mle:  3.95e+01
# reduced chi2:  0.13365949680332992
# 62 / 1000
# Separation (face to face):  4.478000836151045
# Stroke:  100.45724715049518
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.00e-03
# sigma mle:  3.99e+01
# reduced chi2:  0.1339627148354013
# 63 / 1000
# Separation (face to face):  4.478331618408708
# Stroke:  100.45668860260669
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.19e-03
# sigma mle:  4.61e+01
# reduced chi2:  0.13856958087450225
# 64 / 1000
# Separation (face to face):  4.477483362448117
# Stroke:  100.45753975120108
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  6.75e-03
# sigma mle:  3.64e+01
# reduced chi2:  0.13090628450607047
# 65 / 1000
# Separation (face to face):  4.478908924839152
# Stroke:  100.45675092089176
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.41e-03
# sigma mle:  4.12e+01
# reduced chi2:  0.13497496321474345
# 66 / 1000
# Separation (face to face):  4.476056069646495
# Stroke:  100.45717510409317
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.33e-02
# sigma mle:  4.35e+01
# reduced chi2:  0.13670855749363311
# 67 / 1000
# Separation (face to face):  4.476741341723402
# Stroke:  100.45711470982462
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.43e-03
# sigma mle:  3.95e+01
# reduced chi2:  0.13362605162415525
# 68 / 1000
# Separation (face to face):  4.4792464715498905
# Stroke:  100.45662778124722
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  2.28e-03
# sigma mle:  3.72e+01
# reduced chi2:  0.13171466944313084
# 69 / 1000
# Separation (face to face):  4.479331733629101
# Stroke:  100.45761110579201
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.05e-03
# sigma mle:  3.79e+01
# reduced chi2:  0.1323080551577731
# 70 / 1000
# Separation (face to face):  4.478119555954754
# Stroke:  100.45680417040228
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.98e-03
# sigma mle:  3.76e+01
# reduced chi2:  0.1320686736419725
# 71 / 1000
# Separation (face to face):  4.478242917621889
# Stroke:  100.4572770571017
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.98e-03
# sigma mle:  3.79e+01
# reduced chi2:  0.13232504547622798
# 72 / 1000
# Separation (face to face):  4.477853209123827
# Stroke:  100.45729150922527
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.93e-03
# sigma mle:  4.70e+01
# reduced chi2:  0.1392097751190295
# 73 / 1000
# Separation (face to face):  4.478119440144701
# Stroke:  100.45741824184968
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  6.41e-03
# sigma mle:  3.84e+01
# reduced chi2:  0.13270673426190874
# 74 / 1000
# Separation (face to face):  4.477133235274811
# Stroke:  100.45737257401359
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  4.65e-03
# sigma mle:  3.51e+01
# reduced chi2:  0.12985209494225664
# 75 / 1000
# Separation (face to face):  4.475936508100039
# Stroke:  100.45800807792224
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -4.90e-03
# sigma mle:  3.66e+01
# reduced chi2:  0.13117123662410654
# 76 / 1000
# Separation (face to face):  4.477189426701306
# Stroke:  100.45771042534925
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  2.84e-03
# sigma mle:  4.23e+01
# reduced chi2:  0.13585923647119363
# 77 / 1000
# Separation (face to face):  4.47794299985984
# Stroke:  100.45706631081623
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  5.38e-03
# sigma mle:  4.00e+01
# reduced chi2:  0.1340920642159937
# 78 / 1000
# Separation (face to face):  4.476985739483927
# Stroke:  100.45758360455717
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  6.48e-03
# sigma mle:  4.85e+01
# reduced chi2:  0.14022298447965184
# 79 / 1000
# Separation (face to face):  4.478661641371707
# Stroke:  100.45734093731687
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.32e-03
# sigma mle:  4.24e+01
# reduced chi2:  0.13591683528345072
# 80 / 1000
# Separation (face to face):  4.476451567322874
# Stroke:  100.45764172623355
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -3.83e-03
# sigma mle:  3.82e+01
# reduced chi2:  0.13269045930625809
# 81 / 1000
# Separation (face to face):  4.4780084925355705
# Stroke:  100.45739996523328
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.05e-02
# sigma mle:  3.18e+01
# reduced chi2:  0.12671777476641727
# 82 / 1000
# Separation (face to face):  4.476802688392047
# Stroke:  100.45745662176203
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.59e-03
# sigma mle:  4.35e+01
# reduced chi2:  0.13674009796040285
# 83 / 1000
# Separation (face to face):  4.475001937907598
# Stroke:  100.4582593431308
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -3.62e-03
# sigma mle:  3.86e+01
# reduced chi2:  0.13292105592127948
# 84 / 1000
# Separation (face to face):  4.475277271670256
# Stroke:  100.45781306261495
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  5.83e-03
# sigma mle:  3.71e+01
# reduced chi2:  0.13164684543231586
# 85 / 1000
# Separation (face to face):  4.476007034374424
# Stroke:  100.45750681327875
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.01e-02
# sigma mle:  3.93e+01
# reduced chi2:  0.13350689721182202
# 86 / 1000
# Separation (face to face):  4.475035682925613
# Stroke:  100.45787395298372
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  8.49e-03
# sigma mle:  3.79e+01
# reduced chi2:  0.13228051991341336
# 87 / 1000
# Separation (face to face):  4.475170375608206
# Stroke:  100.45793539844145
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -6.26e-03
# sigma mle:  3.81e+01
# reduced chi2:  0.1324871910573934
# 88 / 1000
# Separation (face to face):  4.47540853897309
# Stroke:  100.45790010099044
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  6.26e-03
# sigma mle:  3.66e+01
# reduced chi2:  0.131160416237706
# 89 / 1000
# Separation (face to face):  4.476537546781207
# Stroke:  100.45751913285787
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.32e-03
# sigma mle:  3.35e+01
# reduced chi2:  0.12833134814981095
# 90 / 1000
# Separation (face to face):  4.476451116681096
# Stroke:  100.45735481906674
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  5.01e-03
# sigma mle:  3.51e+01
# reduced chi2:  0.1298390758537679
# 91 / 1000
# Separation (face to face):  4.475200221208899
# Stroke:  100.45788697735719
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  4.05e-03
# sigma mle:  3.94e+01
# reduced chi2:  0.13358671664036517
# 92 / 1000
# Separation (face to face):  4.4753548306549416
# Stroke:  100.45801798721332
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ...
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.59e-03
# sigma mle:  1.16e+02
# reduced chi2:  0.16818928876816266
# 906 / 1000
# Separation (face to face):  4.466652426761732
# Stroke:  100.45818897993264
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -8.78e-03
# sigma mle:  4.46e+01
# reduced chi2:  0.13750500807980048
# 907 / 1000
# Separation (face to face):  4.467620635303467
# Stroke:  100.45800721374366
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -4.29e-03
# sigma mle:  1.25e+02
# reduced chi2:  0.170464928253596
# 908 / 1000
# Separation (face to face):  4.467489492330435
# Stroke:  100.45827229002136
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  2.49e-03
# sigma mle:  7.84e+01
# reduced chi2:  0.15556832042094768
# 909 / 1000
# Separation (face to face):  4.466021349460709
# Stroke:  100.4585362782507
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  5.66e-03
# sigma mle:  6.11e+01
# reduced chi2:  0.14758728255829404
# 910 / 1000
# Separation (face to face):  4.4663043000539115
# Stroke:  100.45775538359615
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -4.30e-03
# sigma mle:  1.06e+02
# reduced chi2:  0.16528963633923133
# 911 / 1000
# Separation (face to face):  4.464886505623587
# Stroke:  100.45835896815488
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -7.88e-03
# sigma mle:  4.11e+01
# reduced chi2:  0.13495511943078395
# 912 / 1000
# Separation (face to face):  4.46509410926692
# Stroke:  100.4578557150106
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.56e-02
# sigma mle:  8.15e+01
# reduced chi2:  0.15683987131117622
# 913 / 1000
# Separation (face to face):  4.465645492720489
# Stroke:  100.45816104833209
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -7.83e-03
# sigma mle:  9.23e+01
# reduced chi2:  0.16080136552996144
# 914 / 1000
# Separation (face to face):  4.465899036255598
# Stroke:  100.45746948984562
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.76e-03
# sigma mle:  5.34e+01
# reduced chi2:  0.14327101253926364
# 915 / 1000
# Separation (face to face):  4.465563047406283
# Stroke:  100.45758126934075
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.28e-03
# sigma mle:  1.04e+02
# reduced chi2:  0.16456527322488668
# 916 / 1000
# Separation (face to face):  4.465637365690986
# Stroke:  100.45763973283415
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.89e-03
# sigma mle:  6.53e+01
# reduced chi2:  0.14971362123735205
# 917 / 1000
# Separation (face to face):  4.4657272168535425
# Stroke:  100.45829472065823
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.15e-03
# sigma mle:  6.89e+01
# reduced chi2:  0.15146583535803584
# 918 / 1000
# Separation (face to face):  4.467508986425264
# Stroke:  100.45771579592612
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  5.09e-03
# sigma mle:  1.18e+02
# reduced chi2:  0.16877610146794048
# 919 / 1000
# Separation (face to face):  4.466034352924828
# Stroke:  100.4579930552279
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.24e-02
# sigma mle:  4.95e+01
# reduced chi2:  0.14085942074428978
# 920 / 1000
# Separation (face to face):  4.467141849898132
# Stroke:  100.45771762407252
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -9.90e-03
# sigma mle:  1.05e+02
# reduced chi2:  0.16506716176182107
# 921 / 1000
# Separation (face to face):  4.467781369788758
# Stroke:  100.4573319064123
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -7.70e-03
# sigma mle:  1.16e+02
# reduced chi2:  0.16802359140430947
# 922 / 1000
# Separation (face to face):  4.466574349368193
# Stroke:  100.45798634626587
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.16e-02
# sigma mle:  5.81e+01
# reduced chi2:  0.14597642006797165
# 923 / 1000
# Separation (face to face):  4.466863504434377
# Stroke:  100.45799667838885
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -3.78e-03
# sigma mle:  1.28e+02
# reduced chi2:  0.17127740311991266
# 924 / 1000
# Separation (face to face):  4.468775613664468
# Stroke:  100.45778500786025
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -2.07e-02
# sigma mle:  8.32e+01
# reduced chi2:  0.15766353252025833
# 925 / 1000
# Separation (face to face):  4.4674092403184655
# Stroke:  100.45849885362256
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  1.53e-02
# sigma mle:  6.10e+01
# reduced chi2:  0.14754975809840337
# 926 / 1000
# Separation (face to face):  4.465663140689037
# Stroke:  100.4582026647716
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.78e-03
# sigma mle:  1.24e+02
# reduced chi2:  0.170313028913691
# 927 / 1000
# Separation (face to face):  4.4650166409449294
# Stroke:  100.45794688059136
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  3.04e-02
# sigma mle:  5.76e+01
# reduced chi2:  0.14573506265127145
# 928 / 1000
# Separation (face to face):  4.465084960575245
# Stroke:  100.45833108600587
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.81e-02
# sigma mle:  7.86e+01
# reduced chi2:  0.15564829894466947
# 929 / 1000
# Separation (face to face):  4.466804207452958
# Stroke:  100.45804693431195
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.28e-01
# sigma mle:  8.79e+01
# reduced chi2:  0.15932631545396192
# 930 / 1000
# Separation (face to face):  4.467867746137506
# Stroke:  100.45756403529775
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  2.53e-02
# sigma mle:  5.17e+01
# reduced chi2:  0.14225321863157447
# 931 / 1000
# Separation (face to face):  4.466556091028371
# Stroke:  100.45791541598149
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.02e-01
# sigma mle:  8.58e+01
# reduced chi2:  0.1584838021576317
# 932 / 1000
# Separation (face to face):  4.467579653547238
# Stroke:  100.45770518105482
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  9.29e-02
# sigma mle:  9.76e+01
# reduced chi2:  0.16590503961273464
# 933 / 1000
# Separation (face to face):  4.4683386424738725
# Stroke:  100.45721907295484
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -1.60e-02
# sigma mle:  6.12e+01
# reduced chi2:  0.14764677509393342
# 934 / 1000
# Separation (face to face):  4.464776255463027
# Stroke:  100.4582045295323
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -4.79e-02
# sigma mle:  8.68e+01
# reduced chi2:  0.17239209584814355
# 935 / 1000
# Separation (face to face):  4.46678106432322
# Stroke:  100.45798562448974
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected
# ***************************************************
# alpha mle:  -5.87e-02
# sigma mle:  1.05e+02
# reduced chi2:  0.1648431930160873
# 936 / 1000
# Separation (face to face):  4.4677039250794675
# Stroke:  100.45774190300895
# Time:  10.0
# Your choice of lambda is not existing
# Taking 1.00e-04 for lambda
# order
# A bead size of 2.40e-06 is selected
# 2.4e-06
# 2.4e-06
# A bead size of 2.40e-06 is selected
# 2.4e-06
# posvec
# A bead size of 2.40e-06 is selected
# 2.4e-06
# A separation of 4.50e-06 is selected
# A height of 6.00e-06 is selected

# %%
m_18_alpha_1 = [m1_.values[0] for m1_ in min_18_z_1]
m_18_sigma_1 = [m1_.values[2] for m1_ in min_18_z_1]

m_18_alpha_2 = [m1_.values[0] for m1_ in min_18_z_2]
m_18_sigma_2 = [m1_.values[2] for m1_ in min_18_z_2]

m_18_alpha_3 = [m1_.values[0] for m1_ in min_18_z_3]
m_18_sigma_3 = [m1_.values[2] for m1_ in min_18_z_3]

m_18_alpha_4 = [m1_.values[0] for m1_ in min_18_z_4]
m_18_sigma_4 = [m1_.values[2] for m1_ in min_18_z_4]

m_12_alpha_3 = [m1_.values[0] for m1_ in min_12_z_3]
m_12_sigma_3 = [m1_.values[2] for m1_ in min_12_z_3]

m_18_alpha = m_18_alpha_1+m_18_alpha_2+m_18_alpha_3+m_18_alpha_4
m_18_sigma = m_18_sigma_1+m_18_sigma_2+m_18_sigma_3+m_18_sigma_4

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].hist(np.array(np.abs(m_18_alpha))*1e10, range=(0,0.02*1e10), bins=100, label=r'$\alpha$ distribution')
ax[1].hist(m_18_sigma,range=(10,30),bins=30,alpha=0.5,normed=True, label=r'$\sigma$ distribution')
[a.legend() for a in ax]
print('6th hsrmonic mean: ',np.mean(m_18_alpha), ' error: ', np.std(m_18_alpha)/np.sqrt(3000))
print('estimated limit: ', format(np.std(np.abs(m_18_alpha))/np.sqrt(5000)*2*1e10,"5.2e"))
# Out:
# <img src="data:image/png;base64,..." width="950">
# 6th hsrmonic mean:  -0.00015349614647870168  error:  0.00010965757079862298
# estimated limit:  1.17e+06
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
_, ax = plt.subplots(figsize=(9.5,4))
ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_1)*1e10,'.')
ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_2)*1e10,'.')
ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_3)*1e10,'.')
ax.set(xlabel='dataset', ylabel=r'Likelihoo-fit', title=r'$\lambda=100 \mu m $')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [Text(0, 0.5, 'Likelihoo-fit'),
#  Text(0.5, 0, 'dataset'),
#  Text(0.5, 1.0, '$\\lambda=100 \\mu m $')]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].hist(np.abs(m_18_alpha_3)*1e10, range=(-0,0.02*1e10), bins=50, label=r'Z - 6th harmonic')
ax[0].hist(np.abs(m_12_alpha_3)*1e10, range=(-0,0.02*1e10), bins=50, alpha=0.5, label=r'Z - 4th harmonic')
ax[0].legend()
ax[1].scatter((m_18_alpha_3),(m_12_alpha_3))
print('6th hsrmonic mean: ',np.mean(m_18_alpha_3), ' error: ', np.std(np.abs(m_18_alpha_3))/np.sqrt(1000))
print('12Hz mean: ',np.mean(m_12_alpha_3), ' error: ', np.std(np.abs(m_12_alpha_3))/np.sqrt(1000))
# Out:
# <img src="data:image/png;base64,..." width="950">
# 6th hsrmonic mean:  -0.0003798533920003564  error:  8.057684669983258e-05
# 12Hz mean:  -0.00047183749389132857  error:  8.177043140850047e-05

# %% [markdown]
# ### Noise Gaussianity

# %%
from scipy.optimize import curve_fit

# %%
bandwidth = 6
i = 200
bb = data_bdfs[i].response_at_freq2('z', drive_freq=18, bandwidth=bandwidth)
bb2 = data_bdfs[i].response_at_freq2('z', drive_freq=18+bandwidth/2, bandwidth=bandwidth)
_,ax = plt.subplots()
_ = ax.hist(bb, bins=100, range=(-500,500))
_ = ax.hist(bb2, bins=100, range=(-500,500), alpha=0.3)
# Out:
# /home/analysis_user/.local/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# <img src="data:image/png;base64,..." width="640">

# %%
hist, bin_edges = np.histogram(bb, density=True, normed=True, range=(-200,200),bins=100)
bin_centres = (bin_edges[:-1] + bin_edges[1:])/2

# Define model function to be used to fit to the data above:
def gauss(x, *p):
    A, mu, sigma = p
    return A*np.exp(-(x-mu)**2/(2.*sigma**2))

# p0 is the initial guess for the fitting coefficients (A, mu and sigma above)
p0 = [0.04, 0., 100.]

coeff, var_matrix = curve_fit(gauss, bin_centres, hist, p0=p0)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: The normed argument is ignored when density is provided. In future passing both will result in an error.
#   """Entry point for launching an IPython kernel.

# %%
# Get the fitted curve
_,ax = plt.subplots()
hist_fit = gauss(bin_centres, *coeff)

ax.plot(bin_centres, hist, label='Test data')
ax.plot(bin_centres, hist_fit, label='Fitted data')

# Finally, lets get the fitting parameters, i.e. the mean and standard deviation:
print ('Fitted mean = ', coeff[1])
print ('Fitted standard deviation = ', coeff[2])
# Out:
# <img src="data:image/png;base64,..." width="640">
# Fitted mean =  0.002238513036020227
# Fitted standard deviation =  38.96072834371385

# %% [markdown]
# ### Heights

# %%
bb = data_bdfs[0]
# heights5 = [1024*0.46-bb.bead_height for bb in data_bdfs]
_,ax = plt.subplots(figsize=(9.5,3))
# ax.scatter(range(1000),heights1)
# ax.scatter(range(1000),heights2)
ax.scatter(range(1000),heights3)
# ax.scatter(range(1000),heights4)
# ax.scatter(range(1000),heights5)
ax.set(ylim=(240,270))
# Out:
# <img src="data:image/png;base64,..." width="950">
# [(240, 270)]

# %%
hhh = [heights1,heights2,heights3,heights4,heights5]
avg_h = [np.mean(h_) for h_ in hhh]

hhh = [m_18_alpha_1,m_18_alpha_2,m_18_alpha_3,m_18_alpha_4,m_18_alpha_5]
avg_alpha = [np.mean(h_) for h_ in hhh]

# %%
m_18_alpha_1 = [m1_.values[0] for m1_ in min_18_z_1]
m_18_sigma_1 = [m1_.values[2] for m1_ in min_18_z_1]

m_18_alpha_2 = [m1_.values[0] for m1_ in min_18_z_2]
m_18_sigma_2 = [m1_.values[2] for m1_ in min_18_z_2]

m_18_alpha_3 = [m1_.values[0] for m1_ in min_18_z_3]
m_18_sigma_3 = [m1_.values[2] for m1_ in min_18_z_3]

m_18_alpha_4 = [m1_.values[0] for m1_ in min_18_z_4]
m_18_sigma_4 = [m1_.values[2] for m1_ in min_18_z_4]

m_18_alpha_5 = [m1_.values[0] for m1_ in min_18_z_5]
m_18_sigma_5 = [m1_.values[2] for m1_ in min_18_z_5]


m_18_alpha_5_noise = [m1_.values[0] for m1_ in min_18_z_5_noise]
m_18_sigma_5_noise = [m1_.values[2] for m1_ in min_18_z_5_noise]

# %%
_, ax = plt.subplots(figsize=(9.5,4))
# ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_1)*1e10,'.')
# ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_2)*1e10,'.')
ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_3)*1e10,'.')
# ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_4)*1e10,'.')
# ax.plot(range(len(m_18_alpha_1)),np.array(m_18_alpha_5)*1e10,'.')
ax.set(xlabel='dataset', ylabel=r'Likelihoo-fit', title=r'$\lambda=100 \mu m $')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [Text(0, 0.5, 'Likelihoo-fit'),
#  Text(0.5, 0, 'dataset'),
#  Text(0.5, 1.0, '$\\lambda=100 \\mu m $')]

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].scatter(np.arange(5)+1, avg_h)
ax[1].scatter(np.arange(5)+1, avg_alpha)
# Out:
# <img src="data:image/png;base64,..." width="950">
