# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_Y_0e5_150s_7Hz.h5'
bb = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_Y_m2e5_150s_7Hz.h5'
bb1 = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_Y_m3e5_150s_7Hz.h5'
bb2 = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_Y_m4e5_150s_7Hz.h5'
bb3 = BeadDataFile.BeadDataFile(fname=fname)
# fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_Y_0e5_150s_7Hz.h5'
# bb4 = BeadDataFile.BeadDataFile(fname=fname)
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
_, ax = plt.subplots()
ax.loglog(*bb.psd2('y'), label='0e5')
ax.loglog(*bb1.psd2('y'), label='m2e5')
ax.loglog(*bb2.psd2('y'), label='m3e5', alpha=0.3)
ax.loglog(*bb3.psd2('y'), label='m4e5')
# ax.loglog(*bb4.psd2('y'), label='8e5', alpha=0.7)
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fname = r'/home/data_transfer/data_from_windows/20200614/Bead1/TransFunc/TransFunc_Y_1_7e5_250s_1Hz.h5'
cc = BeadDataFile.BeadDataFile(fname=fname)
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
_, ax = plt.subplots()
ax.loglog(*cc.psd2('y'), label='7e5')
ax.loglog(*bb3.psd2('y'), label='7e5')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_X_m3e5_250s_1Hz.h5'
tf_x = BeadDataFile.BeadDataFile(fname)
fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_Y_m3e5_250s_1Hz.h5'
tf_y = BeadDataFile.BeadDataFile(fname)
fname = r'/data/new_trap/20200618/Bead1/TransFunc/TransFunc_Z_m3e5_250s_1Hz.h5'
tf_z = BeadDataFile.BeadDataFile(fname)
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
_,ax = plt.subplots()
ax.semilogy(*tf_x.psd2('x'), label='x')
ax.semilogy(*tf_y.psd2('y'), alpha=0.5, label='y')
ax.legend()
ax.set(xlim=(0,100))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [(0.0, 100.0)]
