# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
fname1 = r'/data/new_trap/20200113/Bead1/Shaking/Biasing/Shaking_10mV_0.h5'
bdf1 = BeadDataFile.BeadDataFile(fname=fname1)
fname2 = r'/data/new_trap/20200113/Bead1/Shaking/Biasing/Shaking_10mV_3_Hz0.h5'
bdf2 = BeadDataFile.BeadDataFile(fname=fname2)
fname3 = r'/data/new_trap/20200113/Bead1/Shaking/Biasing/Shaking_3_Hz0.h5'
bdf3 = BeadDataFile.BeadDataFile(fname=fname3)

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].semilogy(*bdf1.psd('x'), label='10mV at 109Hz')
ax[0].semilogy(*bdf2.psd('x'), label='10mV at 109Hz + 3Hz shaking', alpha=0.5)
ax[0].set(xlim=(1,200), xlabel='frequency [Hz]', ylabel='X psd [a.u.]')
ax[0].legend()
ax[1].semilogy(*bdf3.psd('x'), label='3Hz shaking')
ax[1].semilogy(*bdf2.psd('x'), label='10mV at 109Hz + 3Hz shaking', alpha=0.6)
ax[1].set(xlim=(1,200), xlabel='frequency [Hz]')
ax[1].legend()
# Out:
# <img src="data:image/png;base64,..." width="950">
