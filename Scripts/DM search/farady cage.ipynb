# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

# %%
# %matplotlib notebook

# %%
lam = 2e-1
c = 78e-3
r = np.linspace(0,50e-3,num=5000)
func = 1/c + lam/(2*c*r)*(np.exp(-(r+c)/lam)-np.exp(-np.abs(r-c)/lam))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in multiply
#   after removing the cwd from sys.path.

# %%
voltage = 1e4 ## 1kV
charge = 1e4*1.6e-19
charge2 = 8.8e-12*4*np.pi*(80e-3*78e-3)/5e-4*voltage
force = -1*np.gradient(func, 1e-3/100)*charge*9e9*charge2
force2 = 1/3*r/(lam**2)*voltage*charge*1.6e-19

# %%
_,ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].plot(r*1000,func)
ax[1].plot(r*1000,force)
# ax[1].plot(r*1000,force2*10)
[a.set(xlabel='r [mm]') for a in ax]
ax[1].set(title=r'$\lambda=2mm$, R=8mm',ylabel='Force [N]')
# Out:
# <img src="data:image/png;base64,..." width="950">
# [Text(0, 0.5, 'Force [N]'), Text(0.5, 1.0, '$\\lambda=2mm$, R=8mm')]
