# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

# %%
# %matplotlib widget

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ## Discahrge

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20200921/Bead1/Discharge/FineDischarge_after_TF/')
# Out:
# 300  files in folder
# 300  files loaded

# %%
bb = bdf_discharge[0]
bb.electrode_channels
# Out:
# array([1, 2], dtype=uint16)

# %%
dis_z = [np.std(bb.response_at_freq2('z', drive_freq=71)) for bb in bdf_discharge]

# %%
ch = [bb.electrode_channels[0] for bb in bdf_discharge]

# %%
_,ax = plt.subplots(figsize=(9.1,4))
ax.scatter(range(len(dis_z)), dis_z/dis_z[0], label='std')
ax.scatter(range(len(dis_z)), amps/amps[0], label='fit')
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bdf_discharge_z = [bb for bb,ch_ in zip(bdf_discharge, ch)  if ch_==1 ]
bdf_discharge_x = [bb for bb,ch_ in zip(bdf_discharge, ch)  if ch_==4 ]

# %%
index_z = [bb for bb,ch_ in zip(range(len(bdf_discharge)), ch)  if ch_==1 ]
index_x = [bb for bb,ch_ in zip(range(len(bdf_discharge)), ch)  if ch_==4 ]

# %%
m1 = gfw.build_z_response(bdf_discharge_z, drive_freq=71, charges=1, bandwidth=1, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  1.12e+03
# reduced chi2:  3584.1562360793614
# ***************************************************
# Z2-amplitude:  1.14e+03
# reduced chi2:  2056.475519108972
# ***************************************************
# Z2-amplitude:  1.10e+03
# reduced chi2:  2634.4619942522068
# ***************************************************
# Z2-amplitude:  1.12e+03
# reduced chi2:  2640.0084595424937
# ***************************************************
# Z2-amplitude:  1.11e+03
# reduced chi2:  2926.2235240014465
# ***************************************************
# Z2-amplitude:  1.09e+03
# reduced chi2:  3579.601294022411
# ***************************************************
# Z2-amplitude:  1.13e+03
# reduced chi2:  4079.3970480358166
# ***************************************************
# Z2-amplitude:  1.11e+03
# reduced chi2:  5704.452719666814
# ***************************************************
# Z2-amplitude:  1.11e+03
# reduced chi2:  3560.347171646013
# ***************************************************
# Z2-amplitude:  1.09e+03
# reduced chi2:  4181.226235009142
# ***************************************************
# Z2-amplitude:  1.14e+03
# reduced chi2:  2033.9658417413784
# ***************************************************
# Z2-amplitude:  1.11e+03
# reduced chi2:  4373.856531195787
# ***************************************************
# Z2-amplitude:  1.10e+03
# reduced chi2:  3196.9329255059292
# ***************************************************
# Z2-amplitude:  1.14e+03
# reduced chi2:  1012.9359015893023
# ***************************************************
# Z2-amplitude:  1.10e+03
# reduced chi2:  4430.008378980806
# ***************************************************
# Z2-amplitude:  1.11e+03
# reduced chi2:  1273.2440587549531
# ***************************************************
# Z2-amplitude:  1.10e+03
# reduced chi2:  1461.9570944257978
# ***************************************************
# Z2-amplitude:  1.11e+03
# reduced chi2:  2723.1810559404794
# ***************************************************
# Z2-amplitude:  1.08e+03
# reduced chi2:  2004.76777915693
# ***************************************************
# Z2-amplitude:  1.12e+03
# reduced chi2:  2211.7092037705565
# ***************************************************
# Z2-amplitude:  1.12e+03
# reduced chi2:  1793.737722219308
# ***************************************************
# Z2-amplitude:  1.12e+03
# reduced chi2:  2326.1388389493877
# ***************************************************
# Z2-amplitude:  1.13e+03
# reduced chi2:  3215.6278324911327
# ***************************************************
# Z2-amplitude:  1.09e+03
# reduced chi2:  1846.703369799117
# ***************************************************
# Z2-amplitude:  1.15e+03
# reduced chi2:  1988.9398757651038
# ***************************************************
# Z2-amplitude:  1.12e+03
# reduced chi2:  2553.7567517861607
# ***************************************************
# Z2-amplitude:  1.09e+03
# reduced chi2:  3202.203802815312
# ***************************************************
# Z2-amplitude:  1.13e+03
# reduced chi2:  2253.463381101739
# ***************************************************
# Z2-amplitude:  1.12e+03
# reduced chi2:  2574.4325958067134
# ***************************************************
# Z2-amplitude:  1.13e+03
# reduced chi2:  3749.8513285419363
# ***************************************************
# Z2-amplitude:  9.48e+02
# reduced chi2:  2508.672517086741
# ***************************************************
# Z2-amplitude:  9.73e+02
# reduced chi2:  2806.044993393891
# ***************************************************
# Z2-amplitude:  9.66e+02
# reduced chi2:  2544.8624703625132
# ***************************************************
# Z2-amplitude:  9.99e+02
# reduced chi2:  4398.9367682201555
# ***************************************************
# Z2-amplitude:  9.59e+02
# reduced chi2:  3354.078591081118
# ***************************************************
# Z2-amplitude:  9.82e+02
# reduced chi2:  1587.4765524228187
# ***************************************************
# Z2-amplitude:  9.24e+02
# reduced chi2:  3291.3942506688923
# ***************************************************
# Z2-amplitude:  9.75e+02
# reduced chi2:  2675.935408106589
# ***************************************************
# Z2-amplitude:  9.70e+02
# reduced chi2:  1849.558826812458
# ***************************************************
# Z2-amplitude:  9.65e+02
# reduced chi2:  2097.0725289469224
# ***************************************************
# Z2-amplitude:  1.00e+03
# reduced chi2:  3231.0477262393615
# ***************************************************
# Z2-amplitude:  9.53e+02
# reduced chi2:  1853.6338370683031
# ***************************************************
# Z2-amplitude:  9.43e+02
# reduced chi2:  2326.5964435986757
# ***************************************************
# Z2-amplitude:  9.54e+02
# reduced chi2:  2063.8282947011066
# ***************************************************
# Z2-amplitude:  9.26e+02
# reduced chi2:  2423.9192704332436
# ***************************************************
# Z2-amplitude:  8.82e+02
# reduced chi2:  2476.578909809388
# ***************************************************
# Z2-amplitude:  9.10e+02
# reduced chi2:  3229.140332287606
# ***************************************************
# Z2-amplitude:  8.84e+02
# reduced chi2:  1906.9643385432803
# ***************************************************
# Z2-amplitude:  9.15e+02
# reduced chi2:  1711.8246298465451
# ***************************************************
# Z2-amplitude:  9.18e+02
# reduced chi2:  1479.079106808973
# ***************************************************
# Z2-amplitude:  9.00e+02
# reduced chi2:  2726.0211893164415
# ***************************************************
# Z2-amplitude:  9.03e+02
# reduced chi2:  1989.213551820002
# ***************************************************
# Z2-amplitude:  8.94e+02
# reduced chi2:  2710.5949348071395
# ***************************************************
# Z2-amplitude:  8.65e+02
# reduced chi2:  4023.1127365769603
# ***************************************************
# Z2-amplitude:  8.74e+02
# reduced chi2:  2007.740808149397
# ***************************************************
# Z2-amplitude:  8.79e+02
# reduced chi2:  3099.8620439810084
# ***************************************************
# Z2-amplitude:  9.05e+02
# reduced chi2:  2992.5512743929526
# ***************************************************
# Z2-amplitude:  9.01e+02
# reduced chi2:  1916.8412637859624
# ***************************************************
# Z2-amplitude:  8.94e+02
# reduced chi2:  3582.4078314079406
# ***************************************************
# Z2-amplitude:  9.16e+02
# reduced chi2:  3049.9786115557995
# ***************************************************
# Z2-amplitude:  8.31e+02
# reduced chi2:  3421.243331802698
# ***************************************************
# Z2-amplitude:  8.38e+02
# reduced chi2:  1854.153778654443
# ***************************************************
# Z2-amplitude:  8.26e+02
# reduced chi2:  1229.1337388059876
# ***************************************************
# Z2-amplitude:  8.21e+02
# reduced chi2:  1381.7686265506852
# ***************************************************
# Z2-amplitude:  8.07e+02
# reduced chi2:  3002.6491424192104
# ***************************************************
# Z2-amplitude:  6.80e+02
# reduced chi2:  2257.8243694419452
# ***************************************************
# Z2-amplitude:  6.88e+02
# reduced chi2:  3657.5040424153412
# ***************************************************
# Z2-amplitude:  6.62e+02
# reduced chi2:  2955.3788701322774
# ***************************************************
# Z2-amplitude:  6.60e+02
# reduced chi2:  3327.3413422382864
# ***************************************************
# Z2-amplitude:  6.34e+02
# reduced chi2:  1704.1573279266058
# ***************************************************
# Z2-amplitude:  6.40e+02
# reduced chi2:  12869.490170541001
# ***************************************************
# Z2-amplitude:  6.77e+02
# reduced chi2:  14888.515441367032
# ***************************************************
# Z2-amplitude:  5.20e+02
# reduced chi2:  17809.21109512609
# ***************************************************
# Z2-amplitude:  2.28e+02
# reduced chi2:  12977.666469804219
# ***************************************************
# Z2-amplitude:  4.10e+02
# reduced chi2:  18693.072445883616
# ***************************************************
# Z2-amplitude:  3.17e+02
# reduced chi2:  17026.41607841046
# ***************************************************
# Z2-amplitude:  3.25e+02
# reduced chi2:  29270.33549189546
# ***************************************************
# Z2-amplitude:  3.73e+01
# reduced chi2:  11567.280949135333
# ***************************************************
# Z2-amplitude:  7.63e+01
# reduced chi2:  14934.359912632817
# ***************************************************
# Z2-amplitude:  1.63e+02
# reduced chi2:  23544.528860549544
# ***************************************************
# Z2-amplitude:  4.10e+02
# reduced chi2:  2141.6729562302985
# ***************************************************
# Z2-amplitude:  4.72e+02
# reduced chi2:  1406.1275452325733
# ***************************************************
# Z2-amplitude:  4.19e+02
# reduced chi2:  2192.370158899123
# ***************************************************
# Z2-amplitude:  4.23e+02
# reduced chi2:  6667.67154713797
# ***************************************************
# Z2-amplitude:  4.23e+02
# reduced chi2:  16872.212563131972
# ***************************************************
# Z2-amplitude:  9.83e+01
# reduced chi2:  7957.320523122175
# ***************************************************
# Z2-amplitude:  2.19e+02
# reduced chi2:  2424.01777990035
# ***************************************************
# Z2-amplitude:  2.47e+02
# reduced chi2:  2732.5371143829125
# ***************************************************
# Z2-amplitude:  2.13e+02
# reduced chi2:  1161.5221181390164
# ***************************************************
# Z2-amplitude:  2.00e+02
# reduced chi2:  1975.0478677156755
# ***************************************************
# Z2-amplitude:  2.07e+02
# reduced chi2:  1707.4588430302344
# ***************************************************
# Z2-amplitude:  2.24e+02
# reduced chi2:  1388.3017859457975
# ***************************************************
# Z2-amplitude:  2.44e+02
# reduced chi2:  2992.910909129134
# ***************************************************
# Z2-amplitude:  2.33e+02
# reduced chi2:  2281.802029373557
# ***************************************************
# Z2-amplitude:  2.07e+02
# reduced chi2:  2590.2521461288065
# ***************************************************
# Z2-amplitude:  2.11e+02
# reduced chi2:  720.592085484291
# ***************************************************
# Z2-amplitude:  2.19e+02
# reduced chi2:  2400.530457935582
# ***************************************************
# Z2-amplitude:  2.12e+02
# reduced chi2:  1584.9384470504506
# ***************************************************
# Z2-amplitude:  2.16e+02
# reduced chi2:  1389.1393970247004
# ***************************************************
# Z2-amplitude:  2.18e+02
# reduced chi2:  2036.8650346752056
# ***************************************************
# Z2-amplitude:  1.89e+02
# reduced chi2:  838.0802503706121
# ***************************************************
# Z2-amplitude:  2.19e+02
# reduced chi2:  3373.8963123253734
# ***************************************************
# Z2-amplitude:  1.99e+02
# reduced chi2:  2894.507937256537
# ***************************************************
# Z2-amplitude:  2.04e+02
# reduced chi2:  2010.7328123454693
# ***************************************************
# Z2-amplitude:  1.93e+02
# reduced chi2:  7846.722117371722
# ***************************************************
# Z2-amplitude:  3.17e+01
# reduced chi2:  18967.22835642298
# ***************************************************
# Z2-amplitude:  7.64e+01
# reduced chi2:  9885.359743440164
# ***************************************************
# Z2-amplitude:  8.98e+00
# reduced chi2:  10862.07777656476
# ***************************************************
# Z2-amplitude:  2.66e+01
# reduced chi2:  15792.189688047332
# ***************************************************
# Z2-amplitude:  1.38e+02
# reduced chi2:  9773.086054068772
# ***************************************************
# Z2-amplitude:  1.23e+02
# reduced chi2:  20798.15921557308
# ***************************************************
# Z2-amplitude:  1.93e+02
# reduced chi2:  1336.93474999126
# ***************************************************
# Z2-amplitude:  2.24e+02
# reduced chi2:  3078.096853915662
# ***************************************************
# Z2-amplitude:  2.19e+02
# reduced chi2:  1028.6223852623452
# ***************************************************
# Z2-amplitude:  2.16e+02
# reduced chi2:  3263.4850247639665
# ***************************************************
# Z2-amplitude:  2.40e+02
# reduced chi2:  1707.1982097956884
# ***************************************************
# Z2-amplitude:  2.28e+02
# reduced chi2:  1531.3959320037188
# ***************************************************
# Z2-amplitude:  2.04e+02
# reduced chi2:  1424.8915416109623
# ***************************************************
# Z2-amplitude:  2.04e+02
# reduced chi2:  3290.6617406801765
# ***************************************************
# Z2-amplitude:  2.24e+02
# reduced chi2:  1315.3460397488084
# ***************************************************
# Z2-amplitude:  1.70e+02
# reduced chi2:  1739.2856299535595
# ***************************************************
# Z2-amplitude:  2.23e+02
# reduced chi2:  1368.613310246383
# ***************************************************
# Z2-amplitude:  2.30e+02
# reduced chi2:  2151.23819070325
# ***************************************************
# Z2-amplitude:  2.05e+02
# reduced chi2:  897.0418188177465
# ***************************************************
# Z2-amplitude:  2.32e+02
# reduced chi2:  1652.0011830291378
# ***************************************************
# Z2-amplitude:  1.91e+02
# reduced chi2:  2388.6367961012356
# ***************************************************
# Z2-amplitude:  2.42e+02
# reduced chi2:  2002.1788055215366
# ***************************************************
# Z2-amplitude:  2.16e+02
# reduced chi2:  1405.828766028986
# ***************************************************
# Z2-amplitude:  2.14e+02
# reduced chi2:  2636.5473172242323
# ***************************************************
# Z2-amplitude:  1.78e+02
# reduced chi2:  2136.6674232708815
# ***************************************************
# Z2-amplitude:  2.10e+02
# reduced chi2:  2247.108755658947
# ***************************************************
# Z2-amplitude:  2.26e+02
# reduced chi2:  2863.1935885915277
# ***************************************************
# Z2-amplitude:  2.36e+02
# reduced chi2:  1550.1162363916526
# ***************************************************
# Z2-amplitude:  2.35e+02
# reduced chi2:  1753.536459121461
# ***************************************************
# Z2-amplitude:  2.28e+02
# reduced chi2:  1961.475208903375
# ***************************************************
# Z2-amplitude:  2.13e+02
# reduced chi2:  1815.1565113358715
# ***************************************************
# Z2-amplitude:  2.22e+02
# reduced chi2:  1677.5675351474822
# ***************************************************
# Z2-amplitude:  2.12e+02
# reduced chi2:  2856.2922148630114
# ***************************************************
# Z2-amplitude:  2.34e+02
# reduced chi2:  1786.1029437184309
# ***************************************************
# Z2-amplitude:  2.25e+02
# reduced chi2:  2157.455477952796
# ***************************************************
# Z2-amplitude:  2.26e+02
# reduced chi2:  1395.6479746735176
# ***************************************************
# Z2-amplitude:  2.41e+02
# reduced chi2:  2215.3734970621686
# ***************************************************
# Z2-amplitude:  1.87e+02
# reduced chi2:  3409.8222017004773
# ***************************************************
# Z2-amplitude:  2.09e+02
# reduced chi2:  1304.8628963605836
# ***************************************************
# Z2-amplitude:  1.85e+02
# reduced chi2:  1362.7273133812969
# ***************************************************
# Z2-amplitude:  2.24e+02
# reduced chi2:  1559.2789307214368
# ***************************************************
# Z2-amplitude:  2.13e+02
# reduced chi2:  1940.1802567479133
# ***************************************************
# Z2-amplitude:  2.35e+02
# reduced chi2:  1530.6884418923592
# ***************************************************
# Z2-amplitude:  2.53e+02
# reduced chi2:  1791.7583944500814
# ***************************************************
# Z2-amplitude:  2.30e+02
# reduced chi2:  1676.03904501706
# ***************************************************
# Z2-amplitude:  2.51e+02
# reduced chi2:  1715.8079527528362
# ***************************************************
# Z2-amplitude:  1.99e+02
# reduced chi2:  1063.822526410296
# ***************************************************
# Z2-amplitude:  2.16e+02
# reduced chi2:  3066.818429762198
# ***************************************************
# Z2-amplitude:  2.22e+02
# reduced chi2:  2708.44834356214
# ***************************************************
# Z2-amplitude:  1.86e+02
# reduced chi2:  1891.605052361155
# ***************************************************
# Z2-amplitude:  2.26e+02
# reduced chi2:  4005.3515210751734
# ***************************************************
# Z2-amplitude:  1.28e+02
# reduced chi2:  1992.8207410194073
# ***************************************************
# Z2-amplitude:  1.44e+02
# reduced chi2:  788.0575469198293
# ***************************************************
# Z2-amplitude:  1.28e+02
# reduced chi2:  1334.0405162523246
# ***************************************************
# Z2-amplitude:  1.54e+02
# reduced chi2:  998.8966064152239
# ***************************************************
# Z2-amplitude:  1.53e+02
# reduced chi2:  1236.3272937156066
# ***************************************************
# Z2-amplitude:  1.14e+02
# reduced chi2:  15102.884444614618
# ***************************************************
# Z2-amplitude:  1.88e+01
# reduced chi2:  27626.52022934963
# ***************************************************
# Z2-amplitude:  8.58e+01
# reduced chi2:  7838.346621880033
# ***************************************************
# Z2-amplitude:  1.44e+02
# reduced chi2:  24296.781439423343
# ***************************************************
# Z2-amplitude:  8.64e+01
# reduced chi2:  5056.7272500472245
# Z2 response (amplitude): 462.33629846773107

# %%
m2 = gfw.build_x_response(bdf_discharge_x, drive_freq=71, charges=1, bandwidth=1)
# Out:
# ***************************************************
# X2-amplitude:  1.22e+01
# reduced chi2:  1.5077204319970472
# ***************************************************
# X2-amplitude:  1.22e+01
# reduced chi2:  1.6561307426139402
# ***************************************************
# X2-amplitude:  1.23e+01
# reduced chi2:  1.2313121190426974
# ***************************************************
# X2-amplitude:  1.22e+01
# reduced chi2:  1.16464891136188
# ***************************************************
# X2-amplitude:  1.21e+01
# reduced chi2:  1.2168587862400966
# ***************************************************
# X2-amplitude:  1.22e+01
# reduced chi2:  1.2696742562620946
# ***************************************************
# X2-amplitude:  1.23e+01
# reduced chi2:  1.458111243801847
# ***************************************************
# X2-amplitude:  1.23e+01
# reduced chi2:  1.2708153177285613
# ***************************************************
# X2-amplitude:  1.22e+01
# reduced chi2:  1.4039743199327412
# ***************************************************
# X2-amplitude:  1.22e+01
# reduced chi2:  1.525153617586847
# ***************************************************
# X2-amplitude:  1.05e+01
# reduced chi2:  1.1440571047175594
# ***************************************************
# X2-amplitude:  1.06e+01
# reduced chi2:  1.0885389056712558
# ***************************************************
# X2-amplitude:  1.06e+01
# reduced chi2:  1.1312604841331202
# ***************************************************
# X2-amplitude:  1.05e+01
# reduced chi2:  1.0305679507332144
# ***************************************************
# X2-amplitude:  1.06e+01
# reduced chi2:  1.0463703053093947
# ***************************************************
# X2-amplitude:  9.79e+00
# reduced chi2:  1.1066244231737932
# ***************************************************
# X2-amplitude:  9.89e+00
# reduced chi2:  0.991855957822837
# ***************************************************
# X2-amplitude:  9.67e+00
# reduced chi2:  0.8249699573624505
# ***************************************************
# X2-amplitude:  9.81e+00
# reduced chi2:  0.8997933628614184
# ***************************************************
# X2-amplitude:  9.82e+00
# reduced chi2:  0.7946482834113322
# ***************************************************
# X2-amplitude:  8.98e+00
# reduced chi2:  0.6979381108004898
# ***************************************************
# X2-amplitude:  8.95e+00
# reduced chi2:  0.8787075812821716
# ***************************************************
# X2-amplitude:  8.98e+00
# reduced chi2:  0.7789841208103151
# ***************************************************
# X2-amplitude:  8.99e+00
# reduced chi2:  0.7458294886179487
# ***************************************************
# X2-amplitude:  9.05e+00
# reduced chi2:  0.8447501749664127
# ***************************************************
# X2-amplitude:  7.40e+00
# reduced chi2:  0.6888437668593086
# ***************************************************
# X2-amplitude:  8.41e+00
# reduced chi2:  4.245718914590765
# ***************************************************
# X2-amplitude:  8.62e+00
# reduced chi2:  7.217641459553545
# ***************************************************
# X2-amplitude:  1.03e+01
# reduced chi2:  7.707717731868036
# ***************************************************
# X2-amplitude:  9.81e+00
# reduced chi2:  5.6213547462964435
# ***************************************************
# X2-amplitude:  6.25e+00
# reduced chi2:  9.105328092590772
# ***************************************************
# X2-amplitude:  4.15e+00
# reduced chi2:  5.228968311989376
# ***************************************************
# X2-amplitude:  4.08e+00
# reduced chi2:  4.844161228256838
# ***************************************************
# X2-amplitude:  5.37e+00
# reduced chi2:  5.457173659312002
# ***************************************************
# X2-amplitude:  7.68e+00
# reduced chi2:  6.655676928320853
# ***************************************************
# X2-amplitude:  4.12e+00
# reduced chi2:  0.18168338031953185
# ***************************************************
# X2-amplitude:  3.96e+00
# reduced chi2:  0.16046803425845296
# ***************************************************
# X2-amplitude:  4.07e+00
# reduced chi2:  0.14099870734455905
# ***************************************************
# X2-amplitude:  4.02e+00
# reduced chi2:  0.16253243223357014
# ***************************************************
# X2-amplitude:  4.09e+00
# reduced chi2:  0.20479892073392297
# ***************************************************
# X2-amplitude:  3.23e+00
# reduced chi2:  0.12261381785794696
# ***************************************************
# X2-amplitude:  3.33e+00
# reduced chi2:  0.1825885671412315
# ***************************************************
# X2-amplitude:  3.31e+00
# reduced chi2:  0.10920698546546513
# ***************************************************
# X2-amplitude:  3.25e+00
# reduced chi2:  0.11260675099045096
# ***************************************************
# X2-amplitude:  3.24e+00
# reduced chi2:  0.15114936016803948
# ***************************************************
# X2-amplitude:  2.60e+00
# reduced chi2:  0.1315684419225276
# ***************************************************
# X2-amplitude:  2.44e+00
# reduced chi2:  0.10903317055976645
# ***************************************************
# X2-amplitude:  2.38e+00
# reduced chi2:  0.0583381296566374
# ***************************************************
# X2-amplitude:  2.52e+00
# reduced chi2:  0.07532079771701763
# ***************************************************
# X2-amplitude:  2.35e+00
# reduced chi2:  0.11893229265281859
# ***************************************************
# X2-amplitude:  3.49e+00
# reduced chi2:  11.812108861040088
# ***************************************************
# X2-amplitude:  4.97e+00
# reduced chi2:  8.454997820515338
# ***************************************************
# X2-amplitude:  3.40e+00
# reduced chi2:  5.049772340032564
# ***************************************************
# X2-amplitude:  6.76e+00
# reduced chi2:  6.079543094675299
# ***************************************************
# X2-amplitude:  5.71e+00
# reduced chi2:  16.53178911071402
# ***************************************************
# X2-amplitude:  2.50e+00
# reduced chi2:  0.10765460729612583
# ***************************************************
# X2-amplitude:  2.54e+00
# reduced chi2:  0.12381333989639369
# ***************************************************
# X2-amplitude:  2.44e+00
# reduced chi2:  0.09600796700160451
# ***************************************************
# X2-amplitude:  2.49e+00
# reduced chi2:  0.08797950691188987
# ***************************************************
# X2-amplitude:  2.35e+00
# reduced chi2:  0.06589940511427257
# ***************************************************
# X2-amplitude:  1.40e+00
# reduced chi2:  0.20551986836510008
# ***************************************************
# X2-amplitude:  1.52e+00
# reduced chi2:  1.5312793979725436
# ***************************************************
# X2-amplitude:  4.78e+00
# reduced chi2:  8.681514336026593
# ***************************************************
# X2-amplitude:  3.08e+00
# reduced chi2:  5.973730135215721
# ***************************************************
# X2-amplitude:  2.37e+00
# reduced chi2:  5.677498909234125
# X3 to X2 ratio: 0.21
# X2 response (amplitude): -6.763877258009717
# X2 response (amplitude): -6.763877258009717

# %%
dis_x = [np.std(bb.response_at_freq('x', drive_freq=71)) for bb in bdf_discharge_x]
dis_z = [np.std(bb.response_at_freq2('z', drive_freq=71)) for bb in bdf_discharge_z]

# %%
ampsx = np.array([m_.values[0] for m_ in m2])
phasesx = np.array([m_.values[2] for m_ in m2])
_, ax = plt.subplots(1,2,figsize=(9.1,4))
ax[0].scatter(range(len(ampsx)), ampsx)
ax[1].scatter(range(len(ampsx)), phasesx)
np.mean(phases[20:50])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3.1700000000000004

# %%
_,ax = plt.subplots(figsize=(9.5,4))
scale = 74
scale2 = 50
scaleX = -0.8
scaleX2 = 9200

# Perrinf
# ax.scatter(index_z, amps/scale, label='fit fixed-phase')
ax.scatter(index_z, np.array(dis_z)/scale2, label='Z response')
# ax.scatter(index_x, ampsx/scaleX, label='X response')
ax.scatter(index_x, np.array(dis_x)/scaleX2, label='X-pos fit fixed-phases')

ax.legend()
ax.set(xlabel='dataset', ylabel='Charges', ylim=(None,None), xlim=(None,None))
ax.grid(axis='y')
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.legend()
from matplotlib.ticker import MaxNLocator
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## TF

# %%
# 7.6um German bead
fname = r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFuncX2_1Hz_300s.h5'
tf_x = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFuncY1_1Hz_100s.h5'
tf_y = BeadDataFile.BeadDataFile(fname=fname)
fname = r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFuncZ2_1Hz_300s.h5'
tf_z = BeadDataFile.BeadDataFile(fname=fname)
tf_list = [tf_x, tf_y, tf_z]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
_,ax = plt.subplots(1,3, figsize=(9,3))
bb = tf_z
ax[0].semilogy(*bb.psd2('x'))
ax[1].semilogy(*bb.psd2('y'))
ax[2].semilogy(*bb.psd2('z'))
[a.set(xlim=(0,100)) for a in ax]
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [[(0.0, 100.0)], [(0.0, 100.0)], [(0.0, 100.0)]]

# %%
names = ['Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8', 'Y9']
names = ['Y7', 'Y8', 'Y9', 'Y11']
fnames = [r'/home/data_transfer/data_from_windows/20200921/Bead1/TransFunc/TransFunc'+y_+'_7Hz_10s.h5' for y_ in names]
bbs = [BeadDataFile.BeadDataFile(fname_) for fname_ in fnames]
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
_,ax = plt.subplots()
[ax.semilogy(*bb.psd2('y'), label=name_) for bb,name_ in zip(bbs,names)]
ax.legend()
ax.set(xlim=(100,1000))
tmp_freq, tmp_psd = bbs[-1].psd2('x')
np.sqrt(tmp_psd[tmp_freq==71]/tmp_psd[tmp_freq==50])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# array([2.06282349])

# %% [markdown]
# ## Nois floor

# %%
bdf_z = bdf_discharge[245:260]
bdf_x = bdf_discharge[240:245]

freq = bdf_z[0].psd2('z')[0]
z_scale1 = bdf_z[0].psd2('z')[1][freq==71]
for bb in bdf_z:
    z_scale1 += bb.psd2('z')[1][freq==71]
z_scale1 /= len(bdf_z)

x_scale1 = bdf_x[0].psd2('x')[1][freq==71]
for bb in bdf_x:
    x_scale1 += bb.psd2('x')[1][freq==71]
x_scale1 /= len(bdf_x)

charges = 4
force = charges * 1.6e-19 * 20 / 8.6e-3 * 0.63 * np.sqrt(10) # in Newtons/sqrt(Hz)
z_scale1 = force/np.sqrt(z_scale1)
x_scale1 = force/np.sqrt(x_scale1)

# %%
del data_bdfs

# %%
## 100 files of shaking data for nose floor
num_files = 500
data_bdfs = load_dir(dirname='/data/new_trap/20200921/Bead1/Discharge/HeightControl2/', 
                         file_prefix='Discharge_', start_file=500, max_file=num_files)
freq = data_bdfs[0].psd2('x')[0]
fftx1 = data_bdfs[0].psd2('x')[1]
ffty1 = data_bdfs[0].psd2('y')[1]

fftz1 = data_bdfs[0].psd2('z')[1]
for i in range(1,num_files):
    fftx1 += data_bdfs[i].psd2('x')[1]
    fftz1 += data_bdfs[i].psd2('z')[1]
    ffty1 += data_bdfs[i].psd2('y')[1]
fftx1/=num_files
ffty1/=num_files
fftz1/=num_files
# Out:
# 1308  files in folder
# 500  files loaded

# %%
_,ax = plt.subplots(1,2,figsize=(9.1,4), sharex=True)
# tf_freq = np.interp(freq, gfw.tf_freq, gfw.tf_ffts[2])
ax[0].semilogy(freq, np.sqrt(fftx1)*x_scale1)
ax[1].semilogy(freq, np.sqrt(fftz1)*z_scale1)
ax[0].set(xlim=(1,500), ylim=(9e-18,1e-14), xlabel='Frequency [Hz.]', ylabel=r'ASD [N/$\sqrt{Hz}$]', title='X force')
_ = ax[1].set(xlim=(1,500), ylim=(9e-18,1e-14), xlabel='Frequency [Hz.]', title=r'Z force')
# print(np.sqrt(fftx1[freq==18])*x_scale/np.sqrt(10), np.sqrt(fftz1[freq==18])*z_scale/np.sqrt(10))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mm_mle_scale
# Out:
# array([5.25, 5.21, 5.17, 5.19, 5.18, 5.2 , 5.25, 5.22, 5.17, 5.23, 5.22,
#        5.28, 5.3 , 5.29, 5.25, 5.26, 5.21, 5.24, 5.23, 5.24, 5.22, 5.15,
#        5.22, 5.23, 5.24, 5.14, 5.11, 5.03, 5.09, 5.17, 5.16, 5.21, 5.24,
#        5.19, 5.09, 5.14, 5.12, 5.17, 5.22, 5.18, 5.2 , 5.21, 5.2 , 5.17,
#        5.16, 5.28, 5.26, 5.14, 5.22, 5.16, 5.18, 5.16, 5.19, 5.26, 5.23,
#        5.22, 5.15, 5.02, 5.2 , 5.01, 5.09, 5.09, 5.16, 5.06, 5.13, 5.09,
#        5.14, 5.08, 5.13, 5.2 , 5.09, 5.09, 5.09, 5.08, 5.09, 5.22, 5.19,
#        5.11, 5.06, 5.16, 5.17, 5.13, 5.1 , 5.12, 5.05, 5.2 , 5.14, 5.1 ,
#        5.1 , 5.  , 5.06, 5.15, 5.12, 5.13, 5.16, 5.13, 5.2 , 5.22, 5.07,
#        5.14])

# %%
def func1_height(i):
    print(i,'  ******************')
    fname = r'/data/new_trap/20200921/Bead1/Discharge/HeightControl2/Discharge_'+str(i)+'.h5'
    bb = BeadDataFile.BeadDataFile(fname=fname)
    return np.mean(bb.feedback[2])

# %%
func1_height(10)
# Out:
# 10   ******************
# 5.22

# %%
from joblib import Parallel, delayed
from tqdm import tqdm
test1_zfb = Parallel(n_jobs=20)(delayed(func1_height)(i) for i in tqdm(range(1700)))
# Out:
#   0%|          | 0/1700 [00:00<?, ?it/s]
#   1%|          | 20/1700 [00:00<00:15, 105.39it/s]
#   2%|▏         | 40/1700 [00:01<00:31, 52.40it/s]
#   4%|▎         | 60/1700 [00:01<00:38, 42.98it/s]
#   5%|▍         | 80/1700 [00:02<00:39, 41.43it/s]
#   6%|▌         | 100/1700 [00:02<00:35, 45.34it/s]
#   7%|▋         | 120/1700 [00:02<00:32, 48.05it/s]
#   8%|▊         | 140/1700 [00:03<00:31, 49.81it/s]
#   9%|▉         | 160/1700 [00:03<00:30, 50.37it/s]
#  11%|█         | 180/1700 [00:04<00:29, 51.80it/s]
#  12%|█▏        | 200/1700 [00:04<00:30, 49.28it/s]
#  13%|█▎        | 220/1700 [00:04<00:31, 46.38it/s]
#  14%|█▍        | 240/1700 [00:05<00:29, 48.71it/s]
#  15%|█▌        | 260/1700 [00:05<00:30, 47.66it/s]
#  16%|█▋        | 280/1700 [00:06<00:30, 46.16it/s]
#  18%|█▊        | 300/1700 [00:06<00:29, 47.36it/s]
#  19%|█▉        | 320/1700 [00:07<00:29, 46.61it/s]
#  20%|██        | 340/1700 [00:07<00:28, 48.48it/s]
#  21%|██        | 360/1700 [00:07<00:28, 46.35it/s]
#  74%|███████▍  | 1260/1700 [00:32<00:07, 56.10it/s]
#  75%|███████▌  | 1280/1700 [00:32<00:06, 62.06it/s]
#  76%|███████▋  | 1300/1700 [00:33<00:06, 62.47it/s]
#  78%|███████▊  | 1320/1700 [00:33<00:06, 54.65it/s]
#  79%|███████▉  | 1340/1700 [00:34<00:07, 46.95it/s]
#  80%|████████  | 1360/1700 [00:34<00:06, 48.81it/s]
#  81%|████████  | 1380/1700 [00:34<00:06, 51.29it/s]
#  82%|████████▏ | 1400/1700 [00:35<00:05, 54.58it/s]
#  84%|████████▎ | 1420/1700 [00:35<00:04, 60.70it/s]
#  85%|████████▍ | 1440/1700 [00:35<00:04, 63.20it/s]
#  86%|████████▌ | 1460/1700 [00:35<00:03, 64.90it/s]
#  87%|████████▋ | 1480/1700 [00:36<00:03, 57.39it/s]
#  88%|████████▊ | 1500/1700 [00:36<00:03, 57.21it/s]
#  89%|████████▉ | 1520/1700 [00:37<00:03, 53.88it/s]
#  91%|█████████ | 1540/1700 [00:37<00:03, 50.35it/s]
#  92%|█████████▏| 1560/1700 [00:38<00:02, 51.74it/s]
#  93%|█████████▎| 1580/1700 [00:38<00:02, 48.72it/s]
#  94%|█████████▍| 1600/1700 [00:38<00:01, 51.02it/s]
#  95%|█████████▌| 1620/1700 [00:39<00:01, 53.03it/s]
#  96%|█████████▋| 1640/1700 [00:39<00:00, 62.40it/s]
#  98%|█████████▊| 1660/1700 [00:41<00:01, 25.03it/s]
#  99%|█████████▉| 1680/1700 [00:41<00:00, 28.00it/s]
# 100%|██████████| 1700/1700 [00:42<00:00, 31.32it/s]

# %%
_,ax = plt.subplots(figsize=(9.2,4))
ax.scatter(range(1700), test1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
i = 1400
fname = r'/data/new_trap/20200921/Bead1/Discharge/HeightControl2/Discharge_'+str(i)+'.h5'
bb = BeadDataFile.BeadDataFile(fname=fname)

# %%
f = h5py.File(fname,'r')
pos_data = np.array(f['pos_data'])
quad_data = np.array(f['quad_data'])

# %%
sync = pos_data.reshape(-1,11).T[5]

# %%
_,ax = plt.subplots(figsize=(9.5,4))
ax.plot(range(500), sync[:500]/100)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
i_start = np.nonzero(sync[:500])[0][0]
zfb = bb.feedback[2][i_start-1:]
x_sync = bb.xyz[0][i_start-1:]

# %%
_,ax = plt.subplots(figsize=(9.2,4))
ax.plot(range(40000), zfb[100000:140000]/np.mean(zfb[:40000]), label='z_fb')
ax.plot(range(40000), bb.z2[100000:140000]/np.mean(bb.z2[:40000])*50-49, 'r--',label='z', alpha=(0.5))
ax.plot(range(40000), bb.Iz[100000:140000]/np.mean(bb.Iz[:40000])*50-49,label='Iz', alpha=(0.5))
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
_,ax = plt.subplots(figsize=(9.2,4))
# ax.plot(range(40000), x_sync[:40000]/np.mean(x_sync[:40000]), label='z_fb')
ax.plot(range(40000), bb.z2[100000:140000]/np.mean(bb.z2[:40000]), 'r--',label='Iz', alpha=(0.5))
ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
