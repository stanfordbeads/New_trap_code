# %%
##this is derived from Signal_Model_Usage_Example_20191127.ipynb

# %%
import numpy as np
import pickle as pkl
import scipy.interpolate as interp
import scipy, sys, time
from bisect import bisect_left
import matplotlib.pyplot as plt
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile
from discharge_tools import load_dir
sys.path.append('/home/analysis_user/New_trap_code/SensitivityFramework/')
from signal_model_utilities_v3 import *

# %%
#for z force, 3/20 Bead1, Shaking378_3
for i in range(0,70):
    L=pow(10,i/30.0-0.3)
    D=10.39+3.8 #this becomes14.19
    H=-15.7
    Fshake=3
    test = force_vs_time(D,H,200,Fshake,"z",L,yuk_or_grav="yuk",alpha=1e10,offset_y=4.9,bead_size=7.6)
    ofname = "/data/new_trap/Results/AkioK/2020_11_18_Analysis0320Bead1/SignalZD%dumH%dumL%.02f.txt" % (D,H,L)
    
    
    fsamp=5000
    res=50000

    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    
    f1 = open(ofname,"a")
    
    for i in range(1,101):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
     
        SigAmpX=IntNSDs
        SigPhaX=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, 0,0, SigPhaX, 0,0))
    f1.close()
# Out:
# Loading Gravity Data... Done!
# 133 4.98098732095e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 132 5.27409138981e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 130 5.91305720499e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 129 6.2610085276e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 128 6.62943489699e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 126 7.43260305622e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 125 7.86997140463e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 124 8.33307650647e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 122 9.34264396168e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 121 9.89240785038e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 119 1.1090891149e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 118 1.17435298959e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 117 1.24345728906e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 115 1.39410441321e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 114 1.47613989124e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 113 1.56300271189e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 111 1.75236334828e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 110 1.85548042014e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 109 1.964665372e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 107 2.20268817407e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 106 2.33230441773e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 105 2.46954787382e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 103 2.76873811412e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 102 2.93166332444e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 101 3.10417579909e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 99 3.48025237292e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 98 3.68504633553e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 97 3.9018913113e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 95 4.374612578e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 94 4.63203478442e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 93 4.9046048905e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 91 5.49880674071e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 90 5.82238167189e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 89 6.16499723153e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 87 6.91189791839e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 86 7.31862559564e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 85 7.74928698912e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 83 8.68812727689e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 82 9.19937641116e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 81 9.74070978211e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 79 1.09208145824e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 78 1.15634452464e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 77 1.2243891237e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 75 1.37272610475e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 74 1.45350358536e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 72 1.62959820236e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 71 1.7254912117e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 70 1.82702700418e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 68 2.04837466632e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 67 2.16891039761e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 66 2.29653900246e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 64 2.57476890167e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 63 2.72628007663e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 62 2.88670686189e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 60 3.23643667635e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 59 3.42688340856e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 58 3.62853689728e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 56 4.06814077692e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 55 4.30752878126e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 54 4.56100347035e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 52 5.11357738026e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 51 5.41448365446e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 50 5.7330966297e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 48 6.42767176895e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 47 6.8059053655e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 46 7.2063959563e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 44 8.0794640028e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 43 8.554896607e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 42 9.05830583947e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 40 0.000101557361544
# Loaded Yukawa Force

# %%
##above one looks to be wrong. with correct parameter;
#for z force, 3/20 Bead1, Shaking378_3
for i in range(0,70):
    L=pow(10,i/30.0-0.3)
    D=13.9#10.39+3.8 #this becomes14.19
    H=-15.23#-15.7
    Fshake=3
    test = force_vs_time(D,H,-202,Fshake,"z",L,yuk_or_grav="yuk",alpha=1e10,offset_y=4.9,bead_size=7.6)
    ofname = "/data/new_trap/Results/AkioK/2020_11_18_Analysis0320Bead1/SignalZD%dumH%dumL%.02fBugFixed.txt" % (D,H,L)
    
    
    fsamp=5000
    res=50000

    norm = np.sqrt(2 / (res* fsamp))

    s = np.arange(0, 5, 0.0001)
    for i in range(0,10):
        for j in range(0,5000):
            s[j+i*5000]=test[1][j]
    
    sFFT=np.fft.rfft(s)
    spsd = (sFFT * sFFT.conj()).real
    spsd = norm**2 * (sFFT * sFFT.conj()).real
    snsd=np.sqrt(spsd)
    
    f1 = open(ofname,"a")
    
    for i in range(1,101):
        Ints=sFFT[Fshake*10*i]
        IntNSDs=snsd[Fshake*10*i]
     
        SigAmpX=IntNSDs
        SigPhaX=np.angle(Ints)         
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, 0,0, SigPhaX, 0,0))
    f1.close()
# Out:
# Loading Gravity Data... Done!
# 133 4.98098732095e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 132 5.27409138981e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 130 5.91305720499e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 129 6.2610085276e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 128 6.62943489699e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 126 7.43260305622e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 125 7.86997140463e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 124 8.33307650647e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 122 9.34264396168e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 121 9.89240785038e-07
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 119 1.1090891149e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 118 1.17435298959e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 117 1.24345728906e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 115 1.39410441321e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 114 1.47613989124e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 113 1.56300271189e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 111 1.75236334828e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 110 1.85548042014e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 109 1.964665372e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 107 2.20268817407e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 106 2.33230441773e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 105 2.46954787382e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 103 2.76873811412e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 102 2.93166332444e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 101 3.10417579909e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 99 3.48025237292e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 98 3.68504633553e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 97 3.9018913113e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 95 4.374612578e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 94 4.63203478442e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 93 4.9046048905e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 91 5.49880674071e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 90 5.82238167189e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 89 6.16499723153e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 87 6.91189791839e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 86 7.31862559564e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 85 7.74928698912e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 83 8.68812727689e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 82 9.19937641116e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 81 9.74070978211e-06
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 79 1.09208145824e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 78 1.15634452464e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 77 1.2243891237e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 75 1.37272610475e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 74 1.45350358536e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 72 1.62959820236e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 71 1.7254912117e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 70 1.82702700418e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 68 2.04837466632e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 67 2.16891039761e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 66 2.29653900246e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 64 2.57476890167e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 63 2.72628007663e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 62 2.88670686189e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 60 3.23643667635e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 59 3.42688340856e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 58 3.62853689728e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 56 4.06814077692e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 55 4.30752878126e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 54 4.56100347035e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 52 5.11357738026e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 51 5.41448365446e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 50 5.7330966297e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 48 6.42767176895e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 47 6.8059053655e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 46 7.2063959563e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 44 8.0794640028e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 43 8.554896607e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 42 9.05830583947e-05
# Loaded Yukawa Force
# Loading Gravity Data... Done!
# 40 0.000101557361544
# Loaded Yukawa Force
