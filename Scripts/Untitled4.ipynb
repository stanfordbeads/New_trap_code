# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
fil = h5py.File('/home/data_transfer/data_from_windows/20220911/junk/BeamProfilingY_0.h5','r')

# %%
x = fil['cant_data'][0,:]
y = fil['cant_data'][1,:]
z = fil['cant_data'][2,:]

# %%
plt.plot(x)
plt.plot(y)
