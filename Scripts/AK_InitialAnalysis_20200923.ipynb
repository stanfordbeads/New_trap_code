# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import mlab

from scipy import signal
import h5py, time

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile

# %%
Year = "2020"
Month = "09"
Day = "24"
BeadNumber =1
folder = r"/home/data_transfer/data_from_windows/"+ Year + Month + Day

# %%
##Initial Test

# %%
Ndata=35
fname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata

BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz
fsamp=5000
res=5000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)


_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs, xpsd, '.-', label="x",markersize=1,linewidth=1)
ax.loglog(freqs, ypsd, '.-', label="y*1",markersize=1,linewidth=1)
ax.loglog(freqs, zpsd*10000, '.-', label="z*100",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('PSD [a.u.]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
plt.ylim(1e4,1e12)
plt.grid(True)

ofname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.png" % Ndata

plt.savefig(ofname,dpi=300)
# Out:
# No height data
# No electrodes data
# No cantilever data
# No laser power data
# <img src="data:image/png;base64,..." width="640">

# %%
##code for plotting two graphs at the same time.

# %%
Ndata1=20
Ndata2=22
fname1 = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata1
#fname1 = r"/home/data_transfer/data_from_windows/20190828/Bead1/Discharge/Discharge_%d.h5" % Ndata1
BDF1= BeadDataFile.BeadDataFile(fname1)
data1 = BDF1.xyz
#res = 2**12
res=5000
data_det1=signal.detrend(data1)
xpsd1, freqs1 = matplotlib.mlab.psd(data_det1[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd1, freqs1 = matplotlib.mlab.psd(data_det1[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd1, freqs1 = matplotlib.mlab.psd(data_det1[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
#xfnsd1=np.sqrt(xpsd1)*2.86e-21
#yfnsd1=np.sqrt(ypsd1)*1.93e-21
#zfnsd1=np.sqrt(zpsd1)*2.93e-18
# Out:
# No height data
# No electrodes data
# No cantilever data
# No laser power data

# %%
fname2 = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata2
#fname2 = r"/home/data_transfer/data_from_windows/20190828/Bead1/Discharge/Discharge_%d.h5" % Ndata2
BDF2= BeadDataFile.BeadDataFile(fname2)
data2 = BDF2.xyz
data_det2=signal.detrend(data2)
xpsd2, freqs2 = matplotlib.mlab.psd(data_det2[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd2, freqs2 = matplotlib.mlab.psd(data_det2[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd2, freqs2 = matplotlib.mlab.psd(data_det2[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
#xfnsd2=np.sqrt(xpsd2)*2.86e-21
#yfnsd2=np.sqrt(ypsd2)*1.93e-21
#zfnsd2=np.sqrt(zpsd2)*2.93e-18
# Out:
# No height data
# No electrodes data
# No cantilever data
# No laser power data

# %%
_,ax = plt.subplots()
label1='Data%d,x' % Ndata1
label2='Data%d,x' % Ndata2
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs1, xpsd1, '.-', label=label1,markersize=2,linewidth=1)
ax.loglog(freqs2, xpsd2, '.-', label=label2,markersize=2,linewidth=1,alpha=0.5)

ax.legend()
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
#plt.ylim(1e-18,1e-15)
plt.grid(True)
ofname='../../Results/AkioK/PlotDataX%d_%d.png' %(Ndata1, Ndata2)
#plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_,ax = plt.subplots()
label1='Data%d,y' % Ndata1
label2='Data%d,y' % Ndata2
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs1, ypsd1, '.-', label=label1,markersize=2,linewidth=1)
ax.loglog(freqs2, ypsd2, '.-', label=label2,markersize=2,linewidth=1,alpha=0.5)

ax.legend()
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
#plt.ylim(1e-18,1e-15)
plt.grid(True)
ofname='../../Results/AkioK/PlotDataY%d_%d.png' %(Ndata1, Ndata2)
#plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_,ax = plt.subplots()
label1='Data%d,z' % Ndata1
label2='Data%d,z' % Ndata2
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs1, zfnsd1, '.-', label=label1,markersize=2,linewidth=1)
ax.loglog(freqs2, zfnsd2, '.-', label=label2,markersize=2,linewidth=1,alpha=0.5)

ax.legend()
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
plt.ylim(1e-18,1e-14)
plt.grid(True)
ofname='../../Results/AkioK/PlotDataZ%d_%d.png' %(Ndata1, Ndata2)
plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##getting the spinning data

# %%
Compare_File_1 = 57
Compare_File_2 = 58

fname_1 = folder+"/Bead"+str(BeadNumber)+"/initialTest"+"/Data%d.h5" %Compare_File_1
fname_2 = folder+"/Bead"+str(BeadNumber)+"/initialTest"+"/Data%d.h5" %Compare_File_2

BDF = BeadDataFile.BeadDataFile(fname_1)
data1 = BDF.xyz2
fsamp = 5000
fsampspin=200000
res = 5000
data_det1=signal.detrend(data1)
xpsd1, freqs1 = matplotlib.mlab.psd(data_det1[0], Fs = fsamp, NFFT = res)
ypsd1, freqs1 = matplotlib.mlab.psd(data_det1[1], Fs = fsamp, NFFT = res)
zpsd1, freqs1 = matplotlib.mlab.psd(data_det1[2], Fs = fsamp, NFFT = res)
spsd1, freqs1_s = matplotlib.mlab.psd(BDF.spin_data, Fs = fsampspin, NFFT = fsampspin)

BDF = BeadDataFile.BeadDataFile(fname_2)
data2 = BDF.xyz2
data_det2=signal.detrend(data2)
xpsd2, freqs2 = matplotlib.mlab.psd(data_det2[0], Fs = fsamp, NFFT = res)
ypsd2, freqs2 = matplotlib.mlab.psd(data_det2[1], Fs = fsamp, NFFT = res)
zpsd2, freqs2 = matplotlib.mlab.psd(data_det2[2], Fs = fsamp, NFFT = res)
spsd2, freqs2_s = matplotlib.mlab.psd(BDF.spin_data, Fs = fsampspin, NFFT = fsampspin)


_,ax = plt.subplots()
label1='Data%d,spin' % Compare_File_1
label2='Data%d,spin' % Compare_File_2
ax.semilogy(freqs1_s, np.sqrt(spsd1), '.-',markersize=2,linewidth=1)
ax.semilogy(freqs2_s, np.sqrt(spsd2), '.-',markersize=2,linewidth=1,alpha=0.5)

ax.legend()
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('PSD [a.u.]')
ax.set_title('spin')
plt.grid(True)
plt.ylim(5e-7,1e-3)
plt.xlim(0,100000)
#plt.savefig("Temporary_Plots/spin_com_wilson_spin_20200324.png",dpi=300,bbox_inches="tight")
# Out:
# No height data
# No electrodes data
# No cantilever data
# No laser power data
# No height data
# No electrodes data
# No cantilever data
# No laser power data
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# (0.0, 100000.0)

# %%
##Get the power data

# %%
BDF.

# %%
Ndata=0
fname = folder+"/NoBead"+"/Discharge"+"/Discharge_%d.h5" % Ndata

bb = BeadDataFile.BeadDataFile(fname=fname)
#bb.Iz
bb.electrode_data
# Out:
# array([[ 0.00217064,  0.01468204,  0.0274141 , ..., -0.02389371,
#         -0.01141152, -0.00422755],
#        [-0.00981039, -0.02225905, -0.03472426, ...,  0.01632158,
#          0.00381117, -0.00421028]])

# %%
for i in range(0,15):
    Ndata=i
    fname = folder+"/NoBead"+"/Discharge"+"/Discharge_%d.h5" % Ndata
    f = h5py.File(fname,'r')
    power=np.array(f['laser_power'])
    power2=power[10000:49999]
    print(np.average(power2))
# Out:
# -980981.6067151679
# -802597.9648491212
# -541426.7142678567
# -341514.3004075102
# -213465.61016525413
# -135308.39283482087
# -87431.69091727294
# -57168.25378134453
# -70796.34178354459
# -108995.71284282107
# -170006.8790719768
# -270618.42503562587
# -430946.7631690792
# -664825.3300332509
# -904177.96359909

# %%
np.average(power2)
# Out:
# -980981.6067151679

# %%
#millicharge

# %%
Ndata=1
fname = folder+"/Bead"+str(BeadNumber)+"/Millicharge/200VRandom"+"/Discharge_%d.h5" % Ndata

BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
fsamp=5000
res=10000
res=50000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
xfnsd=np.sqrt(xpsd)*2.2e-12
yfnsd=np.sqrt(ypsd)*2.33e-12
zfnsd=np.sqrt(zpsd)*7.04e-19

_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.semilogy(freqs, xfnsd, '.-', label="x",markersize=1,linewidth=1)
ax.semilogy(freqs, yfnsd, '.-', label="y*1",markersize=1,linewidth=1)
ax.semilogy(freqs, zfnsd, '.-', label="z*1",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0,200)
plt.ylim(1e-18,10e-14)
plt.grid(True)

ofname = folder+"/Bead"+str(BeadNumber)+"/Discharge"+"/Discharge_%d.png" % Ndata

#plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##raw data
Ndata=10
fname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata

BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
fsamp=5000
res=50000
#data_det=signal.detrend(data)
time=np.arange(0,50000)/5000

xfnsd=np.sqrt(xpsd)*2.2e-12
yfnsd=np.sqrt(ypsd)*2.33e-12
zfnsd=np.sqrt(zpsd)*7.04e-19

_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)

ax.plot(time,data_det[2], '.-', label="x",markersize=1,linewidth=1)

ax.legend(fontsize=16)
ax.set_xlabel('Time', fontsize=18)
ax.set_ylabel('Force au',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(1,2500)
#plt.ylim(1e-18,1e-15)
plt.grid(True)

ofname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.png" % Ndata

#plt.savefig(ofname,dpi=300)
# Out:
# No height data
# No electrodes data
# No cantilever data
# No laser power data
# <img src="data:image/png;base64,..." width="640">

# %%
time=np.arange(0,50000)/5000
print(time)
# Out:
# [0.0000e+00 2.0000e-04 4.0000e-04 ... 9.9994e+00 9.9996e+00 9.9998e+00]

# %%
Ndata=5
fname = folder+"/Bead"+str(BeadNumber)+"/Discharge"+"/Discharge_%d.h5" % Ndata
#fname = folder+"/NoBead"+"/Discharge_%d.h5" % Ndata
print(fname)

BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz
fsamp=5000
res=10000
res=50000
#data_det=signal.detrend(data)

#xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
#ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
#zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
#xfnsd=np.sqrt(xpsd)*2.2e-12
#yfnsd=np.sqrt(ypsd)*2.33e-12
#zfnsd=np.sqrt(zpsd)*7.04e-19
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)


ax.plot((BDF.Iz+100000)/10, '.-', label="Iz",markersize=1,linewidth=1)
ax.plot((data[2]+3e5)/500, '.-', label="Z position",markersize=1,linewidth=1)
ax.plot(BDF.feedback[2], '.-', label="z feedback",markersize=1,linewidth=1)

ax.legend(fontsize=16)
ax.set_xlabel('Time', fontsize=18)
ax.set_ylabel('au',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0,10000)
plt.ylim(-5e3,5e3)
plt.grid(True)
# Out:
# /home/data_transfer/data_from_windows/20200729/Bead1/Discharge/Discharge_5.h5
# <img src="data:image/png;base64,..." width="640">

# %%
IzRev=BDF.Iz[1023:49999]


_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.plot((IzRev+100000)/10, '.-', label="Iz",markersize=1,linewidth=1)
ax.plot((data[2]+3e5)/500, '.-', label="xyz[2]",markersize=1,linewidth=1)
ax.plot(BDF.feedback[2], '.-', label="feedback[2]",markersize=1,linewidth=1)

ax.legend(fontsize=16)
ax.set_xlabel('Time', fontsize=18)
ax.set_ylabel('au',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0,10000)
plt.ylim(-5e3,5e3)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Neutrality of Matter
Ndata=4124
Fshake=71
Fspin=50
Vx=50

#subfolder="%dHz%dV%dkHzSpin" % (Fshake,Vx,Fspin)
subfolder="%dHz%dVNoSpin2" % (Fshake,Vx)

fname = folder+"/Bead"+str(BeadNumber)+"/NeutralityOnY/"+subfolder+"/Discharge_%d.h5" % Ndata
print(fname)

BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
fsamp=5000
res=10000
res=50000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
xfnsd=np.sqrt(xpsd)*2.2e-12
yfnsd=np.sqrt(ypsd)*2.33e-12
zfnsd=np.sqrt(zpsd)*7.04e-19

_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.semilogy(freqs, xfnsd, '.-', label="x",markersize=1,linewidth=1)
ax.semilogy(freqs, yfnsd, '.-', label="y*1",markersize=1,linewidth=1)
ax.semilogy(freqs, zfnsd, '.-', label="z*1",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0,100)
plt.ylim(1e-18,10e-14)
plt.grid(True)

ofname = folder+"/Bead"+str(BeadNumber)+"/NeutralityOnY/"+subfolder+"/Discharge_%d.png" % Ndata

plt.savefig(ofname,dpi=300)
# Out:
# /home/data_transfer/data_from_windows/20200730/Bead2/NeutralityOnY/71Hz50VNoSpin2/Discharge_4124.h5
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="640">

# %%
Ndata=2000
Fshake=71
Fspin=50
Vx=50

#subfolder="%dHz%dV%dkHzSpin" % (Fshake,Vx,Fspin)
subfolder="%dHz%dVNoSpin2" % (Fshake,Vx)

fname = folder+"/Bead"+str(BeadNumber)+"/NeutralityOnY/"+subfolder+"/Discharge_%d.h5" % Ndata
#fname = folder+"/NoBead"+"/Discharge_%d.h5" % Ndata
print(fname)

BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz
fsamp=5000
res=10000
res=50000
#data_det=signal.detrend(data)

#xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
#ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
#zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
#xfnsd=np.sqrt(xpsd)*2.2e-12
#yfnsd=np.sqrt(ypsd)*2.33e-12
#zfnsd=np.sqrt(zpsd)*7.04e-19
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)


ax.plot((BDF.Iz+120000)/20, '.-', label="Iz",markersize=1,linewidth=1)
ax.plot((data[2]-5e5)/1000, '.-', label="Z position",markersize=1,linewidth=1)
ax.plot(BDF.feedback[2], '.-', label="z feedback",markersize=1,linewidth=1)

#ax.legend(fontsize=16)
ax.set_xlabel('Data point', fontsize=18)
ax.set_ylabel('au',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(2100,5000)
plt.ylim(-3.5e3,3.5e3)
plt.grid(True)
# Out:
# /home/data_transfer/data_from_windows/20200730/Bead2/NeutralityOnY/71Hz50VNoSpin2/Discharge_2000.h5
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <img src="data:image/png;base64,..." width="640">
