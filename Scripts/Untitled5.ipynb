# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
#%matplotlib widget
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile

# %%
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %%
Year = "2022"
Month = "10"
Day = "18"
BeadNumber = 2
folder = r"/home/data_transfer/data_from_windows/"+ Year + Month + Day
subfolder = folder+"/Bead"+str(BeadNumber)+"/overnightHeightFB"

# %%
Data_File_Number=0
# fname = folder+"/Data%d.h5" % Data_File_Number
fname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/InitialTest_%d.h5" % Data_File_Number
# fname = folder+"/NoBead_0.h5"

# %%
z_set_alt = []
z_set_alt = load_dir_reduced_to_zset(subfolder+"/","InitialTest",max_files=1000)
# Out:
# 100%|██████████| 697/697 [00:11<00:00, 47.56it/s]

# %%
height = []
height = load_dir_reduced_to_height(subfolder+"/","InitialTest",max_files=1000)
# Out:
# 100%|██████████| 697/697 [00:09<00:00, 73.25it/s]

# %%
qpd_sum =[]
qpd_sum = load_dir_reduced_to_qpd_sum(subfolder+"/","InitialTest",max_files=1000)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 697
# 100%|██████████| 20/20 [04:24<00:00, 13.23s/it]

# %%
mean_qpd_sum = []
for element in qpd_sum:
    mean_qpd_sum.append(np.mean(element))

# %%
plt.plot(z_set_alt,marker="*")
plt.axvline(275,c="r")
plt.show()
plt.plot(height,marker="*")
plt.axvline(275,c="r")
plt.show()
plt.plot(mean_qpd_sum,marker="*")
plt.axvline(275,c="r")
plt.show()
plt.plot(mean_power,marker="*")
plt.axvline(275,c="r")
plt.show()

# %%
time=[]
time=load_dir_reduced_to_time(subfolder+"/","InitialTest",max_files=1000)
# Out:
# 100%|██████████| 697/697 [01:20<00:00,  8.63it/s]

# %%
power =[]
power = load_dir_reduced_to_power(subfolder+"/","InitialTest",max_files=1000)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 697
# 100%|██████████| 20/20 [03:35<00:00, 10.79s/it]

# %%
mean_power = []
for element in power:
    mean_power.append(np.mean(element))

# %%
img_time=np.load("/home/data_transfer/slowcontrol_data/ImageData/HeightData/20221018/20221018/run/time_info.npy")

# %%
img_height =np.load("/home/data_transfer/slowcontrol_data/ImageData/HeightData/20221018/20221018/run/height_info.npy")

# %%
plt.plot(time,height,marker="*")
plt.show()
plt.plot(img_time,img_height,marker="*")
plt.show()

# %%
plt.plot(z_set_alt)
plt.show()

# %%
z_set = []
for f in os.listdir(subfolder):
    #print(subfolder+"/"+f)
    BDF = BeadDataFile.BeadDataFile(subfolder+"/"+f)
    z_set.append(BDF.z_set)
# Out:
# No p_trans data

# %%
plt.figure()
plt.plot(z_set)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
BDF.xyz2
# Out:
# array([[-3.10028862e-02, -3.11935137e-02, -3.17449582e-02, ...,
#         -3.08729764e-02, -3.11617455e-02, -3.10327727e-02],
#        [-5.13525312e-03, -5.37317656e-03, -4.74124474e-03, ...,
#         -2.63786438e-03, -2.90151596e-03, -3.91385895e-03],
#        [-4.69714500e+06, -4.69590800e+06, -4.69519500e+06, ...,
#         -4.68520200e+06, -4.68557500e+06, -4.68551500e+06]])
