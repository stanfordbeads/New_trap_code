# %%
# %run /home/analysis_user/New_trap_code/Tools/basic_packages.py
from matplotlib.ticker import MaxNLocator


plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["font.size"] = 24
plt.rcParams['xtick.labelsize'] = "small"
plt.rcParams['ytick.labelsize'] = 36

# %% [markdown]
# ## Step 1: Get the scale

# %%
# this functions fits a sine to the discharge data and extacts the response around the drive frequency

ll = likelihood_analyser.LikelihoodAnalyser()
def get_scale_with_sine_fit(file,drive_freq=71,axis="x",phaseCalib=0,fsamp=5000,decimate=10,bandwidth=2):
    
    calibrationFile = file # get file      
    calibFreqs = np.fft.rfftfreq(len(calibrationFile.electrode_data[0]), d=1./5000) # fft
    fft_angles = np.angle(np.fft.rfft(calibrationFile.electrode_data[0])) # get the phase
    phaseResponse = (fft_angles[calibFreqs==drive_freq]+phaseCalib)%(2*np.pi)
        
    fit_kwargs = {'A': 0, 'f': drive_freq, 'phi': phaseResponse, 'sigma': 0.1,
                  'error_A': 1, 'error_f': 1, 'error_phi': 0.5, 'errordef': 1, 'error_sigma':0.1,
                  'limit_phi': [-2 * np.pi, 2 * np.pi], 'limit_sigma': [0, 1],
                  'limit_A': [-100, 100], 
                  'print_level': 0, 'fix_f': True, 'fix_phi': True}

    
    if(axis=="x"):
        inSignal=calibrationFile.x2
    if(axis=="y"):
        inSignal=calibraitonFile.y2
    if(axis=="z"):
        inSignal=calibrationFile.z2

    b, a = signal.butter(3, [2.*(drive_freq-bandwidth/2.)/fsamp, 2.*(drive_freq+bandwidth/2.)/fsamp ], btype = 'bandpass')
    xx2 = signal.filtfilt(b, a, inSignal)[::decimate]
    
    m1_tmp = ll.find_mle_sin(xx2, fsamp=5000/decimate, noise_rms=1, plot=False, suppress_print=True, **fit_kwargs)
    
    return m1_tmp.values[0]#, m1_tmp.values[3] ,m1_tmp.fval

# %%
def get_scale_with_correlation(file,fdrive=71,nsamp=50000,fsamp=5000,sigamp=1,axis="x",offsetPhase=0):
# set the drive and settings for the correlation
    step_cal_file = file
    tarr = np.arange(0, nsamp/fsamp, 1.0/fsamp)
    sig = sigamp * np.sin(2.0 * np.pi * fdrive * tarr+offsetPhase)
    
        
    if(axis=="x"):
        inSignal=step_cal_file.x2
    if(axis=="y"):
        inSignal=step_cal_file.y2
    if(axis=="z"):
        inSignal=step_cal_file.z2
    
    # get the in-phase response x
    corrs = correlation(drive=sig, response=inSignal, fsamp=fsamp, fdrive=fdrive, filt=True, band_width=1)
    #indices = [np.argmax(cc) for cc in corrs]
    return corrs[0]

# %%
# load discharge data for the respective bead

step_cal_dir = r'/data/new_trap/20210830/Bead1/Discharge/FineDischarge/'
step_cal_files = load_dir(step_cal_dir, start_file=0)
# Out:
# 100%|██████████| 185/185 [00:04<00:00, 39.64it/s]
# 185  files in folder
# 185  files loaded

# %%
inPhaseDischarge = [get_scale_with_correlation(step_cal_file) for step_cal_file in tqdm(step_cal_files)]
# Out:
# 100%|██████████| 185/185 [00:01<00:00, 172.68it/s]

# %%
sinFitDischarge = [get_scale_with_sine_fit(step_cal_file) for step_cal_file in tqdm(step_cal_files)]
# Out:
# 100%|██████████| 185/185 [00:09<00:00, 14.42it/s]

# %%
dischargeAmps=inPhaseDischarge

# %%
# extract the applied voltage the
# 200 for TREK
dischargeVoltage = 200*(np.std(step_cal_files[-1].electrode_data[0])*np.sqrt(2)+np.std(step_cal_files[-1].electrode_data[1])*np.sqrt(2)) # 200 for TREK 

# select (manually) the charge and the respective files
charge=1 
scaleX = np.abs(np.mean(dischargeAmps[155:165]))/charge # scales bits to charges
eta=0.6 # get from COMSOL 
scaleForceX= np.abs(np.mean(dischargeAmps[155:165]))/(dischargeVoltage*1.602e-19*eta)*8e-3 #scales bits to Newton : Is there a time missing?

#scaleY = scaleX*-1.0502 # from discharge values in x and y
#print("Scale is ", scaleY)

print("voltage: ", dischargeVoltage) 
print(scaleX)
print(scaleX/scaleForceX)
# Out:
# voltage:  20.010193310794577
# 4.426671723222734e-05
# 2.4042247262919685e-16

# %%
# evaluate your discharge data calbiration in terms of charges

dischargeAmpArr = np.array(dischargeAmps)
_,ax = plt.subplots(figsize=(16,12))

ax.scatter(range(len(dischargeAmpArr)), dischargeAmpArr/(scaleX), label='fit phase')

ax.set(xlabel='dataset', ylabel='Electron charges',ylim=(-5,9.5), xlim=(0,None))
ax.grid(axis='y')
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# ## Step 2 define the functions to get the millicharge response

# %%
### extract voltage from the files on both electrodes
def get_voltage(file):
    trekConvFactor = 200 
    neutralityFile = file
    voltage0= np.std(neutralityFile.electrode_data[0])*np.sqrt(2)*trekConvFactor
    voltage1= np.std(neutralityFile.electrode_data[1])*np.sqrt(2)*trekConvFactor
    return voltage0,voltage1

# %%
# wrapper to extract the total voltage applied, 
# the voltage at each electrode and the response at the drive frequency and its 2nd harmonic
def get_response_total_with_sin(index,folder,drive_freq=71,axis="x",phaseCalib = -0.0563):
    fname= folder + 'Discharge_'+str(index)+'.h5'
    file = BDF.BeadDataFile(fname=fname)
    voltage0,voltage1= get_voltage(file)
    firstVal = get_scale_with_sine_fit(file=file,drive_freq=drive_freq,axis=axis,phaseCalib=phaseCalib)
    secondVal = get_scale_with_sine_fit(file=file,drive_freq=2*drive_freq,axis=axis,phaseCalib=phaseCalib+np.pi/2)
    appliedVoltage=np.abs(np.subtract(voltage0,voltage1))
    return appliedVoltage,firstVal,secondVal,voltage0,voltage1

# %%
# wrapper to extract the total voltage applied, 
# the voltage at each electrode and the response at the drive frequency and its 2nd harmonic
def get_response_total_with_corr(index,folder,drive_freq=71,axis="x",phaseCalib = -0.0563):
    fname= folder + 'Discharge_'+str(index)+'.h5'
    file = BDF.BeadDataFile(fname=fname)
    voltage0,voltage1= get_voltage(file)
    firstVal = get_scale_with_correlation(file,fdrive=71, offsetPhase=0)
    secondVal = get_scale_with_correlation(file,fdrive=71, offsetPhase=phaseCalib+np.pi/2)#+np.pi/2
    appliedVoltage=np.abs(np.subtract(voltage0,voltage1))
    return appliedVoltage,firstVal,secondVal,voltage0,voltage1

# %%
# the main analysis wrapper


def compare_millicharge_full_analysis_perFile(folder,fileNo=2000,drive_freq=71,axis="x",gap=1,ElectrodeRatio=0.85,
                                              scaleFactor=0,scaleForceFactor=0,
                                              dischargeVoltage=20,scaleByForce=False):
    
    
    '''
    folder: input folder
    fileNo: number of files
    gap: 0 for both electrodes at the same time, 1 if there is alternating electrode, 2+ if there is a 1+ file break between two alternating electrodes
    ElectrodeRatio: extract ratio from single electrode response
    drive_freq: frequency to be analyzed (at its 2f)
    scaleFactor: Bits to Charge
    scaleForceFactor: Bits to Force
    dischargeVoltage: voltage at which discharge happened
    axis: "x","y" or "z"
    prinValues: debugging
    '''
    
    
    df = pd.DataFrame() # create a data frame
    
    # get an response array including the voltages, run a parallel loop
    
    #respArr = np.array(Parallel(n_jobs=32)(delayed(get_response_total_with_sin)(index=j,folder=folder,drive_freq=drive_freq,axis=axis) for j in tqdm(range(fileNo))))
    respArr = np.array(Parallel(n_jobs=32)(delayed(get_response_total_with_corr)(index=j,folder=folder,drive_freq=drive_freq,axis=axis) for j in tqdm(range(fileNo))))

    appliedVoltage =respArr.transpose()[0] # from the electrode difference
     
    F=respArr.transpose()[1] # get the response at the drive frequency 
    
    driveDataCharge = np.divide(F,appliedVoltage)*dischargeVoltage/scaleFactor # scale in units of charge
    driveDataForce = 0 # scale in units of force

    G=respArr.transpose()[2] # get the response at 2f
     
    secondDataCharge = np.divide(G,appliedVoltage)*dischargeVoltage/scaleFactor # scale in units of charge
    secondDataForce= 0 # scale in units of force
    
    totalVoltage=[respArr.transpose()[3],respArr.transpose()[4]] # an array to save voltage 
    
    # select whether to scale by charge or force
    if(scaleByForce==True):
        data0=driveDataForce
        data1=secondDataForce
    elif(scaleByForce==False):
        data0=driveDataCharge
        data1=secondDataCharge    
        
    if(gap>0):
        '''
        If the electrodes are alternating there is at least a "gap" of 1 file until the electrode is driven again.
        If there is an additional relaxation gap this gap increases by a factor of 2, e.g. for a single 10s break between
        two alternating electrodes we end up having every 4th file driven at the respective electrode
        '''
        F1=data0[::2*gap] # first electrode
        
        # files without electrode driven or F3=F2 for gap=1. If the gap is larger not all relaxation files will be sampled
        # this is for crosschecks only
        F3=data0[1::2*gap] 
        
        
        F2=data0[gap::2*gap] # second electrode

        G1=data1[::2*gap] # as above for 2f
        G3=data1[1::2*gap] # as above for 2f
        G2=data1[gap::2*gap] # as above for2       

        
        # fill the data frame
        df["F1"] = F1 
        df["F2"] = F2
        df["F3"] = F3

        df["G1"] = G1
        df["G2"] = G2
        df["G3"] = G3
        
        df["A"] = np.add(np.multiply(F2,ElectrodeRatio),F1) #toDO, should this be /(2 x applied voltage * eta1)
        #df["A/Um"]= np.multiply(8e-3,np.divide(np.add(np.multiply(F2,ElectrodeRatio),F1),np.mean(appliedVoltage)))
        df["B"] = np.subtract(-G1,np.multiply(G2,ElectrodeRatio*2)) #toDo 

   
    # if both electrodes are driven, no need to slice the data in any way, just extract the f and 2f response
    else: 

            df["F1"] = data0
            df["G1"] = data1
            
    return df,totalVoltage

# %%
# no gap measurements
folder = r'/data/new_trap/20210830/Bead1/Neutrality/0V_100V_YZspin_29p62kHz_20210830/'
           
df0,v0 = compare_millicharge_full_analysis_perFile(folder,fileNo=999,gap=0,ElectrodeRatio=0.74,scaleFactor=scaleX)
# Out:
# 100%|██████████| 999/999 [00:14<00:00, 68.65it/s]

# %%
plt.plot(v0[0])
plt.plot(v0[1])
plt.show()

# %%
meanDF0 = np.mean(df0)
stdDF0= np.std(df0)/np.sqrt(len(df0))

# %%
print(meanDF0)
# Out:
# F1   -2.856055
# G1   -0.107569
# dtype: float64

# %%
print(stdDF0)
# Out:
# F1    3.302659
# G1    3.425709
# dtype: float64

# %%
np.divide(meanDF0,stdDF0)
# Out:
# F1   -0.864774
# G1   -0.031400
# dtype: float64

# %%
# no gap measurements
folder = r'/data/new_trap/20210830/Bead1/Neutrality/50V_100V_YZspin_29p62kHz_20210830/'
           
df1,v1 = compare_millicharge_full_analysis_perFile(folder,fileNo=2999,gap=0,ElectrodeRatio=0.74,scaleFactor=scaleX)
# Out:
# ...
# 100%|██████████| 2999/2999 [00:41<00:00, 71.84it/s]

# %%
plt.plot(v1[0])
plt.plot(v1[1])
plt.show()

# %%
meanDF1 = np.mean(df1)
stdDF1= np.std(df1)/np.sqrt(len(df1))
print(meanDF1,stdDF1)
# Out:
# F1    12.329380
# G1    11.247172
# dtype: float64 F1    0.378982
# G1    0.354571
# dtype: float64

# %%
folder = r'/data/new_trap/20210830/Bead1/Neutrality/200V_100V_YZspin_29p62kHz_20210831/'
           
df2,v2 = compare_millicharge_full_analysis_perFile(folder,fileNo=720,gap=2,ElectrodeRatio=0.74,scaleFactor=scaleX)
# Out:
# ...
# 100%|██████████| 720/720 [00:04<00:00, 160.44it/s]

# %%
plt.plot(v2[0][::4])
plt.plot(v2[1][2::4])
plt.show()

# %%
meanDF2 = np.mean(df2)
stdDF2= np.std(df2)/np.sqrt(len(df2))
print(meanDF2,stdDF2)
# Out:
# F1    0.004646
# F2    0.006602
# F3    0.040015
# G1    0.024710
# G2   -0.072485
# G3   -0.275763
# A     0.009531
# B     0.082567
# dtype: float64 F1    0.000277
# F2    0.000298
# F3    7.156247
# G1    0.000373
# G2    0.002452
# G3    8.464111
# A     0.000365
# B     0.003584
# dtype: float64

# %%
folder = r'/data/new_trap/20210830/Bead1/Neutrality/20V_100V_YZspin_29p62kHz_20210831/'
df3,v3 = compare_millicharge_full_analysis_perFile(folder,fileNo=7968,gap=2,ElectrodeRatio=0.74,scaleFactor=scaleX)
# Out:
# ...
# 100%|██████████| 7968/7968 [02:20<00:00, 29.98it/s]

# %%
df3
# Out:
#             F1        F2          F3        G1        G2          G3  \
# 0     0.067000 -0.035889  209.114264  0.006825  0.006242   38.514009
# 1    -0.039622 -0.013067 -172.262925 -0.001731  0.016719  168.346350
# 2     0.014896  0.088830  -53.643700  0.060206 -0.035664  -22.172508
# 3    -0.014777  0.014243  220.804867 -0.032666  0.017890  134.351415
# 4     0.081319  0.021530    5.279592 -0.001977  0.008567  -99.032459
# ...        ...       ...         ...       ...       ...         ...
# 1987 -0.028576 -0.003247   72.459817 -0.015436 -0.064760 -141.348216
# 1988 -0.008867 -0.029216  -38.334148  0.055114 -0.028813  -32.586690
# 1989 -0.029140 -0.030845   85.107413  0.001804 -0.102533  -43.408526
# 1990 -0.027562 -0.024004   56.372159  0.009924 -0.029084   63.980912
# 1991  0.000540  0.000202  -78.981890 -0.135355 -0.006235   29.478249
#
#              A         B
# 0     0.040443 -0.016064
# 1    -0.049291 -0.023014
# 2     0.080630 -0.007423
# 3    -0.004237  0.006189
# ...

# %%
plt.plot(v3[0][::4])
plt.plot(v3[1][2::4])
plt.axvline(6550/4,color="red",linestyle="dashed")
#plt.xlim(0,5)
plt.show()

# %%
meanDF3 = np.mean(df3)
stdDF3= np.std(df3)/np.sqrt(len(df3))
print(meanDF3,stdDF3)
# Out:
# F1    0.005116
# F2    0.005841
# F3   -1.493877
# G1   -0.005327
# G2   -0.006825
# G3    0.557414
# A     0.009438
# B     0.015428
# dtype: float64 F1    0.001048
# F2    0.001033
# F3    2.617747
# G1    0.000981
# G2    0.000995
# G3    2.400185
# A     0.001293
# B     0.001765
# dtype: float64

# %%
folder = r'/data/new_trap/20210830/Bead1/Neutrality/20V_100V_YZspin_98p98kHz_20210901/'
df4,v4 = compare_millicharge_full_analysis_perFile(folder,fileNo=7448,gap=2,ElectrodeRatio=0.74,scaleFactor=scaleX)
# Out:
# ...
# 100%|██████████| 7448/7448 [01:39<00:00, 74.55it/s]

# %%
plt.plot(v4[0][::4])
plt.plot(v4[1][2::4])
plt.show()

# %%
meanDF4 = np.mean(df4)
stdDF4= np.std(df4)/np.sqrt(len(df4))
print(meanDF4,stdDF4)
# Out:
# F1    0.001511
# F2    0.001833
# F3    4.915601
# G1   -0.004933
# G2   -0.007117
# G3    0.849379
# A     0.002867
# B     0.015466
# dtype: float64 F1    0.001035
# F2    0.001029
# F3    2.624732
# G1    0.001235
# G2    0.001271
# G3    3.223556
# A     0.001281
# B     0.002255
# dtype: float64

# %%
folder = r'/data/new_trap/20210830/Bead1/Neutrality/200V_100V_YZspin_98p98kHz_20210902/'
df5,v5 = compare_millicharge_full_analysis_perFile(folder,fileNo=2800,gap=2,ElectrodeRatio=0.74,scaleFactor=scaleX)

# %%
plt.hist(df5.F1,bins=10)
plt.hist(df5.F2,bins=10,alpha=0.5)
plt.hist(df5.A,bins=10,alpha=0.3)
#plt.hist(df5.F3,bins=100,alpha=0.5)
plt.show()

# %%
plt.hist(df5.G1,bins=10)
plt.hist(df5.G2,bins=10,alpha=0.5)
plt.hist(df5.B,bins=10,alpha=0.3)
#plt.hist(df5.F3,bins=100,alpha=0.5)
plt.show()

# %%
plt.hist(df5.A,bins=50)

# %%
plt.plot(v5[0][::4])
plt.plot(v5[1][2::4])
plt.show()

# %%
q5= quickAnalyzeDataFrame(df5)

# %%
folder = r'/data/new_trap/20210830/Bead1/Neutrality/50V_100V_YZspin_98p98kHz_20210903/'
df6,v6 = compare_millicharge_full_analysis_perFile(folder,fileNo=1000,gap=2,ElectrodeRatio=0.74,scaleFactor=scaleX)

# %%
plt.plot(v6[0][::4])
plt.plot(v6[1][2::4])
plt.show()

# %%
q6= quickAnalyzeDataFrame(df6)

# %%
plt.plot(df6.F1.ewm(span=100,adjust=True).mean())
plt.plot(df6.F2.ewm(span=100,adjust=True).mean())

# %%
plt.plot(df6.F1.ewm(span=50,adjust=True).mean()/df6.F2.ewm(span=100,adjust=True).mean())
plt.axhline(0)
