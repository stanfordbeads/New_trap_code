# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random

import h5py
from IPython.utils import io

# %%
# %matplotlib widget

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %% [markdown]
# ### 20201211

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20201211/Bead1/Discharge/', 
                         start_file=0, max_file=1000)
# Out:
# 140  files in folder
# 140  files loaded

# %%
bdf_Neutrality = load_dir(dirname='/data/new_trap/20201211/Bead1/Discharge/Neutrality_20201211/', 
                         start_file=0, max_file=100)
# Out:
# 19657  files in folder
# 100  files loaded

# %%
bb = bdf_discharge[0]
np.std(bb.electrode_data[0])*np.sqrt(2)
# Out:
# 9.996204796895377

# %%
direction = np.array([bb.electrode_channels[0] for bb in bdf_discharge])
direction_Neutrality = np.array([bb.electrode_channels[0] for bb in bdf_Neutrality])
bdf_z_discharge = [bb for bb in bdf_discharge if bb.electrode_channels[0]==1]
bdf_z_V = [np.std(bb.electrode_data[0])*np.sqrt(2) for bb in bdf_discharge if bb.electrode_channels[0]==1]

# %%
m2 = gfw.build_z_response(bdf_z_discharge, drive_freq=71, charges=1, bandwidth=1, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  1.91e+03
# reduced chi2:  5072360.89945972
# ***************************************************
# Z2-amplitude:  3.75e+03
# reduced chi2:  8034.099010065413
# ***************************************************
# Z2-amplitude:  3.70e+03
# reduced chi2:  45792.093089081245
# ***************************************************
# Z2-amplitude:  3.71e+03
# reduced chi2:  13335.14231098224
# ***************************************************
# Z2-amplitude:  3.72e+03
# reduced chi2:  23394.7335368101
# ***************************************************
# Z2-amplitude:  3.23e+03
# reduced chi2:  13976.103979837253
# ***************************************************
# Z2-amplitude:  3.21e+03
# reduced chi2:  26054.505687132714
# ***************************************************
# Z2-amplitude:  3.25e+03
# reduced chi2:  10849.636726141676
# ***************************************************
# ...

# %%
m3 = gfw.build_z_response(bdf_discharge[20:40], drive_freq=71, charges=6, bandwidth=1, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  5.47e+02
# reduced chi2:  1268.2371856557063
# ***************************************************
# Z2-amplitude:  5.37e+02
# reduced chi2:  926.0441714804757
# ***************************************************
# Z2-amplitude:  5.24e+02
# reduced chi2:  1582.0343271796032
# ***************************************************
# Z2-amplitude:  5.45e+02
# reduced chi2:  1617.0050070894251
# ***************************************************
# Z2-amplitude:  4.95e+02
# reduced chi2:  1683.324127051179
# ***************************************************
# Z2-amplitude:  5.42e+02
# reduced chi2:  1628.9029870829536
# ***************************************************
# Z2-amplitude:  5.37e+02
# reduced chi2:  1082.2180936784973
# ***************************************************
# Z2-amplitude:  4.95e+02
# reduced chi2:  1557.4931400300857
# ***************************************************
# ...

# %%
amps = np.array([m_.values[0] for m_ in m1])
amps2 = np.array([m_.values[0] for m_ in m2])
phases = [m_.values[2] for m_ in m1]

# %%
1/gfw.scale_Z2
# Out:
# -2.84424436174528e-18

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].scatter(range(len(amps)), amps)
ax[1].scatter(range(len(amps)), phases)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
_,ax = plt.subplots(figsize=(9.5,4))
scale = 90

# Perrinf
# ax.scatter(range(len(amps)), amps/scale, label='fit phase')
ax.scatter(range(len(amps2)), amps2/scale, label='fit fixed-phases')

ax.legend()
# ax.set(xlabel='dataset', ylabel='Charges', ylim=(-11,0.1), xlim=(None,None))
ax.grid(axis='y')
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.legend()
from matplotlib.ticker import MaxNLocator
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 20201116

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20201116/Bead2/Discharge/', 
                         start_file=0, max_file=173)
# Out:
# 2674  files in folder
# 173  files loaded

# %%
bdf_discharge_Neutrality = load_dir(dirname='/data/new_trap/20201116/Bead2/Discharge/Neutrality_20201120/', 
                         start_file=10000, max_file=10)
# Out:
# 21397  files in folder
# 10  files loaded

# %%
direction = np.array([bb.electrode_channels[0] for bb in bdf_discharge])
direction_Neutrality = np.array([bb.electrode_channels[0] for bb in bdf_discharge_Neutrality])
bdf_z_discharge = [bb for bb in bdf_discharge if bb.electrode_channels[0]==1]
bdf_z_V = [np.std(bb.electrode_data[0])*np.sqrt(2) for bb in bdf_discharge if bb.electrode_channels[0]==1]

# %%
m2 = gfw.build_z_response(bdf_z_discharge, drive_freq=71, charges=1, bandwidth=1, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  1.00e+04
# reduced chi2:  7325469177.451487
# ***************************************************
# Z2-amplitude:  1.00e+04
# reduced chi2:  8668412579.313017
# ***************************************************
# Z2-amplitude:  1.00e+04
# reduced chi2:  8803118204.190935
# ***************************************************
# Z2-amplitude:  1.00e+04
# reduced chi2:  9017021212.315632
# ***************************************************
# Z2-amplitude:  1.00e+04
# reduced chi2:  5959111548.397214
# ***************************************************
# Z2-amplitude:  1.00e+04
# reduced chi2:  444521018.0153719
# ***************************************************
# Z2-amplitude:  4.01e+02
# reduced chi2:  3965.621175037425
# ***************************************************
# Z2-amplitude:  4.30e+02
# reduced chi2:  3865.091163805247
# ***************************************************
# Z2-amplitude:  9.86e+03
# ...

# %%
amps = np.array([m_.values[0] for m_ in m1])
amps2 = np.array([m_.values[0] for m_ in m2])
phases = [m_.values[2] for m_ in m1]

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4))
ax[0].scatter(range(len(amps)), amps)
ax[1].scatter(range(len(amps)), phases)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
_,ax = plt.subplots(figsize=(9.5,4))
scale = 390

# Perrinf
# ax.scatter(range(len(amps)), amps/scale, label='fit phase')
ax.scatter(range(len(amps2)), amps2/scale, label='fit fixed-phases')

ax.legend()
ax.set(xlabel='dataset', ylabel='Charges', ylim=(-10,0.2), xlim=(50,None))
ax.grid(axis='y')
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.legend()
from matplotlib.ticker import MaxNLocator
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 20210423

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20210423/Bead3/Discharge/FineDischarge/', 
                         start_file=0, max_file=1000)
# Out:
# 150  files in folder
# 150  files loaded

# %%
bb = bdf_discharge[0]
np.std(bb.electrode_data[0])*np.sqrt(2)
direction = np.array([bb.electrode_channels[0] for bb in bdf_discharge])
bdf_z_discharge = [bb for bb in bdf_discharge if bb.electrode_channels[0]==1]
bdf_z_V = [np.std(bb.electrode_data[0])*np.sqrt(2) for bb in bdf_discharge if bb.electrode_channels[0]==1]

# %%
bb.cant_freq
# Out:
# 71.0

# %%
m2 = gfw.build_z_response(bdf_z_discharge, drive_freq=71, charges=1, bandwidth=1, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  7.86e+03
# reduced chi2:  25721.814878052828
# ***************************************************
# Z2-amplitude:  7.87e+03
# reduced chi2:  70523.23825341347
# ***************************************************
# Z2-amplitude:  7.86e+03
# reduced chi2:  36603.885765402534
# ***************************************************
# Z2-amplitude:  7.86e+03
# reduced chi2:  23798.151303657578
# ***************************************************
# Z2-amplitude:  7.89e+03
# reduced chi2:  34264.595102971405
# ***************************************************
# Z2-amplitude:  7.75e+03
# reduced chi2:  24199.40450840135
# ***************************************************
# Z2-amplitude:  7.77e+03
# reduced chi2:  30075.826741253273
# ***************************************************
# Z2-amplitude:  7.76e+03
# reduced chi2:  83527.14174082878
# ***************************************************
# ...

# %%
amps = np.array([m_.values[0] for m_ in m1])
amps2 = np.array([m_.values[0] for m_ in m2])
phases = [m_.values[2] for m_ in m1]

# %%
_, ax = plt.subplots(1,2,figsize=(9.5,4), sharex=True)
ax[0].scatter(range(len(amps)), amps)
ax[0].scatter(range(len(amps)), amps2)
ax[1].scatter(range(len(amps)), phases)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
_,ax = plt.subplots(figsize=(9.5,4))
scale = 58

# Perrinf
# ax.scatter(range(len(amps)), amps/scale, label='fit phase')
ax.scatter(range(len(amps2)), amps2/scale, label='fit fixed-phases')

ax.legend()
ax.set(xlabel='dataset', ylabel='Charges', ylim=(None, None), xlim=(None,None))
ax.grid(axis='y')
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.legend()
from matplotlib.ticker import MaxNLocator
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
