# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,9)

listi = [392.0510022158628, # aerotech 375
  392.0792862034263, 
  392.0930879800774, # aerotech 380
  392.09653745901005,
  392.10332687837786,
  391.8648537355899, # kinesis 12
  392.30461845983507,
  391.4825439261058, # kinesis 12
  391.6442252020682,
  390.8110063801123, # kinesis 8
  391.1857343566312,
  391.2501854908563] # aerotech 380


plt.plot(listi,marker="*",color="black")
plt.xlabel("Measurement [#]",fontsize=36)
plt.xticks(fontsize="24")
plt.ylabel(r"Beam center [$\mu$m]",fontsize=36)
plt.yticks(fontsize="24")
plt.axvline(1.5, linestyle="dashed",color="red",label="Aerotech moved")
plt.axvline(4.5, linestyle="dashed")
plt.axvline(6.5, linestyle="dashed",label="Kinesis moved")
plt.axvline(8.5, linestyle="dashed")
plt.axvline(10.5, linestyle="dashed",color="red")
plt.legend(fontsize=24)
#plt.show()
plt.savefig("kinesis_movement.png", dpi=300, bbox_inches='tight')
plt.show()
