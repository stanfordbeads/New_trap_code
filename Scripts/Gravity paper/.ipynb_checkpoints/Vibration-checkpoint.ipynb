# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal
import random
from scipy.optimize import curve_fit

import h5py
from IPython.utils import io

# %%
# %matplotlib widget

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../../../nadavp/new_trap/Tools/')
sys.path.append('../../../../nadavp/new_trap/Tools/StatFramework/')
import BeadDataFile
from discharge_tools import *

# %%
bdf_discharge = load_dir(dirname='/data/new_trap/20210503/Bead2/Discharge/FineDischarge/', 
                         start_file=0, max_file=1200)
# Out:
# 205  files in folder
# 205  files loaded

# %%
bb = bdf_discharge[0]
bdf_z = [bb for bb in bdf_discharge if bb.electrode_channels[0]==1]

# %%
from likelihood_calculator import likelihood_analyser
from likelihood_calculator import GravityFramework
from likelihood_calculator import auxiliary_functions as aux
gfw = GravityFramework.GravityFramework()

# %%
# bb = bdf_z[0]
# [bb.cant_freq for bb in bdf_z]
m2 = gfw.build_z_response(bdf_z, drive_freq=71, charges=10, bandwidth=2, decimate=10, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  4.27e+03
# reduced chi2:  4655.31111714961
# ***************************************************
# Z2-amplitude:  4.27e+03
# reduced chi2:  20724.43114671165
# ***************************************************
# Z2-amplitude:  4.26e+03
# reduced chi2:  6230.995234482453
# ***************************************************
# Z2-amplitude:  4.26e+03
# reduced chi2:  9574.646748596355
# ***************************************************
# Z2-amplitude:  4.28e+03
# reduced chi2:  13013.203374008144
# ***************************************************
# Z2-amplitude:  4.20e+03
# reduced chi2:  2862.8437584778762
# ***************************************************
# Z2-amplitude:  4.20e+03
# reduced chi2:  2769.672901914623
# ***************************************************
# Z2-amplitude:  4.20e+03
# reduced chi2:  4854.805954632255
# ***************************************************
# Z2-amplitude:  4.20e+03
# reduced chi2:  7892.593171523756
# ***************************************************
# Z2-amplitude:  4.21e+03
# reduced chi2:  2404.870878991004
# ***************************************************
# Z2-amplitude:  4.14e+03
# reduced chi2:  17192.75638613059
# ***************************************************
# Z2-amplitude:  4.12e+03
# reduced chi2:  18349.024055037375
# ***************************************************
# Z2-amplitude:  4.13e+03
# reduced chi2:  4717.110517971797
# ***************************************************
# Z2-amplitude:  4.13e+03
# reduced chi2:  2660.7536359325554
# ***************************************************
# Z2-amplitude:  4.14e+03
# reduced chi2:  2424.881916807999
# ***************************************************
# Z2-amplitude:  4.00e+03
# reduced chi2:  7121.972704574208
# ***************************************************
# Z2-amplitude:  3.99e+03
# reduced chi2:  4670.679744496599
# ***************************************************
# Z2-amplitude:  3.99e+03
# reduced chi2:  1819.67691150489
# ***************************************************
# Z2-amplitude:  4.01e+03
# reduced chi2:  1719.0570070016117
# ***************************************************
# Z2-amplitude:  4.00e+03
# reduced chi2:  3092.212831533886
# ***************************************************
# Z2-amplitude:  3.47e+03
# reduced chi2:  4267.826342495806
# ***************************************************
# Z2-amplitude:  3.46e+03
# reduced chi2:  2532.0494184072954
# ***************************************************
# Z2-amplitude:  3.47e+03
# reduced chi2:  1868.306885538043
# ***************************************************
# Z2-amplitude:  3.48e+03
# reduced chi2:  2331.686155412595
# ***************************************************
# Z2-amplitude:  3.47e+03
# reduced chi2:  2298.860973797052
# ***************************************************
# Z2-amplitude:  3.46e+03
# reduced chi2:  7083.53807067867
# ***************************************************
# Z2-amplitude:  3.47e+03
# reduced chi2:  2425.9740803308014
# ***************************************************
# Z2-amplitude:  3.45e+03
# reduced chi2:  4002.9730021279242
# ***************************************************
# Z2-amplitude:  3.46e+03
# reduced chi2:  2424.9482343885734
# ***************************************************
# Z2-amplitude:  3.47e+03
# reduced chi2:  1777.0877374852873
# ***************************************************
# Z2-amplitude:  3.29e+03
# reduced chi2:  3385.825320662946
# ***************************************************
# Z2-amplitude:  3.29e+03
# reduced chi2:  8390.929329541212
# ***************************************************
# Z2-amplitude:  3.27e+03
# reduced chi2:  2789.581000655587
# ***************************************************
# Z2-amplitude:  3.28e+03
# reduced chi2:  1177.580058567131
# ***************************************************
# Z2-amplitude:  3.30e+03
# reduced chi2:  10915.01419698931
# ***************************************************
# Z2-amplitude:  3.04e+03
# reduced chi2:  15408.701024476544
# ***************************************************
# Z2-amplitude:  3.05e+03
# reduced chi2:  990.5367952266448
# ***************************************************
# Z2-amplitude:  3.04e+03
# reduced chi2:  5959.240123908965
# ***************************************************
# Z2-amplitude:  3.05e+03
# reduced chi2:  4744.980550024135
# ***************************************************
# Z2-amplitude:  3.04e+03
# reduced chi2:  1502.466649371847
# ***************************************************
# Z2-amplitude:  2.67e+03
# reduced chi2:  2783.810239043414
# ***************************************************
# Z2-amplitude:  2.67e+03
# reduced chi2:  1870.1013153210765
# ***************************************************
# Z2-amplitude:  2.69e+03
# reduced chi2:  2104.735115718847
# ***************************************************
# Z2-amplitude:  2.67e+03
# reduced chi2:  1867.8491168983603
# ***************************************************
# Z2-amplitude:  2.68e+03
# reduced chi2:  2583.9016191046835
# ***************************************************
# Z2-amplitude:  2.51e+03
# reduced chi2:  878.9916266110039
# ***************************************************
# Z2-amplitude:  2.53e+03
# reduced chi2:  3427.617763694824
# ***************************************************
# Z2-amplitude:  2.53e+03
# reduced chi2:  1480.6944398429523
# ***************************************************
# Z2-amplitude:  2.51e+03
# reduced chi2:  3934.1235762043084
# ***************************************************
# Z2-amplitude:  2.51e+03
# reduced chi2:  2492.438973841774
# ***************************************************
# Z2-amplitude:  2.14e+03
# reduced chi2:  996.8654072241649
# ***************************************************
# Z2-amplitude:  2.14e+03
# reduced chi2:  3336.1356796635628
# ***************************************************
# Z2-amplitude:  2.14e+03
# reduced chi2:  1320.819165853201
# ***************************************************
# Z2-amplitude:  2.14e+03
# reduced chi2:  1565.3478051289655
# ***************************************************
# Z2-amplitude:  2.14e+03
# reduced chi2:  1274.8514968331317
# ***************************************************
# Z2-amplitude:  1.88e+03
# reduced chi2:  5973.8371508953
# ***************************************************
# Z2-amplitude:  1.87e+03
# reduced chi2:  3116.965686592025
# ***************************************************
# Z2-amplitude:  1.88e+03
# reduced chi2:  1675.6104039954603
# ***************************************************
# Z2-amplitude:  1.87e+03
# reduced chi2:  5852.721201291686
# ***************************************************
# Z2-amplitude:  1.89e+03
# reduced chi2:  1853.9621277297676
# ***************************************************
# Z2-amplitude:  1.72e+03
# reduced chi2:  882.4598228698854
# ***************************************************
# Z2-amplitude:  1.72e+03
# reduced chi2:  3364.9692706133073
# ***************************************************
# Z2-amplitude:  1.70e+03
# reduced chi2:  3394.225103110746
# ***************************************************
# Z2-amplitude:  1.72e+03
# reduced chi2:  6145.739202237905
# ***************************************************
# Z2-amplitude:  1.71e+03
# reduced chi2:  3366.7105962810188
# ***************************************************
# Z2-amplitude:  1.69e+03
# reduced chi2:  5634.460677347036
# ***************************************************
# Z2-amplitude:  1.68e+03
# reduced chi2:  3223.5162883925072
# ***************************************************
# Z2-amplitude:  1.68e+03
# reduced chi2:  7597.196694842521
# ***************************************************
# Z2-amplitude:  1.68e+03
# reduced chi2:  1830.9936072244202
# ***************************************************
# Z2-amplitude:  1.68e+03
# reduced chi2:  2496.7645012050684
# ***************************************************
# Z2-amplitude:  1.51e+03
# reduced chi2:  4158.031570809985
# ***************************************************
# Z2-amplitude:  1.51e+03
# reduced chi2:  1417.829194735047
# ***************************************************
# Z2-amplitude:  1.52e+03
# reduced chi2:  1120.7848040611766
# ***************************************************
# Z2-amplitude:  1.51e+03
# reduced chi2:  5195.6291640766485
# ***************************************************
# Z2-amplitude:  1.51e+03
# reduced chi2:  4150.8881664250275
# ***************************************************
# Z2-amplitude:  1.19e+03
# reduced chi2:  3601.8985756474276
# ***************************************************
# Z2-amplitude:  1.19e+03
# reduced chi2:  1126.8619945017244
# ***************************************************
# Z2-amplitude:  1.18e+03
# reduced chi2:  752.1385671430196
# ***************************************************
# Z2-amplitude:  1.19e+03
# reduced chi2:  1403.1013898247716
# ***************************************************
# Z2-amplitude:  1.18e+03
# reduced chi2:  1513.0095827652071
# ***************************************************
# Z2-amplitude:  1.19e+03
# reduced chi2:  3410.258939659578
# ***************************************************
# Z2-amplitude:  1.19e+03
# reduced chi2:  943.6801498125561
# ***************************************************
# Z2-amplitude:  1.19e+03
# reduced chi2:  800.6732429821612
# ***************************************************
# Z2-amplitude:  1.19e+03
# reduced chi2:  1902.4326157727883
# ***************************************************
# Z2-amplitude:  1.18e+03
# reduced chi2:  4765.764912640412
# ***************************************************
# Z2-amplitude:  9.82e+02
# reduced chi2:  839.8609143082455
# ***************************************************
# Z2-amplitude:  9.89e+02
# reduced chi2:  1323.922694618391
# ***************************************************
# Z2-amplitude:  9.72e+02
# reduced chi2:  651.8217302547341
# ***************************************************
# Z2-amplitude:  9.82e+02
# reduced chi2:  2230.195290575471
# ***************************************************
# Z2-amplitude:  9.97e+02
# reduced chi2:  1383.950153497724
# ***************************************************
# Z2-amplitude:  6.95e+02
# reduced chi2:  1279.0843404977604
# ***************************************************
# Z2-amplitude:  6.98e+02
# reduced chi2:  1842.4151081491675
# ***************************************************
# Z2-amplitude:  7.08e+02
# reduced chi2:  554.5488936318197
# ***************************************************
# Z2-amplitude:  6.90e+02
# reduced chi2:  1246.1949404085192
# ***************************************************
# Z2-amplitude:  6.82e+02
# reduced chi2:  1605.9569908238352
# ***************************************************
# Z2-amplitude:  6.14e+02
# reduced chi2:  1695.0228276544885
# ***************************************************
# Z2-amplitude:  6.17e+02
# reduced chi2:  1108.0694977990697
# ***************************************************
# Z2-amplitude:  6.08e+02
# reduced chi2:  1098.1708285151294
# ***************************************************
# Z2-amplitude:  6.18e+02
# reduced chi2:  1646.8171407115744
# ***************************************************
# Z2-amplitude:  6.15e+02
# reduced chi2:  1017.0436317438898
# ***************************************************
# Z2-amplitude:  6.11e+02
# reduced chi2:  1042.10207290956
# ***************************************************
# Z2-amplitude:  6.18e+02
# reduced chi2:  1185.4164795835661
# ***************************************************
# Z2-amplitude:  6.14e+02
# reduced chi2:  956.3482808063774
# ***************************************************
# Z2-amplitude:  6.12e+02
# reduced chi2:  1001.5941611018017
# ***************************************************
# Z2-amplitude:  6.23e+02
# reduced chi2:  681.2405417080379
# ***************************************************
# Z2-amplitude:  3.58e+02
# reduced chi2:  938.0020053605411
# ***************************************************
# Z2-amplitude:  3.73e+02
# reduced chi2:  1136.049394172904
# ***************************************************
# Z2-amplitude:  3.74e+02
# reduced chi2:  865.704164800069
# ***************************************************
# Z2-amplitude:  3.64e+02
# reduced chi2:  627.7481638987795
# ***************************************************
# Z2-amplitude:  3.56e+02
# reduced chi2:  732.8355448578627
# ***************************************************
# Z2-amplitude:  3.18e+02
# reduced chi2:  805.3258550250723
# ***************************************************
# Z2-amplitude:  3.33e+02
# reduced chi2:  1378.4873340532447
# ***************************************************
# Z2-amplitude:  3.24e+02
# reduced chi2:  540.7858697608152
# ***************************************************
# Z2-amplitude:  3.29e+02
# reduced chi2:  567.8654103126811
# ***************************************************
# Z2-amplitude:  3.38e+02
# reduced chi2:  882.133614286891
# ***************************************************
# Z2-amplitude:  2.87e+02
# reduced chi2:  987.9964799901285
# ***************************************************
# Z2-amplitude:  2.81e+02
# reduced chi2:  407.19562790258414
# ***************************************************
# Z2-amplitude:  2.88e+02
# reduced chi2:  592.1039835696264
# ***************************************************
# Z2-amplitude:  2.85e+02
# reduced chi2:  374.21550794559016
# ***************************************************
# Z2-amplitude:  2.96e+02
# reduced chi2:  669.7890794775385
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  772.5231981501769
# ***************************************************
# Z2-amplitude:  2.87e+02
# reduced chi2:  822.2384952002166
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  566.633256437276
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  610.7730671084987
# ***************************************************
# Z2-amplitude:  2.82e+02
# reduced chi2:  783.9126161645318
# ***************************************************
# Z2-amplitude:  2.89e+02
# reduced chi2:  824.3076080592563
# ***************************************************
# Z2-amplitude:  2.92e+02
# reduced chi2:  916.6597907763214
# ***************************************************
# Z2-amplitude:  2.89e+02
# reduced chi2:  610.4993733844558
# ***************************************************
# Z2-amplitude:  2.97e+02
# reduced chi2:  805.8161388995162
# ***************************************************
# Z2-amplitude:  2.89e+02
# reduced chi2:  732.5315432347905
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  647.5251213151531
# ***************************************************
# Z2-amplitude:  2.96e+02
# reduced chi2:  840.0356647791707
# ***************************************************
# Z2-amplitude:  2.79e+02
# reduced chi2:  472.06414252637086
# ***************************************************
# Z2-amplitude:  2.77e+02
# reduced chi2:  636.1843378851504
# ***************************************************
# Z2-amplitude:  2.82e+02
# reduced chi2:  774.0439457386663
# ***************************************************
# Z2-amplitude:  2.88e+02
# reduced chi2:  652.6464559219488
# ***************************************************
# Z2-amplitude:  2.93e+02
# reduced chi2:  412.1323072174184
# ***************************************************
# Z2-amplitude:  2.92e+02
# reduced chi2:  965.901908038749
# ***************************************************
# Z2-amplitude:  2.81e+02
# reduced chi2:  940.8237425591568
# ***************************************************
# Z2-amplitude:  2.86e+02
# reduced chi2:  1175.7254865676696
# ***************************************************
# Z2-amplitude:  2.45e+02
# reduced chi2:  902.9494212183348
# ***************************************************
# Z2-amplitude:  2.47e+02
# reduced chi2:  632.4312207078204
# ***************************************************
# Z2-amplitude:  2.49e+02
# reduced chi2:  948.7664631115642
# ***************************************************
# Z2-amplitude:  2.49e+02
# reduced chi2:  614.7565861308481
# ***************************************************
# Z2-amplitude:  2.55e+02
# reduced chi2:  430.1192579348678
# ***************************************************
# Z2-amplitude:  1.62e+02
# reduced chi2:  799.9596134098085
# ***************************************************
# Z2-amplitude:  1.71e+02
# reduced chi2:  738.3374132806518
# ***************************************************
# Z2-amplitude:  1.75e+02
# reduced chi2:  531.5216556929465
# ***************************************************
# Z2-amplitude:  1.65e+02
# reduced chi2:  565.7991789046164
# ***************************************************
# Z2-amplitude:  1.63e+02
# reduced chi2:  704.5962994084801
# ***************************************************
# Z2-amplitude:  8.36e+01
# reduced chi2:  819.1852816561278
# ***************************************************
# Z2-amplitude:  7.74e+01
# reduced chi2:  1425.2955618906437
# ***************************************************
# Z2-amplitude:  7.98e+01
# reduced chi2:  1092.3790522726413
# ***************************************************
# Z2-amplitude:  8.28e+01
# reduced chi2:  611.7507859976299
# ***************************************************
# Z2-amplitude:  6.97e+01
# reduced chi2:  821.6398877628169
# ***************************************************
# Z2-amplitude:  7.64e+01
# reduced chi2:  702.2475941973593
# ***************************************************
# Z2-amplitude:  8.16e+01
# reduced chi2:  829.7469954177908
# ***************************************************
# Z2-amplitude:  7.56e+01
# reduced chi2:  508.0492391865322
# ***************************************************
# Z2-amplitude:  8.07e+01
# reduced chi2:  720.9694978226224
# ***************************************************
# Z2-amplitude:  7.96e+01
# reduced chi2:  990.8449011629212
# ***************************************************
# Z2-amplitude:  6.94e+01
# reduced chi2:  1154.3946614422275
# ***************************************************
# Z2-amplitude:  9.01e+01
# reduced chi2:  763.0159128197774
# ***************************************************
# Z2-amplitude:  7.76e+01
# reduced chi2:  840.755911701801
# ***************************************************
# Z2-amplitude:  8.36e+01
# reduced chi2:  648.682022016528
# ***************************************************
# Z2-amplitude:  9.18e+01
# reduced chi2:  614.9509754473765
# ***************************************************
# Z2-amplitude:  4.53e+01
# reduced chi2:  737.0163699957182
# ***************************************************
# Z2-amplitude:  3.94e+01
# reduced chi2:  908.0240923914074
# ***************************************************
# Z2-amplitude:  4.14e+01
# reduced chi2:  840.7683611757197
# ***************************************************
# Z2-amplitude:  3.96e+01
# reduced chi2:  778.1258673706894
# ***************************************************
# Z2-amplitude:  3.89e+01
# reduced chi2:  754.3321343995392
# ***************************************************
# Z2-amplitude:  0.00e+00
# reduced chi2:  743.9885368846213
# ***************************************************
# Z2-amplitude:  0.00e+00
# reduced chi2:  680.4703082208084
# ***************************************************
# Z2-amplitude:  1.19e+01
# reduced chi2:  774.3018038416436
# ***************************************************
# Z2-amplitude:  1.08e-08
# reduced chi2:  778.61447315357
# ***************************************************
# Z2-amplitude:  1.40e-08
# reduced chi2:  887.4383670367316
# Z2 response (amplitude): 1488.5635686723551

# %%
amps = np.array([m_.values[0] for m_ in m1])
amps2 = np.array([m_.values[0] for m_ in m2])
phases = [m_.values[2] for m_ in m1]
_, ax = plt.subplots(1,2,figsize=(9.2,4))
ax[0].scatter(range(len(phases)), amps)
ax[0].scatter(range(len(phases)), amps2)
ax[1].scatter(range(len(phases)), phases)
# ax.set(ylim=(-3.14, 3.14))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
scale = np.mean(amps2[115:140])/7
fig,ax = plt.subplots(figsize=(9.5,4))
ax.scatter(range(len(amps2)), amps2/scale, label='fit fixed-phase')
ax.legend()
ax.set(xlabel='dataset', ylabel='Charges', ylim=(-0.2,12), xlim=(100,None))
ax.grid(axis='y')
ax.legend()
from matplotlib.ticker import MaxNLocator
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
m2 = gfw.build_z_response(bdf_z[115:140], drive_freq=71, charges=7, bandwidth=2, decimate=10, bimodal=False)
# Out:
# ***************************************************
# Z2-amplitude:  2.87e+02
# reduced chi2:  987.9964799901285
# ***************************************************
# Z2-amplitude:  2.81e+02
# reduced chi2:  407.19562790258414
# ***************************************************
# Z2-amplitude:  2.88e+02
# reduced chi2:  592.1039835696264
# ***************************************************
# Z2-amplitude:  2.85e+02
# reduced chi2:  374.21550794559016
# ***************************************************
# Z2-amplitude:  2.96e+02
# reduced chi2:  669.7890794775385
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  772.5231981501769
# ***************************************************
# Z2-amplitude:  2.87e+02
# reduced chi2:  822.2384952002166
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  566.633256437276
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  610.7730671084987
# ***************************************************
# Z2-amplitude:  2.82e+02
# reduced chi2:  783.9126161645318
# ***************************************************
# Z2-amplitude:  2.89e+02
# reduced chi2:  824.3076080592563
# ***************************************************
# Z2-amplitude:  2.92e+02
# reduced chi2:  916.6597907763214
# ***************************************************
# Z2-amplitude:  2.89e+02
# reduced chi2:  610.4993733844558
# ***************************************************
# Z2-amplitude:  2.97e+02
# reduced chi2:  805.8161388995162
# ***************************************************
# Z2-amplitude:  2.89e+02
# reduced chi2:  732.5315432347905
# ***************************************************
# Z2-amplitude:  2.83e+02
# reduced chi2:  647.5251213151531
# ***************************************************
# Z2-amplitude:  2.96e+02
# reduced chi2:  840.0356647791707
# ***************************************************
# Z2-amplitude:  2.79e+02
# reduced chi2:  472.06414252637086
# ***************************************************
# Z2-amplitude:  2.77e+02
# reduced chi2:  636.1843378851504
# ***************************************************
# Z2-amplitude:  2.82e+02
# reduced chi2:  774.0439457386663
# ***************************************************
# Z2-amplitude:  2.88e+02
# reduced chi2:  652.6464559219488
# ***************************************************
# Z2-amplitude:  2.93e+02
# reduced chi2:  412.1323072174184
# ***************************************************
# Z2-amplitude:  2.92e+02
# reduced chi2:  965.901908038749
# ***************************************************
# Z2-amplitude:  2.81e+02
# reduced chi2:  940.8237425591568
# ***************************************************
# Z2-amplitude:  2.86e+02
# reduced chi2:  1175.7254865676696
# Z2 response (amplitude): 286.7232273594025

# %% [markdown]
# ### Vibration spectrum

# %%
bdf_vibration = load_dir(dirname='/data/new_trap/20210503/Bead2/Shaking/NoAttractorShaking0/',
                         file_prefix='NoAttractorShaking0',start_file=0, max_file=1000)
bdf_vibration2 = bdf_vibration[:1000]

def fft_norm(N, fsamp):
    "Factor to normalize FFT to ASD units"
    return np.sqrt(2 / (N * fsamp))
scale_psd = fft_norm(50000, 5000)

freq = np.fft.rfftfreq(len(bdf_vibration2[0].z2), d=1./5000)
z_psd_vibration = np.abs(np.fft.rfft(bdf_vibration2[0].z2))
for bb in bdf_vibration2[1:]:
    z_psd_vibration += np.abs(np.fft.rfft(bdf_vibration2[0].z2))
z_psd_vibration /= len(bdf_vibration2)
z_psd_vibration *= scale_psd
z_psd_vibration /= gfw.scale_Z2
# Out:
# 5000  files in folder
# 1000  files loaded

# %%
_,ax = plt.subplots(figsize=(9,4))
ax.semilogy(freq, z_psd_vibration, label='Z - no attractir')
ax.legend()
_ = ax.set(xlim=(0,300), ylim=(1e-17,2e-15), xlabel='Frequency [Hz.]', ylabel='Force [N]', title=r'Z force')
ax.grid()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
