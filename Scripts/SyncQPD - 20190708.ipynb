# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import signal

import h5py

# %%
# %matplotlib notebook

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../../nadavp/new_trap/Tools/')
import BeadDataFile
from discharge_tools import *

# %% [markdown]
# ## Test sychronization

# %%
fname = r'/home/data_transfer/data_from_windows/Testdata/syncQPD/Bla2.h5'
bdf = BeadDataFile.BeadDataFile(fname)
# Out:
# No cantilever data

# %%
bdf.spin_amp
# Out:
# array([-0.15152427, -0.15143954, -0.15134626, ..., -0.15121645,
#        -0.15126745, -0.15141681])

# %%
f = h5py.File(fname,'r')
pos_data = np.array(f['pos_data'])
quad_data = np.array(f['quad_data'])

# %%
sync = pos_data.reshape(-1,11).T[5]
sync.shape
# Out:
# (50000,)

# %%
xpos = bdf.cant_pos[0]
xpos -= np.min(xpos)
xpos /= np.max(xpos)

qpdsum = np.sum(bdf.amp[:4], axis=0)
qpdsum -= np.min(qpdsum)
qpdsum = qpdsum/np.max(qpdsum)

# %%
_,ax = plt.subplots()
ax.plot(np.arange(0,2,1/5000.), xpos)
ax.plot(np.arange(0,2,1/5000.), qpdsum)
ax.plot(np.arange(0,2,1/5000.), np.arange(0,2,1/5000.)*0+0.5, 'r--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_,ax = plt.subplots()
# xpos = bdf.cant_pos[0]
ax.plot(xpos*50, qpdsum)
# Out:
# <img src="data:image/png;base64,..." width="640">
