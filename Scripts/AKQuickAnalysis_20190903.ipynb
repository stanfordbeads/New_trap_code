# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import mlab

from scipy import signal
import h5py, time

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile

# %%
Ndata=65
#fname = r'/home/data_transfer/data_from_windows/20191107/Bead1/InitialTest/Data%d.h5' % Ndata
fname = r"/home/data_transfer/data_from_windows/20191128/Bead1/Discharge/Discharge_%d.h5" % Ndata
#fname = r"/home/data_transfer/data_from_windows/20191128/Bead1/TransFunc/TransFunc_Z_%d.h5" % Ndata
#fname = r"/home/data_transfer/data_from_windows/20191126/Bead1/Shaking/Shaking%d_2.h5" % Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz
fsamp=5000
res=10000
#res=50000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
xfnsd=np.sqrt(xpsd)*2.86e-21
yfnsd=np.sqrt(ypsd)*1.93e-21
zfnsd=np.sqrt(zpsd)*2.93e-18

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs, xfnsd, '.-', label="x",markersize=1,linewidth=1)
ax.loglog(freqs, yfnsd, '.-', label="y*1",markersize=1,linewidth=1)
ax.loglog(freqs, zfnsd, '.-', label="z*100",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
plt.ylim(1e-18,1e-13)
plt.grid(True)
#ofname='/home/data_transfer/data_from_windows/20191014/Bead1/InitialTest/DataFNSD%d_300dpi.png' % Ndata
ofname='/home/data_transfer/data_from_windows/20191126/Bead1/Discharge/Discharge%d.png' % Ndata
#ofname='../Documents/AkioK/TransFunc%d.png' % Ndata
#ofname='/home/data_transfer/data_from_windows/20191126/Bead1/Shaking/Shaking%d_0.png' % Ndata

plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
##code for plotting two graphs at the same time.

# %%
Ndata1=20
fname1 = r"/home/data_transfer/data_from_windows/20191024/Bead1/InitialTest/Data%d.h5" % Ndata1
#fname1 = r"/home/data_transfer/data_from_windows/20190828/Bead1/Discharge/Discharge_%d.h5" % Ndata1
BDF1= BeadDataFile.BeadDataFile(fname1)
data1 = BDF1.xyz
#res = 2**12
res=50000
data_det1=signal.detrend(data1)
xpsd1, freqs1 = matplotlib.mlab.psd(data_det1[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd1, freqs1 = matplotlib.mlab.psd(data_det1[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd1, freqs1 = matplotlib.mlab.psd(data_det1[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
xfnsd1=np.sqrt(xpsd1)*2.86e-21
yfnsd1=np.sqrt(ypsd1)*1.93e-21
zfnsd1=np.sqrt(zpsd1)*2.93e-18
# Out:
# No cantilever data

# %%
Ndata2=24
fname2 = r"/home/data_transfer/data_from_windows/20191024/Bead1/InitialTest/Data%d.h5" % Ndata2
#fname2 = r"/home/data_transfer/data_from_windows/20190828/Bead1/Discharge/Discharge_%d.h5" % Ndata2
BDF2= BeadDataFile.BeadDataFile(fname2)
data2 = BDF2.xyz
data_det2=signal.detrend(data2)
xpsd2, freqs2 = matplotlib.mlab.psd(data_det2[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd2, freqs2 = matplotlib.mlab.psd(data_det2[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd2, freqs2 = matplotlib.mlab.psd(data_det2[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
xfnsd2=np.sqrt(xpsd2)*2.86e-21
yfnsd2=np.sqrt(ypsd2)*1.93e-21
zfnsd2=np.sqrt(zpsd2)*2.93e-18
# Out:
# No cantilever data

# %%
_,ax = plt.subplots()
label1='Data%d,x' % Ndata1
label2='Data%d,x' % Ndata2
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs1, xfnsd1, '.-', label=label1,markersize=2,linewidth=1)
ax.loglog(freqs2, xfnsd2, '.-', label=label2,markersize=2,linewidth=1,alpha=0.5)

ax.legend()
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
plt.ylim(1e-18,1e-15)
plt.grid(True)
ofname='../../Results/AkioK/PlotDataX%d_%d.png' %(Ndata1, Ndata2)
plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_,ax = plt.subplots()
label1='Data%d,y' % Ndata1
label2='Data%d,y' % Ndata2
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs1, yfnsd1, '.-', label=label1,markersize=2,linewidth=1)
ax.loglog(freqs2, yfnsd2, '.-', label=label2,markersize=2,linewidth=1,alpha=0.5)

ax.legend()
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
plt.ylim(1e-18,1e-15)
plt.grid(True)
ofname='../../Results/AkioK/PlotDataY%d_%d.png' %(Ndata1, Ndata2)
plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_,ax = plt.subplots()
label1='Data%d,z' % Ndata1
label2='Data%d,z' % Ndata2
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs1, zfnsd1, '.-', label=label1,markersize=2,linewidth=1)
ax.loglog(freqs2, zfnsd2, '.-', label=label2,markersize=2,linewidth=1,alpha=0.5)

ax.legend()
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,2500)
plt.ylim(1e-18,1e-14)
plt.grid(True)
ofname='../../Results/AkioK/PlotDataZ%d_%d.png' %(Ndata1, Ndata2)
plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##getting the spinning data

# %%
Ndata=101
fname = r'/home/data_transfer/data_from_windows/20190812/Bead1/Shaking/Shaking%d_0.h5' % Ndata
BDF = BeadDataFile.BeadDataFile(fname)
fsamp=5000
res=50000
data=BDF.spin_data
data_det=signal.detrend(data)
xpsd, freqs = matplotlib.mlab.psd(data_det, Fs = fsamp, NFFT = res,window=mlab.window_none)
_,ax = plt.subplots()
ax.semilogy(freqs, xpsd, '.-', label="x",markersize=1,linewidth=1)

ax.legend()
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('PSD [a.u.]')
plt.xlim(1,1000)
plt.ylim(1e-12,1e-5)
plt.grid(True)
ofname='../../Results/AkioK/ShakingSpinSemiLog%d.png' % Ndata

plt.savefig(ofname)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##Extracting Cantilever Position Data for y

# %%
for j in range(0,10):
    Ndata=1
    fname = r'/home/data_transfer/data_from_windows/20190813/Bead1/Shaking/Shaking%d_%d.h5' % (Ndata,j)
    BDF = BeadDataFile.BeadDataFile(fname)
    data=BDF.cant_pos
    ofname = "../../Results/AkioK/Shake%d_%dCantPosY.txt" % (Ndata,j)
    f1 = open(ofname,"a")
    for i in  range(0,50000):
        f1.write('%f\n' % data[1][i])
    f1.close()

# %%
##Extracting QPD sum information

# %%
for j in range(29,32):
    Ndata=j
    fname = r'/home/data_transfer/data_from_windows/20191009/NoBead/Shaking/BeamProfile_%d0.h5' % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data=BDF.quad_sum
    ofname = "../../Results/AkioK/BeamProfile%dQuadSumY.txt" % Ndata
    f1 = open(ofname,"a")
    for i in  range(0,50000):
        f1.write('%d\n' % data[i])
    f1.close()
