# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import mlab

from scipy import signal
import h5py, time

# %%
# %matplotlib widget

# %%
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile

# %%
##Force Calibration with single freq, with xyz2

# %%
Year = "2020"
Month = "03"
Day = "20"
BeadNumber =1
folder = r"/data/new_trap/"+ Year + Month + Day
#folder = r"/home/analysis_user/data_from_windows/"+ Year + Month + Day

# %%
ResX=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=225+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResX[i]=np.sqrt(xpsd[SigFreq*10])
    print(np.sqrt(xpsd[SigFreq*10]))
    #print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# No seismometer data
# No z_set data
# 5.3185713932357e-05
# No seismometer data
# No z_set data
# 5.1842811720905074e-05
# No seismometer data
# No z_set data
# 5.1996097914346046e-05
# No seismometer data
# No z_set data
# 4.8568596183011135e-05
# No seismometer data
# No z_set data
# 5.419660819213425e-05

# %%
ResY=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=230+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResY[i]=np.sqrt(ypsd[SigFreq*10])    
    #print(np.sqrt(xpsd[SigFreq*10]))
    print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# No seismometer data
# No z_set data
# 7.459615175107814e-05
# No seismometer data
# No z_set data
# 7.108187292529642e-05
# No seismometer data
# No z_set data
# 6.994467719258683e-05
# No seismometer data
# No z_set data
# 6.256675237016993e-05
# No seismometer data
# No z_set data
# 6.979445574692227e-05

# %%
ResZ=np.arange(0, 3, 0.1)
for i in range(0,30):
    Ndata=235+i
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResZ[i]=np.sqrt(zpsd[SigFreq*10])    
    print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# No seismometer data
# No z_set data
# 610.3424380831602
# No seismometer data
# No z_set data
# 587.691752337657
# No seismometer data
# No z_set data
# 620.9328114106028
# No seismometer data
# No z_set data
# 627.6928492802273
# No seismometer data
# No z_set data
# 623.1305310892386
# No seismometer data
# No z_set data
# 614.4183577761202
# No seismometer data
# No z_set data
# 601.4065068389503
# No seismometer data
# No z_set data
# 594.5148653211008
# No seismometer data
# No z_set data
# 595.6956236833222
# No seismometer data
# No z_set data
# 599.1450557999868
# No seismometer data
# No z_set data
# 610.3580208410517
# No seismometer data
# No z_set data
# 603.6280546156394
# No seismometer data
# No z_set data
# 606.6459909340582
# No seismometer data
# No z_set data
# 587.7283329645918
# No seismometer data
# No z_set data
# 592.5714510332397
# No seismometer data
# No z_set data
# 578.1703291520229
# No seismometer data
# No z_set data
# 605.2220471944413
# No seismometer data
# No z_set data
# 607.6817578077357
# No seismometer data
# No z_set data
# 597.819226471512
# No seismometer data
# No z_set data
# 634.8447199461426
# No seismometer data
# No z_set data
# 632.6532176199229
# No seismometer data
# No z_set data
# 612.2834667354107
# No seismometer data
# No z_set data
# 625.6538603673476
# No seismometer data
# No z_set data
# 616.0149534680545
# No seismometer data
# No z_set data
# 608.4940666965815
# No seismometer data
# No z_set data
# 591.9492675818784
# No seismometer data
# No z_set data
# 597.886834721275
# No seismometer data
# No z_set data
# 618.7396050878481
# No seismometer data
# No z_set data
# 605.3302738509296
# No seismometer data
# No z_set data
# 608.9814990239257

# %%
q=6
V=10
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)*np.sqrt(5)
print(F)
# Out:
# 3.2489547697263225e-15

# %%
AveX=np.average(ResX)
AveY=np.average(ResY)
AveZ=np.average(ResZ)
BtoFx=F/AveX
BtoFy=F/AveY
BtoFz=F/AveZ
print(BtoFx)
print(BtoFy)
print(BtoFz)
# Out:
# 6.25304461582355e-11
# 4.668254302126402e-11
# 5.350237930781558e-18

# %%
#phase data with 1 Hz trans func data

# %%
xPha=np.zeros(100)
yPha=np.zeros(100)
zPha=np.zeros(100)
xAmp=np.zeros(100)
yAmp=np.zeros(100)
zAmp=np.zeros(100)

# %%
##X preparation
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/Repeat_TransFunc_20200104/TransFunc_Z_m300k_250s_1hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
tInt=250
fsamp=5000
res=tInt*fsamp
fBase=1
Nharm=100

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]
freqs=np.linspace(0,2500,(25000)+1)
    
xFFT=np.fft.rfft(x_1000)
yFFT=np.fft.rfft(y_1000)
zFFT=np.fft.rfft(z_1000)
norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real
XphaseX=np.angle(xFFT)
XphaseY=np.angle(yFFT)
XphaseZ=np.angle(zFFT)

XnoiseX=np.sqrt(xpsd)
XnoiseY=np.sqrt(ypsd)
XnoiseZ=np.sqrt(zpsd)


XrespX=np.zeros(Nharm)
XrespY=np.zeros(Nharm)
XrespZ=np.zeros(Nharm)
for i in range (Nharm):
    XrespX[i]=XnoiseX[tInt*(i+1)]
    XrespY[i]=XnoiseY[tInt*(i+1)]
    XrespZ[i]=XnoiseZ[tInt*(i+1)]
    
XtfX=np.zeros(991)
XtfY=np.zeros(991)
XtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        XtfX[i*10+j]=0.1*XrespX[i]*(10-j)+0.1*XrespX[i+1]*j
        XtfY[i*10+j]=0.1*XrespY[i]*(10-j)+0.1*XrespY[i+1]*j
        XtfZ[i*10+j]=0.1*XrespZ[i]*(10-j)+0.1*XrespZ[i+1]*j
XtfX[990]=XrespX[99]
XtfY[990]=XrespY[99]
XtfZ[990]=XrespZ[99]
# Out:
# No seismometer data
# No z_set data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
##Y preparataion
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/Repeat_TransFunc_20200104/TransFunc_Z_m300k_250s_1hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2 
data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]
freqs=np.linspace(0,2500,(25000)+1)
    
xFFT=np.fft.rfft(x_1000)
yFFT=np.fft.rfft(y_1000)
zFFT=np.fft.rfft(z_1000)
norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real
YphaseX=np.angle(xFFT)
YphaseY=np.angle(yFFT)
YphaseZ=np.angle(zFFT)

YnoiseX=np.sqrt(xpsd)
YnoiseY=np.sqrt(ypsd)
YnoiseZ=np.sqrt(zpsd)


YrespX=np.zeros(Nharm)
YrespY=np.zeros(Nharm)
YrespZ=np.zeros(Nharm)
for i in range (Nharm):
    YrespX[i]=YnoiseX[tInt*(i+1)]
    YrespY[i]=YnoiseY[tInt*(i+1)]
    YrespZ[i]=YnoiseZ[tInt*(i+1)]
    
YtfX=np.zeros(991)
YtfY=np.zeros(991)
YtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        YtfX[i*10+j]=0.1*YrespX[i]*(10-j)+0.1*YrespX[i+1]*j
        YtfY[i*10+j]=0.1*YrespY[i]*(10-j)+0.1*YrespY[i+1]*j
        YtfZ[i*10+j]=0.1*YrespZ[i]*(10-j)+0.1*YrespZ[i+1]*j
YtfX[990]=YrespX[99]
YtfY[990]=YrespY[99]
YtfZ[990]=YrespZ[99]
# Out:
# No seismometer data
# No z_set data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
##Z preparataion
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/Repeat_TransFunc_20200104/TransFunc_Z_m300k_250s_1hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2 
data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]
freqs=np.linspace(0,2500,(25000)+1)
    
xFFT=np.fft.rfft(x_1000)
yFFT=np.fft.rfft(y_1000)
zFFT=np.fft.rfft(z_1000)
norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real
ZphaseX=np.angle(xFFT)
ZphaseY=np.angle(yFFT)
ZphaseZ=np.angle(zFFT)

ZnoiseX=np.sqrt(xpsd)
ZnoiseY=np.sqrt(ypsd)
ZnoiseZ=np.sqrt(zpsd)

ZrespX=np.zeros(Nharm)
ZrespY=np.zeros(Nharm)
ZrespZ=np.zeros(Nharm)
for i in range (Nharm):
    ZrespX[i]=ZnoiseX[tInt*(i+1)]
    ZrespY[i]=ZnoiseY[tInt*(i+1)]
    ZrespZ[i]=ZnoiseZ[tInt*(i+1)]
    
ZtfX=np.zeros(991)
ZtfY=np.zeros(991)
ZtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        ZtfX[i*10+j]=0.1*ZrespX[i]*(10-j)+0.1*ZrespX[i+1]*j
        ZtfY[i*10+j]=0.1*ZrespY[i]*(10-j)+0.1*ZrespY[i+1]*j
        ZtfZ[i*10+j]=0.1*ZrespZ[i]*(10-j)+0.1*ZrespZ[i+1]*j
ZtfX[990]=ZrespX[99]
ZtfY[990]=ZrespY[99]
ZtfZ[990]=ZrespZ[99]
# Out:
# No seismometer data
# No z_set data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
for i in range(0,100):
    xPha[i]=XphaseX[(i+1)*tInt*fBase]-(i*i/100-round(i*i/100))*2*3.14159265-np.pi*0.5
    xAmp[i]=XnoiseX[(i+1)*tInt*fBase]
    if(xPha[i]<-3):
        xPha[i]+=2*np.pi
    yPha[i]=YphaseY[(i+1)*tInt*fBase]-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.5
    yAmp[i]=YnoiseY[(i+1)*tInt*fBase]
    if(yPha[i]>3):
        yPha[i]-=2*np.pi
    zPha[i]=ZphaseZ[(i+1)*tInt*fBase]-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.5
    zAmp[i]=ZnoiseZ[(i+1)*tInt*fBase]

    
        
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>4):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-4):
        zPha[i+1]+=2*np.pi
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>4):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-4):
        zPha[i+1]+=2*np.pi

# %%
freqs=np.linspace(0,2500,(375000)+1)

_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)

ax.plot(np.linspace(1,100,100),xPha, '.-', label="x",markersize=1,linewidth=1)
ax.plot(np.linspace(1,100,100),yPha, '.-', label="y",markersize=1,linewidth=1)
ax.plot(np.linspace(1,100,100),zPha, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/√Hz]',fontsize=18)

ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(0.1,500)
#plt.ylim(1e-7,1e-2)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
freqs=np.linspace(0,2500,(375000)+1)

_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)

#ax.plot(np.linspace(1,100,100),xAmp, '.-', label="x",markersize=1,linewidth=1)
#ax.plot(np.linspace(1,100,100),yAmp, '.-', label="y",markersize=1,linewidth=1)
ax.plot(np.linspace(1,100,100),zAmp, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/√Hz]',fontsize=18)

ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(0.1,500)
#plt.ylim(1e-7,1e-2)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/RepeatTransFuncPhase_XYZ_m300k_250s_1hz_3_SignalInjection.txt"
#f1 = open(ofname,"a")
#for k in range(0,100):
#    f1.write('%d %f %f %f %f %f %f\n' % (k+1,xAmp[k], yAmp[k], zAmp[k],xPha[k], yPha[k], zPha[k]))
#f1.close()

# %%
##combining the "#analyzing multiple data in single number,"  
##"##for Noise only analysis for sensitivity. Used bin of 3*n+0.7 Hz, Nint=0", and SortDataTo Harmonics

# %%
import scipy, sys, time

# %%
#100 Test signal injection data

# %%
import time
start_time = time.time()

#DefineParameters
Ndata=1
Dx=340
Fshake=3
DataN=100
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    
    fname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/Noise_add_1_%d.h5" % (NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/SignalInjectionSignal%dthHarmBugFixed.txt" % (i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/SignalInjectionNoise%dthHarmBugFixed.txt" % (i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# Total run time is  3.6210787296295166  s

# %%
#500 data with larger signal

# %%
import time
start_time = time.time()

#DefineParameters
Ndata=1
Dx=340
Fshake=3
DataN=500
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    
    fname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/Noise_add_3_%d.h5" % (NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/SignalInjection3Signal%dthHarm.txt" % (i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/SignalInjection3Noise%dthHarm.txt" % (i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# 100
# 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-e9f3a01926a7> in <module>
#      29
#      30     fname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/Noise_add_3_%d.h5" % (NSubData)
# ---> 31     BDF = BeadDataFile.BeadDataFile(fname)
#      32     data = BDF.xyz2
#      33     fsamp=5000
#
# ~/New_trap_code/Tools/BeadDataFile.py in __init__(self, fname)
#      19
#      20         f = h5py.File(fname,'r')
# ---> 21         pos_data = np.array(f['pos_data'])
#      22         quad_data = np.array(f['quad_data'])
#      23         self.fsamp = f.attrs['Fsamp']
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/.local/lib/python3.6/site-packages/h5py/_hl/dataset.py in __array__(self, dtype)
#     770             return arr
#     771
# --> 772         self.read_direct(arr)
#     773         return arr
#     774
#
# ~/.local/lib/python3.6/site-packages/h5py/_hl/dataset.py in read_direct(self, dest, source_sel, dest_sel)
#     731
#     732             for mspace in dest_sel.broadcast(source_sel.mshape):
# --> 733                 self.id.read(mspace, fspace, dest, dxpl=self._dxpl)
#     734
#     735     def write_direct(self, source, source_sel=None, dest_sel=None):
#
# KeyboardInterrupt:

# %%
#five datasets Alex made for me. 
import time
start_time = time.time()

#DefineParameters
Ndata=5
Dx=340
Fshake=3
DataN=1000
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    
    fname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/Akio/Noise_add_%d_%d.h5" % (Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/Akio/SignalInjection%dSignal%dthHarm.txt" % (Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = "/data/new_trap_processed/mockfiles/Wilson/output/noise/Akio/SignalInjection%dNoise%dthHarm.txt" % (Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 300
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 400
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 500
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 600
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 700
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 800
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 900
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# Total run time is  17.90621519088745  s

# %%
##12/7 analysis-1000 data, 1st test chunk

# %%
import time
start_time = time.time()

#DefineParameters
Ndata=5
Dx=340
Fshake=3
DataN=1000
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    flocation="/data/new_trap_processed/mockfiles/20200320/output/noise/testrun/11/"
    fname = flocation+"Noise_batch_%d.h5" % (NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = flocation+"SignalInjection%dSignal%dthHarm.txt" % (Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = flocation+"SignalInjection%dNoise%dthHarm.txt" % (Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 300
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 400
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 500
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 600
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 700
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 800
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 900
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# Total run time is  24.79453182220459  s

# %%
#100 Signal Injection Data analyzed on 12/9

# %%
import time
start_time = time.time()

for j in range(1,100):
    #DefineParameters
    Ndata=j
    Dx=340
    Fshake=3
    DataN=1000
    HarmN=20
    Noff=3
    ArraySize=(DataN,HarmN)
    DataSpaceXSigAmp=np.zeros(ArraySize)
    DataSpaceYSigAmp=np.zeros(ArraySize)
    DataSpaceZSigAmp=np.zeros(ArraySize)
    DataSpaceXSigPha=np.zeros(ArraySize)
    DataSpaceYSigPha=np.zeros(ArraySize)
    DataSpaceZSigPha=np.zeros(ArraySize)

    DataSpaceXNoiAmp=np.zeros(ArraySize)
    DataSpaceYNoiAmp=np.zeros(ArraySize)
    DataSpaceZNoiAmp=np.zeros(ArraySize)
    DataSpaceXNoiPha=np.zeros(ArraySize)
    DataSpaceYNoiPha=np.zeros(ArraySize)
    DataSpaceZNoiPha=np.zeros(ArraySize)

    for k in range(0,DataN):
    ##FFT the data
        NSubData=k
        flocation="/data/new_trap_processed/mockfiles/20200320/output/noise/Batch1"
        fname = flocation+"/%d/Noise_batch_%d.h5" % (Ndata,NSubData)
        BDF = BeadDataFile.BeadDataFile(fname)
        data = BDF.xyz2
        fsamp=5000
        res=50000

        data_det=signal.detrend(data)
        x_1000=data_det[0]
        y_1000=data_det[1]
        z_1000=data_det[2]
        freqs=np.linspace(0,2500,(25000)+1)

        xFFT=np.fft.rfft(x_1000)
        yFFT=np.fft.rfft(y_1000)
        zFFT=np.fft.rfft(z_1000)
        norm = np.sqrt(2 / (res* fsamp))
        xpsd = norm**2 * (xFFT * xFFT.conj()).real
        ypsd = norm**2 * (yFFT * yFFT.conj()).real
        zpsd = norm**2 * (zFFT * zFFT.conj()).real

        f0=71

        xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
        ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
        znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ##save signal bin data to the array
        for i in range(1,(HarmN+1)):
            DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
            DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
            DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
            DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
            DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
            DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 

    ##save noise bin data to the array
        for i in range(1,(HarmN+1)):
            DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
            DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
            DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
            DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
            DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
            DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 

        if (k%100)==0:
            print(k)

    ##write the harmonics data
    for i in range(1,(HarmN+1)):
        ofname = flocation+"/%d/SignalInjection%dSignal%dthHarm.txt" % (Ndata,Ndata,i)
        f1 = open(ofname,"a")
        for k in range(0,DataN):
            f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                                DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
        f1.close()
        ofname = flocation+"/%d/SignalInjection%dNoise%dthHarm.txt" % (Ndata,Ndata,i)
        f1 = open(ofname,"a")
        for k in range(0,DataN):
            f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                                DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
        f1.close()

    print ("Total run time is ", time.time() - start_time, " s")
# Out:
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 300
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 400
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 500
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 600
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 700
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 800
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 900
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# Total run time is  49.62212371826172  s
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 300
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 400
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# ...
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 900
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# Total run time is  922.8661525249481  s
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data

# %%
#20x100 test data

# %%
import time
start_time = time.time()

for j in range(0,20):
    #DefineParameters
    Ndata=j
    Dx=340
    Fshake=3
    DataN=1000
    HarmN=20
    Noff=3
    ArraySize=(DataN,HarmN)
    DataSpaceXSigAmp=np.zeros(ArraySize)
    DataSpaceYSigAmp=np.zeros(ArraySize)
    DataSpaceZSigAmp=np.zeros(ArraySize)
    DataSpaceXSigPha=np.zeros(ArraySize)
    DataSpaceYSigPha=np.zeros(ArraySize)
    DataSpaceZSigPha=np.zeros(ArraySize)

    DataSpaceXNoiAmp=np.zeros(ArraySize)
    DataSpaceYNoiAmp=np.zeros(ArraySize)
    DataSpaceZNoiAmp=np.zeros(ArraySize)
    DataSpaceXNoiPha=np.zeros(ArraySize)
    DataSpaceYNoiPha=np.zeros(ArraySize)
    DataSpaceZNoiPha=np.zeros(ArraySize)

    for k in range(0,DataN):
    ##FFT the data
        NSubData=k
        flocation="/data/new_trap_processed/mockfiles/20200320/output/noise/Batch2_NR"
        fname = flocation+"/%d/Noise_batch_%d.h5" % (Ndata,NSubData)
        BDF = BeadDataFile.BeadDataFile(fname)
        data = BDF.xyz2
        fsamp=5000
        res=50000

        data_det=signal.detrend(data)
        x_1000=data_det[0]
        y_1000=data_det[1]
        z_1000=data_det[2]
        freqs=np.linspace(0,2500,(25000)+1)

        xFFT=np.fft.rfft(x_1000)
        yFFT=np.fft.rfft(y_1000)
        zFFT=np.fft.rfft(z_1000)
        norm = np.sqrt(2 / (res* fsamp))
        xpsd = norm**2 * (xFFT * xFFT.conj()).real
        ypsd = norm**2 * (yFFT * yFFT.conj()).real
        zpsd = norm**2 * (zFFT * zFFT.conj()).real

        f0=71

        xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
        ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
        znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ##save signal bin data to the array
        for i in range(1,(HarmN+1)):
            DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
            DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
            DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
            DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
            DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
            DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 

    ##save noise bin data to the array
        for i in range(1,(HarmN+1)):
            DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
            DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
            DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
            DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
            DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
            DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 

        if (k%100)==0:
            print(k)

    ##write the harmonics data
    for i in range(1,(HarmN+1)):
        ofname = flocation+"/%d/SignalInjection%dSignal%dthHarm.txt" % (Ndata,Ndata,i)
        f1 = open(ofname,"a")
        for k in range(0,DataN):
            f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                                DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
        f1.close()
        ofname = flocation+"/%d/SignalInjection%dNoise%dthHarm.txt" % (Ndata,Ndata,i)
        f1 = open(ofname,"a")
        for k in range(0,DataN):
            f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                                DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
        f1.close()

    print ("Total run time is ", time.time() - start_time, " s")
# Out:
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 300
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 400
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 500
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 600
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 700
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 800
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 900
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# Total run time is  67.7087869644165  s
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 300
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 400
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# ...
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 600
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 700
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 800
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 900
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# Total run time is  989.3131952285767  s

# %%
#Batch3, 100x1000 data

# %%
import time
start_time = time.time()

for j in range(0,100):
    print ("Time so far is ", time.time() - start_time, " s. Currently we are at Data number ", j, ".")
    #DefineParameters
    Ndata=j
    Dx=340
    Fshake=3
    DataN=1000
    HarmN=20
    Noff=3
    ArraySize=(DataN,HarmN)
    DataSpaceXSigAmp=np.zeros(ArraySize)
    DataSpaceYSigAmp=np.zeros(ArraySize)
    DataSpaceZSigAmp=np.zeros(ArraySize)
    DataSpaceXSigPha=np.zeros(ArraySize)
    DataSpaceYSigPha=np.zeros(ArraySize)
    DataSpaceZSigPha=np.zeros(ArraySize)

    DataSpaceXNoiAmp=np.zeros(ArraySize)
    DataSpaceYNoiAmp=np.zeros(ArraySize)
    DataSpaceZNoiAmp=np.zeros(ArraySize)
    DataSpaceXNoiPha=np.zeros(ArraySize)
    DataSpaceYNoiPha=np.zeros(ArraySize)
    DataSpaceZNoiPha=np.zeros(ArraySize)

    for k in range(0,DataN):
    ##FFT the data
        NSubData=k
        flocation="/data/new_trap_processed/mockfiles/20200320/output/noise/Batch3"
        fname = flocation+"/%d/Noise_batch_%d.h5" % (Ndata,NSubData)
        BDF = BeadDataFile.BeadDataFile(fname)
        data = BDF.xyz2
        fsamp=5000
        res=50000

        data_det=signal.detrend(data)
        x_1000=data_det[0]
        y_1000=data_det[1]
        z_1000=data_det[2]
        freqs=np.linspace(0,2500,(25000)+1)

        xFFT=np.fft.rfft(x_1000)
        yFFT=np.fft.rfft(y_1000)
        zFFT=np.fft.rfft(z_1000)
        norm = np.sqrt(2 / (res* fsamp))
        xpsd = norm**2 * (xFFT * xFFT.conj()).real
        ypsd = norm**2 * (yFFT * yFFT.conj()).real
        zpsd = norm**2 * (zFFT * zFFT.conj()).real

        f0=71

        xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
        ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
        znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ##save signal bin data to the array
        for i in range(1,(HarmN+1)):
            DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
            DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
            DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
            DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
            DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
            DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 

    ##save noise bin data to the array
        for i in range(1,(HarmN+1)):
            DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
            DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
            DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
            DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
            DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
            DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 

        if (k%100)==0:
            print(k)

    ##write the harmonics data
    for i in range(1,(HarmN+1)):
        ofname = flocation+"/%d/SignalInjection%dSignal%dthHarm.txt" % (Ndata,Ndata,i)
        f1 = open(ofname,"a")
        for k in range(0,DataN):
            f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                                DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
        f1.close()
        ofname = flocation+"/%d/SignalInjection%dNoise%dthHarm.txt" % (Ndata,Ndata,i)
        f1 = open(ofname,"a")
        for k in range(0,DataN):
            f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                                DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
        f1.close()

print ("Total run time is ", time.time() - start_time, " s")
# Out:
# Time so far is  0.00045800209045410156  s. Currently we are at Data number  0 .
# No seismometer data
# No z_set data
# 0
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 100
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 200
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 300
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 400
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 500
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 600
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 700
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 800
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# 900
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# No seismometer data
# No z_set data
# Total run time is  34.06313109397888  s
