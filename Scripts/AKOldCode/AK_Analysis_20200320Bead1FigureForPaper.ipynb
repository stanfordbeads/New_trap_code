# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import mlab

from scipy import signal
import h5py, time

# %%
# %matplotlib widget

# %%
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile

# %%
##Force Calibration with single freq, with xyz2

# %%
Year = "2020"
Month = "03"
Day = "20"
BeadNumber =1
folder = r"/data/new_trap/"+ Year + Month + Day
#folder = r"/home/analysis_user/data_from_windows/"+ Year + Month + Day

# %%
import time
start_time = time.time()

#DefineParameters
Ndata=3
Dx=378
Fshake=3
DataN=10000
HarmN=20
Noff=3

NSubData=1
fname = folder+"/Bead"+str(BeadNumber)+"/Shaking/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
BDF = BeadDataFile.BeadDataFile(fname)
fsamp=5000
res=50000
data=BDF.cant_pos[1]


yFFT=np.fft.rfft(data)
norm = np.sqrt(2 / (res* fsamp))
ypsd = norm**2 * (yFFT * yFFT.conj()).real
ynsd=np.sqrt(ypsd)
   
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# No seismometer data
# No z_set data
# Total run time is  0.11558008193969727  s

# %%
np.linspace(0.1, 2500, num=25000, endpoint=True)
# Out:
# array([1.0000e-01, 2.0000e-01, 3.0000e-01, ..., 2.4998e+03, 2.4999e+03,
#        2.5000e+03])

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
freqs=np.linspace(0, 2500, num=25001, endpoint=True)
ax.loglog(freqs,ynsd/ynsd[30], '.-',markersize=1,linewidth=1)
#ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('ASD of the attractor motion [a.u.]',fontsize=18)

ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,100)
plt.ylim(2e-5,2)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivity%d.png" % Ndata
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ResX=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=225+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)
    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResX[i]=np.sqrt(xpsd[SigFreq*10])
    print(np.sqrt(xpsd[SigFreq*10]))
    #print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# No seismometer data
# No z_set data
# 5.3185713932357e-05
# No seismometer data
# No z_set data
# 5.1842811720905074e-05
# No seismometer data
# No z_set data
# 5.1996097914346046e-05
# No seismometer data
# No z_set data
# 4.8568596183011135e-05
# No seismometer data
# No z_set data
# 5.419660819213425e-05

# %%
ResY=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=230+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResY[i]=np.sqrt(ypsd[SigFreq*10])    
    #print(np.sqrt(xpsd[SigFreq*10]))
    print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# No seismometer data
# No z_set data
# 7.459615175107814e-05
# No seismometer data
# No z_set data
# 7.108187292529642e-05
# No seismometer data
# No z_set data
# 6.994467719258683e-05
# No seismometer data
# No z_set data
# 6.256675237016993e-05
# No seismometer data
# No z_set data
# 6.979445574692227e-05

# %%
ResZ=np.arange(0, 3, 0.1)
for i in range(0,30):
    Ndata=235+i
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResZ[i]=np.sqrt(zpsd[SigFreq*10])    
    print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# No seismometer data
# No z_set data
# 610.3424380831602
# No seismometer data
# No z_set data
# 587.691752337657
# No seismometer data
# No z_set data
# 620.9328114106028
# No seismometer data
# No z_set data
# 627.6928492802273
# No seismometer data
# No z_set data
# 623.1305310892386
# No seismometer data
# No z_set data
# 614.4183577761202
# No seismometer data
# No z_set data
# 601.4065068389503
# No seismometer data
# No z_set data
# 594.5148653211008
# No seismometer data
# No z_set data
# 595.6956236833222
# No seismometer data
# No z_set data
# 599.1450557999868
# No seismometer data
# No z_set data
# 610.3580208410517
# No seismometer data
# No z_set data
# 603.6280546156394
# No seismometer data
# No z_set data
# 606.6459909340582
# No seismometer data
# No z_set data
# 587.7283329645918
# No seismometer data
# No z_set data
# 592.5714510332397
# No seismometer data
# No z_set data
# 578.1703291520229
# No seismometer data
# No z_set data
# 605.2220471944413
# No seismometer data
# No z_set data
# 607.6817578077357
# No seismometer data
# No z_set data
# 597.819226471512
# No seismometer data
# No z_set data
# 634.8447199461426
# No seismometer data
# No z_set data
# 632.6532176199229
# No seismometer data
# No z_set data
# 612.2834667354107
# No seismometer data
# No z_set data
# 625.6538603673476
# No seismometer data
# No z_set data
# 616.0149534680545
# No seismometer data
# No z_set data
# 608.4940666965815
# No seismometer data
# No z_set data
# 591.9492675818784
# No seismometer data
# No z_set data
# 597.886834721275
# No seismometer data
# No z_set data
# 618.7396050878481
# No seismometer data
# No z_set data
# 605.3302738509296
# No seismometer data
# No z_set data
# 608.9814990239257

# %%
q=6
V=10
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)*np.sqrt(5)
print(F)
# Out:
# 3.2489547697263225e-15

# %%
AveX=np.average(ResX)
AveY=np.average(ResY)
AveZ=np.average(ResZ)
BtoFx=F/AveX
BtoFy=F/AveY
BtoFz=F/AveZ
print(BtoFx)
print(BtoFy)
print(BtoFz)
# Out:
# 6.25304461582355e-11
# 4.668254302126402e-11
# 5.350237930781558e-18

# %%
xPha=np.zeros(100)
yPha=np.zeros(100)
zPha=np.zeros(100)
xAmp=np.zeros(100)
yAmp=np.zeros(100)
zAmp=np.zeros(100)

# %%
#phase data with 1 Hz trans func data

# %%
##X preparation
Ndata=11
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/Repeat_TransFunc_20200104/TransFunc_X_m300k_250s_1hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
tInt=250
fsamp=5000
res=tInt*fsamp
fBase=1
Nharm=100

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]
freqs=np.linspace(0,2500,(25000)+1)
    
xFFT=np.fft.rfft(x_1000)
yFFT=np.fft.rfft(y_1000)
zFFT=np.fft.rfft(z_1000)
norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real
XphaseX=np.angle(xFFT)
XphaseY=np.angle(yFFT)
XphaseZ=np.angle(zFFT)

XnoiseX=np.sqrt(xpsd)
XnoiseY=np.sqrt(ypsd)
XnoiseZ=np.sqrt(zpsd)


XrespX=np.zeros(Nharm)
XrespY=np.zeros(Nharm)
XrespZ=np.zeros(Nharm)
for i in range (Nharm):
    XrespX[i]=XnoiseX[tInt*(i+1)]
    XrespY[i]=XnoiseY[tInt*(i+1)]
    XrespZ[i]=XnoiseZ[tInt*(i+1)]
    
XtfX=np.zeros(991)
XtfY=np.zeros(991)
XtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        XtfX[i*10+j]=0.1*XrespX[i]*(10-j)+0.1*XrespX[i+1]*j
        XtfY[i*10+j]=0.1*XrespY[i]*(10-j)+0.1*XrespY[i+1]*j
        XtfZ[i*10+j]=0.1*XrespZ[i]*(10-j)+0.1*XrespZ[i+1]*j
XtfX[990]=XrespX[99]
XtfY[990]=XrespY[99]
XtfZ[990]=XrespZ[99]
# Out:
# No seismometer data
# No z_set data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
##Y preparataion
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/Repeat_TransFunc_20200104/TransFunc_Y_m300k_250s_1hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2 
data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]
freqs=np.linspace(0,2500,(25000)+1)
    
xFFT=np.fft.rfft(x_1000)
yFFT=np.fft.rfft(y_1000)
zFFT=np.fft.rfft(z_1000)
norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real
YphaseX=np.angle(xFFT)
YphaseY=np.angle(yFFT)
YphaseZ=np.angle(zFFT)

YnoiseX=np.sqrt(xpsd)
YnoiseY=np.sqrt(ypsd)
YnoiseZ=np.sqrt(zpsd)


YrespX=np.zeros(Nharm)
YrespY=np.zeros(Nharm)
YrespZ=np.zeros(Nharm)
for i in range (Nharm):
    YrespX[i]=YnoiseX[tInt*(i+1)]
    YrespY[i]=YnoiseY[tInt*(i+1)]
    YrespZ[i]=YnoiseZ[tInt*(i+1)]
    
YtfX=np.zeros(991)
YtfY=np.zeros(991)
YtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        YtfX[i*10+j]=0.1*YrespX[i]*(10-j)+0.1*YrespX[i+1]*j
        YtfY[i*10+j]=0.1*YrespY[i]*(10-j)+0.1*YrespY[i+1]*j
        YtfZ[i*10+j]=0.1*YrespZ[i]*(10-j)+0.1*YrespZ[i+1]*j
YtfX[990]=YrespX[99]
YtfY[990]=YrespY[99]
YtfZ[990]=YrespZ[99]
# Out:
# No seismometer data
# No z_set data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
##Z preparataion
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/Repeat_TransFunc_20200104/TransFunc_Z_m300k_250s_1hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2 
data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]
freqs=np.linspace(0,2500,(25000)+1)
    
xFFT=np.fft.rfft(x_1000)
yFFT=np.fft.rfft(y_1000)
zFFT=np.fft.rfft(z_1000)
norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real
ZphaseX=np.angle(xFFT)
ZphaseY=np.angle(yFFT)
ZphaseZ=np.angle(zFFT)

ZnoiseX=np.sqrt(xpsd)
ZnoiseY=np.sqrt(ypsd)
ZnoiseZ=np.sqrt(zpsd)

ZrespX=np.zeros(Nharm)
ZrespY=np.zeros(Nharm)
ZrespZ=np.zeros(Nharm)
for i in range (Nharm):
    ZrespX[i]=ZnoiseX[tInt*(i+1)]
    ZrespY[i]=ZnoiseY[tInt*(i+1)]
    ZrespZ[i]=ZnoiseZ[tInt*(i+1)]
    
ZtfX=np.zeros(991)
ZtfY=np.zeros(991)
ZtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        ZtfX[i*10+j]=0.1*ZrespX[i]*(10-j)+0.1*ZrespX[i+1]*j
        ZtfY[i*10+j]=0.1*ZrespY[i]*(10-j)+0.1*ZrespY[i+1]*j
        ZtfZ[i*10+j]=0.1*ZrespZ[i]*(10-j)+0.1*ZrespZ[i+1]*j
ZtfX[990]=ZrespX[99]
ZtfY[990]=ZrespY[99]
ZtfZ[990]=ZrespZ[99]
# Out:
# No seismometer data
# No z_set data
# No height data
# No cantilever data
# Error loading spinning data
# No laser power data

# %%
for i in range(0,100):
    xPha[i]=XphaseX[(i+1)*tInt*fBase]-(i*i/100-round(i*i/100))*2*3.14159265-np.pi*0.5
    xAmp[i]=XnoiseX[(i+1)*tInt*fBase]
    if(xPha[i]<-3):
        xPha[i]+=2*np.pi
    yPha[i]=YphaseY[(i+1)*tInt*fBase]-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.5
    yAmp[i]=YnoiseY[(i+1)*tInt*fBase]
    if(yPha[i]>3):
        yPha[i]-=2*np.pi
    zPha[i]=ZphaseZ[(i+1)*tInt*fBase]-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.5
    zAmp[i]=ZnoiseZ[(i+1)*tInt*fBase]

    
        
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>4):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-4):
        zPha[i+1]+=2*np.pi
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>4):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-4):
        zPha[i+1]+=2*np.pi

# %%
freqs=np.linspace(0,2500,(375000)+1)

_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)

ax.plot(np.linspace(1,100,100),xPha, '.-', label="x",markersize=1,linewidth=1)
ax.plot(np.linspace(1,100,100),yPha, '.-', label="y",markersize=1,linewidth=1)
ax.plot(np.linspace(1,100,100),zPha, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/√Hz]',fontsize=18)

ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(0.1,500)
#plt.ylim(1e-7,1e-2)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
freqs=np.linspace(0,2500,(375000)+1)

_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)

#ax.plot(np.linspace(1,100,100),xAmp, '.-', label="x",markersize=1,linewidth=1)
#ax.plot(np.linspace(1,100,100),yAmp, '.-', label="y",markersize=1,linewidth=1)
ax.plot(np.linspace(1,100,100),zAmp, '.-', label="z",markersize=1,linewidth=1)
#ax.semilogy(ZnoiseZ, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/√Hz]',fontsize=18)

ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(0.1,500)
#plt.ylim(1e-7,1e-2)
plt.grid(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Here, there is no conversion factor
q=20
V=0.65
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)
Nharm=100


FnoiseXX=XnoiseX
FnoiseXY=XnoiseY
FnoiseXZ=XnoiseZ
FnoiseYX=YnoiseX
FnoiseYY=YnoiseY
FnoiseYZ=YnoiseZ
FnoiseZX=ZnoiseX
FnoiseZY=ZnoiseY
FnoiseZZ=ZnoiseZ

TFXX=np.zeros(Nharm)
TFXY=np.zeros(Nharm)
TFXZ=np.zeros(Nharm)
TFYX=np.zeros(Nharm)
TFYY=np.zeros(Nharm)
TFYZ=np.zeros(Nharm)
TFZX=np.zeros(Nharm)
TFZY=np.zeros(Nharm)
TFZZ=np.zeros(Nharm)

FreqTF=np.zeros(Nharm)
for i in range(Nharm):
    FreqTF[i]=fBase*(i+1)
    TFXX[i]=FnoiseXX[fBase*tInt*(i+1)]
    TFXY[i]=FnoiseXY[fBase*tInt*(i+1)]
    TFXZ[i]=FnoiseXZ[fBase*tInt*(i+1)]
    TFYX[i]=FnoiseYX[fBase*tInt*(i+1)]
    TFYY[i]=FnoiseYY[fBase*tInt*(i+1)]
    TFYZ[i]=FnoiseYZ[fBase*tInt*(i+1)]
    TFZX[i]=FnoiseZX[fBase*tInt*(i+1)]
    TFZY[i]=FnoiseZY[fBase*tInt*(i+1)]
    TFZZ[i]=FnoiseZZ[fBase*tInt*(i+1)]

# %%
##force sensitivity

# %%
Ndata=52
fname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata
print(fname)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res = 50000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
xnsd=np.sqrt(xpsd)
ynsd=np.sqrt(ypsd)
znsd=np.sqrt(zpsd)
f0=71
Xsens=np.zeros(991)
Ysens=np.zeros(991)
Zsens=np.zeros(991)

for i in range(991):
    Xsens[i]=xnsd[10+i]*XtfX[f0*10-10]/XtfX[i]*BtoFx
    Ysens[i]=ynsd[10+i]*YtfY[f0*10-10]/YtfY[i]*BtoFy
    Zsens[i]=znsd[10+i]*ZtfZ[f0*10-10]/ZtfZ[i]*BtoFz
# Out:
# /data/new_trap/20200320/Bead1/InitialTest/Data52.h5
# No seismometer data
# No z_set data
# No height data
# No electrodes data
# No cantilever data
# No laser power data

# %%
import sys, os

Ndata=3
Dx=378
Fshake=3
DataN=10000
HarmN=20
Noff=3
znsd=np.zeros(25001)

for k in range(700,800):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking/Shaking2_20200403/NoShaking_1_%d.h5" % (NSubData)
    print(fname)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    res = 50000
    data_det=signal.detrend(data)

    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    znsd+=np.sqrt(zpsd)
f0=71
Zsens=np.zeros(991)

for i in range(991):
    Zsens[i]=znsd[10+i]*ZtfZ[f0*10-10]/ZtfZ[i]*BtoFz
# Out:
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_700.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_701.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_702.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_703.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_704.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_705.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_706.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_707.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_708.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_709.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_710.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_711.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_712.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_713.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_714.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_715.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_716.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_717.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_718.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_719.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_720.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_721.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_722.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_723.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_724.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_725.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_726.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_727.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_728.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_729.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_730.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_731.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_732.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_733.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_734.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_735.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_736.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_737.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_738.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_739.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_740.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_741.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_742.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_743.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_744.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_745.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_746.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_747.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_748.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_749.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_750.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_751.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_752.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_753.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_754.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_755.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_756.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_757.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_758.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_759.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_760.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_761.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_762.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_763.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_764.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_765.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_766.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_767.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_768.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_769.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_770.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_771.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_772.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_773.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_774.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_775.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_776.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_777.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_778.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_779.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_780.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_781.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_782.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_783.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_784.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_785.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_786.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_787.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_788.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_789.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_790.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_791.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_792.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_793.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_794.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_795.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_796.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_797.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_798.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/NoShaking_1_799.h5
# No seismometer data
# No z_set data

# %%
Ndata=3
Dx=378
Fshake=3
DataN=10000
HarmN=20
Noff=3
z2nsd=np.zeros(25001)

for k in range(1000,1100):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    print(fname)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    res = 50000
    data_det=signal.detrend(data)

    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    z2nsd+=np.sqrt(zpsd)
f0=71
Z2sens=np.zeros(991)

for i in range(991):
    Z2sens[i]=z2nsd[10+i]*ZtfZ[f0*10-10]/ZtfZ[i]*BtoFz
# Out:
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1000.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1001.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1002.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1003.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1004.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1005.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1006.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1007.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1008.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1009.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1010.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1011.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1012.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1013.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1014.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1015.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1016.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1017.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1018.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1019.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1020.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1021.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1022.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1023.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1024.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1025.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1026.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1027.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1028.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1029.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1030.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1031.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1032.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1033.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1034.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1035.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1036.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1037.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1038.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1039.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1040.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1041.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1042.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1043.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1044.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1045.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1046.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1047.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1048.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1049.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1050.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1051.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1052.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1053.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1054.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1055.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1056.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1057.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1058.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1059.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1060.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1061.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1062.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1063.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1064.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1065.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1066.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1067.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1068.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1069.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1070.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1071.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1072.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1073.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1074.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1075.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1076.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1077.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1078.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1079.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1080.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1081.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1082.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1083.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1084.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1085.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1086.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1087.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1088.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1089.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1090.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1091.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1092.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1093.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1094.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1095.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1096.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1097.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1098.h5
# No seismometer data
# No z_set data
# /data/new_trap/20200320/Bead1/Shaking/Shaking378/Shaking3_1099.h5
# No seismometer data
# No z_set data

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
freqs=np.linspace(0, 2500, num=25001, endpoint=True)
freqs2=np.linspace(1, 100, num=991, endpoint=True)
#ax.semilogy(freqs,znsd/100, '.-', label="w/o shaking",markersize=1,linewidth=1)
#ax.semilogy(freqs,z2nsd/100, '.-', label="w/ shaking",markersize=1,linewidth=1)
ax.semilogy(freqs2,Zsens/100, '.-', label="w/o shaking",markersize=1,linewidth=1)
ax.semilogy(freqs2,Z2sens/100, '.-', label="w/ shaking",markersize=1,linewidth=1)


ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force ASD [N/√Hz]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0,60)
plt.ylim(3e-17,1e-15)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivity1-100HzSemi_%dNewDischarge.png" % Ndata

#plt.savefig(ofname,dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
##Get the signal model

# %%
import numpy as np
import pickle as pkl
import scipy.interpolate as interp
import scipy, sys, time
from bisect import bisect_left
import matplotlib.pyplot as plt
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile
from discharge_tools import load_dir
sys.path.append('/home/analysis_user/New_trap_code/SensitivityFramework/')
from signal_model_utilities_v3 import *

# %%
##above one looks to be wrong. with correct parameter;
#for z force, 3/20 Bead1, Shaking378_3

L=10
D=13.9#10.39+3.8 #this becomes14.19
H=-15.23#-15.7
Fshake=3
test = force_vs_time(D,H,-202,Fshake,"z",L,yuk_or_grav="yuk",alpha=1e10,offset_y=4.9,bead_size=7.6)
ofname = "/data/new_trap/Results/AkioK/2020_11_18_Analysis0320Bead1/SignalZD%dumH%dumL%.02fBugFixed.txt" % (D,H,L)


fsamp=5000
res=50000

norm = np.sqrt(2 / (res* fsamp))

s = np.arange(0, 5, 0.0001)
for i in range(0,10):
    for j in range(0,5000):
        s[j+i*5000]=test[1][j]

sFFT=np.fft.rfft(s)
spsd = (sFFT * sFFT.conj()).real
spsd = norm**2 * (sFFT * sFFT.conj()).real
snsd=np.sqrt(spsd)
Zsigmod=np.zeros(991)
# Out:
# Loading Gravity Data... Done!
# 81 9.74070978211e-06
# Loaded Yukawa Force

# %%
Zsigmod=np.zeros(991)
for i in range(0,991):
    Zsigmod[i]=snsd[10+i]

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
freqs=np.linspace(0, 2500, num=25001, endpoint=True)
freqs2=np.linspace(1, 100, num=991, endpoint=True)
#ax.semilogy(freqs,znsd/100, '.-', label="w/o shaking",markersize=1,linewidth=1)
#ax.semilogy(freqs,z2nsd/100, '.-', label="w/ shaking",markersize=1,linewidth=1)
ax.semilogy(freqs2,Zsens/100+Zsigmod, '.--', label="Noise+signal model",markersize=5,linewidth=1)
ax.semilogy(freqs2,Zsens/100, '-', label="Noise only",markersize=1,linewidth=1,color='g')
ax.semilogy(freqs2,Z2sens/100, '-', label="w/ shaking",markersize=1,linewidth=1,color='r')



ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force ASD [N/√Hz]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0,60)
plt.ylim(3e-17,1e-15)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivity1-100HzSemi_%dNewDischarge.png" % Ndata

#plt.savefig(ofname,dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
freqs=np.linspace(0, 2500, num=25001, endpoint=True)
freqs2=np.linspace(1, 100, num=991, endpoint=True)
#ax.semilogy(freqs,znsd/100, '.-', label="w/o shaking",markersize=1,linewidth=1)
#ax.semilogy(freqs,z2nsd/100, '.-', label="w/ shaking",markersize=1,linewidth=1)
ax.semilogy(freqs2,Zsens/100+Zsigmod, '.--',markersize=5,linewidth=1)
ax.semilogy(freqs2,Zsens/100, '-',markersize=1,linewidth=1,color='g')
ax.semilogy(freqs2,Z2sens/100, '-',markersize=1,linewidth=1,color='r')



#ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force ASD [N/√Hz]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0,80)
plt.ylim(3e-17,1e-15)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivity1-100HzSemi_%dNewDischarge.png" % Ndata

#plt.savefig(ofname,dpi=300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import scipy, sys, time

# %%
DataN=991
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivityPaper2.txt" 
f1 = open(ofname,"a")
for k in range(0,DataN):
    f1.write('%f %e \n' % (freqs2[k],Zsens[k]/100))
f1.close()

ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/SignalPaper2.txt" 
f1 = open(ofname,"a")
for k in range(0,DataN):
    f1.write('%f %e \n' % (freqs2[k],Z2sens[k]/100))
f1.close()          
             
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/SignalModelPaper2.txt" 
f1 = open(ofname,"a")
for k in range(0,DataN):
    f1.write('%f %e \n' % (freqs2[k],Zsigmod[k]))
f1.close()
