# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import mlab

from scipy import signal
import h5py, time

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile

# %%
##Force Calibration with single freq, with xyz2

# %%
Year = "2020"
Month = "02"
Day = "03"
BeadNumber =1
folder = r"/data/new_trap/"+ Year + Month + Day

# %%
ResX=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=263+i
    SigFreq=151
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResX[i]=np.sqrt(xpsd[SigFreq*10])
    print(np.sqrt(xpsd[SigFreq*10]))
    #print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 0.0023750285314367487
# 0.002378962868290629
# 0.0023822927551997706
# 0.0023354630663001675
# 0.002329927750829756

# %%
ResY=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=268+i
    SigFreq=151
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResY[i]=np.sqrt(ypsd[SigFreq*10])    
    #print(np.sqrt(xpsd[SigFreq*10]))
    print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 0.002100517392977425
# 0.0020937725470838706
# 0.0020790371657735387
# 0.002096421970818025
# 0.002099076072980181

# %%
ResZ=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=273+i
    SigFreq=151
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResZ[i]=np.sqrt(zpsd[SigFreq*10])    
    print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 7505.212937844892
# 7429.682556036644
# 7476.9614679160295
# 7356.434497894171
# 7372.600544483596

# %%
q=9
V=10
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)*np.sqrt(5)
print(F)
# Out:
# 4.8734321545894835e-15

# %%
AveX=np.average(ResX)
AveY=np.average(ResY)
AveZ=np.average(ResZ)
BtoFx=F/AveX
BtoFy=F/AveY
BtoFz=F/AveZ
print(BtoFx)
print(BtoFy)
print(BtoFz)
# Out:
# 2.0647205443838908e-12
# 2.3275926787067935e-12
# 6.56073655156373e-19

# %%
##code for Transfer Function

# %%
##X preparation
NdataX=13
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_X_%d.h5" % NdataX
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res=50000
data_det=signal.detrend(data)
fbase=7

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
Noise0X=np.sqrt(xpsd[fbase*10])
XnoiseX=np.sqrt(xpsd)
XnoiseY=np.sqrt(ypsd)
XnoiseZ=np.sqrt(zpsd)
# Out:
# No height data
# No cantilever data
# Error loading spinning data

# %%
##Y preparataion
NdataY=14
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Y_%d.h5" % NdataY
BDF = BeadDataFile.BeadDataFile(fname) 
data = BDF.xyz2 
res=50000 
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none) 
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none) 
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none) 
Noise0Y=np.sqrt(ypsd[fbase*10]) 
YnoiseX=np.sqrt(xpsd) 
YnoiseY=np.sqrt(ypsd) 
YnoiseZ=np.sqrt(zpsd)
# Out:
# No height data
# No cantilever data
# Error loading spinning data

# %%
##Z preparation
NdataZ=15
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Z_%d.h5" % NdataZ
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res=50000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
Noise0Z=np.sqrt(zpsd[fbase*10])
ZnoiseX=np.sqrt(xpsd)
ZnoiseY=np.sqrt(ypsd)
ZnoiseZ=np.sqrt(zpsd)
# Out:
# No height data
# No cantilever data
# Error loading spinning data

# %%
#Here, there is no conversion factor
q=9
V=0.65
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)
Nharm=100

FnoiseXX=XnoiseX
FnoiseXY=XnoiseY
FnoiseXZ=XnoiseZ
FnoiseYX=YnoiseX
FnoiseYY=YnoiseY
FnoiseYZ=YnoiseZ
FnoiseZX=ZnoiseX
FnoiseZY=ZnoiseY
FnoiseZZ=ZnoiseZ

TFXX=np.zeros(Nharm)
TFXY=np.zeros(Nharm)
TFXZ=np.zeros(Nharm)
TFYX=np.zeros(Nharm)
TFYY=np.zeros(Nharm)
TFYZ=np.zeros(Nharm)
TFZX=np.zeros(Nharm)
TFZY=np.zeros(Nharm)
TFZZ=np.zeros(Nharm)

FreqTF=np.zeros(Nharm)
for i in range(Nharm):
    FreqTF[i]=fbase*(i+1)
    TFXX[i]=FnoiseXX[fbase*10*(i+1)]
    TFXY[i]=FnoiseXY[fbase*10*(i+1)]
    TFXZ[i]=FnoiseXZ[fbase*10*(i+1)]
    TFYX[i]=FnoiseYX[fbase*10*(i+1)]
    TFYY[i]=FnoiseYY[fbase*10*(i+1)]
    TFYZ[i]=FnoiseYZ[fbase*10*(i+1)]
    TFZX[i]=FnoiseZX[fbase*10*(i+1)]
    TFZY[i]=FnoiseZY[fbase*10*(i+1)]
    TFZZ[i]=FnoiseZZ[fbase*10*(i+1)]

# %%
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TFBead%d%d%d_Bit.txt" % (NdataX,NdataY,NdataZ)

f1 = open(ofname,"a")
for i in range(Nharm):
    f1.write('%f %e %e %e %e %e %e %e %e %e\n' % (FreqTF[i],TFXX[i],TFXY[i],TFXZ[i],
                                                  TFYX[i],TFYY[i],TFYZ[i],TFZX[i],TFZY[i],TFZZ[i]))
f1.close()

# %%
## Plotting the force sensitivity with transfer function compensation

# %%
Ndata=24
fname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata
print(fname)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res = 5000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)

w0x=292.074
gx=39.0032
w0y=300.148
gy=26.9106
w0z=289.137
gz=210.248

f0=151
F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
ax.loglog(freqs, xnsd, '.-', label="x",markersize=1,linewidth=1)
ax.loglog(freqs, ynsd, '.-', label="y",markersize=1,linewidth=1)
ax.loglog(freqs, znsd, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
if (res==5000):
    ax.set_ylabel('Force NSD [N/√Hz]',fontsize=18)
elif (res==50000):
    ax.set_ylabel('Force NSD [N/√0.1Hz]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,500)
plt.ylim(1e-18,1e-14)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivity%d.png" % Ndata

plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##1000 Data Analysis

# %%
#analyzing multiple data in single number
Nint=2
Ndata=7
Dx=382
Fshake=7
for k in range(0,1000):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(res/2)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=151
    F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
    F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
    F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XSignalNint2%d_%d.txt" % (Dx,Ndata,NSubData)

    f1 = open(ofname,"a")
    for i in range(1,21):
        Intx=xFFT[Fshake*10*i]
        IntNSDx=xnsd[Fshake*10*i]
        Inty=yFFT[Fshake*10*i]
        IntNSDy=ynsd[Fshake*10*i]
        Intz=zFFT[Fshake*10*i]
        IntNSDz=znsd[Fshake*10*i]

        for j in range(1,(Nint)):
            Intx+=xFFT[Fshake*10*i+j]+xFFT[Fshake*10*i-j]
            IntNSDx+=xnsd[Fshake*10*i+j]+xnsd[Fshake*10*i-j]
            Inty+=yFFT[Fshake*10*i+j]+yFFT[Fshake*10*i-j]
            IntNSDy+=ynsd[Fshake*10*i+j]+ynsd[Fshake*10*i-j]
            Intz+=zFFT[Fshake*10*i+j]+zFFT[Fshake*10*i-j]
            IntNSDz+=znsd[Fshake*10*i+j]+znsd[Fshake*10*i-j]

        AveNoiseX=0
        AveNoiseY=0
        AveNoiseZ=0
        SigAmpX=IntNSDx
        SigPhaX=np.angle(Intx) 
        SigAmpY=IntNSDy
        SigPhaY=np.angle(Inty) 
        SigAmpZ=IntNSDz
        SigPhaZ=np.angle(Intz) 
        
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, SigAmpY, SigAmpZ, SigPhaX, SigPhaY, SigPhaZ))
    f1.close()

# %%
##Extracting Cantilever Position Data for y

# %%
Ndata=24
Dx=377
for k in range(0,1):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data=BDF.cant_pos
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/CantPosY%d_%d.txt" % (Dx,Ndata,NSubData)
    f1 = open(ofname,"a")
    for i in  range(0,50000):
        f1.write('%f\n' % data[1][i])
    f1.close()
# Out:
# No height data

# %%
##Extracting QPD sum information

# %%
Ndata=24
Dx=377
for k in range(0,1):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data=BDF.quad_sum
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/BeamProfile%d_%dQuadSumY.txt" % (Dx,Ndata,NSubData)
    f1 = open(ofname,"a")
    for i in  range(0,50000):
        f1.write('%d\n' % data[i])
    f1.close()
# Out:
# No height data

# %%
##for Noise only analysis for sensitivity. Used bin of 3*n-0.7 Hz, Nint=2
Nint=0
Ndata=6
Dx=382
Fshake=3
for k in range(0,1000):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(res/2)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=151
    F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
    F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
    F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise%d_%d.txt" % (Dx,Ndata,NSubData)

    f1 = open(ofname,"a")

    for i in range(1,21):
        Intx=xFFT[Fshake*10*i-7]
        IntNSDx=xnsd[Fshake*10*i-7]
        Inty=yFFT[Fshake*10*i-7]
        IntNSDy=ynsd[Fshake*10*i-7]
        Intz=zFFT[Fshake*10*i-7]
        IntNSDz=znsd[Fshake*10*i-7]

        for j in range(1,(Nint)):
            Intx+=xFFT[Fshake*10*i+j-7]+xFFT[Fshake*10*i-j-7]
            IntNSDx+=xnsd[Fshake*10*i+j-7]+xnsd[Fshake*10*i-j-7]
            Inty+=yFFT[Fshake*10*i+j-7]+yFFT[Fshake*10*i-j-7]
            IntNSDy+=ynsd[Fshake*10*i+j-7]+ynsd[Fshake*10*i-j-7]
            Intz+=zFFT[Fshake*10*i+j-7]+zFFT[Fshake*10*i-j-7]
            IntNSDz+=znsd[Fshake*10*i+j-7]+znsd[Fshake*10*i-j-7]

        AveNoiseX=0
        AveNoiseY=0
        AveNoiseZ=0
        SigAmpX=IntNSDx
        SigPhaX=np.angle(Intx) 
        SigAmpY=IntNSDy
        SigPhaY=np.angle(Inty) 
        SigAmpZ=IntNSDz
        SigPhaZ=np.angle(Intz) 
        
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, SigAmpY, SigAmpZ, SigPhaX, SigPhaY, SigPhaZ))
    f1.close()

# %%
##for Noise only analysis for sensitivity. Used bin of 3*n+0.7 Hz, Nint=0
Nint=0
Ndata=6
Dx=382
Fshake=3
for k in range(0,1000):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(res/2)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=151
    F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
    F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
    F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoisePlus%d_%d.txt" % (Dx,Ndata,NSubData)

    f1 = open(ofname,"a")

    for i in range(1,21):
        Intx=xFFT[Fshake*10*i+7]
        IntNSDx=xnsd[Fshake*10*i+7]
        Inty=yFFT[Fshake*10*i+7]
        IntNSDy=ynsd[Fshake*10*i+7]
        Intz=zFFT[Fshake*10*i+7]
        IntNSDz=znsd[Fshake*10*i+7]

        for j in range(1,(Nint)):
            Intx+=xFFT[Fshake*10*i+j+7]+xFFT[Fshake*10*i-j+7]
            IntNSDx+=xnsd[Fshake*10*i+j+7]+xnsd[Fshake*10*i-j+7]
            Inty+=yFFT[Fshake*10*i+j+7]+yFFT[Fshake*10*i-j+7]
            IntNSDy+=ynsd[Fshake*10*i+j+7]+ynsd[Fshake*10*i-j+7]
            Intz+=zFFT[Fshake*10*i+j+7]+zFFT[Fshake*10*i-j+7]
            IntNSDz+=znsd[Fshake*10*i+j+7]+znsd[Fshake*10*i-j+7]

        AveNoiseX=0
        AveNoiseY=0
        AveNoiseZ=0
        SigAmpX=IntNSDx
        SigPhaX=np.angle(Intx) 
        SigAmpY=IntNSDy
        SigPhaY=np.angle(Inty) 
        SigAmpZ=IntNSDz
        SigPhaZ=np.angle(Intz) 
        
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, SigAmpY, SigAmpZ, SigPhaX, SigPhaY, SigPhaZ))
    f1.close()

# %%
##for Noise only analysis for sensitivity. Used bin of 3*n-0.7 Hz, Nint=2
Nint=2
Ndata=6
Dx=382
Fshake=3
for k in range(0,1000):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(res/2)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=151
    F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
    F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
    F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoiseInt%d_%d.txt" % (Dx,Ndata,NSubData)

    f1 = open(ofname,"a")

    for i in range(1,21):
        Intx=xFFT[Fshake*10*i-7]
        IntNSDx=xnsd[Fshake*10*i-7]
        Inty=yFFT[Fshake*10*i-7]
        IntNSDy=ynsd[Fshake*10*i-7]
        Intz=zFFT[Fshake*10*i-7]
        IntNSDz=znsd[Fshake*10*i-7]

        for j in range(1,(Nint)):
            Intx+=xFFT[Fshake*10*i+j-7]+xFFT[Fshake*10*i-j-7]
            IntNSDx+=xnsd[Fshake*10*i+j-7]+xnsd[Fshake*10*i-j-7]
            Inty+=yFFT[Fshake*10*i+j-7]+yFFT[Fshake*10*i-j-7]
            IntNSDy+=ynsd[Fshake*10*i+j-7]+ynsd[Fshake*10*i-j-7]
            Intz+=zFFT[Fshake*10*i+j-7]+zFFT[Fshake*10*i-j-7]
            IntNSDz+=znsd[Fshake*10*i+j-7]+znsd[Fshake*10*i-j-7]

        AveNoiseX=0
        AveNoiseY=0
        AveNoiseZ=0
        SigAmpX=IntNSDx
        SigPhaX=np.angle(Intx) 
        SigAmpY=IntNSDy
        SigPhaY=np.angle(Inty) 
        SigAmpZ=IntNSDz
        SigPhaZ=np.angle(Intz) 
        
        f1.write('%f %e %e %e %e %e %e\n' % (Fshake*i, SigAmpX, SigAmpY, SigAmpZ, SigPhaX, SigPhaY, SigPhaZ))
    f1.close()

# %%
##analysis of the 100 discharge data

# %%
#analyzing multiple data in single number
Nint=0
Fshake=151
for k in range(0,800):
    NData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/NoiseCharacterization"+"/Discharge_%d.h5" % NData
    print(fname)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(res/2)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=151
    F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
    F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
    F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    ofname = folder+"/Bead"+str(BeadNumber)+"/NoiseCharacterization"+"/DischargeResponse.txt" 

    i=1;
    f1 = open(ofname,"a")
    Intx=xFFT[Fshake*10*i]
    IntNSDx=xnsd[Fshake*10*i]
    Inty=yFFT[Fshake*10*i]
    IntNSDy=ynsd[Fshake*10*i]
    Intz=zFFT[Fshake*10*i]
    IntNSDz=znsd[Fshake*10*i]


    SigAmpX=IntNSDx
    SigPhaX=np.angle(Intx) 
    SigAmpY=IntNSDy
    SigPhaY=np.angle(Inty) 
    SigAmpZ=IntNSDz
    SigPhaZ=np.angle(Intz) 
    print(SigAmpZ)
        
    f1.write('%f %e %e %e %e %e %e\n' % (k, SigAmpX, SigAmpY, SigAmpZ, SigPhaX, SigPhaY, SigPhaZ))
    f1.close()
# Out:
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge
-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_779.h5
# 7.487950459423684e-18
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_780.h5
# 1.0836955153881661e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_781.h5
# 1.142710378624969e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_782.h5
# 2.0792187095082845e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_783.h5
# 1.1003642350620768e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_784.h5
# 2.007305081963889e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_785.h5
# 1.973588119665065e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_786.h5
# 8.7970034105747e-18
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_787.h5
# 1.3022711701099536e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_788.h5
# 1.521305258107555e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_789.h5
# 3.8599868830359615e-18
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_790.h5
# 1.5110315519570856e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_791.h5
# 1.2724984051547065e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_792.h5
# 1.6238612261178475e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_793.h5
# 2.5095755534594908e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_794.h5
# 1.2835905400865922e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_795.h5
# 9.244481665230373e-18
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_796.h5
# 7.017395784269227e-18
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_797.h5
# 2.048506543217165e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_798.h5
# 1.419010436181831e-17
# /data/new_trap/20200203/Bead1/NoiseCharacterization/Discharge_799.h5
# 1.8738798064665297e-17

# %%
##combining the "#analyzing multiple data in single number,"  
##"##for Noise only analysis for sensitivity. Used bin of 3*n+0.7 Hz, Nint=0", and SortDataTo Harmonics

# %%
#DefineParameters
Nint=0
Ndata=6
Dx=382
Fshake=3
DataN=10
HarmN=20
Noff=7
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(res/2)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=151
    F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
    F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
    F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
   

        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/XSignalTest%d_%d_%dthHarm.txt" % (Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/XNoiseTest%d_%d_%dthHarm.txt" % (Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()

# %%
DataN=2
HarmN=3
ArraySize=(DataN,HarmN)
DataSpace=np.zeros(ArraySize)

# %%
DataSpace[0][0]=1.01
DataSpace[0][1]=1.02
DataSpace[0][2]=1.03
DataSpace[1][0]=2.01
DataSpace[1][1]=2.02
DataSpace[1][2]=2.03

print(DataSpace)
# Out:
# [[1.01 1.02 1.03]
#  [2.01 2.02 2.03]]
