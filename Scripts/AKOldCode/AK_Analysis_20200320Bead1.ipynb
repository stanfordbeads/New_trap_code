# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import mlab

from scipy import signal
import h5py, time

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('/home/analysis_user/New_trap_code/Tools/')
import BeadDataFile

# %%
##Force Calibration with single freq, with xyz2

# %%
Year = "2020"
Month = "03"
Day = "20"
BeadNumber =1
folder = r"/data/new_trap/"+ Year + Month + Day

# %%
ResX=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=225+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResX[i]=np.sqrt(xpsd[SigFreq*10])
    print(np.sqrt(xpsd[SigFreq*10]))
    #print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 5.3185713932357e-05
# 5.1842811720905074e-05
# 5.1996097914346046e-05
# 4.8568596183011135e-05
# 5.419660819213425e-05

# %%
ResY=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=230+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResY[i]=np.sqrt(ypsd[SigFreq*10])    
    #print(np.sqrt(xpsd[SigFreq*10]))
    print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 7.459615175107814e-05
# 7.108187292529642e-05
# 6.994467719258683e-05
# 6.256675237016993e-05
# 6.979445574692227e-05

# %%
ResZ=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=220+i
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/Discharge_after_Mass_20200402/After_spinning_again_20200403"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResZ[i]=np.sqrt(zpsd[SigFreq*10])    
    print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 593.1042094526559
# 604.2796408368257
# 593.7653481702566
# 599.8167847192939
# 610.4468798499673

# %%
q=6
V=10
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)*np.sqrt(5)
print(F)
# Out:
# 3.2489547697263225e-15

# %%
AveX=np.average(ResX)
AveY=np.average(ResY)
AveZ=np.average(ResZ)
BtoFx=F/AveX
BtoFy=F/AveY
BtoFz=F/AveZ
print(BtoFx)
print(BtoFy)
print(BtoFz)
# Out:
# 6.25304461582355e-11
# 4.668254302126402e-11
# 5.41237563439957e-18

# %%
##auxiliary force calibration. New_Discharge is a useful data

# %%
ResX=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=5+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/New_Discharge"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResX[i]=np.sqrt(xpsd[SigFreq*10])
    print(np.sqrt(xpsd[SigFreq*10]))
    #print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 0.0002710659109235403
# 0.0002754358247428201
# 0.00027374295606173607
# 0.00026931560399147365
# 0.0002774851026748514

# %%
ResY=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=10+i
    SigFreq=71
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/New_Discharge"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResY[i]=np.sqrt(ypsd[SigFreq*10])    
    #print(np.sqrt(xpsd[SigFreq*10]))
    print(np.sqrt(ypsd[SigFreq*10]))
    #print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 0.0003283005068077278
# 0.00033345278668207574
# 0.0003315063385773604
# 0.0003276605922930189
# 0.0003268623871889636

# %%
ResZ=np.arange(0, 0.5, 0.1)
for i in range(0,5):
    Ndata=0+i
    fname = folder+"/Bead"+str(BeadNumber)+"/Discharge/New_Discharge"+"/Discharge_%d.h5" % Ndata
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000
    data_det=signal.detrend(data)

    xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
    zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
    ResZ[i]=np.sqrt(zpsd[SigFreq*10])    
    print(np.sqrt(zpsd[SigFreq*10]))
# Out:
# 757.3256996396474
# 743.4378086531398
# 755.8859297272302
# 736.3401685816547
# 754.2909795107544

# %%
q=6
V=10
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)*np.sqrt(5)
print(F)
# Out:
# 3.2489547697263225e-15

# %%
AveX=np.average(ResX)
AveY=np.average(ResY)
AveZ=np.average(ResZ)
BtoFx=F/AveX
BtoFy=F/AveY
BtoFz=F/AveZ
print(BtoFx)
print(BtoFy)
print(BtoFz)
# Out:
# 1.1883126827909961e-11
# 9.858566132919224e-12
# 4.335083395899256e-18

# %%
##code for Transfer Function- 7Hz

# %%
##X preparation
Ndata=11
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_X_m800k_150s_7hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res=50000
data_det=signal.detrend(data)
fbase=7

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
Noise0X=np.sqrt(xpsd[fbase*10])
XnoiseX=np.sqrt(xpsd)
XnoiseY=np.sqrt(ypsd)
XnoiseZ=np.sqrt(zpsd)
# Out:
# No height data
# No cantilever data
# Error loading spinning data

# %%
##Y preparataion
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Y_m800k_150s_7hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname) 
data = BDF.xyz2 
res=50000 
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none) 
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none) 
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none) 
Noise0Y=np.sqrt(ypsd[fbase*10]) 
YnoiseX=np.sqrt(xpsd) 
YnoiseY=np.sqrt(ypsd) 
YnoiseZ=np.sqrt(zpsd)
# Out:
# No height data
# No cantilever data
# Error loading spinning data

# %%
##Z preparation

fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Z_m800k_150s_7hz.h5" #% Ndata
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res=50000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
Noise0Z=np.sqrt(zpsd[fbase*10])
ZnoiseX=np.sqrt(xpsd)
ZnoiseY=np.sqrt(ypsd)
ZnoiseZ=np.sqrt(zpsd)
# Out:
# No height data
# No cantilever data
# Error loading spinning data

# %%
#Here, there is no conversion factor
q=10
V=0.65
F=(q*1.602e-19)*(V*2/8.6e-3*0.65)
Nharm=100

FnoiseXX=XnoiseX
FnoiseXY=XnoiseY
FnoiseXZ=XnoiseZ
FnoiseYX=YnoiseX
FnoiseYY=YnoiseY
FnoiseYZ=YnoiseZ
FnoiseZX=ZnoiseX
FnoiseZY=ZnoiseY
FnoiseZZ=ZnoiseZ

TFXX=np.zeros(Nharm)
TFXY=np.zeros(Nharm)
TFXZ=np.zeros(Nharm)
TFYX=np.zeros(Nharm)
TFYY=np.zeros(Nharm)
TFYZ=np.zeros(Nharm)
TFZX=np.zeros(Nharm)
TFZY=np.zeros(Nharm)
TFZZ=np.zeros(Nharm)

FreqTF=np.zeros(Nharm)
for i in range(Nharm):
    FreqTF[i]=fbase*(i+1)
    TFXX[i]=FnoiseXX[fbase*10*(i+1)]
    TFXY[i]=FnoiseXY[fbase*10*(i+1)]
    TFXZ[i]=FnoiseXZ[fbase*10*(i+1)]
    TFYX[i]=FnoiseYX[fbase*10*(i+1)]
    TFYY[i]=FnoiseYY[fbase*10*(i+1)]
    TFYZ[i]=FnoiseYZ[fbase*10*(i+1)]
    TFZX[i]=FnoiseZX[fbase*10*(i+1)]
    TFZY[i]=FnoiseZY[fbase*10*(i+1)]
    TFZZ[i]=FnoiseZZ[fbase*10*(i+1)]

# %%
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TFBead%d_Bit.txt" % (Ndata)

f1 = open(ofname,"a")
for i in range(Nharm):
    f1.write('%f %e %e %e %e %e %e %e %e %e\n' % (FreqTF[i],TFXX[i],TFXY[i],TFXZ[i],
                                                  TFYX[i],TFYY[i],TFYZ[i],TFZX[i],TFZY[i],TFZZ[i]))
f1.close()

# %%
## Plotting the force sensitivity with transfer function compensation

# %%
Ndata=38
fsamp=5000
fname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata
print(fname)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res = 5000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)

w0x=472.484
gx=32.4034
w0y=406.723
gy=18.0961
w0z=531.948
gz=40.15

f0=71
F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)
# Out:
# /data/new_trap/20200320/Bead1/InitialTest/Data38.h5
# No height data
# No electrodes data
# No cantilever data
# No laser power data

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
ax.loglog(freqs, xnsd, '.-', label="x",markersize=1,linewidth=1)
ax.loglog(freqs, ynsd, '.-', label="y",markersize=1,linewidth=1)
ax.loglog(freqs, znsd, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/√Hz]',fontsize=18)

ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(1,500)
plt.ylim(1e-18,1e-14)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivity%dNewDischarge.png" % Ndata

plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## 1-100 Hz Transfer Function Test

# %%
##X preparation
Ndata=12
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_X_m800k_100s_1Hz_2.h5" #% Ndata
print(fname)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
tInt=100
Nharm=100
fsamp=5000
res=fsamp*tInt
fBase=1;

data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
XnoiseX=np.sqrt(xpsd)
XnoiseY=np.sqrt(ypsd)
XnoiseZ=np.sqrt(zpsd)
XrespX=np.zeros(Nharm)
XrespY=np.zeros(Nharm)
XrespZ=np.zeros(Nharm)
for i in range (Nharm):
    XrespX[i]=XnoiseX[tInt*(i+1)]
    XrespY[i]=XnoiseY[tInt*(i+1)]
    XrespZ[i]=XnoiseZ[tInt*(i+1)]
    
XtfX=np.zeros(991)
XtfY=np.zeros(991)
XtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        XtfX[i*10+j]=0.1*XrespX[i]*(10-j)+0.1*XrespX[i+1]*j
        XtfY[i*10+j]=0.1*XrespY[i]*(10-j)+0.1*XrespY[i+1]*j
        XtfZ[i*10+j]=0.1*XrespZ[i]*(10-j)+0.1*XrespZ[i+1]*j
XtfX[990]=XrespX[99]
XtfY[990]=XrespY[99]
XtfZ[990]=XrespZ[99]
# Out:
# /data/new_trap/20200320/Bead1/TransFunc/TransFunc_X_m800k_100s_1Hz_2.h5
# No height data
# No cantilever data
# Error loading spinning data

# %%
##Y preparation
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Y_m800k_150s.h5" #% Ndata
print(fname)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2

data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
YnoiseX=np.sqrt(xpsd)
YnoiseY=np.sqrt(ypsd)
YnoiseZ=np.sqrt(zpsd)
YrespX=np.zeros(Nharm)
YrespY=np.zeros(Nharm)
YrespZ=np.zeros(Nharm)
for i in range (Nharm):
    YrespX[i]=YnoiseX[tInt*(i+1)]
    YrespY[i]=YnoiseY[tInt*(i+1)]
    YrespZ[i]=YnoiseZ[tInt*(i+1)]
    
YtfX=np.zeros(991)
YtfY=np.zeros(991)
YtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        YtfX[i*10+j]=0.1*YrespX[i]*(10-j)+0.1*YrespX[i+1]*j
        YtfY[i*10+j]=0.1*YrespY[i]*(10-j)+0.1*YrespY[i+1]*j
        YtfZ[i*10+j]=0.1*YrespZ[i]*(10-j)+0.1*YrespZ[i+1]*j
YtfX[990]=YrespX[99]
YtfY[990]=YrespY[99]
YtfZ[990]=YrespZ[99]
# Out:
# /data/new_trap/20200320/Bead1/TransFunc/TransFunc_Y_m800k_150s.h5
# No height data
# No cantilever data
# Error loading spinning data

# %%
##Z preparation
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Z_m800k_100s_1Hz_2.h5" #% Ndata
print(fname)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2

data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
ZnoiseX=np.sqrt(xpsd)
ZnoiseY=np.sqrt(ypsd)
ZnoiseZ=np.sqrt(zpsd)
ZrespX=np.zeros(Nharm)
ZrespY=np.zeros(Nharm)
ZrespZ=np.zeros(Nharm)
for i in range (Nharm):
    ZrespX[i]=ZnoiseX[tInt*(i+1)]
    ZrespY[i]=ZnoiseY[tInt*(i+1)]
    ZrespZ[i]=ZnoiseZ[tInt*(i+1)]
    
ZtfX=np.zeros(991)
ZtfY=np.zeros(991)
ZtfZ=np.zeros(991)

for i in range (99):
    for j in range(10):
        ZtfX[i*10+j]=0.1*ZrespX[i]*(10-j)+0.1*ZrespX[i+1]*j
        ZtfY[i*10+j]=0.1*ZrespY[i]*(10-j)+0.1*ZrespY[i+1]*j
        ZtfZ[i*10+j]=0.1*ZrespZ[i]*(10-j)+0.1*ZrespZ[i+1]*j
ZtfX[990]=ZrespX[99]
ZtfY[990]=ZrespY[99]
ZtfZ[990]=ZrespZ[99]
# Out:
# /data/new_trap/20200320/Bead1/TransFunc/TransFunc_Z_m800k_100s_1Hz_2.h5
# No height data
# No cantilever data
# Error loading spinning data

# %%
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TFintBit%d.txt" % Ndata

f1 = open(ofname,"a")
for i in range(991):
    f1.write('%f %e %e %e %e %e %e %e %e %e\n' % ((0.1*(i+10)),XtfX[i],XtfY[i],XtfZ[i],YtfX[i],YtfY[i],YtfZ[i],ZtfX[i],ZtfY[i],ZtfZ[i]))

#    f1.write('%f %e %e %e %e %e %e %e %e %e\n' % (FreqTF[i],TFXX[i],TFXY[i],TFXZ[i],
#                                                  TFYX[i],TFYY[i],TFYZ[i],TFZX[i],TFZY[i],TFZZ[i]))
f1.close()

# %%
##force sensitivity

# %%
Ndata=37
fname = folder+"/Bead"+str(BeadNumber)+"/InitialTest"+"/Data%d.h5" % Ndata
print(fname)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
res = 50000
data_det=signal.detrend(data)

xpsd, freqs = matplotlib.mlab.psd(data_det[0], Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(data_det[1], Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(data_det[2], Fs = fsamp, NFFT = res,window=mlab.window_none)
xnsd=np.sqrt(xpsd)
ynsd=np.sqrt(ypsd)
znsd=np.sqrt(zpsd)
f0=71
Xsens=np.zeros(991)
Ysens=np.zeros(991)
Zsens=np.zeros(991)

for i in range(991):
    Xsens[i]=xnsd[10+i]*XtfX[f0*10-10]/XtfX[i]*BtoFx
    Ysens[i]=ynsd[10+i]*YtfY[f0*10-10]/YtfY[i]*BtoFy
    Zsens[i]=znsd[10+i]*ZtfZ[f0*10-10]/ZtfZ[i]*BtoFz
# Out:
# /data/new_trap/20200320/Bead1/InitialTest/Data37.h5
# No height data
# No electrodes data
# No cantilever data

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
ax.semilogy(np.linspace(1,100,991),Xsens, '.-', label="x",markersize=1,linewidth=1)
ax.semilogy(np.linspace(1,100,991),Ysens, '.-', label="y",markersize=1,linewidth=1)
ax.semilogy(np.linspace(1,100,991),Zsens, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/√Hz]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(1,100)
plt.ylim(3e-18,3e-15)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/ForceSensitivity1-100HzSemi_%dNewDischarge.png" % Ndata

plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##combining the "#analyzing multiple data in single number,"  
##"##for Noise only analysis for sensitivity. Used bin of 3*n+0.7 Hz, Nint=0", and SortDataTo Harmonics

# %%
import scipy, sys, time

# %%
import time
start_time = time.time()

#DefineParameters
Ndata=3
Dx=378
Fshake=3
DataN=10000
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XSignal%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# Total run time is  618.8401122093201  s

# %%
## analysis of Shaking 378_3 again
import time
start_time = time.time()

#DefineParameters
Ndata=1
Dx=378
Fshake=3
DataN=5000
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
#    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking2_20200403/NoShaking_%d_%d.h5" % (Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XSignal%d_%d_%dthHarmRev2.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise%d_%d_%dthHarmRev2.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# Total run time is  254.58504033088684  s

# %%
## analysis of grid

# %%
import time
start_time = time.time()

#DefineParameters
Ndata=0
Dx=376
Fshake=3
DataN=100
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking2_20200403/Small_Grid/Shaking%d_%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) 
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking2_20200403/Small_Grid/XSignal%d_%d_%dthHarmRev.txt" % (Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking2_20200403/Small_Grid/XNoise%d_%d_%dthHarmRev.txt" % (Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# Total run time is  7.262481451034546  s

# %%
fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking2_20200403/SmallGrid/Shaking%d_%d_%d.h5" % (Dx,Ndata,NSubData)
print(fname)
/data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/Small_Grid
# Out:
# /data/new_trap/20200320/Bead1/Shaking/Shaking2_20200403/SmallGrid/Shaking372_0_0.h5

# %%
##FFT the data
NData=11
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_X_%d.h5" % NData
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
tInt=10
Nharm=100
fsamp=5000
res=fsamp*tInt
fBase=7;

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]

xFFT=np.fft.rfft(x_1000)
#yFFT=np.fft.rfft(y_1000)
#zFFT=np.fft.rfft(z_1000)

fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Y_%d.h5" % NData
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
tInt=10
Nharm=100
fsamp=5000
res=fsamp*tInt
fBase=7;

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]

yFFT=np.fft.rfft(y_1000)

fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Z_%d.h5" % NData
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
tInt=10
Nharm=100
fsamp=5000
res=fsamp*tInt
fBase=7;

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]

zFFT=np.fft.rfft(z_1000)

norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real

xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

xPha=np.zeros(100)
yPha=np.zeros(100)
zPha=np.zeros(100)
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data

# %%
for i in range(0,100):
    xPha[i]=np.angle(xFFT[fBase*tInt*(i+1)])-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.5
    if(xPha[i]>3):
        xPha[i]-=2*np.pi
    yPha[i]=np.angle(yFFT[fBase*tInt*(i+1)])-(i*i/100-round(i*i/100))*2*3.14159265-np.pi*0.5
    zPha[i]=np.angle(zFFT[fBase*tInt*(i+1)])-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.5

for i in range(0,99):  
    if((yPha[i+1]-yPha[i])>4):
        yPha[i+1]-=2*np.pi
    elif((yPha[i+1]-yPha[i])<-4):
        yPha[i+1]+=2*np.pi
for i in range(0,99):  
    if((yPha[i+1]-yPha[i])>4):
        yPha[i+1]-=2*np.pi
    elif((yPha[i+1]-yPha[i])<-4):
        yPha[i+1]+=2*np.pi
        
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>3):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-3):
        zPha[i+1]+=2*np.pi
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>4):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-4):
        zPha[i+1]+=2*np.pi

     
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
ax.plot(np.linspace(7,700,100),xPha, '.-', label="x",markersize=1,linewidth=1)
ax.plot(np.linspace(7,700,100),yPha, '.-', label="y",markersize=1,linewidth=1)
ax.plot(np.linspace(7,700,100),zPha, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Phase [rad]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(1,100)
#plt.ylim(1e-18,1e-15)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFuncPhase%d.png" % NData

plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Obtain the information of the phase from transfer function- 1Hz

# %%
##FFT the data
NData=12
fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_X_%d.h5" % NData
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
tInt=100
Nharm=100
fsamp=5000
res=fsamp*tInt
fBase=1;

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]

xFFT=np.fft.rfft(x_1000)
#yFFT=np.fft.rfft(y_1000)
#zFFT=np.fft.rfft(z_1000)

fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Y_%d.h5" % NData
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]

yFFT=np.fft.rfft(y_1000)

fname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFunc_Z_%d.h5" % NData
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2

data_det=signal.detrend(data)
x_1000=data_det[0]
y_1000=data_det[1]
z_1000=data_det[2]

zFFT=np.fft.rfft(z_1000)

norm = np.sqrt(2 / (res* fsamp))
xpsd = norm**2 * (xFFT * xFFT.conj()).real
ypsd = norm**2 * (yFFT * yFFT.conj()).real
zpsd = norm**2 * (zFFT * zFFT.conj()).real

xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

xPha=np.zeros(100)
yPha=np.zeros(100)
zPha=np.zeros(100)
# Out:
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data
# No height data
# No cantilever data
# Error loading spinning data

# %%
for i in range(0,100):
    xPha[i]=np.angle(xFFT[fBase*tInt*(i+1)])-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.5
    if(xPha[i]>3):
        xPha[i]-=2*np.pi
    yPha[i]=np.angle(yFFT[fBase*tInt*(i+1)])-(i*i/100-round(i*i/100))*2*3.14159265-np.pi*0.5
    zPha[i]=np.angle(zFFT[fBase*tInt*(i+1)])-(i*i/100-round(i*i/100))*2*3.14159265+np.pi*0.

for i in range(0,99):  
    if((yPha[i+1]-yPha[i])>4):
        yPha[i+1]-=2*np.pi
    elif((yPha[i+1]-yPha[i])<-4):
        yPha[i+1]+=2*np.pi
for i in range(0,99):  
    if((yPha[i+1]-yPha[i])>4):
        yPha[i+1]-=2*np.pi
    elif((yPha[i+1]-yPha[i])<-4):
        yPha[i+1]+=2*np.pi
        
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>3):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-3):
        zPha[i+1]+=2*np.pi
for i in range(0,99):  
    if((zPha[i+1]-zPha[i])>4):
        zPha[i+1]-=2*np.pi
    elif((zPha[i+1]-zPha[i])<-4):
        zPha[i+1]+=2*np.pi

     
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.96, top=0.96, bottom=0.14)
ax.semilogx(np.linspace(1,100,100),xPha, '.-', label="x",markersize=1,linewidth=1)
ax.semilogx(np.linspace(1,100,100),yPha, '.-', label="y",markersize=1,linewidth=1)
ax.semilogx(np.linspace(1,100,100),zPha, '.-', label="z",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Phase [rad]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
#plt.xlim(1,100)
#plt.ylim(1e-18,1e-15)
plt.grid(True)
ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFuncPhase%dRev.png" % NData

plt.savefig(ofname,dpi=300)


ofname = folder+"/Bead"+str(BeadNumber)+"/TransFunc"+"/TransFuncPhase%dRev.txt" % NData
f1 = open(ofname,"a")
for k in range(0,100):
    f1.write('%d %f %f %f\n' % (k+1, xPha[k], yPha[k], zPha[k]))
f1.close()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#1000 measurement analysis with phase information of the transfer function included

# %%
import time
start_time = time.time()

#DefineParameters
Ndata=0
Dx=370
Fshake=3
DataN=1000
HarmN=20
Noff=3
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

p0=65.0917
p1=24.3633
p2=2.59224
p3=-0.00446208


for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=71

    xnsd=np.sqrt(xpsd)*BtoFx#*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy#*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz#*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXSigAmp[k][i-1]=xnsd[Fshake*10*i]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXSigPha[k][i-1]=np.angle(xFFT[Fshake*10*i]) 
        DataSpaceYSigAmp[k][i-1]=ynsd[Fshake*10*i]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYSigPha[k][i-1]=np.angle(yFFT[Fshake*10*i]) 
        DataSpaceZSigAmp[k][i-1]=znsd[Fshake*10*i]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZSigPha[k][i-1]=np.angle(zFFT[Fshake*10*i]) -(p0/(Fshake*i+p1)-p2+p3*Fshake*i)
        
##save noise bin data to the array
    for i in range(1,(HarmN+1)):
        DataSpaceXNoiAmp[k][i-1]=xnsd[Fshake*10*i-Noff]/XtfX[Fshake*10*i-10]*XtfX[f0*10-10]
        DataSpaceXNoiPha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoiAmp[k][i-1]=ynsd[Fshake*10*i-Noff]/YtfY[Fshake*10*i-10]*YtfY[f0*10-10]
        DataSpaceYNoiPha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoiAmp[k][i-1]=znsd[Fshake*10*i-Noff]/ZtfZ[Fshake*10*i-10]*ZtfZ[f0*10-10]
        DataSpaceZNoiPha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff])  -(p0/(Fshake*i+p1)-p2+p3*(Fshake*i-Noff/10))
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XSignal%d_%d_%dthHarmRev.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXSigAmp[k][i-1], DataSpaceYSigAmp[k][i-1], DataSpaceZSigAmp[k][i-1], 
                                            DataSpaceXSigPha[k][i-1], DataSpaceYSigPha[k][i-1], DataSpaceZSigPha[k][i-1]))
    f1.close()
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise%d_%d_%dthHarmRev.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoiAmp[k][i-1], DataSpaceYNoiAmp[k][i-1], DataSpaceZNoiAmp[k][i-1], 
                                            DataSpaceXNoiPha[k][i-1], DataSpaceYNoiPha[k][i-1], DataSpaceZNoiPha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# Total run time is  58.64482545852661  s

# %%
##Extracting Cantilever Position Data for y

# %%
Ndata=24
Dx=377
for k in range(0,1):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data=BDF.cant_pos
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/CantPosY%d_%d.txt" % (Dx,Ndata,NSubData)
    f1 = open(ofname,"a")
    for i in  range(0,50000):
        f1.write('%f\n' % data[1][i])
    f1.close()
# Out:
# No height data

# %%
##Extracting QPD sum information

# %%
Ndata=24
Dx=377
for k in range(0,1):
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data=BDF.quad_sum
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/BeamProfile%d_%dQuadSumY.txt" % (Dx,Ndata,NSubData)
    f1 = open(ofname,"a")
    for i in  range(0,50000):
        f1.write('%d\n' % data[i])
    f1.close()
# Out:
# No height data

# %%
##Getting different parameters from the h5 file

# %%
import time
start_time = time.time()

#DefineParameters
Nint=0
Ndata=3
Dx=384
Fshake=3
DataN=16000
HarmN=20
Noff=7
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/AuxData%d_%d.txt" % (Dx,Dx,Ndata)
f1 = open(ofname,"a")
for k in range(0,DataN):
    if(k%100==0):
        print(k)
    ##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    
    f1.write('%d %f %f %e %d %d\n' % (k, BDF.bead_height, np.average(BDF.feedback[2]), np.average(BDF.quad_sum), 
                                            BDF.time[0], BDF.time[49999]))

f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-91a0291b7c0b> in <module>()
#      31     NSubData=k
#      32     fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
# ---> 33     BDF = BeadDataFile.BeadDataFile(fname)
#      34
#      35     f1.write('%d %f %f %e %d %d\n' % (k, BDF.bead_height, np.average(BDF.feedback[2]), np.average(BDF.quad_sum),
#
# /home/analysis_user/New_trap_code/Tools/BeadDataFile.py in __init__(self, fname)
#      19
#      20         f = h5py.File(fname,'r')
# ---> 21         pos_data = np.array(f['pos_data'])
#      22         quad_data = np.array(f['quad_data'])
#      23         self.fsamp = f.attrs['Fsamp']
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /home/analysis_user/.local/lib/python3.6/site-packages/h5py/_hl/dataset.py in __array__(self, dtype)
#     770             return arr
#     771
# --> 772         self.read_direct(arr)
#     773         return arr
#     774
#
# /home/analysis_user/.local/lib/python3.6/site-packages/h5py/_hl/dataset.py in read_direct(self, dest, source_sel, dest_sel)
#     731
#     732             for mspace in dest_sel.broadcast(source_sel.mshape):
# --> 733                 self.id.read(mspace, fspace, dest, dxpl=self._dxpl)
#     734
#     735     def write_direct(self, source, source_sel=None, dest_sel=None):
#
# KeyboardInterrupt:

# %%
##Following is for extracting temperature data

# %%
import time
import datetime as dt
import os
start_time = time.time()

#DefineParameters
Nint=0
Ndata=3
Dx=384
Fshake=3
DataN=16000
HarmN=20
Noff=7
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)


ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/TempDataRev%d_%d.txt" % (Dx,Dx,Ndata)
f1 = open(ofname,"a")
for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    DataTime=dt.datetime.fromtimestamp(BDF.time[49998]/1e9)
#    print(k,DataTime)
    if(k%100==0):
        print(k,DataTime)
    yr=DataTime.year
    mo=DataTime.month
    day=DataTime.day
    hr=DataTime.hour
    mn=DataTime.minute
    sec=DataTime.second
#    print(yr, mo, day, hr, mn, sec)
    SCfname= "/data/SC_data/TemperatureAndPressure%d%02d%02d/TempAndPressure%d%02d%02d_%02d.hdf5" %(yr,mo,day,yr,mo,day,hr)
    if os.path.exists(SCfname):
        SCf=h5py.File(SCfname,'r')
        f1.write('%d %d %f %f %f\n' % (k, BDF.time[49999], SCf['Pressure/Pressures'][(mn*60+sec)], SCf['AirTemperature/AirTemperatures'][(mn*60+sec)], SCf['SurfaceTemperature/SurfaceTemperatures'][(mn*60+sec)]))
        SCf.close()
    else:
        print(k,"file", SCfname, "does not exist")
f1.close()    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0 2020-02-15 10:32:36.702309
# 100 2020-02-15 10:49:57.341666
# 116 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 125 file /data/SC_data/TemperatureAndPressure25431005/TempAndPressure25431005_08.hdf5 does not exist
# 132 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 136 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 154 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 200 2020-02-15 11:07:21.979118
# 227 file /data/SC_data/TemperatureAndPressure25500808/TempAndPressure25500808_15.hdf5 does not exist
# 228 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 268 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 278 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 292 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 300 2020-02-15 11:24:48.989026
# 383 file /data/SC_data/TemperatureAndPressure25440609/TempAndPressure25440609_18.hdf5 does not exist
# 400 2020-02-15 11:42:08.157748
# 500 2020-02-15 11:59:34.049030
# 513 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 583 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 600 2020-02-15 12:16:52.838943
# 611 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 645 file /data/SC_data/TemperatureAndPressure25441106/TempAndPressure25441106_10.hdf5 does not exist
# 683 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 700 2020-02-15 12:34:16.119163
# 704 file /data/SC_data/TemperatureAndPressure22690304/TempAndPressure22690304_07.hdf5 does not exist
# 748 file /data/SC_data/TemperatureAndPressure25501007/TempAndPressure25501007_12.hdf5 does not exist
# 787 file /data/SC_data/TemperatureAndPressure25000628/TempAndPressure25000628_04.hdf5 does not exist
# 799 file /data/SC_data/TemperatureAndPressure25531003/TempAndPressure25531003_00.hdf5 does not exist
# 800 2020-02-15 12:51:37.824345
# 833 file /data/SC_data/TemperatureAndPressure25510531/TempAndPressure25510531_09.hdf5 does not exist
# 834 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 847 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 876 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 900 2020-02-15 13:08:59.927537
# 918 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 988 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 1000 2020-02-15 13:26:21.258911
# 1006 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1008 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1026 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1027 file /data/SC_data/TemperatureAndPressure25511105/TempAndPressure25511105_06.hdf5 does not exist
# 1030 file /data/SC_data/TemperatureAndPressure25520123/TempAndPressure25520123_14.hdf5 does not exist
# 1039 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 1100 2020-02-15 13:43:45.423551
# 1138 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1200 2020-02-15 14:01:06.957730
# 1201 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1214 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1238 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1272 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 1276 file /data/SC_data/TemperatureAndPressure25530913/TempAndPressure25530913_03.hdf5 does not exist
# 1277 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1300 2020-02-15 14:18:38.171336
# 1318 file /data/SC_data/TemperatureAndPressure25530814/TempAndPressure25530814_02.hdf5 does not exist
# 1400 2020-02-15 14:36:00.936944
# 1485 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1500 2020-02-15 14:53:23.349543
# 1525 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1542 file /data/SC_data/TemperatureAndPressure25501006/TempAndPressure25501006_02.hdf5 does not exist
# 1587 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1600 2020-02-15 15:10:45.767342
# 1604 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1608 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 1693 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1700 2553-11-23 19:33:39.873268
# 1700 file /data/SC_data/TemperatureAndPressure25531123/TempAndPressure25531123_19.hdf5 does not exist
# 1720 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1745 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 1800 2020-02-15 15:45:31.787169
# 1900 2020-02-15 16:02:50.989892
# 1995 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2000 2020-02-15 16:20:13.543095
# 2100 2020-02-15 16:37:34.066049
# 2133 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 2134 file /data/SC_data/TemperatureAndPressure25500418/TempAndPressure25500418_00.hdf5 does not exist
# 2143 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2158 file /data/SC_data/TemperatureAndPressure25440606/TempAndPressure25440606_06.hdf5 does not exist
# 2171 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2173 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 2179 file /data/SC_data/TemperatureAndPressure24990122/TempAndPressure24990122_23.hdf5 does not exist
# 2200 2020-02-15 16:54:58.014085
# 2219 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2246 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 2248 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 2250 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2286 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2300 2020-02-15 17:12:23.650960
# 2301 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2334 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 2336 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2367 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2386 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2400 2020-02-15 17:29:47.405990
# 2403 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2404 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 2437 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2460 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2471 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2486 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 2487 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 2500 2020-02-15 17:47:13.613079
# 2504 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 2524 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 2534 file /data/SC_data/TemperatureAndPressure25440617/TempAndPressure25440617_05.hdf5 does not exist
# 2556 file /data/SC_data/TemperatureAndPressure25540219/TempAndPressure25540219_22.hdf5 does not exist
# 2562 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2573 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2600 2020-02-15 18:04:38.094327
# 2656 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 2668 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 2700 2020-02-15 18:21:56.773638
# 2707 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2722 file /data/SC_data/TemperatureAndPressure25441104/TempAndPressure25441104_20.hdf5 does not exist
# 2725 file /data/SC_data/TemperatureAndPressure25531030/TempAndPressure25531030_22.hdf5 does not exist
# 2759 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2765 file /data/SC_data/TemperatureAndPressure25540512/TempAndPressure25540512_19.hdf5 does not exist
# 2766 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2783 file /data/SC_data/TemperatureAndPressure25500409/TempAndPressure25500409_19.hdf5 does not exist
# 2787 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2798 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2800 2020-02-15 18:39:24.517963
# 2812 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 2873 file /data/SC_data/TemperatureAndPressure25500423/TempAndPressure25500423_17.hdf5 does not exist
# 2900 2020-02-15 18:56:43.277276
# 2945 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 2982 file /data/SC_data/TemperatureAndPressure25540324/TempAndPressure25540324_00.hdf5 does not exist
# 3000 2020-02-15 19:14:04.727252
# 3029 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3100 2020-02-15 19:31:24.216583
# 3125 file /data/SC_data/TemperatureAndPressure25540125/TempAndPressure25540125_03.hdf5 does not exist
# 3169 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 3200 2020-02-15 19:48:44.562733
# 3225 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3231 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3235 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3238 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3273 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 3291 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3300 2020-02-15 20:06:08.241562
# 3327 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3395 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3400 2020-02-15 20:23:28.011299
# 3412 file /data/SC_data/TemperatureAndPressure25530926/TempAndPressure25530926_15.hdf5 does not exist
# 3413 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 3437 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 3451 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 3500 2020-02-15 20:40:48.682257
# 3512 file /data/SC_data/TemperatureAndPressure24361124/TempAndPressure24361124_14.hdf5 does not exist
# 3524 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3553 file /data/SC_data/TemperatureAndPressure25441203/TempAndPressure25441203_07.hdf5 does not exist
# 3561 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3567 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3571 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3572 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3600 2020-02-15 20:58:09.615421
# 3606 file /data/SC_data/TemperatureAndPressure25540217/TempAndPressure25540217_20.hdf5 does not exist
# 3629 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3631 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3635 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 3661 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3663 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_22.hdf5 does not exist
# 3675 file /data/SC_data/TemperatureAndPressure25531217/TempAndPressure25531217_10.hdf5 does not exist
# 3700 2020-02-15 21:15:33.530655
# 3708 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3711 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3719 file /data/SC_data/TemperatureAndPressure25531224/TempAndPressure25531224_18.hdf5 does not exist
# 3720 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3800 2020-02-15 21:32:58.692120
# 3838 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 3847 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 3859 file /data/SC_data/TemperatureAndPressure24340803/TempAndPressure24340803_01.hdf5 does not exist
# 3877 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 3878 file /data/SC_data/TemperatureAndPressure25430902/TempAndPressure25430902_12.hdf5 does not exist
# 3891 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 3900 2020-02-15 21:50:20.510505
# 3901 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3906 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 3918 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 3923 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3984 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 3996 file /data/SC_data/TemperatureAndPressure25431109/TempAndPressure25431109_10.hdf5 does not exist
# 3997 file /data/SC_data/TemperatureAndPressure25500903/TempAndPressure25500903_02.hdf5 does not exist
# 4000 2020-02-15 22:07:46.439187
# 4006 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4023 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4026 file /data/SC_data/TemperatureAndPressure21090206/TempAndPressure21090206_04.hdf5 does not exist
# 4031 file /data/SC_data/TemperatureAndPressure25540707/TempAndPressure25540707_14.hdf5 does not exist
# 4032 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4035 file /data/SC_data/TemperatureAndPressure25500801/TempAndPressure25500801_19.hdf5 does not exist
# 4057 file /data/SC_data/TemperatureAndPressure25421227/TempAndPressure25421227_20.hdf5 does not exist
# 4065 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4075 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4078 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4100 2020-02-15 22:25:16.797173
# 4143 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4193 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4200 2020-02-15 22:42:41.667830
# 4209 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4239 file /data/SC_data/TemperatureAndPressure25540111/TempAndPressure25540111_01.hdf5 does not exist
# 4269 file /data/SC_data/TemperatureAndPressure25491223/TempAndPressure25491223_16.hdf5 does not exist
# 4300 2554-07-21 12:31:23.256542
# 4300 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4337 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 4395 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 4400 2020-02-15 23:17:19.712469
# 4408 file /data/SC_data/TemperatureAndPressure25490426/TempAndPressure25490426_15.hdf5 does not exist
# 4427 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 4434 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 4435 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4500 2020-02-15 23:34:42.021865
# 4503 file /data/SC_data/TemperatureAndPressure25490817/TempAndPressure25490817_09.hdf5 does not exist
# 4518 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4530 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 4538 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4543 file /data/SC_data/TemperatureAndPressure25540211/TempAndPressure25540211_05.hdf5 does not exist
# 4579 file /data/SC_data/TemperatureAndPressure25540206/TempAndPressure25540206_18.hdf5 does not exist
# 4600 2020-02-15 23:52:03.620845
# 4603 file /data/SC_data/TemperatureAndPressure25420220/TempAndPressure25420220_12.hdf5 does not exist
# 4626 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 4657 file /data/SC_data/TemperatureAndPressure25530718/TempAndPressure25530718_03.hdf5 does not exist
# 4668 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4671 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4682 file /data/SC_data/TemperatureAndPressure25520901/TempAndPressure25520901_08.hdf5 does not exist
# 4700 2020-02-16 00:09:24.430807
# 4719 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4745 file /data/SC_data/TemperatureAndPressure25540412/TempAndPressure25540412_03.hdf5 does not exist
# 4756 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4762 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4775 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 4800 2020-02-16 00:26:48.503645
# 4809 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4863 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 4899 file /data/SC_data/TemperatureAndPressure25530427/TempAndPressure25530427_20.hdf5 does not exist
# 4900 2554-05-24 01:01:23.361225
# 4900 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_01.hdf5 does not exist
# 4916 file /data/SC_data/TemperatureAndPressure25420416/TempAndPressure25420416_02.hdf5 does not exist
# 4918 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4942 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 4954 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 4968 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5000 2020-02-16 01:01:34.729676
# 5022 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5030 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5052 file /data/SC_data/TemperatureAndPressure21240516/TempAndPressure21240516_00.hdf5 does not exist
# 5053 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 5061 file /data/SC_data/TemperatureAndPressure25540116/TempAndPressure25540116_17.hdf5 does not exist
# 5068 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 5070 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5100 2020-02-16 01:18:53.456589
# 5101 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 5139 file /data/SC_data/TemperatureAndPressure25530508/TempAndPressure25530508_11.hdf5 does not exist
# 5150 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5151 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5170 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5190 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5200 2554-07-21 12:25:43.954128
# 5200 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5210 file /data/SC_data/TemperatureAndPressure25540129/TempAndPressure25540129_13.hdf5 does not exist
# 5232 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5300 2020-02-16 01:53:38.096182
# 5328 file /data/SC_data/TemperatureAndPressure25490802/TempAndPressure25490802_11.hdf5 does not exist
# 5330 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5360 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5368 file /data/SC_data/TemperatureAndPressure25540314/TempAndPressure25540314_12.hdf5 does not exist
# 5369 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5372 file /data/SC_data/TemperatureAndPressure25540210/TempAndPressure25540210_18.hdf5 does not exist
# 5388 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5397 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5400 2020-02-16 02:11:06.724128
# 5403 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5417 file /data/SC_data/TemperatureAndPressure25420211/TempAndPressure25420211_07.hdf5 does not exist
# 5419 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5436 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5455 file /data/SC_data/TemperatureAndPressure25530814/TempAndPressure25530814_19.hdf5 does not exist
# 5456 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5458 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 5459 file /data/SC_data/TemperatureAndPressure25540515/TempAndPressure25540515_01.hdf5 does not exist
# 5461 file /data/SC_data/TemperatureAndPressure25490902/TempAndPressure25490902_14.hdf5 does not exist
# 5471 file /data/SC_data/TemperatureAndPressure21590905/TempAndPressure21590905_09.hdf5 does not exist
# 5474 file /data/SC_data/TemperatureAndPressure25410725/TempAndPressure25410725_08.hdf5 does not exist
# 5500 2020-02-16 02:28:34.447253
# 5507 file /data/SC_data/TemperatureAndPressure24771105/TempAndPressure24771105_00.hdf5 does not exist
# 5521 file /data/SC_data/TemperatureAndPressure25540102/TempAndPressure25540102_05.hdf5 does not exist
# 5525 file /data/SC_data/TemperatureAndPressure25540310/TempAndPressure25540310_13.hdf5 does not exist
# 5527 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5531 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5534 file /data/SC_data/TemperatureAndPressure25420401/TempAndPressure25420401_02.hdf5 does not exist
# 5538 file /data/SC_data/TemperatureAndPressure25410314/TempAndPressure25410314_01.hdf5 does not exist
# 5555 file /data/SC_data/TemperatureAndPressure25410818/TempAndPressure25410818_17.hdf5 does not exist
# 5600 2020-02-16 02:45:56.784250
# 5629 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 5639 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5641 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5647 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 5663 file /data/SC_data/TemperatureAndPressure25411123/TempAndPressure25411123_21.hdf5 does not exist
# 5682 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5684 file /data/SC_data/TemperatureAndPressure25490819/TempAndPressure25490819_14.hdf5 does not exist
# 5700 2020-02-16 03:03:21.904513
# 5701 file /data/SC_data/TemperatureAndPressure24800302/TempAndPressure24800302_20.hdf5 does not exist
# 5704 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5731 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5735 file /data/SC_data/TemperatureAndPressure25540206/TempAndPressure25540206_03.hdf5 does not exist
# 5797 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5798 file /data/SC_data/TemperatureAndPressure25491009/TempAndPressure25491009_14.hdf5 does not exist
# 5800 2020-02-16 03:20:43.732898
# 5819 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5833 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5836 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5842 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 5845 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 5847 file /data/SC_data/TemperatureAndPressure25530111/TempAndPressure25530111_18.hdf5 does not exist
# 5848 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5866 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5868 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5871 file /data/SC_data/TemperatureAndPressure25530204/TempAndPressure25530204_06.hdf5 does not exist
# 5877 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5900 2020-02-16 03:38:08.609956
# 5917 file /data/SC_data/TemperatureAndPressure25281205/TempAndPressure25281205_18.hdf5 does not exist
# 5919 file /data/SC_data/TemperatureAndPressure25540409/TempAndPressure25540409_09.hdf5 does not exist
# 5926 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5934 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 5960 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 5961 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5981 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 5982 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_22.hdf5 does not exist
# 5987 file /data/SC_data/TemperatureAndPressure25521107/TempAndPressure25521107_22.hdf5 does not exist
# 5989 file /data/SC_data/TemperatureAndPressure25490928/TempAndPressure25490928_00.hdf5 does not exist
# 5990 file /data/SC_data/TemperatureAndPressure20740430/TempAndPressure20740430_02.hdf5 does not exist
# 6000 2020-02-16 03:55:39.654358
# 6011 file /data/SC_data/TemperatureAndPressure25531011/TempAndPressure25531011_23.hdf5 does not exist
# 6015 file /data/SC_data/TemperatureAndPressure25410820/TempAndPressure25410820_21.hdf5 does not exist
# 6045 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 6049 file /data/SC_data/TemperatureAndPressure25421109/TempAndPressure25421109_07.hdf5 does not exist
# 6072 file /data/SC_data/TemperatureAndPressure25420810/TempAndPressure25420810_14.hdf5 does not exist
# 6073 file /data/SC_data/TemperatureAndPressure24081123/TempAndPressure24081123_01.hdf5 does not exist
# 6074 file /data/SC_data/TemperatureAndPressure20560509/TempAndPressure20560509_14.hdf5 does not exist
# 6080 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6081 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6083 file /data/SC_data/TemperatureAndPressure25520302/TempAndPressure25520302_17.hdf5 does not exist
# 6090 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6094 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6100 2020-02-16 04:13:06.772469
# 6139 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6146 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6147 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6163 file /data/SC_data/TemperatureAndPressure25420711/TempAndPressure25420711_13.hdf5 does not exist
# 6172 file /data/SC_data/TemperatureAndPressure25500123/TempAndPressure25500123_14.hdf5 does not exist
# 6173 file /data/SC_data/TemperatureAndPressure25131125/TempAndPressure25131125_22.hdf5 does not exist
# 6182 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 6193 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6200 2020-02-16 04:30:35.651220
# 6203 file /data/SC_data/TemperatureAndPressure25430326/TempAndPressure25430326_09.hdf5 does not exist
# 6216 file /data/SC_data/TemperatureAndPressure20560505/TempAndPressure20560505_12.hdf5 does not exist
# 6221 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6222 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6237 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6292 file /data/SC_data/TemperatureAndPressure25490801/TempAndPressure25490801_02.hdf5 does not exist
# 6295 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6299 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6300 2020-02-16 04:47:56.686987
# 6325 file /data/SC_data/TemperatureAndPressure22460127/TempAndPressure22460127_20.hdf5 does not exist
# 6329 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6331 file /data/SC_data/TemperatureAndPressure23220408/TempAndPressure23220408_20.hdf5 does not exist
# 6336 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6337 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6350 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6351 file /data/SC_data/TemperatureAndPressure20780621/TempAndPressure20780621_03.hdf5 does not exist
# 6353 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6354 file /data/SC_data/TemperatureAndPressure25491207/TempAndPressure25491207_19.hdf5 does not exist
# 6357 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6377 file /data/SC_data/TemperatureAndPressure25500125/TempAndPressure25500125_00.hdf5 does not exist
# 6378 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6379 file /data/SC_data/TemperatureAndPressure25430613/TempAndPressure25430613_07.hdf5 does not exist
# 6380 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 6381 file /data/SC_data/TemperatureAndPressure25530130/TempAndPressure25530130_23.hdf5 does not exist
# 6397 file /data/SC_data/TemperatureAndPressure25491221/TempAndPressure25491221_11.hdf5 does not exist
# 6400 2020-02-16 05:05:24.490713
# 6438 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6440 file /data/SC_data/TemperatureAndPressure22820109/TempAndPressure22820109_10.hdf5 does not exist
# 6441 file /data/SC_data/TemperatureAndPressure22060806/TempAndPressure22060806_10.hdf5 does not exist
# 6461 file /data/SC_data/TemperatureAndPressure20540823/TempAndPressure20540823_01.hdf5 does not exist
# 6483 file /data/SC_data/TemperatureAndPressure25411109/TempAndPressure25411109_19.hdf5 does not exist
# 6500 2020-02-16 05:22:47.019515
# 6537 file /data/SC_data/TemperatureAndPressure25540116/TempAndPressure25540116_05.hdf5 does not exist
# 6545 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 6546 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6576 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6595 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 6600 2020-02-16 05:40:10.568541
# 6666 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6687 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6700 2020-02-16 05:57:33.632156
# 6724 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6725 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6758 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6785 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6787 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6797 file /data/SC_data/TemperatureAndPressure25421115/TempAndPressure25421115_20.hdf5 does not exist
# 6800 2020-02-16 06:15:01.542684
# 6819 file /data/SC_data/TemperatureAndPressure25531215/TempAndPressure25531215_20.hdf5 does not exist
# 6820 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 6822 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6847 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6860 file /data/SC_data/TemperatureAndPressure25531031/TempAndPressure25531031_00.hdf5 does not exist
# 6870 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 6890 file /data/SC_data/TemperatureAndPressure25520909/TempAndPressure25520909_01.hdf5 does not exist
# 6900 2020-02-16 06:32:24.376894
# 6905 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6906 file /data/SC_data/TemperatureAndPressure25540306/TempAndPressure25540306_17.hdf5 does not exist
# 6910 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6911 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 6927 file /data/SC_data/TemperatureAndPressure25430502/TempAndPressure25430502_10.hdf5 does not exist
# 6979 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 6985 file /data/SC_data/TemperatureAndPressure25430511/TempAndPressure25430511_09.hdf5 does not exist
# 6988 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 6989 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7000 2020-02-16 06:49:49.248151
# 7016 file /data/SC_data/TemperatureAndPressure25500114/TempAndPressure25500114_21.hdf5 does not exist
# 7043 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 7045 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 7076 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7078 file /data/SC_data/TemperatureAndPressure25500107/TempAndPressure25500107_23.hdf5 does not exist
# 7079 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7081 file /data/SC_data/TemperatureAndPressure25531106/TempAndPressure25531106_04.hdf5 does not exist
# 7100 2020-02-16 07:07:12.293365
# 7158 file /data/SC_data/TemperatureAndPressure25420922/TempAndPressure25420922_08.hdf5 does not exist
# 7165 file /data/SC_data/TemperatureAndPressure25491013/TempAndPressure25491013_09.hdf5 does not exist
# 7200 2020-02-16 07:24:32.332908
# 7208 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7246 file /data/SC_data/TemperatureAndPressure21640129/TempAndPressure21640129_10.hdf5 does not exist
# 7247 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 7270 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7300 2020-02-16 07:41:55.793132
# 7336 file /data/SC_data/TemperatureAndPressure25430705/TempAndPressure25430705_15.hdf5 does not exist
# 7337 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7365 file /data/SC_data/TemperatureAndPressure25531109/TempAndPressure25531109_01.hdf5 does not exist
# 7366 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 7398 file /data/SC_data/TemperatureAndPressure25491203/TempAndPressure25491203_20.hdf5 does not exist
# 7400 2020-02-16 07:59:19.396159
# 7404 file /data/SC_data/TemperatureAndPressure25491209/TempAndPressure25491209_18.hdf5 does not exist
# 7405 file /data/SC_data/TemperatureAndPressure25500304/TempAndPressure25500304_11.hdf5 does not exist
# 7409 file /data/SC_data/TemperatureAndPressure25531026/TempAndPressure25531026_08.hdf5 does not exist
# 7413 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7445 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7451 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7457 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 7459 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 7460 file /data/SC_data/TemperatureAndPressure25421223/TempAndPressure25421223_03.hdf5 does not exist
# 7474 file /data/SC_data/TemperatureAndPressure25531022/TempAndPressure25531022_07.hdf5 does not exist
# 7475 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7500 2020-02-16 08:16:49.830547
# 7509 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 7511 file /data/SC_data/TemperatureAndPressure25420308/TempAndPressure25420308_23.hdf5 does not exist
# 7512 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7531 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 7550 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 7576 file /data/SC_data/TemperatureAndPressure25491129/TempAndPressure25491129_04.hdf5 does not exist
# 7577 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 7600 2020-02-16 08:34:12.521953
# 7628 file /data/SC_data/TemperatureAndPressure25530322/TempAndPressure25530322_03.hdf5 does not exist
# 7629 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 7693 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7695 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7700 2020-02-16 08:51:38.542237
# 7705 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 7706 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7720 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7730 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 7732 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 7733 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 7756 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 7757 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7782 file /data/SC_data/TemperatureAndPressure25531121/TempAndPressure25531121_09.hdf5 does not exist
# 7799 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7800 2020-02-16 09:09:08.049004
# 7853 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7860 file /data/SC_data/TemperatureAndPressure25540117/TempAndPressure25540117_01.hdf5 does not exist
# 7861 file /data/SC_data/TemperatureAndPressure25411214/TempAndPressure25411214_06.hdf5 does not exist
# 7863 file /data/SC_data/TemperatureAndPressure22210526/TempAndPressure22210526_15.hdf5 does not exist
# 7864 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7866 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7893 file /data/SC_data/TemperatureAndPressure24080418/TempAndPressure24080418_17.hdf5 does not exist
# 7900 2020-02-16 09:26:31.595030
# 7930 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7951 file /data/SC_data/TemperatureAndPressure25530813/TempAndPressure25530813_07.hdf5 does not exist
# 7957 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 7984 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 7988 file /data/SC_data/TemperatureAndPressure24340604/TempAndPressure24340604_16.hdf5 does not exist
# 7991 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7992 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 7999 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 8000 2553-11-17 16:00:35.497967
# 8000 file /data/SC_data/TemperatureAndPressure25531117/TempAndPressure25531117_16.hdf5 does not exist
# 8037 file /data/SC_data/TemperatureAndPressure25531120/TempAndPressure25531120_17.hdf5 does not exist
# 8050 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 8058 file /data/SC_data/TemperatureAndPressure25420521/TempAndPressure25420521_03.hdf5 does not exist
# 8059 file /data/SC_data/TemperatureAndPressure25530826/TempAndPressure25530826_03.hdf5 does not exist
# 8069 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 8078 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 8090 file /data/SC_data/TemperatureAndPressure25491206/TempAndPressure25491206_06.hdf5 does not exist
# 8100 2167-07-07 04:01:09.515450
# 8100 file /data/SC_data/TemperatureAndPressure21670707/TempAndPressure21670707_04.hdf5 does not exist
# 8101 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 8162 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 8170 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 8182 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 8190 file /data/SC_data/TemperatureAndPressure25531206/TempAndPressure25531206_11.hdf5 does not exist
# 8200 2020-02-16 10:18:47.972243
# 8203 file /data/SC_data/TemperatureAndPressure25421222/TempAndPressure25421222_06.hdf5 does not exist
# 8204 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 8235 file /data/SC_data/TemperatureAndPressure25531006/TempAndPressure25531006_02.hdf5 does not exist
# 8240 file /data/SC_data/TemperatureAndPressure25410919/TempAndPressure25410919_20.hdf5 does not exist
# 8251 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 8273 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 8279 file /data/SC_data/TemperatureAndPressure25540210/TempAndPressure25540210_01.hdf5 does not exist
# 8294 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 8300 2020-02-16 10:36:10.537846
# 8315 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 8337 file /data/SC_data/TemperatureAndPressure25420305/TempAndPressure25420305_19.hdf5 does not exist
# 8359 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 8364 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 8383 file /data/SC_data/TemperatureAndPressure25411001/TempAndPressure25411001_05.hdf5 does not exist
# 8390 file /data/SC_data/TemperatureAndPressure22080418/TempAndPressure22080418_20.hdf5 does not exist
# 8400 2020-02-16 10:53:29.911573
# 8410 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 8413 file /data/SC_data/TemperatureAndPressure25531117/TempAndPressure25531117_11.hdf5 does not exist
# 8419 file /data/SC_data/TemperatureAndPressure25410810/TempAndPressure25410810_05.hdf5 does not exist
# 8425 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 8443 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# ...
# 14073 file /data/SC_data/TemperatureAndPressure24010620/TempAndPressure24010620_07.hdf5 does not exist
# 14074 file /data/SC_data/TemperatureAndPressure19710613/TempAndPressure19710613_02.hdf5 does not exist
# 14079 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14092 file /data/SC_data/TemperatureAndPressure25480302/TempAndPressure25480302_22.hdf5 does not exist
# 14093 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14100 2020-02-17 03:25:59.873849
# 14111 file /data/SC_data/TemperatureAndPressure25480204/TempAndPressure25480204_17.hdf5 does not exist
# 14112 file /data/SC_data/TemperatureAndPressure24990804/TempAndPressure24990804_01.hdf5 does not exist
# 14115 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14116 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14133 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14145 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14149 file /data/SC_data/TemperatureAndPressure19730922/TempAndPressure19730922_10.hdf5 does not exist
# 14150 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 14152 file /data/SC_data/TemperatureAndPressure25370711/TempAndPressure25370711_01.hdf5 does not exist
# 14153 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14197 file /data/SC_data/TemperatureAndPressure25480628/TempAndPressure25480628_10.hdf5 does not exist
# 14198 file /data/SC_data/TemperatureAndPressure25480130/TempAndPressure25480130_19.hdf5 does not exist
# 14200 2020-02-17 03:43:22.881262
# 14264 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14280 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14281 file /data/SC_data/TemperatureAndPressure25380419/TempAndPressure25380419_16.hdf5 does not exist
# 14300 2020-02-17 04:00:43.803626
# 14307 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14316 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14317 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14337 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14362 file /data/SC_data/TemperatureAndPressure25480331/TempAndPressure25480331_19.hdf5 does not exist
# 14363 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14367 file /data/SC_data/TemperatureAndPressure19710516/TempAndPressure19710516_02.hdf5 does not exist
# 14372 file /data/SC_data/TemperatureAndPressure19730310/TempAndPressure19730310_20.hdf5 does not exist
# 14373 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14384 file /data/SC_data/TemperatureAndPressure25370715/TempAndPressure25370715_10.hdf5 does not exist
# 14385 file /data/SC_data/TemperatureAndPressure25380420/TempAndPressure25380420_13.hdf5 does not exist
# 14399 file /data/SC_data/TemperatureAndPressure25480229/TempAndPressure25480229_10.hdf5 does not exist
# 14400 2554-07-21 12:43:24.811073
# 14400 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14413 file /data/SC_data/TemperatureAndPressure24210114/TempAndPressure24210114_19.hdf5 does not exist
# 14415 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14416 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14433 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14437 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14479 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14486 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14495 file /data/SC_data/TemperatureAndPressure25370208/TempAndPressure25370208_04.hdf5 does not exist
# 14500 2020-02-17 04:35:43.185767
# 14513 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14533 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14535 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 14556 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14561 file /data/SC_data/TemperatureAndPressure25370327/TempAndPressure25370327_15.hdf5 does not exist
# 14564 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14583 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14600 2554-07-21 12:38:54.228130
# 14600 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14614 file /data/SC_data/TemperatureAndPressure24561105/TempAndPressure24561105_07.hdf5 does not exist
# 14639 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 14649 file /data/SC_data/TemperatureAndPressure25360328/TempAndPressure25360328_09.hdf5 does not exist
# 14653 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14672 file /data/SC_data/TemperatureAndPressure19730920/TempAndPressure19730920_07.hdf5 does not exist
# 14678 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14686 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14687 file /data/SC_data/TemperatureAndPressure25371114/TempAndPressure25371114_09.hdf5 does not exist
# 14700 2020-02-17 05:10:30.731030
# 14727 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14728 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14732 file /data/SC_data/TemperatureAndPressure19701123/TempAndPressure19701123_01.hdf5 does not exist
# 14752 file /data/SC_data/TemperatureAndPressure25371103/TempAndPressure25371103_09.hdf5 does not exist
# 14756 file /data/SC_data/TemperatureAndPressure24960511/TempAndPressure24960511_08.hdf5 does not exist
# 14757 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14762 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14763 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14773 file /data/SC_data/TemperatureAndPressure25480408/TempAndPressure25480408_10.hdf5 does not exist
# 14800 2020-02-17 05:27:59.176372
# 14822 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14846 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14849 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_22.hdf5 does not exist
# 14878 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14880 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14884 file /data/SC_data/TemperatureAndPressure19721210/TempAndPressure19721210_22.hdf5 does not exist
# 14900 2020-02-17 05:45:22.259786
# 14922 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14928 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14930 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 14931 file /data/SC_data/TemperatureAndPressure19710217/TempAndPressure19710217_04.hdf5 does not exist
# 14940 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 14945 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 14949 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 14966 file /data/SC_data/TemperatureAndPressure25361112/TempAndPressure25361112_13.hdf5 does not exist
# 15000 2020-02-17 06:02:46.610231
# 15003 file /data/SC_data/TemperatureAndPressure19720605/TempAndPressure19720605_17.hdf5 does not exist
# 15004 file /data/SC_data/TemperatureAndPressure25470829/TempAndPressure25470829_01.hdf5 does not exist
# 15006 file /data/SC_data/TemperatureAndPressure23901219/TempAndPressure23901219_20.hdf5 does not exist
# 15007 file /data/SC_data/TemperatureAndPressure19710318/TempAndPressure19710318_01.hdf5 does not exist
# 15011 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_01.hdf5 does not exist
# 15050 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15054 file /data/SC_data/TemperatureAndPressure20440803/TempAndPressure20440803_10.hdf5 does not exist
# 15055 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15084 file /data/SC_data/TemperatureAndPressure20890213/TempAndPressure20890213_07.hdf5 does not exist
# 15095 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15100 2020-02-17 06:20:11.400486
# 15103 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 15122 file /data/SC_data/TemperatureAndPressure19720905/TempAndPressure19720905_03.hdf5 does not exist
# 15125 file /data/SC_data/TemperatureAndPressure24100603/TempAndPressure24100603_17.hdf5 does not exist
# 15131 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 15132 file /data/SC_data/TemperatureAndPressure19721023/TempAndPressure19721023_18.hdf5 does not exist
# 15143 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15147 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15148 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_01.hdf5 does not exist
# 15153 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 15198 file /data/SC_data/TemperatureAndPressure25360301/TempAndPressure25360301_03.hdf5 does not exist
# 15200 2020-02-17 06:37:33.927088
# 15237 file /data/SC_data/TemperatureAndPressure19720802/TempAndPressure19720802_04.hdf5 does not exist
# 15243 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15244 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15249 file /data/SC_data/TemperatureAndPressure24701026/TempAndPressure24701026_05.hdf5 does not exist
# 15260 file /data/SC_data/TemperatureAndPressure25470721/TempAndPressure25470721_02.hdf5 does not exist
# 15261 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 15269 file /data/SC_data/TemperatureAndPressure21800622/TempAndPressure21800622_06.hdf5 does not exist
# 15291 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 15292 file /data/SC_data/TemperatureAndPressure25540524/TempAndPressure25540524_00.hdf5 does not exist
# 15300 2020-02-17 06:54:56.465690
# 15301 file /data/SC_data/TemperatureAndPressure19711106/TempAndPressure19711106_07.hdf5 does not exist
# 15311 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_22.hdf5 does not exist
# 15316 file /data/SC_data/TemperatureAndPressure19710724/TempAndPressure19710724_11.hdf5 does not exist
# 15317 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15320 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15321 file /data/SC_data/TemperatureAndPressure25350825/TempAndPressure25350825_01.hdf5 does not exist
# 15325 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15326 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15349 file /data/SC_data/TemperatureAndPressure25341103/TempAndPressure25341103_07.hdf5 does not exist
# 15350 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15372 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15373 file /data/SC_data/TemperatureAndPressure19721211/TempAndPressure19721211_02.hdf5 does not exist
# 15374 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15377 file /data/SC_data/TemperatureAndPressure25471018/TempAndPressure25471018_12.hdf5 does not exist
# 15378 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15392 file /data/SC_data/TemperatureAndPressure19730521/TempAndPressure19730521_09.hdf5 does not exist
# 15400 2020-02-17 07:12:25.560447
# 15404 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_17.hdf5 does not exist
# 15428 file /data/SC_data/TemperatureAndPressure19691231/TempAndPressure19691231_16.hdf5 does not exist
# 15469 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 15470 file /data/SC_data/TemperatureAndPressure19701208/TempAndPressure19701208_23.hdf5 does not exist
# 15500 2020-02-17 07:29:45.469787
# 15539 file /data/SC_data/TemperatureAndPressure19721120/TempAndPressure19721120_20.hdf5 does not exist
# 15544 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 15545 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15546 file /data/SC_data/TemperatureAndPressure20410524/TempAndPressure20410524_20.hdf5 does not exist
# 15568 file /data/SC_data/TemperatureAndPressure22580113/TempAndPressure22580113_19.hdf5 does not exist
# 15570 file /data/SC_data/TemperatureAndPressure22691120/TempAndPressure22691120_04.hdf5 does not exist
# 15594 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15600 2020-02-17 07:47:10.068838
# 15603 file /data/SC_data/TemperatureAndPressure25470814/TempAndPressure25470814_02.hdf5 does not exist
# 15613 file /data/SC_data/TemperatureAndPressure25540523/TempAndPressure25540523_23.hdf5 does not exist
# 15629 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15700 2020-02-17 08:04:39.417201
# 15727 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15774 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15782 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15800 2020-02-17 08:22:13.316271
# 15826 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15836 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15880 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15900 2020-02-17 08:39:38.059725
# 15938 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15941 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# 15987 file /data/SC_data/TemperatureAndPressure25540721/TempAndPressure25540721_12.hdf5 does not exist
# Total run time is  597.0777778625488  s

# %%
import time
import os
start_time = time.time()

#DefineParameters
Nint=0
Ndata=0
Dx=383
Fshake=3
DataN=5000
HarmN=20
Noff=7
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)


ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/TempDataTest%d_%d.txt" % (Dx,Dx,Ndata)
f1 = open(ofname,"a")
for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    DataTime=dt.datetime.fromtimestamp(BDF.time[0]/1e9)
    print(k,DataTime)
    yr=DataTime.year
    mo=DataTime.month
    day=DataTime.day
    hr=DataTime.hour
    mn=DataTime.minute
    sec=DataTime.second
    SCfname= "/data/SC_data/TemperatureAndPressure%d%02d%02d/TempAndPressure%d%02d%02d_%02d.hdf5" %(yr,mo,day,yr,mo,day,hr)
    if os.path.exists(SCfname):
        SCf=h5py.File(SCfname,'r')
        aveP=np.average(f['Pressure/Pressures'][(mn*60+sec):(mn*60+sec+2)])
        aveTa=np.average(f['AirTemperature/AirTemperatures'][(mn*60+sec):(mn*60+sec+2)])
        aveTs=np.average(f['SurfaceTemperature/SurfaceTemperatures'][(mn*60+sec):(mn*60+sec+2)])
        f1.write('%d %d %f %f %f\n' % (k, BDF.time[0],aveP, aveTa, aveTs))
        SCf.close()
f1.close()    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0 2020-02-11 15:24:46.083392
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-3adaddb1eb07> in <module>()
#      45     if os.path.exists(SCfname):
#      46         SCf=h5py.File(SCfname,'r')
# ---> 47         aveP=np.average(f['Pressure/Pressures'][(mn*60+sec):(mn*60+sec+2)])
#      48         aveTa=np.average(f['AirTemperature/AirTemperatures'][(mn*60+sec):(mn*60+sec+2)])
#      49         aveTs=np.average(f['SurfaceTemperature/SurfaceTemperatures'][(mn*60+sec):(mn*60+sec+2)])
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /home/analysis_user/.local/lib/python3.6/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     260                 raise ValueError("Invalid HDF5 object reference")
#     261         else:
# --> 262             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     263
#     264         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: 'Unable to open object (component not found)'

# %%
##following is the code to get xyz mean position
import time
start_time = time.time()

#DefineParameters
Nint=0
Ndata=3
Dx=384
Fshake=3
DataN=16000
HarmN=20
Noff=7
ArraySize=(DataN,HarmN)
DataSpaceXSigAmp=np.zeros(ArraySize)
DataSpaceYSigAmp=np.zeros(ArraySize)
DataSpaceZSigAmp=np.zeros(ArraySize)
DataSpaceXSigPha=np.zeros(ArraySize)
DataSpaceYSigPha=np.zeros(ArraySize)
DataSpaceZSigPha=np.zeros(ArraySize)

DataSpaceXNoiAmp=np.zeros(ArraySize)
DataSpaceYNoiAmp=np.zeros(ArraySize)
DataSpaceZNoiAmp=np.zeros(ArraySize)
DataSpaceXNoiPha=np.zeros(ArraySize)
DataSpaceYNoiPha=np.zeros(ArraySize)
DataSpaceZNoiPha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=np.mean(data[0])
    y_1000=np.mean(data[1])
    z_1000=np.mean(data[2])

    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XYZMeanPos%d_%d.txt" % (Dx,Dx,Ndata,)
    f1 = open(ofname,"a")
    f1.write('%d %f %f %f\n' % (k, x_1000,y_1000,z_1000))
    f1.close()
    if(k%100==0):
        print(k)
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# Total run time is  614.8009781837463  s

# %%
##test of detrending

# %%
Ndata=119
Nshake=3
Dx=384
#fname = r'/home/data_transfer/data_from_windows/20191107/Bead1/InitialTest/Data%d.h5' % Ndata
#fname = r"/home/data_transfer/data_from_windows/20200203/Bead1/NoiseCharacterization/Discharge_%d.h5" % Ndata
#fname = r"/home/data_transfer/data_from_windows/20200207/Bead1/TransFunc/TransFunc_Z_%d.h5" % Ndata
fname = r"/home/data_transfer/data_from_windows/20200210/Bead2/Shaking/Shaking%d/Shaking%d_%d.h5" % (Dx,Nshake,Ndata)
#fname = r"/home/data_transfer/data_from_windows/20200210/Bead2/Shaking/Shaking%d/Test%d_%d.h5" % (Dx,Nshake,Ndata)
BDF = BeadDataFile.BeadDataFile(fname)
data = BDF.xyz2
fsamp=5000
res=10000
res=50000
x_det=signal.detrend(data[0])
y_det=signal.detrend(data[1])
z_det=signal.detrend(data[2])


xpsd, freqs = matplotlib.mlab.psd(x_det, Fs = fsamp, NFFT = res,window=mlab.window_none)
ypsd, freqs = matplotlib.mlab.psd(y_det, Fs = fsamp, NFFT = res,window=mlab.window_none)
zpsd, freqs = matplotlib.mlab.psd(z_det, Fs = fsamp, NFFT = res,window=mlab.window_none)
xfnsd=np.sqrt(xpsd)*2.21e-12
yfnsd=np.sqrt(ypsd)*2.33e-12
zfnsd=np.sqrt(zpsd)*7.04e-19

# %%
_,ax = plt.subplots()
plt.subplots_adjust(left=0.18, right=0.99, top=0.96, bottom=0.14)
ax.loglog(freqs, xfnsd, '.-', label="x",markersize=1,linewidth=1)
ax.loglog(freqs, yfnsd, '.-', label="y*1",markersize=1,linewidth=1)
ax.loglog(freqs, zfnsd, '.-', label="z*1",markersize=1,linewidth=1)
ax.legend(fontsize=16)
ax.set_xlabel('Frequency [Hz]', fontsize=18)
ax.set_ylabel('Force NSD [N/sqrt(Hz)]',fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.xlim(0.5,200)
plt.ylim(1e-17,1e-11)
plt.grid(True)
#ofname='/home/data_transfer/data_from_windows/20191014/Bead1/InitialTest/DataFNSD%d_300dpi.png' % Ndata
#ofname='/home/data_transfer/data_from_windows/20200203/Bead1/NoiseCharacterization/Discharge%d.png' % Ndata
#ofname='/data/new_trap/20200207/Bead1/TransFunc/TransFunc_Z_%d.png' % Ndata
ofname='/data/new_trap/20200210/Bead2/Shaking/Shaking%d/Shaking%d_%dXYZ2.png' % (Dx,Nshake,Ndata)
#ofname='/home/data_transfer/data_from_windows/20200210/Bead2/Shaking/Shaking%d/Test%d_%d.png' % (Dx,Nshake,Ndata)

plt.savefig(ofname,dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##Code to get 10 noise data
start_time = time.time()

#DefineParameters
Nint=0
Ndata=3
Dx=384
Fshake=3
DataN=16000
HarmN=20
Noff=7
ArraySize=(DataN,HarmN)

DataSpaceXNoi1Amp=np.zeros(ArraySize)
DataSpaceYNoi1Amp=np.zeros(ArraySize)
DataSpaceZNoi1Amp=np.zeros(ArraySize)
DataSpaceXNoi1Pha=np.zeros(ArraySize)
DataSpaceYNoi1Pha=np.zeros(ArraySize)
DataSpaceZNoi1Pha=np.zeros(ArraySize)

DataSpaceXNoi2Amp=np.zeros(ArraySize)
DataSpaceYNoi2Amp=np.zeros(ArraySize)
DataSpaceZNoi2Amp=np.zeros(ArraySize)
DataSpaceXNoi2Pha=np.zeros(ArraySize)
DataSpaceYNoi2Pha=np.zeros(ArraySize)
DataSpaceZNoi2Pha=np.zeros(ArraySize)

DataSpaceXNoi3Amp=np.zeros(ArraySize)
DataSpaceYNoi3Amp=np.zeros(ArraySize)
DataSpaceZNoi3Amp=np.zeros(ArraySize)
DataSpaceXNoi3Pha=np.zeros(ArraySize)
DataSpaceYNoi3Pha=np.zeros(ArraySize)
DataSpaceZNoi3Pha=np.zeros(ArraySize)

DataSpaceXNoi4Amp=np.zeros(ArraySize)
DataSpaceYNoi4Amp=np.zeros(ArraySize)
DataSpaceZNoi4Amp=np.zeros(ArraySize)
DataSpaceXNoi4Pha=np.zeros(ArraySize)
DataSpaceYNoi4Pha=np.zeros(ArraySize)
DataSpaceZNoi4Pha=np.zeros(ArraySize)

DataSpaceXNoi5Amp=np.zeros(ArraySize)
DataSpaceYNoi5Amp=np.zeros(ArraySize)
DataSpaceZNoi5Amp=np.zeros(ArraySize)
DataSpaceXNoi5Pha=np.zeros(ArraySize)
DataSpaceYNoi5Pha=np.zeros(ArraySize)
DataSpaceZNoi5Pha=np.zeros(ArraySize)

DataSpaceXNoi6Amp=np.zeros(ArraySize)
DataSpaceYNoi6Amp=np.zeros(ArraySize)
DataSpaceZNoi6Amp=np.zeros(ArraySize)
DataSpaceXNoi6Pha=np.zeros(ArraySize)
DataSpaceYNoi6Pha=np.zeros(ArraySize)
DataSpaceZNoi6Pha=np.zeros(ArraySize)

DataSpaceXNoi7Amp=np.zeros(ArraySize)
DataSpaceYNoi7Amp=np.zeros(ArraySize)
DataSpaceZNoi7Amp=np.zeros(ArraySize)
DataSpaceXNoi7Pha=np.zeros(ArraySize)
DataSpaceYNoi7Pha=np.zeros(ArraySize)
DataSpaceZNoi7Pha=np.zeros(ArraySize)

DataSpaceXNoi8Amp=np.zeros(ArraySize)
DataSpaceYNoi8Amp=np.zeros(ArraySize)
DataSpaceZNoi8Amp=np.zeros(ArraySize)
DataSpaceXNoi8Pha=np.zeros(ArraySize)
DataSpaceYNoi8Pha=np.zeros(ArraySize)
DataSpaceZNoi8Pha=np.zeros(ArraySize)

DataSpaceXNoi9Amp=np.zeros(ArraySize)
DataSpaceYNoi9Amp=np.zeros(ArraySize)
DataSpaceZNoi9Amp=np.zeros(ArraySize)
DataSpaceXNoi9Pha=np.zeros(ArraySize)
DataSpaceYNoi9Pha=np.zeros(ArraySize)
DataSpaceZNoi9Pha=np.zeros(ArraySize)

DataSpaceXNoi10Amp=np.zeros(ArraySize)
DataSpaceYNoi10Amp=np.zeros(ArraySize)
DataSpaceZNoi10Amp=np.zeros(ArraySize)
DataSpaceXNoi10Pha=np.zeros(ArraySize)
DataSpaceYNoi10Pha=np.zeros(ArraySize)
DataSpaceZNoi10Pha=np.zeros(ArraySize)

for k in range(0,DataN):
##FFT the data
    NSubData=k
    fname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/Shaking%d_%d.h5" % (Dx,Ndata,NSubData)
    BDF = BeadDataFile.BeadDataFile(fname)
    data = BDF.xyz2
    fsamp=5000
    res=50000

    data_det=signal.detrend(data)
    x_1000=data_det[0]
    y_1000=data_det[1]
    z_1000=data_det[2]
    freqs=np.linspace(0,2500,(25000)+1)
    
    xFFT=np.fft.rfft(x_1000)
    yFFT=np.fft.rfft(y_1000)
    zFFT=np.fft.rfft(z_1000)
    norm = np.sqrt(2 / (res* fsamp))
    xpsd = norm**2 * (xFFT * xFFT.conj()).real
    ypsd = norm**2 * (yFFT * yFFT.conj()).real
    zpsd = norm**2 * (zFFT * zFFT.conj()).real
  
    f0=151
    F0x=1/np.sqrt((f0*f0-w0x*w0x)*(f0*f0-w0x*w0x)+gx*gx*f0*f0)
    F0y=1/np.sqrt((f0*f0-w0y*w0y)*(f0*f0-w0y*w0y)+gy*gy*f0*f0)
    F0z=1/np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

    xnsd=np.sqrt(xpsd)*BtoFx*F0x*np.sqrt((freqs*freqs-w0x*w0x)*(freqs*freqs-w0x*w0x)+gx*gx*freqs*freqs)
    ynsd=np.sqrt(ypsd)*BtoFy*F0y*np.sqrt((freqs*freqs-w0y*w0y)*(freqs*freqs-w0y*w0y)+gy*gy*freqs*freqs)
    znsd=np.sqrt(zpsd)*BtoFz*F0z*np.sqrt((f0*f0-w0z*w0z)*(f0*f0-w0z*w0z)+gz*gz*f0*f0)

##save signal bin data to the array
#save noise bin data to the array
    for i in range(1,(HarmN+1)):
        Noff=-5
        DataSpaceXNoi1Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi1Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi1Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi1Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi1Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi1Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=-4
        DataSpaceXNoi2Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi2Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi2Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi2Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi2Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi2Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=-3
        DataSpaceXNoi3Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi3Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi3Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi3Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi3Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi3Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=-2
        DataSpaceXNoi4Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi4Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi4Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi4Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi4Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi4Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=-1
        DataSpaceXNoi5Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi5Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi5Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi5Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi5Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi5Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=1
        DataSpaceXNoi6Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi6Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi6Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi6Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi6Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi6Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=2
        DataSpaceXNoi7Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi7Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi7Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi7Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi7Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi7Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=3
        DataSpaceXNoi8Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi8Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi8Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi8Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi8Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi8Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=4
        DataSpaceXNoi9Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi9Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi9Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi9Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi9Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi9Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
        Noff=5
        DataSpaceXNoi10Amp[k][i-1]=xnsd[Fshake*10*i-Noff]
        DataSpaceXNoi10Pha[k][i-1]=np.angle(xFFT[Fshake*10*i-Noff]) 
        DataSpaceYNoi10Amp[k][i-1]=ynsd[Fshake*10*i-Noff]
        DataSpaceYNoi10Pha[k][i-1]=np.angle(yFFT[Fshake*10*i-Noff]) 
        DataSpaceZNoi10Amp[k][i-1]=znsd[Fshake*10*i-Noff]
        DataSpaceZNoi10Pha[k][i-1]=np.angle(zFFT[Fshake*10*i-Noff]) 
  
    if (k%100)==0:
        print(k)
        
##write the harmonics data
for i in range(1,(HarmN+1)):
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise-5%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi1Amp[k][i-1], DataSpaceYNoi1Amp[k][i-1], DataSpaceZNoi1Amp[k][i-1], 
                                            DataSpaceXNoi1Pha[k][i-1], DataSpaceYNoi1Pha[k][i-1], DataSpaceZNoi1Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise-4%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi2Amp[k][i-1], DataSpaceYNoi2Amp[k][i-1], DataSpaceZNoi2Amp[k][i-1], 
                                            DataSpaceXNoi2Pha[k][i-1], DataSpaceYNoi2Pha[k][i-1], DataSpaceZNoi2Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise-3%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi3Amp[k][i-1], DataSpaceYNoi3Amp[k][i-1], DataSpaceZNoi3Amp[k][i-1], 
                                            DataSpaceXNoi3Pha[k][i-1], DataSpaceYNoi3Pha[k][i-1], DataSpaceZNoi3Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise-2%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi4Amp[k][i-1], DataSpaceYNoi4Amp[k][i-1], DataSpaceZNoi4Amp[k][i-1], 
                                            DataSpaceXNoi4Pha[k][i-1], DataSpaceYNoi4Pha[k][i-1], DataSpaceZNoi4Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise-1%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi5Amp[k][i-1], DataSpaceYNoi5Amp[k][i-1], DataSpaceZNoi5Amp[k][i-1], 
                                            DataSpaceXNoi5Pha[k][i-1], DataSpaceYNoi5Pha[k][i-1], DataSpaceZNoi5Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise+1%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi6Amp[k][i-1], DataSpaceYNoi6Amp[k][i-1], DataSpaceZNoi6Amp[k][i-1], 
                                            DataSpaceXNoi6Pha[k][i-1], DataSpaceYNoi6Pha[k][i-1], DataSpaceZNoi6Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise+2%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi7Amp[k][i-1], DataSpaceYNoi7Amp[k][i-1], DataSpaceZNoi7Amp[k][i-1], 
                                            DataSpaceXNoi7Pha[k][i-1], DataSpaceYNoi7Pha[k][i-1], DataSpaceZNoi7Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise+3%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi8Amp[k][i-1], DataSpaceYNoi8Amp[k][i-1], DataSpaceZNoi8Amp[k][i-1], 
                                            DataSpaceXNoi8Pha[k][i-1], DataSpaceYNoi8Pha[k][i-1], DataSpaceZNoi8Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise+4%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi9Amp[k][i-1], DataSpaceYNoi9Amp[k][i-1], DataSpaceZNoi9Amp[k][i-1], 
                                            DataSpaceXNoi9Pha[k][i-1], DataSpaceYNoi9Pha[k][i-1], DataSpaceZNoi9Pha[k][i-1]))
    f1.close()
    
    ofname = folder+"/Bead"+str(BeadNumber)+"/Shaking"+"/Shaking%d/XNoise+5%d_%d_%dthHarm.txt" % (Dx,Dx,Ndata,i)
    f1 = open(ofname,"a")
    for k in range(0,DataN):
        f1.write('%d %e %e %e %f %f %f\n' % (k, DataSpaceXNoi10Amp[k][i-1], DataSpaceYNoi10Amp[k][i-1], DataSpaceZNoi10Amp[k][i-1], 
                                            DataSpaceXNoi10Pha[k][i-1], DataSpaceYNoi10Pha[k][i-1], DataSpaceZNoi10Pha[k][i-1]))
    f1.close()
    
print ("Total run time is ", time.time() - start_time, " s")
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# Total run time is  582.5065748691559  s

# %%
Z
